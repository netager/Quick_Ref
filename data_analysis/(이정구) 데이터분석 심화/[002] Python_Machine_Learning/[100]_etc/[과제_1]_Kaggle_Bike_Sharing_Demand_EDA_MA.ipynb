# %% [markdown]
# # Kaggle Bike Sharing Demand
# [http://www.kaggle.com/c/bike-sharing-demand](http://www.kaggle.com/c/bike-sharing-demand)
#
# - Bike_Sharing_Demand.csv (10,886 * 12)
#    - datetime : Date + Timestamp
#    - season : 1(봄), 2(여름), 3(가을), 4(겨울)
#    - holiday : 1(토요일, 일요일을 제외한 공휴일), 0(휴일이 아닌 날)
#    - workingday : 1(토요일, 일요일 및 휴일이 아닌 주중), 0(주말 및 휴일)
#    - weather : 1(맑음, 약간흐림), 2(안개, 흐림), 3(가벼운 눈/비 + 천둥), 4(심한 눈/비, 천둥/ 번개)
#    - temp : 온도(섭씨)
#    - atemp : 체감온도(섭씨)
#    - humidity : 습도
#    - windspeed : 풍속
#    - casual : 사전 등록되지 않은 사용자 대여 횟수
#    - registered : 사전 등록된 사용자 대여 횟수
#    - count : 총 대여 횟수 -> y

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Load
# * 'Bike_Sharing_Demand.csv' Github에서 읽어오기

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/rusita-ai/pyData/master/Bike_Sharing_Demand.csv'

df = pd.read_csv(url)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# # I. Data Preprocessing

# %% [markdown]
# > ## 1) 'String' -> 'Date'
#
# * 'year', 'month', 'day', 'hour' 추출

# %%
df['datetime'] = df.datetime.apply(pd.to_datetime)
df['year'] = df.datetime.apply(lambda x : x.year)
df['month'] = df.datetime.apply(lambda x : x.month)
df['day'] = df.datetime.apply(lambda x : x.day)
df['hour'] = df.datetime.apply(lambda x : x.hour)

# %%
df
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  year  month  \
# 0      14.395        81     0.0000       3          13     16  2011      1
# 1      13.635        80     0.0000       8          32     40  2011      1
# 2      13.635        80     0.0000       5          27     32  2011      1
# 3      14.395        75     0.0000       3          10     13  2011      1
# 4      14.395        75     0.0000       0           1      1  2011      1
# ...       ...       ...        ...     ...         ...    ...   ...    ...
# 10881  19.695        50    26.0027       7         329    336  2012     12
# 10882  17.425        57    15.0013      10         231    241  2012     12
# 10883  15.910        61    15.0013       4         164    168  2012     12
# 10884  17.425        61     6.0032      12         117    129  2012     12
# 10885  16.665        66     8.9981       4          84     88  2012     12
#
#        day  hour
# 0        1     0
# 1        1     1
# 2        1     2
# 3        1     3
# 4        1     4
# ...    ...   ...
# 10881   19    19
# 10882   19    20
# 10883   19    21
# 10884   19    22
# 10885   19    23
#
# [10886 rows x 16 columns]

# %% [markdown]
# > ## 2) Drop Columns
#
# - 'datetime'

# %%
drop_columns = ['datetime']

df.drop(drop_columns, axis = 1, inplace = True)

# %%
df.head(5)
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    casual  registered  count  year  month  day  hour
# 0       3          13     16  2011      1    1     0
# 1       8          32     40  2011      1    1     1
# 2       5          27     32  2011      1    1     2
# 3       3          10     13  2011      1    1     3
# 4       0           1      1  2011      1    1     4

# %% [markdown]
# # II. 탐색적데이터분석(EDA)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.barplot(x = 'year', 
            y = 'count', 
            data = df)
plt.show()
print('2011년에 비해 2012년의 대여 수 증가.')
# Out:
# 2011년에 비해 2012년의 대여 수 증가.

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# > ## 1) 'month'

# %%
df.groupby(['month']).count()
# Out:
#        season  holiday  workingday  weather  temp  atemp  humidity  windspeed  \
# month
# 1         884      884         884      884   884    884       884        884
# 2         901      901         901      901   901    901       901        901
# 3         901      901         901      901   901    901       901        901
# 4         909      909         909      909   909    909       909        909
# 5         912      912         912      912   912    912       912        912
# 6         912      912         912      912   912    912       912        912
# 7         912      912         912      912   912    912       912        912
# 8         912      912         912      912   912    912       912        912
# 9         909      909         909      909   909    909       909        909
# 10        911      911         911      911   911    911       911        911
# 11        911      911         911      911   911    911       911        911
# 12        912      912         912      912   912    912       912        912
#
#        casual  registered  count  year  day  hour
# month
# 1         884         884    884   884  884   884
# 2         901         901    901   901  901   901
# 3         901         901    901   901  901   901
# 4         909         909    909   909  909   909
# 5         912         912    912   912  912   912
# 6         912         912    912   912  912   912
# 7         912         912    912   912  912   912
# 8         912         912    912   912  912   912
# 9         909         909    909   909  909   909
# 10        911         911    911   911  911   911
# 11        911         911    911   911  911   911
# 12        912         912    912   912  912   912

# %%
sns.boxplot(x = 'month', 
            y = 'count', 
            data = df)
plt.show()

# %%
sns.pointplot(x = 'month', 
              y = 'atemp', 
              data = df)
plt.show()

# %%
sns.pointplot(x = 'month', 
              y = 'count', 
              data = df)
plt.show()

# 6월의 수요가 가장 많고, 1월이 가장 적다.

# %% [markdown]
# > ## 2) 'atemp'

# %%
sns.scatterplot(x = 'atemp', 
                y = 'count', 
                data = df)
plt.show()

# 우상향 경향

# %% [markdown]
# > ## 3) 'season'

# %%
sns.boxplot(x = 'season', 
            y = 'count', 
            data = df)
plt.show()

# %%
sns.pointplot(x = 'season', 
              y = 'count', 
              data = df)
plt.show()

# 여름, 가을 수요 높고, 봄은 낮다.

# %% [markdown]
# > ## 4) 'weather'

# %% [markdown]
# - weather

# %%
sns.countplot(x = 'weather', 
              data = df)
plt.show()

# 날씨별 도수
# 1(맑음, 약간흐림), 2(안개, 흐림), 3(가벼운 눈/비 + 천둥), 4(심한 눈/비, 천둥/ 번개)

# %%
df.weather.value_counts()
# Out:
# 1    7192
# 2    2834
# 3     859
# 4       1
# Name: weather, dtype: int64

# %%
df.loc[(df['weather'] == 4)]

# 심한 눈, 비, 천둥, 번개 날씨는 2년 동|안 한 번
# Out:
#       season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 5631       1        0           1        4   8.2  11.365        86     6.0032
#
#       casual  registered  count  year  month  day  hour
# 5631       6         158    164  2012      1    9    18

# %%
sns.stripplot(x = 'weather', 
              y = 'count', 
              data = df)
plt.show()

# %%
a = df.groupby(by = 'weather').sum()
a['count']

# 날씨가 좋을 수록 총 대여 수가 많다.
# Out:
# weather
# 1    1476063
# 2     507160
# 3     102089
# 4        164
# Name: count, dtype: int64

# %% [markdown]
# > ## 5) 'hour'

# %%
sns.boxplot(x = 'hour', 
            y = 'count', 
            data = df)
plt.show()

# %%
sns.pointplot(x = 'hour', 
              y = 'count', 
              data = df)
plt.show()

# 출근시간대와 퇴근시간대에 수요가 높다.

# %%
sns.pointplot(x = 'hour', 
              y = 'registered', 
              data = df)
plt.show()

# 예약을 하고 대여하는 횟수가 시간대별 빈도 그래프와 거의 일치
# 출근, 퇴근 시간대의 이용자들은 정기적으로 대여하는 고객인 것 같음

# %%
sns.pointplot(x = 'hour', 
              y = 'casual', 
              data = df)
plt.show()

# 반면, 예약을 하지 않고 대여할 땐 출근, 퇴근 시간대보다는 낮시간 전반적으로 많이 이용

# %% [markdown]
# > ## 6) 'workingday' -> 'registered'

# %%
plt.figure(figsize = (18, 4))
sns.pointplot(x = 'count', 
              y = 'registered', 
              hue = 'workingday', 
              data = df)
plt.show()

# 주중에 예약한 대여 수가 많고, 주말은 그에 비해 적음
# hour의 결과에 더해서 예약 대여한 자전거는 출퇴근 목적임을 예상
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-1ae1675235ac> in <module>
#       4               hue = 'workingday',
#       5               data = df)
# ----> 6 plt.show()
#       7
#       8 # 주중에 예약한 대여 수가 많고, 주말은 그에 비해 적음
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# c:\Users\User\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# c:\Users\User\anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# c:\Users\User\anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# c:\Users\User\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# c:\Users\User\anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# c:\Users\User\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\Users\User\anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\Users\User\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         FigureCanvasAgg.draw(self)
#     510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2705                 artists.remove(spine)
#    2706
# -> 2707         self._update_title_position(renderer)
#    2708
#    2709         if not self.axison or inframe:
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2636                 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2637                         or ax.xaxis.get_label_position() == 'top'):
# -> 2638                     bb = ax.xaxis.get_tightbbox(renderer)
#    2639                 else:
#    2640                     bb = ax.get_window_extent(renderer)
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1109         ticks_to_draw = self._update_ticks()
#    1110
# -> 1111         self._update_label_position(renderer)
#    1112
#    1113         # go back to just this axis's tick labels
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\axis.py in _update_label_position(self, renderer)
#    2059         # get bounding boxes for this axis and any siblings
#    2060         # that have been set by `fig.align_xlabels()`
# -> 2061         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2062
#    2063         x, y = self.label.get_position()
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick_boxes_siblings(self, renderer)
#    2044         for nn, axx in enumerate(grp.get_siblings(self.axes)):
#    2045             ticks_to_draw = axx.xaxis._update_ticks()
# -> 2046             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2047             bboxes.extend(tlb)
#    2048             bboxes2.extend(tlb2)
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     900
#     901         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 902             bbox, info, descent = self._get_layout(self._renderer)
#     903             x, y = self.get_unitless_position()
#     904             x, y = self.get_transform().transform((x, y))
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     293             clean_line, ismath = self._preprocess_math(line)
#     294             if clean_line:
# --> 295                 w, h, d = renderer.get_text_width_height_descent(
#     296                     clean_line, self._fontproperties, ismath=ismath)
#     297             else:
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     235
#     236         flags = get_hinting_flag()
# --> 237         font = self._get_agg_font(prop)
#     238         font.set_text(s, 0.0, flags=flags)
#     239         w, h = font.get_width_height()  # width and height of unrotated string
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in _get_agg_font(self, prop)
#     270         Get the font for text instance t, caching for efficiency
#     271         """
# --> 272         fname = findfont(prop)
#     273         font = get_font(fname)
#     274
#
# c:\Users\User\anaconda3\lib\site-packages\matplotlib\font_manager.py in findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1312             prop, fontext, directory, fallback_to_default, rebuild_if_missing,
#    1313             rc_params)
# -> 1314         return os.path.realpath(filename)
#    1315
#    1316     @lru_cache()
#
# c:\Users\User\anaconda3\lib\ntpath.py in realpath(path)
#     645             path = join(cwd, path)
#     646         try:
# --> 647             path = _getfinalpathname(path)
#     648             initial_winerror = 0
#     649         except OSError as ex:
#
# KeyboardInterrupt:

# %% [markdown]
# > ## 7) 'workingday' -> 'casual'

# %%
plt.figure(figsize = (18, 4))
sns.pointplot(x = 'count', 
              y = 'casual', 
              hue = 'workingday', 
              data = df)
plt.show()

# 반대로, 주말엔 예약하지 않은 자전거 대여 수가 많고, 주중은 적다.

# %% [markdown]
# # III. 변수 선택
#
# - X : 'month', 'day', 'hour', 'season', 'holiday', 'workingday', 'weather', 'atemp', 'casual', 'registered'
# - y : 'count'

# %%
df1 = df[[ 'month', 'day', 'hour', 'season', 'holiday', 'workingday', 'weather', 'atemp', 'casual', 'registered', 'count']]
df1.head()
# Out:
#    month  day  hour  season  holiday  workingday  weather   atemp  casual  \
# 0      1    1     0       1        0           0        1  14.395       3
# 1      1    1     1       1        0           0        1  13.635       8
# 2      1    1     2       1        0           0        1  13.635       5
# 3      1    1     3       1        0           0        1  14.395       3
# 4      1    1     4       1        0           0        1  14.395       0
#
#    registered  count
# 0          13     16
# 1          32     40
# 2          27     32
# 3          10     13
# 4           1      1

# %%
df['count'].plot(kind = 'hist')
plt.show()

# %%
df['count'].mean()
# Out:
# 191.57413191254824

# %% [markdown]
# > ## 1) Train & Test Split
#
# - 7 : 3

# %%
from sklearn.model_selection import train_test_split

X = df1[['month', 'day', 'hour', 'season', 'holiday', 'workingday', 'weather', 'atemp']]
y = df1['count']

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.3,
                                                    random_state = 2045)
print('Train Data : ', X_train.shape, y_train.shape)
print('Test Data : ', X_test.shape, y_test.shape)
# Out:
# Train Data :  (7620, 8) (7620,)
# Test Data :  (3266, 8) (3266,)

# %% [markdown]
# # IV. Multivariate Regression Modeling

# %% [markdown]
# > ## 1) 모델 생성

# %%
# %%time

from sklearn.linear_model import LinearRegression

MR = LinearRegression(normalize = True, n_jobs = -1)

MR.fit(X_train, y_train)
# Out:
# Wall time: 256 ms
# LinearRegression(n_jobs=-1, normalize=True)

# %% [markdown]
# > ## 2) 모델 평가

# %%
from sklearn.metrics import mean_squared_error

MR_mse = np.sqrt(mean_squared_error(y_test, MR.predict(X_test)))
MR_mse
# Out:
# 152.9117201870579

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
