# %% [markdown]
# # Python Data Structure

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. String

# %% [markdown]
# * 문자열(String) 생성

# %%
S1 = 'The truth is out there.'
print(S1)
# Out:
# The truth is out there.

# %% [markdown]
# > ## 1) Concatenation

# %% [markdown]
# * <font color = 'blue'>'*': 문자열 반복</font>
# * <font color = 'blue'>'+': 문자열 연결</font>

# %%
print('=' * 40)
print('\t', S1)
print('=' * 40)
# Out:
# ...
# 	 The truth is out there.
# ...

# %%
S2 = 'The truth is'
S3 = ' out there.'

# %%
S2 + S3
# Out:
# 'The truth is out there.'

# %%
S2 * 3
# Out:
# 'The truth isThe truth isThe truth is'

# %%
S3 * 3
# Out:
# ' out there. out there. out there.'

# %% [markdown]
# > ## 2) Length

# %%
len(S1)
# Out:
# 23

# %% [markdown]
# > ## 3) Indexing

# %% [markdown]
# ![제목 없음.png](data:image/png;base64,...)

# %%
print(S1)
# Out:
# The truth is out there.

# %%
S1[1]
# Out:
# 'h'

# %%
S1[5]
# Out:
# 'r'

# %%
S1[0]
# Out:
# 'T'

# %%
S1[-1]
# Out:
# '.'

# %%
S1[-13]
# Out:
# 'i'

# %%
S1[-18]
# Out:
# 'r'

# %% [markdown]
# > ## 4) Slicing

# %% [markdown]
# ![제목 없음2.png](data:image/png;base64,...)

# %%
print(S1)
# Out:
# The truth is out there.

# %% [markdown]
# * with Indexing

# %%
S1[4] + S1[5] + S1[6] + S1[7] + S1[8]
# Out:
# 'truth'

# %% [markdown]
# * with Slicing
#  - <font color = 'red'>S1[이상:미만]

# %%
S1[4:9]
# Out:
# 'truth'

# %%
S1[-19:-14]
# Out:
# 'truth'

# %%
S1[-6:-1]
# Out:
# 'there'

# %%
S1[17:22]
# Out:
# 'there'

# %%
S1[10:12]
# Out:
# 'is'

# %%
S1[:12]
# Out:
# 'The truth is'

# %%
S1[13:]
# Out:
# 'out there.'

# %%
S1[13:-7]
# Out:
# 'out'

# %% [markdown]
# > ## 5) Formatting

# %% [markdown]
# * '%s': String

# %%
'The X-Files is an American science fiction %s.' % 'Drama'
# Out:
# 'The X-Files is an American science fiction Drama.'

# %% [markdown]
# * 우측정렬

# %%
'%7s' % 'Drama'
# Out:
# '  Drama'

# %% [markdown]
# * 좌측정렬

# %%
'%-7s' % 'Drama'
# Out:
# 'Drama  '

# %% [markdown]
# * '%d': Integer

# %%
'The program spanned nine seasons, with %d episodes.' % 202
# Out:
# 'The program spanned nine seasons, with 202 episodes.'

# %% [markdown]
# * '%f': Floating Point

# %%
'%f' % 3.141593
# Out:
# '3.141593'

# %%
'%.2f' % 3.141593
# Out:
# '3.14'

# %%
'%5.2f' % 3.141593
# Out:
# ' 3.14'

# %% [markdown]
# * 2개 값 대입

# %%
String = 'Drama'
Integer = 202

'The X-Files is an American science fiction %s, with %d episodes.' % (String, Integer)
# Out:
# 'The X-Files is an American science fiction Drama, with 202 episodes.'

# %% [markdown]
# > ## 6) Function( )

# %% [markdown]
# * 문자 개수 세기

# %%
'happy'.count('p')
# Out:
# 2

# %% [markdown]
# * 문자 위치 확인

# %%
'happy'.find('a')
# Out:
# 1

# %% [markdown]
# * <font color = 'red'>Error 발생 시 '-1' 리턴

# %%
'happy'.find('b')
# Out:
# -1

# %%
'happy'.index('a')
# Out:
# 1

# %% [markdown]
# * <font color = 'red'>Error

# %%
'happy'.index('b')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-83acd20677e6> in <module>
# ----> 1 'happy'.index('b')
#
# ValueError: substring not found

# %% [markdown]
# * 대문자 변환

# %%
'happy'.upper()
# Out:
# 'HAPPY'

# %% [markdown]
# * 소문자 변환

# %%
'HAPPY'.lower()
# Out:
# 'happy'

# %% [markdown]
# * 공백 지우기

# %%
'   happy   '.lstrip()
# Out:
# 'happy   '

# %%
'   happy   '.rstrip()
# Out:
# '   happy'

# %%
'   happy   '.strip()
# Out:
# 'happy'

# %% [markdown]
# * 문자열 변경

# %%
'happy day'.replace('day', 'birthday')
# Out:
# 'happy birthday'

# %% [markdown]
# * 문자열 나누기

# %%
'happy day my day'.split()
# Out:
# ['happy', 'day', 'my', 'day']

# %%
'happy:day:my:day'.split(':')
# Out:
# ['happy', 'day', 'my', 'day']

# %% [markdown]
# # II.  List

# %% [markdown]
# > ## 1) [ ] 기호로 생성 - 값 변경 가능

# %%
L1 = [1, 3, 5, 7, 9]
print(L1)
# Out:
# [1, 3, 5, 7, 9]

# %%
print(type(L1))
print(type(L1[0]))
# Out:
# <class 'list'>
# <class 'int'>

# %%
L2 = ['HP', 'IBM', 'DELL', 'EMC', 'MS']
print(L2)
# Out:
# ['HP', 'IBM', 'DELL', 'EMC', 'MS']

# %%
print(type(L2))
print(type(L2[0]))
# Out:
# <class 'list'>
# <class 'str'>

# %%
L3 = [1, '삼', 5, '칠', 9]
print(L3)
# Out:
# [1, '삼', 5, '칠', 9]

# %%
print(type(L3))
print(type(L3[0]))
print(type(L3[1]))
# Out:
# <class 'list'>
# <class 'int'>
# <class 'str'>

# %%
L4 = [1, 3, ['HP', 'MS']]
print(L4)
# Out:
# [1, 3, ['HP', 'MS']]

# %%
print(type(L4))
print(type(L4[1]))
print(type(L4[2]))
print(type(L4[2][0]))
# Out:
# <class 'list'>
# <class 'int'>
# <class 'list'>
# <class 'str'>

# %%
L5 = [5, 7, ('IBM', 'EMC')]
print(L5)
# Out:
# [5, 7, ('IBM', 'EMC')]

# %%
print(type(L5))
print(type(L5[1]))
print(type(L5[2]))
print(type(L5[2][0]))
# Out:
# <class 'list'>
# <class 'int'>
# <class 'tuple'>
# <class 'str'>

# %% [markdown]
# > ## 2) Indexing

# %% [markdown]
# * with L1

# %%
print(L1)
# Out:
# [1, 3, 5, 7, 9]

# %%
L1[2]
# Out:
# 5

# %%
L1[2] + L1[4]
# Out:
# 14

# %%
L1[-2]
# Out:
# 7

# %% [markdown]
# * with L4

# %%
print(L4)
# Out:
# [1, 3, ['HP', 'MS']]

# %%
L4[1]
# Out:
# 3

# %%
L4[2]
# Out:
# ['HP', 'MS']

# %%
L4[2][1]
# Out:
# 'MS'

# %%
L4[2][0] + L4[2][1]
# Out:
# 'HPMS'

# %% [markdown]
# > ## 3) Slicing

# %% [markdown]
# * with L1

# %%
print(L1)
# Out:
# [1, 3, 5, 7, 9]

# %%
L1[1:4]
# Out:
# [3, 5, 7]

# %%
L1[:3]
# Out:
# [1, 3, 5]

# %%
L1[2:]
# Out:
# [5, 7, 9]

# %% [markdown]
# * with L6

# %%
L6 = [1, 3, 5, [2, 4, 6]]
print(L6)
# Out:
# [1, 3, 5, [2, 4, 6]]

# %%
L6[2:]
# Out:
# [5, [2, 4, 6]]

# %%
L6[3]
# Out:
# [2, 4, 6]

# %%
L6[3][0:2]
# Out:
# [2, 4]

# %% [markdown]
# > ## 4) Change Values

# %% [markdown]
# * 5 to 6

# %%
print(L1)
# Out:
# [1, 3, 5, 7, 9]

# %%
L1[2] = 6
print(L1)
# Out:
# [1, 3, 6, 7, 9]

# %% [markdown]
# > ## 5) Delete Values

# %%
print(L1)
# Out:
# [1, 3, 6, 7, 9]

# %%
L1[2:4] = []
print(L1)
# Out:
# [1, 3, 9]

# %%
del L1[2]
print(L1)
# Out:
# [1, 3]

# %%
del L1
print(L1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-6e970b11d734> in <module>
# ----> 1 del L1
#       2 print(L1)
#
# NameError: name 'L1' is not defined

# %% [markdown]
# > ## 6) Function( )

# %%
L7 = [8, 3, 9, 2, 1]
print(L7)
# Out:
# [8, 3, 9, 2, 1]

# %% [markdown]
# * 오름차순 정렬

# %%
L7.sort()
print(L7)
# Out:
# [1, 2, 3, 8, 9]

# %% [markdown]
# * 역순 정렬

# %%
L7.reverse()
print(L7)
# Out:
# [9, 8, 3, 2, 1]

# %% [markdown]
# * 마지막에 값('0') 추가

# %%
L7.append(0)
print(L7)
# Out:
# [9, 8, 3, 2, 1, 0]

# %% [markdown]
# * 2번 인덱스에 값('5') 추가

# %%
L7.insert(2, 5)
print(L7)
# Out:
# [9, 8, 5, 3, 2, 1, 0]

# %% [markdown]
# > ## 7) Operators

# %%
L8 = [1, 3, 5, 7, 9]
L9 = [2, 4, 6, 8, 10]

# %% [markdown]
# * Concatenation
#  - '+': 리스트 연결

# %%
L8 + L9
# Out:
# [1, 3, 5, 7, 9, 2, 4, 6, 8, 10]

# %% [markdown]
# * Concatenation
#  - '*': 리스트 반복

# %%
L8 * 2
# Out:
# [1, 3, 5, 7, 9, 1, 3, 5, 7, 9]

# %%
L9 * 3
# Out:
# [2, 4, 6, 8, 10, 2, 4, 6, 8, 10, 2, 4, 6, 8, 10]

# %% [markdown]
# # III. Tuple

# %% [markdown]
# > ## 1) ( ) 기호로 생성 - 값 변경 불가능

# %%
T1 = (1, 2)
print(T1)
# Out:
# (1, 2)

# %% [markdown]
# * <font color = 'red'>Error-1

# %%
del T1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-5dbf3ae207d5> in <module>
# ----> 1 del T1[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# * <font color = 'red'>Error-2

# %%
T1[0] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-81186ea111e4> in <module>
# ----> 1 T1[0] = 'a'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# > ## 2) Tuple in Tuple

# %%
T3 = (1, 2, (3, 4))
print(T3)
# Out:
# (1, 2, (3, 4))

# %% [markdown]
# * <font color = 'red'>Error-3

# %%
T3[2][0] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-05b84266fba5> in <module>
# ----> 1 T3[2][0] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# > ## 3) List in Tuple

# %%
T4 = (1, 2, [3, 4])
print(T4)
# Out:
# (1, 2, [3, 4])

# %% [markdown]
# * Change Values

# %%
T4[2][1] = 6
print(T4)
# Out:
# (1, 2, [3, 6])

# %% [markdown]
# # IV. Dictionary
#
# * 순서가 없음(Unordered)
# * <font color = 'blue'>Key와 Value 한쌍으로 구성

# %% [markdown]
# > ## 1) {Key:Value} 구조 선언

# %%
D1 = {'Name':'LEE', 'Age':24}
print(D1)
# Out:
# {'Name': 'LEE', 'Age': 24}

# %%
print(type(D1))
print(type(D1['Name']))
print(type(D1['Age']))
# Out:
# <class 'dict'>
# <class 'str'>
# <class 'int'>

# %%
D1['Name']
# Out:
# 'LEE'

# %% [markdown]
# > ## 2) Key:Value 추가

# %%
D1['Height'] = 183

print(D1)
# Out:
# {'Name': 'LEE', 'Age': 24, 'Height': 183}

# %% [markdown]
# > ## 3) Key:Value 삭제

# %%
del D1['Age']
print(D1)
# Out:
# {'Name': 'LEE', 'Height': 183}

# %% [markdown]
# > ## 4) Function( )

# %% [markdown]
# * Key 확인

# %%
D1.keys()
# Out:
# dict_keys(['Name', 'Height'])

# %% [markdown]
# * Value 확인

# %%
D1.values()
# Out:
# dict_values(['LEE', 183])

# %% [markdown]
# * Key:Value 삭제

# %%
print(D1)
D1.clear()
print(D1)
# Out:
# {'Name': 'LEE', 'Height': 183}
# {}

# %% [markdown]
# > ## 5) Dictionary with List

# %%
L1 = ['Red', 'Green', 'Blue']
L2 = [255, 127, 63]

# %%
D2 = {x : y for x, y in zip(L1, L2)}
print(D2)
# Out:
# {'Red': 255, 'Green': 127, 'Blue': 63}

# %% [markdown]
# # V. Casting

# %% [markdown]
# > ## 1) Data Type

# %% [markdown]
# * int to float

# %%
print(type(9))
print(float(9))
# Out:
# <class 'int'>
# 9.0

# %% [markdown]
# * str to float

# %%
print(type('9.4'))
print(float('9.4'))
# Out:
# <class 'str'>
# 9.4

# %% [markdown]
# * float to int

# %%
print(type(9.0))
print(9.0)
print(type(int(9.0)))
print(int(9.0))
# Out:
# <class 'float'>
# 9.0
# <class 'int'>
# 9

# %% [markdown]
# * str to int

# %%
print(type('9'))
print(9)
print(type(int('9')))
print(int(9))
# Out:
# <class 'str'>
# 9
# <class 'int'>
# 9

# %% [markdown]
# * float to int
# * <font color = 'red'>Warning!!!

# %%
print(type(3.14))
print(3.14)
print(type(int(3.14)))
print(int(3.14))
# Out:
# <class 'float'>
# 3.14
# <class 'int'>
# 3

# %% [markdown]
# * int to str

# %%
print(type(9))
print(type(str(9)))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# * float to str

# %%
print(type(3.14))
print(type(str(3.14)))
# Out:
# <class 'float'>
# <class 'str'>

# %% [markdown]
# > ## 2) Data Structure

# %% [markdown]
# * List to Tuple

# %%
tuple([1, 3, 5, 7, 9])
# Out:
# (1, 3, 5, 7, 9)

# %% [markdown]
# * Tuple to List

# %%
list((1, 3, 5, 7, 9))
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# * List to Dictionary

# %%
dict([['A', 123], ['B', 234], ['C', 567]])
# Out:
# {'A': 123, 'B': 234, 'C': 567}

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
