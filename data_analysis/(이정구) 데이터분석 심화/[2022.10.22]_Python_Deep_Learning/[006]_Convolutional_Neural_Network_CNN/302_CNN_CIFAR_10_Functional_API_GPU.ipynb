# %% [markdown]
# # CIFAR 10 - Functional API Modeling
#
# * Categorical Classification

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * import Tensorflow

# %%
import tensorflow

tensorflow.__version__
# Out:
# '2.9.2'

# %% [markdown]
# # I. CIFAR 10 Data_Set Load & Review

# %% [markdown]
# > ## 1) Load CIFAR 10 Data_Set

# %%
from tensorflow.keras.datasets import cifar10

(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 14s 0us/step

# %% [markdown]
# * Train_Data Information

# %%
print(len(X_train))
print(X_train.shape)

print(len(y_train))
print(y_train[0:5])
# Out:
# 50000
# (50000, 32, 32, 3)
# 50000
# [[6]
#  [9]
#  [9]
#  [4]
#  [1]]

# %% [markdown]
# * Test_Data Information

# %%
print(len(X_test))
print(X_test.shape)

print(len(y_test))
print(y_test[0:5])
# Out:
# 10000
# (10000, 32, 32, 3)
# 10000
# [[3]
#  [8]
#  [8]
#  [0]
#  [6]]

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. Keras Functional API Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의

# %%
# %%time

from tensorflow.keras import models
from tensorflow.keras import layers

input_img = layers.Input((32, 32, 3))

x = layers.Conv2D(filters=32, kernel_size=(3,3), strides=(1,1), padding='valid')(input_img)
x = layers.ReLU()(x)

x = layers.MaxPool2D(pool_size=(2,2))(x)

x = layers.Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='valid')(x)
x = layers.ReLU()(x)

x = layers.MaxPool2D(pool_size=(2,2))(x)

x = layers.Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='valid')(x)
x = layers.ReLU()(x)


x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(64)(x)
x = layers.ReLU()(x)

x = layers.Dense(10)(x)
output_y_hat = layers.Activation('softmax')(x)

CIFAR = models.Model(input_img, output_y_hat)
# Out:
# CPU times: user 574 ms, sys: 335 ms, total: 910 ms
# Wall time: 2.13 s

# %% [markdown]
# * 모델 구조 확인

# %%
CIFAR.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  re_lu (ReLU)                (None, 30, 30, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  re_lu_1 (ReLU)              (None, 13, 13, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  re_lu_2 (ReLU)              (None, 4, 4, 64)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  re_lu_3 (ReLU)              (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
#  activation (Activation)     (None, 10)                0
#
# =================================================================
# Total params: 122,570
# Trainable params: 122,570
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
CIFAR.compile(loss = 'categorical_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 5분

# %%
# %%time

Hist_CIFAR = CIFAR.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 313/313 [==============================] - 10s 9ms/step - loss: 1.7757 - accuracy: 0.3420 - val_loss: 1.5189 - val_accuracy: 0.4508
# Epoch 2/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4332 - accuracy: 0.4808 - val_loss: 1.3690 - val_accuracy: 0.5151
# Epoch 3/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.2899 - accuracy: 0.5365 - val_loss: 1.1972 - val_accuracy: 0.5766
# Epoch 4/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.1926 - accuracy: 0.5777 - val_loss: 1.1312 - val_accuracy: 0.5969
# Epoch 5/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.1249 - accuracy: 0.5961 - val_loss: 1.0666 - val_accuracy: 0.6265
# Epoch 6/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.0662 - accuracy: 0.6234 - val_loss: 1.0447 - val_accuracy: 0.6277
# Epoch 7/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.0126 - accuracy: 0.6428 - val_loss: 0.9513 - val_accuracy: 0.6659
# Epoch 8/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.9714 - accuracy: 0.6575 - val_loss: 0.9250 - val_accuracy: 0.6756
# Epoch 9/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.9406 - accuracy: 0.6688 - val_loss: 0.9051 - val_accuracy: 0.6886
# Epoch 10/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.9092 - accuracy: 0.6783 - val_loss: 0.8914 - val_accuracy: 0.6880
# Epoch 11/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.8807 - accuracy: 0.6889 - val_loss: 0.8596 - val_accuracy: 0.7001
# Epoch 12/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.8532 - accuracy: 0.6999 - val_loss: 0.8471 - val_accuracy: 0.7069
# Epoch 13/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.8373 - accuracy: 0.7048 - val_loss: 0.8388 - val_accuracy: 0.7049
# Epoch 14/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.8042 - accuracy: 0.7189 - val_loss: 0.8100 - val_accuracy: 0.7162
# Epoch 15/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.7877 - accuracy: 0.7239 - val_loss: 0.8055 - val_accuracy: 0.7157
# Epoch 16/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.7713 - accuracy: 0.7296 - val_loss: 0.7778 - val_accuracy: 0.7288
# Epoch 17/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.7604 - accuracy: 0.7307 - val_loss: 0.7907 - val_accuracy: 0.7206
# Epoch 18/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.7483 - accuracy: 0.7363 - val_loss: 0.7809 - val_accuracy: 0.7267
# Epoch 19/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.7218 - accuracy: 0.7461 - val_loss: 0.7581 - val_accuracy: 0.7380
# Epoch 20/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.7111 - accuracy: 0.7491 - val_loss: 0.7626 - val_accuracy: 0.7359
# Epoch 21/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6968 - accuracy: 0.7528 - val_loss: 0.7671 - val_accuracy: 0.7356
# Epoch 22/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6863 - accuracy: 0.7560 - val_loss: 0.7593 - val_accuracy: 0.7396
# Epoch 23/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6654 - accuracy: 0.7638 - val_loss: 0.7374 - val_accuracy: 0.7430
# Epoch 24/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6604 - accuracy: 0.7646 - val_loss: 0.7312 - val_accuracy: 0.7469
# Epoch 25/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6473 - accuracy: 0.7705 - val_loss: 0.7528 - val_accuracy: 0.7410
# Epoch 26/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6445 - accuracy: 0.7721 - val_loss: 0.7417 - val_accuracy: 0.7465
# Epoch 27/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6342 - accuracy: 0.7754 - val_loss: 0.7204 - val_accuracy: 0.7522
# Epoch 28/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6226 - accuracy: 0.7783 - val_loss: 0.7589 - val_accuracy: 0.7380
# Epoch 29/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6116 - accuracy: 0.7828 - val_loss: 0.7189 - val_accuracy: 0.7514
# Epoch 30/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6032 - accuracy: 0.7873 - val_loss: 0.7037 - val_accuracy: 0.7617
# Epoch 31/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5936 - accuracy: 0.7905 - val_loss: 0.7020 - val_accuracy: 0.7611
# Epoch 32/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5895 - accuracy: 0.7886 - val_loss: 0.7292 - val_accuracy: 0.7548
# Epoch 33/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5783 - accuracy: 0.7950 - val_loss: 0.7220 - val_accuracy: 0.7534
# Epoch 34/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5769 - accuracy: 0.7966 - val_loss: 0.7093 - val_accuracy: 0.7634
# Epoch 35/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5636 - accuracy: 0.8008 - val_loss: 0.7120 - val_accuracy: 0.7553
# Epoch 36/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5623 - accuracy: 0.8006 - val_loss: 0.7336 - val_accuracy: 0.7558
# Epoch 37/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5543 - accuracy: 0.8005 - val_loss: 0.7183 - val_accuracy: 0.7558
# Epoch 38/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5382 - accuracy: 0.8083 - val_loss: 0.7074 - val_accuracy: 0.7601
# Epoch 39/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5416 - accuracy: 0.8049 - val_loss: 0.7059 - val_accuracy: 0.7635
# Epoch 40/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5306 - accuracy: 0.8134 - val_loss: 0.7134 - val_accuracy: 0.7607
# Epoch 41/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5362 - accuracy: 0.8070 - val_loss: 0.7538 - val_accuracy: 0.7472
# Epoch 42/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5235 - accuracy: 0.8135 - val_loss: 0.7164 - val_accuracy: 0.7573
# Epoch 43/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5225 - accuracy: 0.8132 - val_loss: 0.7136 - val_accuracy: 0.7620
# Epoch 44/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5192 - accuracy: 0.8145 - val_loss: 0.7189 - val_accuracy: 0.7611
# Epoch 45/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5049 - accuracy: 0.8193 - val_loss: 0.7222 - val_accuracy: 0.7599
# Epoch 46/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5073 - accuracy: 0.8171 - val_loss: 0.7092 - val_accuracy: 0.7636
# Epoch 47/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5000 - accuracy: 0.8202 - val_loss: 0.7209 - val_accuracy: 0.7622
# Epoch 48/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5024 - accuracy: 0.8187 - val_loss: 0.7280 - val_accuracy: 0.7599
# Epoch 49/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4898 - accuracy: 0.8244 - val_loss: 0.7167 - val_accuracy: 0.7632
# Epoch 50/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4828 - accuracy: 0.8267 - val_loss: 0.7258 - val_accuracy: 0.7651
# Epoch 51/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4762 - accuracy: 0.8290 - val_loss: 0.7224 - val_accuracy: 0.7639
# Epoch 52/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4825 - accuracy: 0.8253 - val_loss: 0.7176 - val_accuracy: 0.7647
# Epoch 53/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4744 - accuracy: 0.8299 - val_loss: 0.7542 - val_accuracy: 0.7558
# Epoch 54/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4692 - accuracy: 0.8312 - val_loss: 0.7246 - val_accuracy: 0.7651
# Epoch 55/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4704 - accuracy: 0.8298 - val_loss: 0.7334 - val_accuracy: 0.7628
# Epoch 56/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4626 - accuracy: 0.8343 - val_loss: 0.7231 - val_accuracy: 0.7687
# Epoch 57/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4618 - accuracy: 0.8337 - val_loss: 0.7163 - val_accuracy: 0.7696
# Epoch 58/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4587 - accuracy: 0.8345 - val_loss: 0.7176 - val_accuracy: 0.7663
# Epoch 59/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4510 - accuracy: 0.8393 - val_loss: 0.7323 - val_accuracy: 0.7590
# Epoch 60/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4516 - accuracy: 0.8374 - val_loss: 0.7101 - val_accuracy: 0.7634
# Epoch 61/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4414 - accuracy: 0.8415 - val_loss: 0.7198 - val_accuracy: 0.7661
# Epoch 62/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4386 - accuracy: 0.8416 - val_loss: 0.7492 - val_accuracy: 0.7645
# Epoch 63/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4402 - accuracy: 0.8424 - val_loss: 0.7269 - val_accuracy: 0.7670
# Epoch 64/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4340 - accuracy: 0.8443 - val_loss: 0.7490 - val_accuracy: 0.7610
# Epoch 65/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4309 - accuracy: 0.8459 - val_loss: 0.7773 - val_accuracy: 0.7614
# Epoch 66/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4320 - accuracy: 0.8435 - val_loss: 0.7415 - val_accuracy: 0.7638
# Epoch 67/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4322 - accuracy: 0.8455 - val_loss: 0.7475 - val_accuracy: 0.7639
# Epoch 68/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4297 - accuracy: 0.8446 - val_loss: 0.7526 - val_accuracy: 0.7665
# Epoch 69/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4173 - accuracy: 0.8480 - val_loss: 0.7519 - val_accuracy: 0.7599
# Epoch 70/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4242 - accuracy: 0.8469 - val_loss: 0.7611 - val_accuracy: 0.7622
# Epoch 71/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4095 - accuracy: 0.8536 - val_loss: 0.7652 - val_accuracy: 0.7675
# Epoch 72/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4138 - accuracy: 0.8516 - val_loss: 0.7548 - val_accuracy: 0.7667
# Epoch 73/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4102 - accuracy: 0.8507 - val_loss: 0.7520 - val_accuracy: 0.7638
# Epoch 74/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4098 - accuracy: 0.8524 - val_loss: 0.7471 - val_accuracy: 0.7644
# Epoch 75/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4046 - accuracy: 0.8533 - val_loss: 0.7700 - val_accuracy: 0.7630
# Epoch 76/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4065 - accuracy: 0.8533 - val_loss: 0.7671 - val_accuracy: 0.7671
# Epoch 77/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3986 - accuracy: 0.8577 - val_loss: 0.7772 - val_accuracy: 0.7662
# Epoch 78/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4029 - accuracy: 0.8558 - val_loss: 0.7685 - val_accuracy: 0.7623
# Epoch 79/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4036 - accuracy: 0.8529 - val_loss: 0.7645 - val_accuracy: 0.7613
# Epoch 80/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3959 - accuracy: 0.8577 - val_loss: 0.7370 - val_accuracy: 0.7708
# Epoch 81/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3914 - accuracy: 0.8576 - val_loss: 0.7500 - val_accuracy: 0.7679
# Epoch 82/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3934 - accuracy: 0.8587 - val_loss: 0.7531 - val_accuracy: 0.7711
# Epoch 83/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3938 - accuracy: 0.8571 - val_loss: 0.7620 - val_accuracy: 0.7663
# Epoch 84/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3843 - accuracy: 0.8619 - val_loss: 0.7566 - val_accuracy: 0.7724
# Epoch 85/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3880 - accuracy: 0.8579 - val_loss: 0.7569 - val_accuracy: 0.7704
# Epoch 86/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3850 - accuracy: 0.8618 - val_loss: 0.7529 - val_accuracy: 0.7684
# Epoch 87/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3794 - accuracy: 0.8635 - val_loss: 0.7701 - val_accuracy: 0.7709
# Epoch 88/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3794 - accuracy: 0.8622 - val_loss: 0.7706 - val_accuracy: 0.7695
# Epoch 89/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3740 - accuracy: 0.8661 - val_loss: 0.7754 - val_accuracy: 0.7642
# Epoch 90/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3693 - accuracy: 0.8664 - val_loss: 0.7782 - val_accuracy: 0.7666
# Epoch 91/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3689 - accuracy: 0.8668 - val_loss: 0.7693 - val_accuracy: 0.7696
# Epoch 92/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3683 - accuracy: 0.8658 - val_loss: 0.7819 - val_accuracy: 0.7640
# Epoch 93/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3657 - accuracy: 0.8680 - val_loss: 0.7855 - val_accuracy: 0.7644
# Epoch 94/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3740 - accuracy: 0.8657 - val_loss: 0.7762 - val_accuracy: 0.7668
# Epoch 95/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3687 - accuracy: 0.8659 - val_loss: 0.8006 - val_accuracy: 0.7577
# Epoch 96/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3658 - accuracy: 0.8653 - val_loss: 0.7685 - val_accuracy: 0.7709
# Epoch 97/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3647 - accuracy: 0.8680 - val_loss: 0.7624 - val_accuracy: 0.7669
# Epoch 98/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3678 - accuracy: 0.8680 - val_loss: 0.7905 - val_accuracy: 0.7700
# Epoch 99/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3599 - accuracy: 0.8701 - val_loss: 0.7874 - val_accuracy: 0.7637
# Epoch 100/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3535 - accuracy: 0.8734 - val_loss: 0.7645 - val_accuracy: 0.7751
# CPU times: user 3min 44s, sys: 21.6 s, total: 4min 6s
# Wall time: 4min 23s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_CIFAR.history['loss']) + 1)

plt.figure(figsize = (15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, Hist_CIFAR.history['loss'], 'b-')
plt.plot(epochs, Hist_CIFAR.history['val_loss'], 'r--')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, Hist_CIFAR.history['accuracy'], 'b-')
plt.plot(epochs, Hist_CIFAR.history['val_accuracy'], 'r--')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = CIFAR.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7790 - accuracy: 0.7664
# Loss = 0.77903
# Accuracy = 0.76640

# %% [markdown]
# # IV. 성능평가

# %% [markdown]
# > ## 1) Label Name 지정

# %%
import numpy as np

CLASSES = np.array(['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 
                    'Dog', 'Frog', 'Horse', 'Ship', 'Truck'])

preds = CIFAR.predict(X_test)
preds_single = CLASSES[np.argmax(preds, axis = -1)]
actual_single = CLASSES[np.argmax(y_test, axis = -1)]
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# > ## 2) 비교 시각화

# %%
import matplotlib.pyplot as plt

n_to_show = 10
indices = np.random.choice(range(len(X_test)), n_to_show)

fig = plt.figure(figsize = (15, 3))
fig.subplots_adjust(hspace = 0.4, wspace = 0.4)

for i, idx in enumerate(indices):
    img = X_test[idx]
    ax = fig.add_subplot(1, n_to_show, i + 1)
    ax.axis('off')
    ax.text(0.5, -0.35, 
            'Pred = ' + str(preds_single[idx]), 
            fontsize = 10, 
            ha = 'center', 
            transform = ax.transAxes) 
    ax.text(0.5, -0.7, 
            'Act = ' + str(actual_single[idx]), 
            fontsize = 10, 
            ha = 'center', 
            transform = ax.transAxes)
    ax.imshow(img)

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
