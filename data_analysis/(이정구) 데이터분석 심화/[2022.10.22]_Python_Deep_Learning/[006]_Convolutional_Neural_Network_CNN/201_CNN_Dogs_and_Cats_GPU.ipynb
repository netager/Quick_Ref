# %% [markdown]
# # 이미지 데이터 셋을 이용한 CNN Modeling
#
# ## Dogs and Cats Image_Data
# * Train_Data : 2000(1000_Dogs, 1000_Cats)
# * Valid_Data : 1000(500_Dogs, 500_Cats)
# * Test_Data : 1000(500_Dogs, 500_Cats)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * Import TensorFlow

# %%
import tensorflow as tf

tf.__version__
# Out:
# '2.9.2'

# %% [markdown]
# # I. wget From Github
# * 'dogs_and_cats_small.zip' 파일 다운로드

# %%
# !wget https://raw.githubusercontent.com/rusita-ai/pyData/master/dogs_and_cats_small.zip
# Out:
# --2022-11-08 01:23:21--  https://raw.githubusercontent.com/rusita-ai/pyData/master/dogs_and_cats_small.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90618980 (86M) [application/zip]
# Saving to: ‘dogs_and_cats_small.zip’
#
# dogs_and_cats_small 100%[===================>]  86.42M   369MB/s    in 0.2s
#
# 2022-11-08 01:23:25 (369 MB/s) - ‘dogs_and_cats_small.zip’ saved [90618980/90618980]

# %% [markdown]
# * 다운로드 결과 확인

# %%
# !ls -l
# Out:
# total 88500
# -rw-r--r-- 1 root root 90618980 Nov  8 01:23 dogs_and_cats_small.zip
# drwxr-xr-x 1 root root     4096 Oct 28 13:37 sample_data

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Unzip 'dogs_and_cats_small.zip'

# %%
# !unzip -q /content/dogs_and_cats_small.zip

# %% [markdown]
# * 학습 데이터 확인

# %%
# !ls -l
# Out:
# total 88512
# -rw-r--r-- 1 root root 90618980 Nov  8 01:23 dogs_and_cats_small.zip
# drwxr-xr-x 1 root root     4096 Oct 28 13:37 sample_data
# drwxr-xr-x 4 root root     4096 Nov  8 01:23 test
# drwxr-xr-x 4 root root     4096 Nov  8 01:23 train
# drwxr-xr-x 4 root root     4096 Nov  8 01:23 validation

# %% [markdown]
# > ## 2) Image_File Directory Setting

# %% [markdown]
# * train_dir
# * valid_dir
# * test_dir

# %%
train_dir = 'train'
valid_dir = 'validation'
test_dir  = 'test'

# %% [markdown]
# > ## 3) ImageDataGenerator( ) & flow_from_directory( )

# %% [markdown]
# * Normalization
#  * ImageDataGenerator( )
# * Resizing & Generator
#  * flow_from_directory( )

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255)
valid_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = train_datagen.flow_from_directory(
                  train_dir,
                  target_size = (150, 150),
                  batch_size = 20,
                  class_mode = 'binary')

valid_generator = valid_datagen.flow_from_directory(
                  valid_dir,
                  target_size = (150, 150),
                  batch_size = 20,
                  class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# > ## 4) Test train_generator

# %%
for data_batch, labels_batch in train_generator:
    print('배치 데이터 크기:', data_batch.shape)
    print('배치 레이블 크기:', labels_batch.shape)
    break
# Out:
# 배치 데이터 크기: (20, 150, 150, 3)
# 배치 레이블 크기: (20,)

# %%
labels_batch
# Out:
# array([0., 0., 1., 1., 0., 1., 1., 1., 0., 0., 0., 1., 0., 0., 0., 1., 0.,
#        0., 0., 0.], dtype=float32)

# %% [markdown]
# # III. CNN Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * Feature Extraction & Classification

# %%
from tensorflow.keras import layers
from tensorflow.keras import models

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation = 'relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation = 'relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation = 'relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation = 'relu'))
model.add(layers.Dense(1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
model.compile(loss = 'binary_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 모델 학습 수행
#  * 약 10분

# %%
# %%time

Hist_dandc = model.fit(train_generator,
                       steps_per_epoch = 100,
                       epochs = 60,
                       validation_data = valid_generator,
                       validation_steps = 50)
# Out:
# Epoch 1/60
# 100/100 [==============================] - 18s 90ms/step - loss: 0.6984 - accuracy: 0.5355 - val_loss: 0.6833 - val_accuracy: 0.4990
# Epoch 2/60
# 100/100 [==============================] - 9s 90ms/step - loss: 0.6890 - accuracy: 0.5215 - val_loss: 0.6894 - val_accuracy: 0.5090
# Epoch 3/60
# 100/100 [==============================] - 9s 90ms/step - loss: 0.6805 - accuracy: 0.5735 - val_loss: 0.6924 - val_accuracy: 0.5660
# Epoch 4/60
# 100/100 [==============================] - 9s 90ms/step - loss: 0.6385 - accuracy: 0.6400 - val_loss: 0.6244 - val_accuracy: 0.6530
# Epoch 5/60
# 100/100 [==============================] - 10s 97ms/step - loss: 0.5895 - accuracy: 0.6910 - val_loss: 0.5737 - val_accuracy: 0.7100
# Epoch 6/60
# 100/100 [==============================] - 9s 89ms/step - loss: 0.5519 - accuracy: 0.7120 - val_loss: 0.5555 - val_accuracy: 0.7200
# Epoch 7/60
# 100/100 [==============================] - 9s 90ms/step - loss: 0.4977 - accuracy: 0.7505 - val_loss: 0.5465 - val_accuracy: 0.7330
# Epoch 8/60
# 100/100 [==============================] - 9s 89ms/step - loss: 0.4433 - accuracy: 0.7955 - val_loss: 0.5305 - val_accuracy: 0.7440
# Epoch 9/60
# 100/100 [==============================] - 9s 90ms/step - loss: 0.3827 - accuracy: 0.8300 - val_loss: 0.5708 - val_accuracy: 0.7320
# Epoch 10/60
# 100/100 [==============================] - 11s 114ms/step - loss: 0.3183 - accuracy: 0.8495 - val_loss: 0.5782 - val_accuracy: 0.7360
# Epoch 11/60
# 100/100 [==============================] - 9s 91ms/step - loss: 0.2419 - accuracy: 0.8990 - val_loss: 0.7539 - val_accuracy: 0.7260
# Epoch 12/60
# 100/100 [==============================] - 9s 90ms/step - loss: 0.1686 - accuracy: 0.9320 - val_loss: 0.7479 - val_accuracy: 0.7260
# Epoch 13/60
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0899 - accuracy: 0.9670 - val_loss: 1.0517 - val_accuracy: 0.7210
# Epoch 14/60
# 100/100 [==============================] - 9s 90ms/step - loss: 0.1098 - accuracy: 0.9580 - val_loss: 0.9357 - val_accuracy: 0.7360
# Epoch 15/60
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0402 - accuracy: 0.9875 - val_loss: 1.2107 - val_accuracy: 0.7500
# Epoch 16/60
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0196 - accuracy: 0.9930 - val_loss: 1.3872 - val_accuracy: 0.7170
# Epoch 17/60
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0660 - accuracy: 0.9755 - val_loss: 1.2579 - val_accuracy: 0.7180
# Epoch 18/60
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0375 - accuracy: 0.9880 - val_loss: 1.5083 - val_accuracy: 0.7280
# Epoch 19/60
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0251 - accuracy: 0.9905 - val_loss: 1.4749 - val_accuracy: 0.7240
# Epoch 20/60
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0132 - accuracy: 0.9970 - val_loss: 1.5799 - val_accuracy: 0.7380
# Epoch 21/60
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0204 - accuracy: 0.9930 - val_loss: 1.5289 - val_accuracy: 0.7010
# Epoch 22/60
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0525 - accuracy: 0.9855 - val_loss: 1.5820 - val_accuracy: 0.7170
# Epoch 23/60
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0347 - accuracy: 0.9880 - val_loss: 1.5328 - val_accuracy: 0.7270
# Epoch 24/60
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0033 - accuracy: 0.9995 - val_loss: 1.6150 - val_accuracy: 0.7320
# Epoch 25/60
# 100/100 [==============================] - 9s 90ms/step - loss: 6.3361e-04 - accuracy: 1.0000 - val_loss: 1.7399 - val_accuracy: 0.7400
# Epoch 26/60
# 100/100 [==============================] - 9s 91ms/step - loss: 2.9343e-04 - accuracy: 1.0000 - val_loss: 1.7993 - val_accuracy: 0.7430
# Epoch 27/60
# 100/100 [==============================] - 9s 90ms/step - loss: 1.5260e-04 - accuracy: 1.0000 - val_loss: 2.0267 - val_accuracy: 0.7360
# Epoch 28/60
# 100/100 [==============================] - 9s 90ms/step - loss: 1.0071e-04 - accuracy: 1.0000 - val_loss: 2.0357 - val_accuracy: 0.7370
# Epoch 29/60
# 100/100 [==============================] - 9s 90ms/step - loss: 7.5796e-05 - accuracy: 1.0000 - val_loss: 2.1463 - val_accuracy: 0.7320
# Epoch 30/60
# 100/100 [==============================] - 9s 91ms/step - loss: 6.0488e-05 - accuracy: 1.0000 - val_loss: 2.1847 - val_accuracy: 0.7390
# Epoch 31/60
# 100/100 [==============================] - 9s 89ms/step - loss: 5.0545e-05 - accuracy: 1.0000 - val_loss: 2.2199 - val_accuracy: 0.7390
# Epoch 32/60
# 100/100 [==============================] - 9s 90ms/step - loss: 4.2011e-05 - accuracy: 1.0000 - val_loss: 2.2549 - val_accuracy: 0.7380
# Epoch 33/60
# 100/100 [==============================] - 9s 90ms/step - loss: 3.6654e-05 - accuracy: 1.0000 - val_loss: 2.2927 - val_accuracy: 0.7380
# Epoch 34/60
# 100/100 [==============================] - 9s 90ms/step - loss: 3.1524e-05 - accuracy: 1.0000 - val_loss: 2.3137 - val_accuracy: 0.7380
# Epoch 35/60
# 100/100 [==============================] - 9s 90ms/step - loss: 2.7526e-05 - accuracy: 1.0000 - val_loss: 2.3469 - val_accuracy: 0.7420
# Epoch 36/60
# 100/100 [==============================] - 9s 90ms/step - loss: 2.4839e-05 - accuracy: 1.0000 - val_loss: 2.3669 - val_accuracy: 0.7360
# Epoch 37/60
# 100/100 [==============================] - 9s 91ms/step - loss: 2.1731e-05 - accuracy: 1.0000 - val_loss: 2.3886 - val_accuracy: 0.7400
# Epoch 38/60
# 100/100 [==============================] - 9s 89ms/step - loss: 1.9664e-05 - accuracy: 1.0000 - val_loss: 2.4000 - val_accuracy: 0.7390
# Epoch 39/60
# 100/100 [==============================] - 9s 89ms/step - loss: 1.7563e-05 - accuracy: 1.0000 - val_loss: 2.4252 - val_accuracy: 0.7390
# Epoch 40/60
# 100/100 [==============================] - 9s 90ms/step - loss: 1.5467e-05 - accuracy: 1.0000 - val_loss: 2.4435 - val_accuracy: 0.7370
# Epoch 41/60
# 100/100 [==============================] - 9s 89ms/step - loss: 1.3622e-05 - accuracy: 1.0000 - val_loss: 2.4613 - val_accuracy: 0.7360
# Epoch 42/60
# 100/100 [==============================] - 9s 91ms/step - loss: 1.2063e-05 - accuracy: 1.0000 - val_loss: 2.4962 - val_accuracy: 0.7370
# Epoch 43/60
# 100/100 [==============================] - 9s 89ms/step - loss: 1.0280e-05 - accuracy: 1.0000 - val_loss: 2.5030 - val_accuracy: 0.7360
# Epoch 44/60
# 100/100 [==============================] - 9s 91ms/step - loss: 8.8616e-06 - accuracy: 1.0000 - val_loss: 2.5344 - val_accuracy: 0.7380
# Epoch 45/60
# 100/100 [==============================] - 9s 90ms/step - loss: 7.5918e-06 - accuracy: 1.0000 - val_loss: 2.5486 - val_accuracy: 0.7350
# Epoch 46/60
# 100/100 [==============================] - 9s 88ms/step - loss: 6.3348e-06 - accuracy: 1.0000 - val_loss: 2.5688 - val_accuracy: 0.7360
# Epoch 47/60
# 100/100 [==============================] - 9s 89ms/step - loss: 5.6770e-06 - accuracy: 1.0000 - val_loss: 2.5976 - val_accuracy: 0.7390
# Epoch 48/60
# 100/100 [==============================] - 9s 92ms/step - loss: 4.7747e-06 - accuracy: 1.0000 - val_loss: 2.6290 - val_accuracy: 0.7410
# Epoch 49/60
# 100/100 [==============================] - 9s 89ms/step - loss: 4.4715e-06 - accuracy: 1.0000 - val_loss: 2.6344 - val_accuracy: 0.7380
# Epoch 50/60
# 100/100 [==============================] - 9s 89ms/step - loss: 3.9382e-06 - accuracy: 1.0000 - val_loss: 2.6353 - val_accuracy: 0.7340
# Epoch 51/60
# 100/100 [==============================] - 9s 90ms/step - loss: 3.3790e-06 - accuracy: 1.0000 - val_loss: 2.6586 - val_accuracy: 0.7350
# Epoch 52/60
# 100/100 [==============================] - 9s 89ms/step - loss: 3.0905e-06 - accuracy: 1.0000 - val_loss: 2.6858 - val_accuracy: 0.7370
# Epoch 53/60
# 100/100 [==============================] - 9s 89ms/step - loss: 2.8361e-06 - accuracy: 1.0000 - val_loss: 2.6890 - val_accuracy: 0.7320
# Epoch 54/60
# 100/100 [==============================] - 9s 90ms/step - loss: 2.5844e-06 - accuracy: 1.0000 - val_loss: 2.7283 - val_accuracy: 0.7360
# Epoch 55/60
# 100/100 [==============================] - 9s 89ms/step - loss: 2.4954e-06 - accuracy: 1.0000 - val_loss: 2.7193 - val_accuracy: 0.7350
# Epoch 56/60
# 100/100 [==============================] - 9s 89ms/step - loss: 2.2569e-06 - accuracy: 1.0000 - val_loss: 2.7248 - val_accuracy: 0.7310
# Epoch 57/60
# 100/100 [==============================] - 9s 90ms/step - loss: 2.0252e-06 - accuracy: 1.0000 - val_loss: 2.7422 - val_accuracy: 0.7310
# Epoch 58/60
# 100/100 [==============================] - 9s 90ms/step - loss: 1.8967e-06 - accuracy: 1.0000 - val_loss: 2.7449 - val_accuracy: 0.7340
# Epoch 59/60
# 100/100 [==============================] - 9s 89ms/step - loss: 1.7820e-06 - accuracy: 1.0000 - val_loss: 2.7523 - val_accuracy: 0.7300
# Epoch 60/60
# 100/100 [==============================] - 9s 88ms/step - loss: 1.6374e-06 - accuracy: 1.0000 - val_loss: 2.7703 - val_accuracy: 0.7280
# CPU times: user 10min 52s, sys: 20 s, total: 11min 12s
# Wall time: 9min 13s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_dandc.history['loss']) + 1)

plt.figure(figsize = (15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, Hist_dandc.history['loss'], 'b-')
plt.plot(epochs, Hist_dandc.history['val_loss'], 'r--')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, Hist_dandc.history['accuracy'], 'b-')
plt.plot(epochs, Hist_dandc.history['val_accuracy'], 'r--')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * test_generator

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_generator = test_datagen.flow_from_directory(
                 test_dir,
                 target_size = (150, 150),
                 batch_size = 20,
                 class_mode = 'binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = model.evaluate(test_generator,
                                steps = 50)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 50/50 [==============================] - 3s 59ms/step - loss: 3.3978 - accuracy: 0.7280
# Loss = 3.39779
# Accuracy = 0.72800

# %% [markdown]
# # IV. Model Save & Load to Google Drive

# %% [markdown]
# > ## 1) Google Drive Mount

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# > ## 2) Model Save

# %%
model.save('/content/drive/My Drive/Colab Notebooks/models/002_dogs_and_cats_small.h5')

# %%
# !ls -l /content/drive/My\ Drive/Colab\ Notebooks/models
# Out:
# total 40562
# -rw------- 1 root root    35432 Nov  5 02:33 001_Model_iris.h5
# -rw------- 1 root root 41499528 Nov  8 01:36 002_dogs_and_cats_small.h5

# %% [markdown]
# > ## 3) Model Load

# %%
from tensorflow.keras.models import load_model

model_small = load_model('/content/drive/My Drive/Colab Notebooks/models/002_dogs_and_cats_small.h5')

# %%
loss, accuracy = model_small.evaluate(test_generator,
                                      steps = 50)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 50/50 [==============================] - 3s 57ms/step - loss: 3.3978 - accuracy: 0.7280
# Loss = 3.39779
# Accuracy = 0.72800

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
