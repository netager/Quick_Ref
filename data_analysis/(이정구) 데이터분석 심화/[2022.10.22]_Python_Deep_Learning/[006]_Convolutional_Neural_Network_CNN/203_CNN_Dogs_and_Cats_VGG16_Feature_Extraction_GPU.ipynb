# %% [markdown]
# # 사전 학습된 CNN(VGG-16)을 이용한 Feature Extraction
# ## VGG-16 Model
# * University of Oxford - Visual Geometry Group
# * 2014 ILSVRC 2nd Model
# * ImageNet Large Scale Visual Recognition Challenge (ILSVRC)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * Import TensorFlow

# %%
import tensorflow as tf

tf.__version__
# Out:
# '2.9.2'

# %% [markdown]
# # I. wget From Github
# * 'dogs_and_cats_small.zip' 파일 다운로드

# %%
# !wget https://raw.githubusercontent.com/rusita-ai/pyData/master/dogs_and_cats_small.zip
# Out:
# --2022-11-08 01:19:44--  https://raw.githubusercontent.com/rusita-ai/pyData/master/dogs_and_cats_small.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90618980 (86M) [application/zip]
# Saving to: ‘dogs_and_cats_small.zip’
#
# dogs_and_cats_small 100%[===================>]  86.42M   196MB/s    in 0.4s
#
# 2022-11-08 01:19:50 (196 MB/s) - ‘dogs_and_cats_small.zip’ saved [90618980/90618980]

# %% [markdown]
# * 다운로드 결과 확인

# %%
# !ls -l
# Out:
# total 88500
# -rw-r--r-- 1 root root 90618980 Nov  8 01:19 dogs_and_cats_small.zip
# drwxr-xr-x 1 root root     4096 Oct 28 13:37 sample_data

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Unzip 'dogs_and_cats_small.zip'

# %%
# !unzip -q /content/dogs_and_cats_small.zip

# %% [markdown]
# * 학습 데이터 확인

# %%
# !ls -l
# Out:
# total 88512
# -rw-r--r-- 1 root root 90618980 Nov  8 01:19 dogs_and_cats_small.zip
# drwxr-xr-x 1 root root     4096 Oct 28 13:37 sample_data
# drwxr-xr-x 4 root root     4096 Nov  8 01:19 test
# drwxr-xr-x 4 root root     4096 Nov  8 01:19 train
# drwxr-xr-x 4 root root     4096 Nov  8 01:19 validation

# %% [markdown]
# > ## 2) Image_File Directory Setting

# %% [markdown]
# * train_dir
# * valid_dir
# * test_dir

# %%
train_dir = 'train'
valid_dir = 'validation'
test_dir = 'test'

# %% [markdown]
# # III. Import VGG-16 Model

# %% [markdown]
# > ## 1) conv_base

# %%
from tensorflow.keras.applications import VGG16

conv_base = VGG16(weights = 'imagenet',
                  include_top = False,
                  input_shape = (150, 150, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step

# %% [markdown]
# > ## 2) Model Information

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # IV. Feature Extraction

# %% [markdown]
# > ## 1) 특징추출 함수 정의 : extract_feature( )
# * conv_base.predict( )

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

datagen = ImageDataGenerator(rescale = 1./255)

batch_size = 20

def extract_features(directory, sample_count):
    features = np.zeros(shape = (sample_count, 4, 4, 512))
    labels = np.zeros(shape = (sample_count))
    
    generator = datagen.flow_from_directory(directory,
                                            target_size = (150, 150),
                                            batch_size = batch_size,
                                            class_mode = 'binary')
    
    i = 0
    for inputs_batch, labels_batch in generator:
        features_batch = conv_base.predict(inputs_batch, verbose = 0)
        features[i * batch_size : (i + 1) * batch_size] = features_batch
        labels[i * batch_size : (i + 1) * batch_size] = labels_batch
        i += 1
        if i * batch_size >= sample_count:
            break
    return features, labels

# %% [markdown]
# > ## 2) 특징추출 함수 적용
# * train_dir
# * valid_dir
# * test_dir

# %% [markdown]
# * 약 1분

# %%
# %%time

train_features, train_labels = extract_features(train_dir, 2000)
valid_features, valid_labels = extract_features(valid_dir, 1000)
test_features, test_labels = extract_features(test_dir, 1000)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# CPU times: user 32.1 s, sys: 1.57 s, total: 33.7 s
# Wall time: 42 s

# %%
train_features.shape, valid_features.shape, test_features.shape
# Out:
# ((2000, 4, 4, 512), (1000, 4, 4, 512), (1000, 4, 4, 512))

# %% [markdown]
# > ## 3) Reshape Features
# * For 'Classification' Network

# %%
train_features = np.reshape(train_features, (2000, 4 * 4 * 512))
valid_features = np.reshape(valid_features, (1000, 4 * 4 * 512))
test_features = np.reshape(test_features, (1000, 4 * 4 * 512))

train_features.shape, valid_features.shape, test_features.shape
# Out:
# ((2000, 8192), (1000, 8192), (1000, 8192))

# %% [markdown]
# # V. Keras DNN Modeling with VGG-16 Featured Data

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 'Classification' Network Only
# * Dropout Layer

# %%
from tensorflow.keras import models, layers

model = models.Sequential()
model.add(layers.Dense(256, activation = 'relu', input_dim = 4 * 4 * 512))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2097408
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 2,097,665
# Trainable params: 2,097,665
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
model.compile(loss = 'binary_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 2분

# %%
# %%time

Hist_dandc = model.fit(train_features, train_labels,
                       epochs = 100,
                       batch_size = 20,
                       validation_data = (valid_features, valid_labels))
# Out:
# Epoch 1/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4536 - accuracy: 0.7955 - val_loss: 0.2798 - val_accuracy: 0.8970
# Epoch 2/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2640 - accuracy: 0.8945 - val_loss: 0.2544 - val_accuracy: 0.8910
# Epoch 3/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2060 - accuracy: 0.9205 - val_loss: 0.2415 - val_accuracy: 0.9040
# Epoch 4/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1721 - accuracy: 0.9325 - val_loss: 0.2435 - val_accuracy: 0.8930
# Epoch 5/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1444 - accuracy: 0.9440 - val_loss: 0.2512 - val_accuracy: 0.8990
# Epoch 6/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1199 - accuracy: 0.9535 - val_loss: 0.2649 - val_accuracy: 0.9040
# Epoch 7/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0995 - accuracy: 0.9625 - val_loss: 0.2585 - val_accuracy: 0.9010
# Epoch 8/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0865 - accuracy: 0.9650 - val_loss: 0.2764 - val_accuracy: 0.9050
# Epoch 9/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0739 - accuracy: 0.9735 - val_loss: 0.2789 - val_accuracy: 0.9030
# Epoch 10/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0563 - accuracy: 0.9825 - val_loss: 0.2969 - val_accuracy: 0.8970
# Epoch 11/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0447 - accuracy: 0.9860 - val_loss: 0.2850 - val_accuracy: 0.9030
# Epoch 12/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0444 - accuracy: 0.9840 - val_loss: 0.3386 - val_accuracy: 0.8930
# Epoch 13/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0378 - accuracy: 0.9890 - val_loss: 0.3512 - val_accuracy: 0.9030
# Epoch 14/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0533 - accuracy: 0.9785 - val_loss: 0.3204 - val_accuracy: 0.9050
# Epoch 15/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0463 - accuracy: 0.9805 - val_loss: 0.3443 - val_accuracy: 0.9010
# Epoch 16/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0321 - accuracy: 0.9890 - val_loss: 0.3705 - val_accuracy: 0.9010
# Epoch 17/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0220 - accuracy: 0.9915 - val_loss: 0.3811 - val_accuracy: 0.9060
# Epoch 18/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0160 - accuracy: 0.9960 - val_loss: 0.4335 - val_accuracy: 0.9050
# Epoch 19/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0277 - accuracy: 0.9885 - val_loss: 0.3596 - val_accuracy: 0.8980
# Epoch 20/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0329 - accuracy: 0.9875 - val_loss: 0.3670 - val_accuracy: 0.9030
# Epoch 21/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0310 - accuracy: 0.9895 - val_loss: 0.3739 - val_accuracy: 0.9020
# Epoch 22/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 0.9930 - val_loss: 0.4274 - val_accuracy: 0.9070
# Epoch 23/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0154 - accuracy: 0.9940 - val_loss: 0.4184 - val_accuracy: 0.9110
# Epoch 24/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0302 - accuracy: 0.9880 - val_loss: 0.4511 - val_accuracy: 0.8940
# Epoch 25/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0308 - accuracy: 0.9900 - val_loss: 0.3699 - val_accuracy: 0.9050
# Epoch 26/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0312 - accuracy: 0.9885 - val_loss: 0.5052 - val_accuracy: 0.8880
# Epoch 27/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 0.9935 - val_loss: 0.4768 - val_accuracy: 0.9030
# Epoch 28/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 0.9940 - val_loss: 0.5451 - val_accuracy: 0.8920
# Epoch 29/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0358 - accuracy: 0.9845 - val_loss: 0.4663 - val_accuracy: 0.9040
# Epoch 30/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0163 - accuracy: 0.9945 - val_loss: 0.4922 - val_accuracy: 0.9060
# Epoch 31/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 0.9960 - val_loss: 0.4494 - val_accuracy: 0.9070
# Epoch 32/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0288 - accuracy: 0.9895 - val_loss: 0.5697 - val_accuracy: 0.8890
# Epoch 33/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0243 - accuracy: 0.9925 - val_loss: 0.6257 - val_accuracy: 0.8770
# Epoch 34/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0330 - accuracy: 0.9885 - val_loss: 0.4392 - val_accuracy: 0.9020
# Epoch 35/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0211 - accuracy: 0.9920 - val_loss: 0.4934 - val_accuracy: 0.8980
# Epoch 36/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0284 - accuracy: 0.9870 - val_loss: 0.4870 - val_accuracy: 0.9070
# Epoch 37/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 0.6722 - val_accuracy: 0.8710
# Epoch 38/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0276 - accuracy: 0.9895 - val_loss: 0.4902 - val_accuracy: 0.9070
# Epoch 39/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9950 - val_loss: 0.5602 - val_accuracy: 0.8970
# Epoch 40/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.5471 - val_accuracy: 0.9070
# Epoch 41/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0154 - accuracy: 0.9930 - val_loss: 0.5649 - val_accuracy: 0.9030
# Epoch 42/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 0.9960 - val_loss: 0.5953 - val_accuracy: 0.9050
# Epoch 43/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0190 - accuracy: 0.9925 - val_loss: 0.5181 - val_accuracy: 0.8890
# Epoch 44/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0370 - accuracy: 0.9860 - val_loss: 0.5211 - val_accuracy: 0.8920
# Epoch 45/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.9945 - val_loss: 0.5299 - val_accuracy: 0.8970
# Epoch 46/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 0.9950 - val_loss: 0.5021 - val_accuracy: 0.9040
# Epoch 47/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 0.9955 - val_loss: 0.4905 - val_accuracy: 0.9050
# Epoch 48/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9890 - val_loss: 0.4607 - val_accuracy: 0.9060
# Epoch 49/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9950 - val_loss: 0.5582 - val_accuracy: 0.8990
# Epoch 50/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0369 - accuracy: 0.9865 - val_loss: 0.7779 - val_accuracy: 0.8690
# Epoch 51/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9925 - val_loss: 0.5115 - val_accuracy: 0.9010
# Epoch 52/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 0.9955 - val_loss: 0.5997 - val_accuracy: 0.8910
# Epoch 53/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.5722 - val_accuracy: 0.8980
# Epoch 54/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.5566 - val_accuracy: 0.9030
# Epoch 55/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.5988 - val_accuracy: 0.9080
# Epoch 56/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9965 - val_loss: 0.5231 - val_accuracy: 0.8960
# Epoch 57/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0221 - accuracy: 0.9905 - val_loss: 0.5437 - val_accuracy: 0.8920
# Epoch 58/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9925 - val_loss: 0.5835 - val_accuracy: 0.9030
# Epoch 59/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 0.7462 - val_accuracy: 0.8980
# Epoch 60/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 0.9950 - val_loss: 0.5459 - val_accuracy: 0.9040
# Epoch 61/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9950 - val_loss: 0.6046 - val_accuracy: 0.9040
# Epoch 62/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9960 - val_loss: 0.5857 - val_accuracy: 0.9010
# Epoch 63/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 0.9925 - val_loss: 0.7214 - val_accuracy: 0.8930
# Epoch 64/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0276 - accuracy: 0.9895 - val_loss: 0.6136 - val_accuracy: 0.8980
# Epoch 65/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0265 - accuracy: 0.9885 - val_loss: 0.5690 - val_accuracy: 0.8980
# Epoch 66/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0239 - accuracy: 0.9915 - val_loss: 0.5298 - val_accuracy: 0.9000
# Epoch 67/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0297 - accuracy: 0.9880 - val_loss: 0.5680 - val_accuracy: 0.9010
# Epoch 68/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0259 - accuracy: 0.9900 - val_loss: 0.6838 - val_accuracy: 0.9000
# Epoch 69/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 0.9875 - val_loss: 0.9358 - val_accuracy: 0.8740
# Epoch 70/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0312 - accuracy: 0.9865 - val_loss: 0.5494 - val_accuracy: 0.8970
# Epoch 71/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.5019 - val_accuracy: 0.9000
# Epoch 72/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 0.9960 - val_loss: 0.6304 - val_accuracy: 0.8960
# Epoch 73/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0139 - accuracy: 0.9940 - val_loss: 0.6206 - val_accuracy: 0.8980
# Epoch 74/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0124 - accuracy: 0.9965 - val_loss: 0.6395 - val_accuracy: 0.8970
# Epoch 75/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9980 - val_loss: 0.6286 - val_accuracy: 0.9020
# Epoch 76/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9920 - val_loss: 0.7979 - val_accuracy: 0.8900
# Epoch 77/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 0.9945 - val_loss: 0.6573 - val_accuracy: 0.9050
# Epoch 78/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 0.9975 - val_loss: 0.7782 - val_accuracy: 0.8990
# Epoch 79/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.7262 - val_accuracy: 0.9030
# Epoch 80/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 0.9970 - val_loss: 0.7892 - val_accuracy: 0.8970
# Epoch 81/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.7084 - val_accuracy: 0.9030
# Epoch 82/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0124 - accuracy: 0.9940 - val_loss: 0.7328 - val_accuracy: 0.8970
# Epoch 83/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0263 - accuracy: 0.9920 - val_loss: 0.8000 - val_accuracy: 0.9010
# Epoch 84/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.7593 - val_accuracy: 0.9050
# Epoch 85/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0122 - accuracy: 0.9960 - val_loss: 0.6345 - val_accuracy: 0.9050
# Epoch 86/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0174 - accuracy: 0.9915 - val_loss: 0.8754 - val_accuracy: 0.8750
# Epoch 87/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 0.9955 - val_loss: 0.9369 - val_accuracy: 0.8820
# Epoch 88/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0183 - accuracy: 0.9905 - val_loss: 0.6565 - val_accuracy: 0.8940
# Epoch 89/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.6701 - val_accuracy: 0.9040
# Epoch 90/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 0.9950 - val_loss: 0.7242 - val_accuracy: 0.9040
# Epoch 91/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.7754 - val_accuracy: 0.9060
# Epoch 92/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0102 - accuracy: 0.9970 - val_loss: 0.7089 - val_accuracy: 0.9070
# Epoch 93/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.7547 - val_accuracy: 0.9040
# Epoch 94/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 0.7825 - val_accuracy: 0.9060
# Epoch 95/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 1.1216 - val_accuracy: 0.8840
# Epoch 96/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.9542 - val_accuracy: 0.9070
# Epoch 97/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0255 - accuracy: 0.9895 - val_loss: 0.6273 - val_accuracy: 0.8980
# Epoch 98/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0184 - accuracy: 0.9925 - val_loss: 0.5855 - val_accuracy: 0.8920
# Epoch 99/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0222 - accuracy: 0.9925 - val_loss: 0.8013 - val_accuracy: 0.8900
# Epoch 100/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9930 - val_loss: 0.6375 - val_accuracy: 0.9000
# CPU times: user 45.1 s, sys: 4 s, total: 49.1 s
# Wall time: 1min 22s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_dandc.history['loss']) + 1)

plt.figure(figsize = (15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, Hist_dandc.history['loss'], 'b-')
plt.plot(epochs, Hist_dandc.history['val_loss'], 'r--')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, Hist_dandc.history['accuracy'], 'b-')
plt.plot(epochs, Hist_dandc.history['val_accuracy'], 'r--')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = model.evaluate(test_features, test_labels)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7187 - accuracy: 0.8730
# Loss = 0.71874
# Accuracy = 0.87300

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
