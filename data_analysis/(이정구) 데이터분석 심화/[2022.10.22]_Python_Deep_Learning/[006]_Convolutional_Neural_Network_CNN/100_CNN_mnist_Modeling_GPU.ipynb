# %% [markdown]
# # MNIST - Categorical Classification
# > # Convolutional Neural Network

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * import Tensorflow

# %%
import tensorflow

tensorflow.__version__
# Out:
# '2.9.2'

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Normalization

# %% [markdown]
# * 범위: 0 ~ 1

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) Reshape
#
#  * (60000, 28, 28) to (60000, 28, 28, 1)

# %%
X_train = X_train.reshape((60000, 28, 28, 1))
X_test = X_test.reshape((10000, 28, 28, 1))

# %% [markdown]
# > ## 3) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# > ## 4) train_test_split( )
#
# * Train(48,000) vs. Validation(12,000)

# %%
from sklearn.model_selection import train_test_split 

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train,
                                                      test_size = 0.2,
                                                      random_state = 2045)

X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((48000, 28, 28, 1), (48000, 10), (12000, 28, 28, 1), (12000, 10))

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * Feature Extraction Layer

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
# =================================================================
# Total params: 55,744
# Trainable params: 55,744
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * Classification Layer

# %%
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(units=64, activation='relu'))
model.add(layers.Dense(units=10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  flatten (Flatten)           (None, 576)               0
#
#  dropout (Dropout)           (None, 576)               0
#
#  dense (Dense)               (None, 64)                36928
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 5분

# %%
# %%time

Hist_mnist = model.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_data = (X_valid, y_valid))
# Out:
# Epoch 1/100
# 375/375 [==============================] - 17s 7ms/step - loss: 0.3379 - accuracy: 0.8926 - val_loss: 0.0888 - val_accuracy: 0.9745
# Epoch 2/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1013 - accuracy: 0.9684 - val_loss: 0.0680 - val_accuracy: 0.9787
# Epoch 3/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0719 - accuracy: 0.9775 - val_loss: 0.0552 - val_accuracy: 0.9841
# Epoch 4/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0582 - accuracy: 0.9816 - val_loss: 0.0448 - val_accuracy: 0.9877
# Epoch 5/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0489 - accuracy: 0.9844 - val_loss: 0.0424 - val_accuracy: 0.9889
# Epoch 6/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0417 - accuracy: 0.9871 - val_loss: 0.0418 - val_accuracy: 0.9887
# Epoch 7/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0363 - accuracy: 0.9884 - val_loss: 0.0421 - val_accuracy: 0.9881
# Epoch 8/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0336 - accuracy: 0.9891 - val_loss: 0.0342 - val_accuracy: 0.9903
# Epoch 9/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0295 - accuracy: 0.9906 - val_loss: 0.0375 - val_accuracy: 0.9903
# Epoch 10/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0275 - accuracy: 0.9912 - val_loss: 0.0402 - val_accuracy: 0.9904
# Epoch 11/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0256 - accuracy: 0.9918 - val_loss: 0.0377 - val_accuracy: 0.9909
# Epoch 12/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0253 - accuracy: 0.9919 - val_loss: 0.0346 - val_accuracy: 0.9919
# Epoch 13/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0217 - accuracy: 0.9931 - val_loss: 0.0317 - val_accuracy: 0.9923
# Epoch 14/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0200 - accuracy: 0.9937 - val_loss: 0.0337 - val_accuracy: 0.9918
# Epoch 15/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0188 - accuracy: 0.9940 - val_loss: 0.0431 - val_accuracy: 0.9905
# Epoch 16/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0180 - accuracy: 0.9941 - val_loss: 0.0327 - val_accuracy: 0.9927
# Epoch 17/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0162 - accuracy: 0.9949 - val_loss: 0.0383 - val_accuracy: 0.9916
# Epoch 18/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0175 - accuracy: 0.9946 - val_loss: 0.0340 - val_accuracy: 0.9917
# Epoch 19/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.0370 - val_accuracy: 0.9923
# Epoch 20/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0148 - accuracy: 0.9950 - val_loss: 0.0321 - val_accuracy: 0.9923
# Epoch 21/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0152 - accuracy: 0.9951 - val_loss: 0.0432 - val_accuracy: 0.9908
# Epoch 22/100
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0134 - accuracy: 0.9957 - val_loss: 0.0354 - val_accuracy: 0.9919
# Epoch 23/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 0.0414 - val_accuracy: 0.9912
# Epoch 24/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.0354 - val_accuracy: 0.9922
# Epoch 25/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0123 - accuracy: 0.9959 - val_loss: 0.0386 - val_accuracy: 0.9914
# Epoch 26/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0117 - accuracy: 0.9963 - val_loss: 0.0403 - val_accuracy: 0.9927
# Epoch 27/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.0482 - val_accuracy: 0.9911
# Epoch 28/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.0434 - val_accuracy: 0.9918
# Epoch 29/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.0408 - val_accuracy: 0.9923
# Epoch 30/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0110 - accuracy: 0.9963 - val_loss: 0.0484 - val_accuracy: 0.9908
# Epoch 31/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0107 - accuracy: 0.9966 - val_loss: 0.0356 - val_accuracy: 0.9915
# Epoch 32/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.0667 - val_accuracy: 0.9893
# Epoch 33/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.0433 - val_accuracy: 0.9920
# Epoch 34/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.0557 - val_accuracy: 0.9916
# Epoch 35/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.0667 - val_accuracy: 0.9908
# Epoch 36/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.0454 - val_accuracy: 0.9920
# Epoch 37/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0114 - accuracy: 0.9965 - val_loss: 0.0456 - val_accuracy: 0.9911
# Epoch 38/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0106 - accuracy: 0.9967 - val_loss: 0.0591 - val_accuracy: 0.9918
# Epoch 39/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.0491 - val_accuracy: 0.9921
# Epoch 40/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0109 - accuracy: 0.9968 - val_loss: 0.0457 - val_accuracy: 0.9920
# Epoch 41/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.0641 - val_accuracy: 0.9914
# Epoch 42/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0097 - accuracy: 0.9972 - val_loss: 0.0500 - val_accuracy: 0.9922
# Epoch 43/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0104 - accuracy: 0.9969 - val_loss: 0.0416 - val_accuracy: 0.9920
# Epoch 44/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 0.0459 - val_accuracy: 0.9908
# Epoch 45/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0096 - accuracy: 0.9971 - val_loss: 0.0496 - val_accuracy: 0.9915
# Epoch 46/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0110 - accuracy: 0.9970 - val_loss: 0.0498 - val_accuracy: 0.9918
# Epoch 47/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.0640 - val_accuracy: 0.9907
# Epoch 48/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0103 - accuracy: 0.9971 - val_loss: 0.0662 - val_accuracy: 0.9918
# Epoch 49/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0405 - val_accuracy: 0.9918
# Epoch 50/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0601 - val_accuracy: 0.9904
# Epoch 51/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.0671 - val_accuracy: 0.9906
# Epoch 52/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.0681 - val_accuracy: 0.9922
# Epoch 53/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.0480 - val_accuracy: 0.9919
# Epoch 54/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0104 - accuracy: 0.9971 - val_loss: 0.0586 - val_accuracy: 0.9904
# Epoch 55/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.0638 - val_accuracy: 0.9908
# Epoch 56/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9973 - val_loss: 0.0518 - val_accuracy: 0.9919
# Epoch 57/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.0546 - val_accuracy: 0.9922
# Epoch 58/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0118 - accuracy: 0.9971 - val_loss: 0.0552 - val_accuracy: 0.9903
# Epoch 59/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.0903 - val_accuracy: 0.9908
# Epoch 60/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0112 - accuracy: 0.9970 - val_loss: 0.0555 - val_accuracy: 0.9910
# Epoch 61/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9972 - val_loss: 0.0623 - val_accuracy: 0.9919
# Epoch 62/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0102 - accuracy: 0.9970 - val_loss: 0.0610 - val_accuracy: 0.9910
# Epoch 63/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0110 - accuracy: 0.9969 - val_loss: 0.0531 - val_accuracy: 0.9918
# Epoch 64/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9970 - val_loss: 0.0841 - val_accuracy: 0.9907
# Epoch 65/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0112 - accuracy: 0.9970 - val_loss: 0.0704 - val_accuracy: 0.9912
# Epoch 66/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0114 - accuracy: 0.9969 - val_loss: 0.0526 - val_accuracy: 0.9915
# Epoch 67/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0101 - accuracy: 0.9975 - val_loss: 0.0601 - val_accuracy: 0.9918
# Epoch 68/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0101 - accuracy: 0.9971 - val_loss: 0.0653 - val_accuracy: 0.9915
# Epoch 69/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0113 - accuracy: 0.9969 - val_loss: 0.0603 - val_accuracy: 0.9912
# Epoch 70/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0098 - accuracy: 0.9971 - val_loss: 0.0623 - val_accuracy: 0.9927
# Epoch 71/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0099 - accuracy: 0.9975 - val_loss: 0.0616 - val_accuracy: 0.9917
# Epoch 72/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9971 - val_loss: 0.1037 - val_accuracy: 0.9900
# Epoch 73/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0121 - accuracy: 0.9963 - val_loss: 0.0508 - val_accuracy: 0.9910
# Epoch 74/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0118 - accuracy: 0.9969 - val_loss: 0.0537 - val_accuracy: 0.9923
# Epoch 75/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0096 - accuracy: 0.9975 - val_loss: 0.0848 - val_accuracy: 0.9914
# Epoch 76/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 0.0845 - val_accuracy: 0.9908
# Epoch 77/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0136 - accuracy: 0.9965 - val_loss: 0.0471 - val_accuracy: 0.9923
# Epoch 78/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0124 - accuracy: 0.9968 - val_loss: 0.0651 - val_accuracy: 0.9922
# Epoch 79/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0117 - accuracy: 0.9971 - val_loss: 0.0448 - val_accuracy: 0.9914
# Epoch 80/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0107 - accuracy: 0.9972 - val_loss: 0.0677 - val_accuracy: 0.9911
# Epoch 81/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0110 - accuracy: 0.9971 - val_loss: 0.0671 - val_accuracy: 0.9902
# Epoch 82/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0113 - accuracy: 0.9970 - val_loss: 0.0561 - val_accuracy: 0.9913
# Epoch 83/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0105 - accuracy: 0.9975 - val_loss: 0.0598 - val_accuracy: 0.9910
# Epoch 84/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0105 - accuracy: 0.9972 - val_loss: 0.0950 - val_accuracy: 0.9915
# Epoch 85/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0098 - accuracy: 0.9974 - val_loss: 0.0629 - val_accuracy: 0.9914
# Epoch 86/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0120 - accuracy: 0.9973 - val_loss: 0.0557 - val_accuracy: 0.9895
# Epoch 87/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9970 - val_loss: 0.0663 - val_accuracy: 0.9908
# Epoch 88/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0112 - accuracy: 0.9974 - val_loss: 0.0767 - val_accuracy: 0.9916
# Epoch 89/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0114 - accuracy: 0.9973 - val_loss: 0.1000 - val_accuracy: 0.9916
# Epoch 90/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0129 - accuracy: 0.9969 - val_loss: 0.0758 - val_accuracy: 0.9884
# Epoch 91/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0122 - accuracy: 0.9968 - val_loss: 0.0988 - val_accuracy: 0.9914
# Epoch 92/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0103 - accuracy: 0.9972 - val_loss: 0.0998 - val_accuracy: 0.9922
# Epoch 93/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0140 - accuracy: 0.9970 - val_loss: 0.0751 - val_accuracy: 0.9899
# Epoch 94/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0146 - accuracy: 0.9966 - val_loss: 0.1191 - val_accuracy: 0.9902
# Epoch 95/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0132 - accuracy: 0.9966 - val_loss: 0.0891 - val_accuracy: 0.9910
# Epoch 96/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0127 - accuracy: 0.9967 - val_loss: 0.0724 - val_accuracy: 0.9918
# Epoch 97/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0128 - accuracy: 0.9964 - val_loss: 0.0954 - val_accuracy: 0.9916
# Epoch 98/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0122 - accuracy: 0.9969 - val_loss: 0.1040 - val_accuracy: 0.9901
# Epoch 99/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0128 - accuracy: 0.9971 - val_loss: 0.0900 - val_accuracy: 0.9912
# Epoch 100/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0130 - accuracy: 0.9968 - val_loss: 0.0891 - val_accuracy: 0.9909
# CPU times: user 4min 7s, sys: 21.1 s, total: 4min 28s
# Wall time: 4min 25s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, Hist_mnist.history['loss'], 'b-')
plt.plot(epochs, Hist_mnist.history['val_loss'], 'r--')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, Hist_mnist.history['accuracy'], 'b-')
plt.plot(epochs, Hist_mnist.history['val_accuracy'], 'r--')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0544 - accuracy: 0.9921
# Loss = 0.05441
# Accuracy = 0.99210

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
