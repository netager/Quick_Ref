# %% [markdown]
# # JBFG Data Analysis Competition

# %%
#!pip install watermark
# %load_ext watermark
# %watermark -a 'DataLine' -nmv --packages numpy,pandas,sklearn,imblearn,tensorflow,plotly,matplotlib,seaborn,missingno,lightgbm
# Out:
# Author: DataLine
#
# Python implementation: CPython
# Python version       : 3.9.18
# IPython version      : 8.15.0
#
# numpy     : 1.24.3
# pandas    : 2.0.3
# sklearn   : 1.3.0
# imblearn  : 0.0
# tensorflow: 2.10.0
# plotly    : 5.9.0
# matplotlib: 3.7.2
# seaborn   : 0.12.2
# missingno : 0.5.1
# lightgbm  : 3.3.5
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 165 Stepping 3, GenuineIntel
# CPU cores   : 12
# Architecture: 64bit

# %%
import imblearn

# %% [markdown]
# #### 컬럼 데이터 및 Null 건수 확인

# %%
"""
# 데이터 포맷 함수
# ---------------
def change_format(df, column, format):
    '''
    데이터프레임의 지정된 컬럼에 컴마, 백분율로 변경하여 데이터프레임을 반환하는 함수
        Args:
            df (df) : DataFrame
            column (str) : column of DataFrame
            format (str) : 'comma' | 'percent'
        Return:
            DataFrame
    '''
    if format == 'comma':
        df[column] = df[column].apply(lambda x: f"{x:,}")
    elif format == 'percent':
        df[column] = df[column].apply(lambda x: f"{x:.2%}")
        
    return df


# 데이터프레임의 특정 컬럼에 대한 건수, Null, Percent 표시
# -----------------------------------------------------
def count_column_na_count(df, column):
    '''
    데이터프레임의 특정 컬럼에 대한 건수, Null, Percent를 출력하는 함수
        Args:
            df (df) : DataFrame
            column (str) : column of DataFrame
        Return:
            None
    '''
    column_na_counts = df[column].size, df[column].count(), df[column].isnull().sum()
    column_na_counts_df = pd.Series(column_na_counts).to_frame().T
    column_na_counts_df.columns = ['tot_counts', 'data_counts', 'null_counts']
    column_na_counts_df['data_percents'] = column_na_counts_df['data_counts'].values/column_na_counts_df['tot_counts'].values
    column_na_counts_df['null_percents'] = column_na_counts_df['null_counts'].values/column_na_counts_df['tot_counts'].values


    column_na_counts_df = change_format(column_na_counts_df, 'tot_counts', 'comma')
    column_na_counts_df = change_format(column_na_counts_df, 'data_counts','comma')
    column_na_counts_df = change_format(column_na_counts_df, 'null_counts','comma')
    column_na_counts_df = change_format(column_na_counts_df, 'data_percents', 'percent')
    column_na_counts_df = change_format(column_na_counts_df, 'null_percents', 'percent')

    print(column_na_counts_df.to_string(index=False))
    print('-'*70)


def count_column_data_count(df, column):
    ''' 
    '''
    # column_data_countcounts = df.groupby(column)['is_churned'].value_counts().unstack()


    column_counts = df.groupby(column)['is_churned'].value_counts().unstack()
    column_counts = column_counts.rename(columns={0: 'exist_counts', 1: 'churned_counts'})
    column_counts['total_counts'] =  column_counts['exist_counts'] + column_counts['churned_counts']
    column_counts = column_counts.fillna(0)

    column_percents = df.groupby(column)['is_churned'].value_counts(normalize=True).unstack()
    column_percents = column_percents.rename(columns={0: 'exist_percents', 1: 'churned_percents'})
    column_percents = column_percents.fillna(0)


    column_count_percent = pd.concat([column_counts, column_percents], axis=1)
    column_count_percent = column_count_percent.reset_index()
    column_count_percent = column_count_percent.sort_values(by='churned_percents', ascending=False)

    
    column_count_percent = change_format(column_count_percent, 'exist_counts', 'comma')
    column_count_percent = change_format(column_count_percent, 'churned_counts', 'comma')
    column_count_percent = change_format(column_count_percent, 'total_counts', 'comma')
    column_count_percent = change_format(column_count_percent, 'exist_percents', 'percent')
    column_count_percent = change_format(column_count_percent, 'churned_percents', 'percent')
    

    print(column_count_percent.to_string(index=False))

"""
# Out:
# '\n# 데이터 포맷 함수\n# ---------------\ndef change_format(df, column, format):\n    \'\'\'\n    데이터프레임의 지정된 컬럼에 컴마, 백분율로 변경하여 데이터프레임을 반환하는 함수\n        Args:\n            df (df) : DataFrame\n            column (str) : column of DataFrame\n            format (str) : \'comma\' | \'percent\'\n        Return:\n            DataFrame\n    \'\'\'\n    if format == \'comma\':\n        df[column] = df[column].apply(lambda x: f"{x:,}")\n    elif format == \'percent\':\n        df[column] = df[column].apply(lambda x: f"{x:.2%}")\n        \n    return df\n\n\n# 데이터프레임의 특정 컬럼에 대한 건수, Null, Percent 표시\n# -----------------------------------------------------\ndef count_column_na_count(df, column):\n    \'\'\'\n    데이터프레임의 특정 컬럼에 대한 건수, Null, Percent를 출력하는 함수\n        Args:\n            df (df) : DataFrame\n            column (str) : column of DataFrame\n        Return:\n            None\n    \'\'\'\n    column_na_counts = df[column].size, df[column].count(), df[column].isnull().sum()\n    column_na_counts_df = pd.Series(column_na_counts).to_frame().T\n    column_na_counts_df.columns = [\'tot_counts\', \'data_counts\', \'null_counts\']\n    column_na_counts_df[\'data_percents\'] = column_na_counts_df[\'data_counts\'].values/column_na_counts_df[\'tot_counts\'].values\n    column_na_counts_df[\'null_percents\'] = column_na_counts_df[\'null_counts\'].values/column_na_counts_df[\'tot_counts\'].values\n\n\n    column_na_counts_df = change_format(column_na_counts_df, \'tot_counts\', \'comma\')\n    column_na_counts_df = change_format(column_na_counts_df, \'data_counts\',\'comma\')\n    column_na_counts_df = change_format(column_na_counts_df, \'null_counts\',\'comma\')\n    column_na_counts_df = change_format(column_na_counts_df, \'data_percents\', \'percent\')\n    column_na_counts_df = change_format(column_na_counts_df, \'null_percents\', \'percent\')\n\n    print(column_na_counts_df.to_string(index=False))\n    print(\'-\'*70)\n\n\ndef count_column_data_count(df, column):\n    \'\'\' \n    \'\'\'\n    # column_data_countcounts = df.groupby(column)[\'is_churned\'].value_counts().unstack()\n\n\n    column_counts = df.groupby(column)[\'is_churned\'].value_counts().unstack()\n    column_counts = column_counts.rename(columns={0: \'exist_counts\', 1: \'churned_counts\'})\n    column_counts[\'total_counts\'] =  column_counts[\'exist_counts\'] + column_counts[\'churned_counts\']\n    column_counts = column_counts.fillna(0)\n\n    column_percents = df.groupby(column)[\'is_churned\'].value_counts(normalize=True).unstack()\n    column_percents = column_percents.rename(columns={0: \'exist_percents\', 1: \'churned_percents\'})\n    column_percents = column_percents.fillna(0)\n\n\n    column_count_percent = pd.concat([column_counts, column_percents], axis=1)\n    column_count_percent = column_count_percent.reset_index()\n    column_count_percent = column_count_percent.sort_values(by=\'churned_percents\', ascending=False)\n\n    \n    column_count_percent = change_format(column_count_percent, \'exist_counts\', \'comma\')\n    column_count_percent = change_format(column_count_percent, \'churned_counts\', \'comma\')\n    column_count_percent = change_format(column_count_percent, \'total_counts\', \'comma\')\n    column_count_percent = change_format(column_count_percent, \'exist_percents\', \'percent\')\n    column_count_percent = change_format(column_count_percent, \'churned_percents\', \'percent\')\n    \n\n    print(column_count_percent.to_string(index=False))\n\n'

# %% [markdown]
# ## Machine Learning
# ***

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np
from itertools import combinations
import time
import datetime
import joblib

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from lightgbm import LGBMClassifier, LGBMRegressor
from xgboost import XGBClassifier

from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.feature_selection import RFE
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Function Definition

# %% [markdown]
# #### tot_column_count()

# %%
"""
def tot_column_counts(df):
    ''' 
    '''
    data_counts = df.count()
    null_counts = df.isnull().sum()
    tot_counts_df = pd.concat([data_counts, null_counts], axis=1)
    tot_counts_df = tot_counts_df.rename(columns={0: 'data_counts', 1: 'null_counts'})
    tot_counts_df.insert(0,'tot_counts', tot_counts_df['data_counts'] + tot_counts_df['null_counts'])
    tot_counts_df['data_percents'] = tot_counts_df['data_counts'].values / tot_counts_df['tot_counts'].values
    tot_counts_df['null_percents'] = tot_counts_df['null_counts'].values / tot_counts_df['tot_counts'].values
    tot_counts_df = tot_counts_df.sort_values(by='null_percents', ascending=False)

    tot_counts_df = change_format(tot_counts_df, 'tot_counts', 'comma')
    tot_counts_df = change_format(tot_counts_df, 'data_counts','comma')
    tot_counts_df = change_format(tot_counts_df, 'null_counts','comma')
    tot_counts_df = change_format(tot_counts_df, 'data_percents', 'percent')
    tot_counts_df = change_format(tot_counts_df, 'null_percents', 'percent')

    tot_counts_df = tot_counts_df.reset_index()

    print(tot_counts_df.to_string(index=False))
    
"""
# Out:
# "\ndef tot_column_counts(df):\n    ''' \n    '''\n    data_counts = df.count()\n    null_counts = df.isnull().sum()\n    tot_counts_df = pd.concat([data_counts, null_counts], axis=1)\n    tot_counts_df = tot_counts_df.rename(columns={0: 'data_counts', 1: 'null_counts'})\n    tot_counts_df.insert(0,'tot_counts', tot_counts_df['data_counts'] + tot_counts_df['null_counts'])\n    tot_counts_df['data_percents'] = tot_counts_df['data_counts'].values / tot_counts_df['tot_counts'].values\n    tot_counts_df['null_percents'] = tot_counts_df['null_counts'].values / tot_counts_df['tot_counts'].values\n    tot_counts_df = tot_counts_df.sort_values(by='null_percents', ascending=False)\n\n    tot_counts_df = change_format(tot_counts_df, 'tot_counts', 'comma')\n    tot_counts_df = change_format(tot_counts_df, 'data_counts','comma')\n    tot_counts_df = change_format(tot_counts_df, 'null_counts','comma')\n    tot_counts_df = change_format(tot_counts_df, 'data_percents', 'percent')\n    tot_counts_df = change_format(tot_counts_df, 'null_percents', 'percent')\n\n    tot_counts_df = tot_counts_df.reset_index()\n\n    print(tot_counts_df.to_string(index=False))\n    \n"

# %% [markdown]
# #### drop_null_column()

# %%
# 데이터프레임의 특정컬럼을 리스트로 받아 삭제
def drop_null_column(df, drop_list):
    '''
        데이터프레임의 특정컬럼을 리스트로 받아 삭제후 반환하는 함수
        
        Args:
            df (df) : DataFrame
            drop_list (list) : 삭제대상 컬럼의 List 
        Return:
            DataFrame
    '''
    for col_name in drop_list:
        # print(col_name, type(col_name))
        df = df.drop(col_name, axis=1)
    df.dropna(axis=0, inplace=True)

    return df

# %% [markdown]
# #### encode_onehot()

# %%
# 원-핫 인코딩 처리 
# ----------------
def encode_onehot(df):
    '''
        데이터프레임의 object type 컬럼을 원-핫 인코딩하는 함수
        
        Args:
            df (df) : DataFrame
        Return:
            DataFrame
    '''
    catcols = df.select_dtypes(exclude = ['int64','float64']).columns
    df = pd.get_dummies(df, columns = catcols)
    
    return df

# %% [markdown]
# #### select_feature()

# %%
# 중요 Feature 식별
# ----------------
def select_feature(df, y, chosen_model):

    np.random.seed(42)    
    
    available_models = {
    'ExtraTrees': ExtraTreesClassifier(n_estimators=100),
    'RandomForest': RandomForestClassifier(n_estimators=100),
    'KNN': KNeighborsClassifier(n_neighbors=5),
    'RFE': RFE(estimator=RandomForestClassifier(n_estimators=100), n_features_to_select=13),
    'LGBMC': LGBMClassifier(),
    'LGBMR': LGBMRegressor(),
    'Xg Boost':XGBClassifier(booster='gbtree', importance_type='gain', eval_metric='auc'),
    }

    # Create the selected model
    clf = available_models[chosen_model]

    clf = clf.fit(df.values, y)                                     # Train

    if chosen_model == 'LGBMC' or chosen_model == 'LGBMR': 
        feature_importances = clf.booster_.feature_importance(importance_type="gain")
    else:        
        feature_importances = clf.feature_importances_


    chosen_model = SelectFromModel(clf, prefit=True)
    X_df = chosen_model.transform(df.values) 
    selected_feature_indices = chosen_model.get_support(indices=True)

    selected_columns = df.columns[selected_feature_indices]         # Get the indices of the selected features
    
    return X_df, selected_columns

# %% [markdown]
# #### proc_smote()

# %%
def proc_smote(X_new, y):
    #Model Training
    from sklearn.model_selection import train_test_split
    from imblearn.over_sampling import SMOTE

    X_train,X_test,y_train,y_test=train_test_split(X_new,y,test_size=0.25,stratify=y,random_state=0)

    sm = SMOTE(sampling_strategy='auto', random_state=42)
    X_train, y_train=sm.fit_resample(X_train,y_train)
    
    return X_train, y_train, X_test, y_test

# %% [markdown]
# #### proc_normalization()

# %%
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer

def proc_normalization(X_train, X_test):
    scaler=StandardScaler()
    # scaler = QuantileTransformer()
    # scaler = PowerTransformer()
    X_train=scaler.fit_transform(X_train)
    X_test=scaler.transform(X_test)
    
    return X_train, X_test

# %% [markdown]
# #### fit_predict_eval()

# %%
# 예측 및 평가
# -----------
def fit_predict_eval(proc_type, drop_no, group_no, model_comparison, X_train, y_train, X_test, y_test):
    
    # 초기화
    # ------
    best_roc_auc = 0
    
    # Define Models
    # ------------- 
    models = [
        # ('LogisticRegression', LogisticRegression()),
        # ('DecisionTree', DecisionTreeClassifier(criterion='entropy', random_state=0)),
        # ('KNN', KNeighborsClassifier(n_neighbors=5)),
        # ('NaiveBayes', GaussianNB()),
        # ('RandomForest', RandomForestClassifier(n_estimators=700, criterion='entropy', random_state=0)),
        ('LightGBM', LGBMClassifier(n_estimators=700, random_state=42, boosting_type='GOSS')),
        # ('XgBoost', XGBClassifier(n_estimators=700, random_state=42, use_label_encoder=False,  eval_metric='auc')),
        # ('Xg Boost', XGBClassifier(n_estimators=700, random_state=42, use_label_encoder=False, eval_metric='logloss')),        
        # ('ExtraTrees', ExtraTreesClassifier(n_estimators=700)),
        # ('SVM', SVC(kernel='linear')),
        # ('LASSO', Lasso(alpha=0.01)),
    ]


    # Model Fit and Testing
    # ---------------------
    for model_name, classifier in models:
        start_time = time.time()

        # 학습
        # ----            
        classifier.fit(X_train, y_train)            # Fit
        
        # 학습된 모델 저장
        # ---------------
        # file_name = f'./models/{model_name}.pkl'
        # print
        # joblib.dump(classifier, file_name)

        # 평가
        # ---- 
        y_pred = classifier.predict(X_test)         # Test
        pred_proba = classifier.predict_proba(X_test)[:, 1]

        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average='weighted')
        
        accuracies = cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=5, scoring="roc_auc")
        # accuracies = cross_val_score(estimator=classifier, X=X_test, y=y_test, cv=5, scoring="recall")
        cv_auc = accuracies.mean()
        cv_std = accuracies.std()
        
        accuracy_class_0 = accuracy_score(y_test[y_test == 0], y_pred[y_test == 0])
        accuracy_class_1 = accuracy_score(y_test[y_test == 1], y_pred[y_test == 1], )
        
        roc_auc = roc_auc_score(y_test, pred_proba)
        
        
        # Collect Result
        # --------------
        model_comparison[f'{model_name}_{proc_type}_{drop_no}_{group_no}'] = [accuracy, accuracy_class_0, accuracy_class_1, f1, cv_auc, cv_std, roc_auc]
        
        
        # Best ROC_AUC Value Return
        # -------------------------
        if roc_auc > best_roc_auc:
            best_roc_auc = roc_auc

        cur_datetime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        end_time = time.time()
        delta_time = end_time - start_time
        # print(f'[테스트] {cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, [{proc_type}_{drop_no}], Model Name: {model_name:<18}, BEST AUC: {best_roc_auc:0.6f}, AUC: {roc_auc:0.6f}')

    return best_roc_auc

# %% [markdown]
# #### print_eval_result()

# %%
def print_eval_result(model_comparison):

    # # MODEL COMPARISSON
    # Model_com_df=pd.DataFrame(model_comparison).T
    # Model_com_df.columns=['Model Accuracy','Model Accuracy-0','Model Accuracy-1','Model F1-Score','CV Accuracy','CV std', 'AUC']
    # Model_com_df=Model_com_df.sort_values(by='AUC',ascending=False)
    # # display(Model_com_df.style.format("{:.2%}").background_gradient(cmap='magma'))

    Model_com_df = pd.DataFrame(model_comparison).T
    Model_com_df.columns = ['Accuracy', 'Accuracy-No', 'Accuracy-Yes', 'F1-Score', 'CV AUC', 'CV std', 'AUC']
    Model_com_df = Model_com_df.sort_values(by='AUC', ascending=False)

    def highlight_below_75(s):
        if s.name != 'CV std' and isinstance(s, pd.Series) and s.dtype == 'float64':
            return ['color: red' if value < 0.75 else 'color: black' for value in s]
        else:
            return ['color: black'] * len(s)

    styled_df = Model_com_df.iloc[:10,:].style.highlight_max(axis=0).apply(highlight_below_75, subset=pd.IndexSlice[:, :'CV AUC']).format("{:.2%}", subset=pd.IndexSlice[:, :'CV AUC'])
    display(styled_df)

# %% [markdown]
# #### test_transform()

# %%
def test_transform(df):
    
    # 데이터 변환
    # ------------------- 
    df = df.drop('cstno', axis=1)
    df = df.drop('sex', axis=1)
    # after_drop_cnt=len(df)
    df['imcome_cat']=df['imcome_cat'].replace({'Less than $40K':40000, '$40K - $60K':50000, '$60K - $80K':70000, '$80K - $120K':100000, '$120K +':120000, 'Unknown':63000})

    
    # 결측치 처리
    # ----------
    df = df.fillna(df.mean(numeric_only=True))
    df.dropna(axis=0, inplace=True)
    # after_drop_cnt=len(df)
    
    # One-Hot Encoding
    # ----------------
    df = encode_onehot(df)  
   
    return df

# %% [markdown]
# ### 학습 및 Test 단계

# %% [markdown]
# #### 데이터 로딩

# %%
ml_churner_df = pd.read_csv("./data/bank_churner.csv")
tot_cnt = len(ml_churner_df)

# %% [markdown]
# #### 예측 및 결과

# %%
# 결과 저장소 초기화
# -----------------
model_comparison = {}  #Dictionary to store the comparison metrics of models
model_eval_comparison = {}       
drop_no = 1

# %%
'''
# 결과 저장소 초기화
# -----------------
model_comparison = {}  #Dictionary to store the comparison metrics of models
model_eval_comparison = {}                        
drop_no = 1
start_time = time.time()


ml_churner_df = test_transform(ml_churner_df)
after_drop_cnt = len(ml_churner_df)

# ML 데이터 분리
# --------------
X=ml_churner_df.drop(['is_churned'],axis=1)
y=ml_churner_df['is_churned']


# 중요 Feature Column 선택
# -----------------------
# X_new, selected_columns = select_feature(X, y, 'Xg Boost')
X_new, selected_columns = select_feature(X, y, 'ExtraTrees')


# Train and Test 데이터 생성 및 가공
# ---------------------------------
X_train, y_train, X_test, y_test = proc_smote(X_new, y)
X_train_for_normalization = X_train.copy()
after_smote_cnt = len(X_train)


# Normalization
# -------------
X_train, X_test = proc_normalization(X_train, X_test)    


# Pridict 및 Test 평가
# --------------------
proc_type='T'
test_auc = fit_predict_eval(proc_type, drop_no, model_comparison, X_train, y_train, X_test, y_test)


# 예측 및 테스트 로그 출력
# ----------------------
cur_datetime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
end_time = time.time()
delta_time = end_time - start_time
print(f'[테스트] {cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, [{proc_type}_{drop_no}], AUC: {test_auc:0.6f}, tot_cnt: {tot_cnt:<6}, after_drop_cnt : {after_drop_cnt:<6}, after_smote_cnt: {after_smote_cnt:<6}, X_train:{X_train.shape}, y_train:{y_train.shape}, X_test:{X_test.shape}, y_test:{y_test.shape}')


# print_eval_result(model_comparison)

'''
# Out:
# '\n# 결과 저장소 초기화\n# -----------------\nmodel_comparison = {}  #Dictionary to store the comparison metrics of models\nmodel_eval_comparison = {}                        \ndrop_no = 1\nstart_time = time.time()\n\n\nml_churner_df = test_transform(ml_churner_df)\nafter_drop_cnt = len(ml_churner_df)\n\n# ML 데이터 분리\n# --------------\nX=ml_churner_df.drop([\'is_churned\'],axis=1)\ny=ml_churner_df[\'is_churned\']\n\n\n# 중요 Feature Column 선택\n# -----------------------\n# X_new, selected_columns = select_feature(X, y, \'Xg Boost\')\nX_new, selected_columns = select_feature(X, y, \'ExtraTrees\')\n\n\n# Train and Test 데이터 생성 및 가공\n# ---------------------------------\nX_train, y_train, X_test, y_test = proc_smote(X_new, y)\nX_train_for_normalization = X_train.copy()\nafter_smote_cnt = len(X_train)\n\n\n# Normalization\n# -------------\nX_train, X_test = proc_normalization(X_train, X_test)    \n\n\n# Pridict 및 Test 평가\n# --------------------\nproc_type=\'T\'\ntest_auc = fit_predict_eval(proc_type, drop_no, model_comparison, X_train, y_train, X_test, y_test)\n\n\n# 예측 및 테스트 로그 출력\n# ----------------------\ncur_datetime = datetime.datetime.now().strftime(\'%Y-%m-%d %H:%M:%S\')\nend_time = time.time()\ndelta_time = end_time - start_time\nprint(f\'[테스트] {cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, [{proc_type}_{drop_no}], AUC: {test_auc:0.6f}, tot_cnt: {tot_cnt:<6}, after_drop_cnt : {after_drop_cnt:<6}, after_smote_cnt: {after_smote_cnt:<6}, X_train:{X_train.shape}, y_train:{y_train.shape}, X_test:{X_test.shape}, y_test:{y_test.shape}\')\n\n\n# print_eval_result(model_comparison)\n\n'

# %% [markdown]
# ### 평가 단계 ~ 평가자가 Competition 평가를 위해 사용 하는 단계

# %% [markdown]
# #### 데이터 로딩

# %%
eval_df = pd.read_csv("./data/test_churner.csv") # 평가를 위한 데이터 로드 - 평가데이터 경로를 입력해 주세요!!!
# eval_df = pd.read_csv("./data/test_churner_kaggle_all.csv") # 평가를 위한 데이터 로드 - 평가데이터 경로를 입력해 주세요!!!

fit_df = pd.read_csv("./data/bank_churner.csv") # 학습을 위한 데이터 로드
tot_cnt = len(eval_df)

# %% [markdown]
# #### 평가 및 결과

# %%
fit_df = pd.read_csv("./data/bank_churner.csv") # 학습을 위한 데이터 로드
eval_df = pd.read_csv("./data/test_churner.csv")

fit_df = fit_df.drop('sex', axis=1)
fit_df = fit_df.fillna(fit_df.mean(numeric_only=True))
fit_df.dropna(axis=0, inplace=True)
# fit_df = test_transform(fit_df)

# X_train=fit_df.drop(['is_churned'],axis=1)
# y_train=fit_df['is_churned']
# X_eval=eval_df.drop(['is_churned'],axis=1)
# y_eval=eval_df['is_churned']


# X_new, selected_columns = select_feature(X_train, y_train, 'ExtraTrees')
# X_eval = X_eval[selected_columns]

# X_train, y_train, X_test_temp, y_test_temp = proc_smote(X_new, y_train)

# X_train, X_eval = proc_normalization(X_train, X_eval.values)

# %%
fit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8101 entries, 0 to 8100
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cstno                  8101 non-null   int64
#  1   is_churned             8101 non-null   int64
#  2   age                    8101 non-null   int64
#  3   dependent_num          8101 non-null   int64
#  4   education              8101 non-null   object
#  5   marital_stat           8101 non-null   object
#  6   imcome_cat             6482 non-null   object
#  7   card_type              8101 non-null   object
#  8   mon_on_book            8101 non-null   int64
#  9   tot_product_count      8101 non-null   int64
#  10  months_inact_for_12m   8101 non-null   int64
#  11  contact_cnt_for_12m    8101 non-null   int64
#  12  credit_line            8101 non-null   float64
#  13  tot_revol_balance      8101 non-null   float64
#  14  mean_open_to_buy       8101 non-null   float64
#  15  tot_amt_ratio_q4_q1    8101 non-null   float64
#  16  tot_trans_amt_for_12m  8101 non-null   float64
#  17  tot_trans_cnt_for_12m  8101 non-null   float64
#  18  tot_cnt_ratio_q4_q1    8101 non-null   float64
#  19  mean_util_pct          8101 non-null   float64
# dtypes: float64(8), int64(8), object(4)
# memory usage: 1.2+ MB

# %%
fit_df.shape
# fit_df.shape, X_train.shape
# Out:
# (8101, 20)

# %%
from itertools import combinations

model_comparison = {}  #Dictionary to store the comparison metrics of models
model_eval_comparison = {}                        

def drop_null_column(df, drop_list):
    for col_name in drop_list:
        df = df.drop(col_name, axis=1)

    return df

def test_transform(df, drop_list):
    
    # 데이터 변환
    # ------------------- 
    df = df.drop('cstno', axis=1)
    for col_name in drop_list:
        df = df.drop(col_name, axis=1)

    if 'imcome_cat' not in drop_list:
        df['imcome_cat']=df['imcome_cat'].replace({'Less than $40K':40000, '$40K - $60K':50000, '$60K - $80K':70000, '$80K - $120K':100000, '$120K +':120000, 'Unknown':63000})

    df = df.fillna(df.mean(numeric_only=True))
    df.dropna(axis=0, inplace=True)
        
    # 결측치 처리
    # ----------
    # after_drop_cnt=len(df)
    
    # One-Hot Encoding
    # ----------------
    df = encode_onehot(df)  
   
    return df

        
# -----------
# 예측
# -----------

# 데이터 로드 및 고객번호 삭제
fit_df = pd.read_csv("./data/bank_churner.csv") # 학습을 위한 데이터 로드
eval_df = pd.read_csv("./data/test_churner.csv")
tot_cnt = fit_df.shape

fit_df_org = fit_df.copy()
eval_df_org = eval_df.copy()

best_auc = 0

# Null 처리
result_list = []
drop_target_columns = ['sex','imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m','age','mean_open_to_buy','tot_trans_amt_for_12m']
for j in range(1, len(drop_target_columns)+1):
    for i in combinations(drop_target_columns, j):
        result_list.append(list(i))

# result_list = [['sex'], ['sex', 'age', 'imcome_cat']]

for drop_no, drop_column in enumerate(result_list):
    start_time = time.time()

    fit_df = fit_df_org
    eval_df = eval_df_org
    
    # -----------------------------------------------------------------------------------    
    # 평가 for Competition
    # -----------------------------------------------------------------------------------

    # 전처리 단계
    # -----------
    fit_df = test_transform(fit_df, drop_column)
    eval_df = test_transform(eval_df, drop_column)
    after_drop_cnt = len(fit_df)
    
    
    # 평가를 위한 데이터 분리
    # ---------------------
    X_train=fit_df.drop(['is_churned'],axis=1)
    y_train=fit_df['is_churned']
    X_train_cnt = X_train.shape
    
    X_eval=eval_df.drop(['is_churned'],axis=1)
    y_eval=eval_df['is_churned']


    # 중요 Feature Column 선택
    # -----------------------
    X_new, selected_columns = select_feature(X_train, y_train, 'ExtraTrees')
    X_eval = X_eval[selected_columns]


    # Train and Test 데이터 생성 및 가공
    # ---------------------------------
    X_train, y_train, X_test_temp, y_test_temp = proc_smote(X_new, y_train)
    after_smote_cnt = X_train.shape

    # Evaluation 데이터 생성 및 가공
    # ---------------------------------
    X_train, X_eval = proc_normalization(X_train, X_eval.values)   


    # 최종 평가
    # --------
    proc_type='E'
    group_no=1
    # eval_auc = fit_predict(proc_type, drop_no, model_eval_comparison, X_train_for_evaluation, y_train_for_evaluation, X_eval, y_eval)
    eval_auc = fit_predict_eval(proc_type, drop_no, group_no, model_eval_comparison, X_train, y_train, X_eval, y_eval)
    
    if eval_auc > best_auc:
        best_type = f'{proc_type}_{drop_no}_{group_no}'
        best_auc = eval_auc
        


    # 최종 평가 로그 출력
    # ------------------
    cur_datetime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    end_time = time.time()
    delta_time = end_time - start_time
    # print(f'[평  가] {cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, AUC: {test_auc:0.6f}, 처리 건수: {len(eval_df)}, 최종 평가 건수: {len(X_eval)}')
    print(f'[평  가] {cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, [{proc_type}_{drop_no}_{group_no}], best-type: [{best_type}], Best-AUC: {best_auc:0.6f}, AUC: {eval_auc:0.6f}, tot_cnt: {tot_cnt}, after_drop_cnt: {after_drop_cnt}, after_smote_cnt: {after_smote_cnt}, X_train_cnt: {X_train_cnt}, drop_column: {drop_column}')


    # print_eval_result(model_eval_comparison)
# Out:
# [평  가] 2023-09-17 17:42:30, 0:00:06, [E_0_1], best-type: [E_0_1], Best-AUC: 0.989888, AUC: 0.989888, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 30), drop_column: ['sex']
# [평  가] 2023-09-17 17:42:37, 0:00:07, [E_1_1], best-type: [E_0_1], Best-AUC: 0.989888, AUC: 0.989881, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), X_train_cnt: (7293, 31), drop_column: ['imcome_cat']
# [평  가] 2023-09-17 17:42:44, 0:00:07, [E_2_1], best-type: [E_0_1], Best-AUC: 0.989888, AUC: 0.983981, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 31), drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 17:42:50, 0:00:06, [E_3_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.990320, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 31), drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 17:42:58, 0:00:07, [E_4_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.983387, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), X_train_cnt: (7293, 31), drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 17:43:04, 0:00:06, [E_5_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989818, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 31), drop_column: ['age']
# [평  가] 2023-09-17 17:43:11, 0:00:07, [E_6_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989935, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 31), drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 17:43:19, 0:00:08, [E_7_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.963252, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), X_train_cnt: (7293, 31), drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:43:28, 0:00:08, [E_8_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989888, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 29), drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 17:43:36, 0:00:08, [E_9_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.983374, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 14), X_train_cnt: (8101, 29), drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 17:43:44, 0:00:08, [E_10_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989103, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 29), drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 17:43:52, 0:00:07, [E_11_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.983757, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 14), X_train_cnt: (8101, 29), drop_column: ['sex', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 17:43:58, 0:00:06, [E_12_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989685, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 29), drop_column: ['sex', 'age']
# [평  가] 2023-09-17 17:44:04, 0:00:06, [E_13_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989659, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 29), drop_column: ['sex', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:44:11, 0:00:06, [E_14_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.961107, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 14), X_train_cnt: (8101, 29), drop_column: ['sex', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:44:17, 0:00:06, [E_15_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.983981, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 17:44:23, 0:00:06, [E_16_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.990320, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['imcome_cat', 'mean_util_pct']
# [평  가] 2023-09-17 17:44:29, 0:00:05, [E_17_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.984211, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['imcome_cat', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 17:44:35, 0:00:06, [E_18_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989818, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['imcome_cat', 'age']
# [평  가] 2023-09-17 17:44:42, 0:00:06, [E_19_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989935, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['imcome_cat', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:44:50, 0:00:07, [E_20_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.961587, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['imcome_cat', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:44:58, 0:00:07, [E_21_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.984214, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 30), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct']
# [평  가] 2023-09-17 17:45:06, 0:00:08, [E_22_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.971804, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 17:45:13, 0:00:06, [E_23_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.983297, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 30), drop_column: ['tot_amt_ratio_q4_q1', 'age']
# [평  가] 2023-09-17 17:45:20, 0:00:07, [E_24_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.982352, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['tot_amt_ratio_q4_q1', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:45:25, 0:00:05, [E_25_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.951056, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['tot_amt_ratio_q4_q1', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:45:33, 0:00:08, [E_26_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.983664, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 17:45:40, 0:00:06, [E_27_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989902, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['mean_util_pct', 'age']
# [평  가] 2023-09-17 17:45:49, 0:00:09, [E_28_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989856, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 30), drop_column: ['mean_util_pct', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:45:58, 0:00:09, [E_29_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.965715, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['mean_util_pct', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:46:07, 0:00:08, [E_30_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.983289, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['tot_trans_cnt_for_12m', 'age']
# [평  가] 2023-09-17 17:46:16, 0:00:08, [E_31_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.982560, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:46:24, 0:00:08, [E_32_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.914108, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:46:31, 0:00:06, [E_33_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989805, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 30), drop_column: ['age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:46:37, 0:00:06, [E_34_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.962275, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:46:44, 0:00:06, [E_35_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.964356, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), X_train_cnt: (7293, 30), drop_column: ['mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:46:51, 0:00:06, [E_36_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.984267, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 17:46:59, 0:00:07, [E_37_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989103, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 28), drop_column: ['sex', 'imcome_cat', 'mean_util_pct']
# [평  가] 2023-09-17 17:47:07, 0:00:08, [E_38_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.984614, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'imcome_cat', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 17:47:16, 0:00:09, [E_39_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989685, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'imcome_cat', 'age']
# [평  가] 2023-09-17 17:47:25, 0:00:08, [E_40_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989458, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 28), drop_column: ['sex', 'imcome_cat', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:47:34, 0:00:09, [E_41_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.958961, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'imcome_cat', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:47:40, 0:00:06, [E_42_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.981873, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'mean_util_pct']
# [평  가] 2023-09-17 17:47:47, 0:00:06, [E_43_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.974338, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 17:47:54, 0:00:06, [E_44_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.982650, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'age']
# [평  가] 2023-09-17 17:48:00, 0:00:06, [E_45_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.983086, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:48:07, 0:00:06, [E_46_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.949744, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:48:15, 0:00:08, [E_47_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.983336, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'mean_util_pct', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 17:48:24, 0:00:08, [E_48_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.988722, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 28), drop_column: ['sex', 'mean_util_pct', 'age']
# [평  가] 2023-09-17 17:48:32, 0:00:08, [E_49_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989307, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'mean_util_pct', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:48:40, 0:00:08, [E_50_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.962199, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'mean_util_pct', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:48:49, 0:00:08, [E_51_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.983430, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'tot_trans_cnt_for_12m', 'age']
# [평  가] 2023-09-17 17:48:54, 0:00:05, [E_52_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.984062, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:49:01, 0:00:06, [E_53_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.915808, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:49:08, 0:00:06, [E_54_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989901, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:49:15, 0:00:07, [E_55_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.958774, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:49:21, 0:00:06, [E_56_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.961213, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), X_train_cnt: (8101, 28), drop_column: ['sex', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:49:27, 0:00:06, [E_57_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.984214, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct']
# [평  가] 2023-09-17 17:49:34, 0:00:06, [E_58_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.971107, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 17:49:42, 0:00:08, [E_59_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.983297, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'age']
# [평  가] 2023-09-17 17:49:51, 0:00:08, [E_60_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.983237, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:49:59, 0:00:08, [E_61_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.949011, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:50:08, 0:00:08, [E_62_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.985014, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 17:50:15, 0:00:07, [E_63_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989605, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['imcome_cat', 'mean_util_pct', 'age']
# [평  가] 2023-09-17 17:50:21, 0:00:06, [E_64_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989856, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['imcome_cat', 'mean_util_pct', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:50:28, 0:00:07, [E_65_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.962383, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['imcome_cat', 'mean_util_pct', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:50:36, 0:00:07, [E_66_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.983279, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['imcome_cat', 'tot_trans_cnt_for_12m', 'age']
# [평  가] 2023-09-17 17:50:43, 0:00:06, [E_67_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.984630, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['imcome_cat', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:50:49, 0:00:06, [E_68_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.913815, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['imcome_cat', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:50:57, 0:00:07, [E_69_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.989805, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['imcome_cat', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:51:04, 0:00:07, [E_70_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.960277, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['imcome_cat', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:51:13, 0:00:08, [E_71_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.962646, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['imcome_cat', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:51:21, 0:00:08, [E_72_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.971460, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 17:51:30, 0:00:08, [E_73_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.983624, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct', 'age']
# [평  가] 2023-09-17 17:51:37, 0:00:07, [E_74_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.982211, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:51:46, 0:00:08, [E_75_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.952764, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:51:51, 0:00:05, [E_76_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.969325, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'age']
# [평  가] 2023-09-17 17:52:00, 0:00:08, [E_77_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.971467, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:52:07, 0:00:07, [E_78_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.900650, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:52:12, 0:00:05, [E_79_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.982886, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['tot_amt_ratio_q4_q1', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:52:19, 0:00:07, [E_80_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.950581, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['tot_amt_ratio_q4_q1', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:52:27, 0:00:07, [E_81_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.951346, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['tot_amt_ratio_q4_q1', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:52:35, 0:00:07, [E_82_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.984211, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'age']
# [평  가] 2023-09-17 17:52:43, 0:00:08, [E_83_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.984250, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:52:51, 0:00:07, [E_84_1], best-type: [E_3_1], Best-AUC: 0.990320, AUC: 0.915322, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:52:59, 0:00:07, [E_85_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.990331, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 29), drop_column: ['mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:53:06, 0:00:06, [E_86_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.963281, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['mean_util_pct', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:53:12, 0:00:06, [E_87_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.965614, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['mean_util_pct', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:53:18, 0:00:06, [E_88_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.982213, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:53:25, 0:00:06, [E_89_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.911445, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['tot_trans_cnt_for_12m', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:53:32, 0:00:06, [E_90_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.915251, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['tot_trans_cnt_for_12m', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:53:39, 0:00:07, [E_91_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.962450, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), X_train_cnt: (7293, 29), drop_column: ['age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:53:48, 0:00:08, [E_92_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.983293, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct']
# [평  가] 2023-09-17 17:53:56, 0:00:08, [E_93_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.975456, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 17:54:02, 0:00:06, [E_94_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.982935, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'age']
# [평  가] 2023-09-17 17:54:09, 0:00:06, [E_95_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.983536, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:54:15, 0:00:06, [E_96_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.944007, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:54:22, 0:00:06, [E_97_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.983649, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 17:54:29, 0:00:07, [E_98_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.988722, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'imcome_cat', 'mean_util_pct', 'age']
# [평  가] 2023-09-17 17:54:36, 0:00:07, [E_99_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.989096, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'imcome_cat', 'mean_util_pct', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:54:44, 0:00:08, [E_100_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.959042, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'imcome_cat', 'mean_util_pct', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:54:52, 0:00:08, [E_101_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.982227, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'imcome_cat', 'tot_trans_cnt_for_12m', 'age']
# [평  가] 2023-09-17 17:55:01, 0:00:08, [E_102_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.984027, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'imcome_cat', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:55:07, 0:00:06, [E_103_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.912478, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'imcome_cat', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:55:11, 0:00:04, [E_104_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.988835, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'imcome_cat', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:55:15, 0:00:04, [E_105_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.958465, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'imcome_cat', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:55:20, 0:00:04, [E_106_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.958731, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'imcome_cat', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:55:24, 0:00:04, [E_107_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.971500, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 17:55:28, 0:00:04, [E_108_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.982208, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'age']
# [평  가] 2023-09-17 17:55:32, 0:00:04, [E_109_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.981502, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:55:36, 0:00:04, [E_110_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.949301, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:55:41, 0:00:04, [E_111_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.971199, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'age']
# [평  가] 2023-09-17 17:55:45, 0:00:04, [E_112_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.972324, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:55:50, 0:00:05, [E_113_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.898291, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:55:54, 0:00:04, [E_114_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.983162, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:55:58, 0:00:04, [E_115_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.949873, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:56:05, 0:00:06, [E_116_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.948666, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:56:10, 0:00:05, [E_117_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.983586, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age']
# [평  가] 2023-09-17 17:56:14, 0:00:04, [E_118_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.984132, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:56:19, 0:00:05, [E_119_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.916303, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:56:24, 0:00:04, [E_120_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.988979, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:56:28, 0:00:04, [E_121_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.957912, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'mean_util_pct', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:56:32, 0:00:04, [E_122_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.964300, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'mean_util_pct', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:56:37, 0:00:04, [E_123_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.984924, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:56:41, 0:00:04, [E_124_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.914040, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'tot_trans_cnt_for_12m', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:56:46, 0:00:04, [E_125_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.915622, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'tot_trans_cnt_for_12m', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:56:50, 0:00:04, [E_126_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.959778, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), X_train_cnt: (8101, 27), drop_column: ['sex', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:56:54, 0:00:04, [E_127_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.973850, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 17:56:59, 0:00:04, [E_128_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.983061, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'age']
# [평  가] 2023-09-17 17:57:08, 0:00:08, [E_129_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.984038, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:57:16, 0:00:08, [E_130_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.952224, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:57:25, 0:00:08, [E_131_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.969916, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'age']
# [평  가] 2023-09-17 17:57:33, 0:00:08, [E_132_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.971296, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:57:42, 0:00:08, [E_133_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.897871, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:57:49, 0:00:07, [E_134_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.983707, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:57:57, 0:00:07, [E_135_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.946250, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:58:05, 0:00:07, [E_136_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.950460, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:58:12, 0:00:07, [E_137_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.983376, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age']
# [평  가] 2023-09-17 17:58:20, 0:00:07, [E_138_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.985377, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:58:27, 0:00:07, [E_139_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.913336, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:58:32, 0:00:05, [E_140_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.990331, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:58:37, 0:00:05, [E_141_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.962261, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'mean_util_pct', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:58:43, 0:00:05, [E_142_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.964815, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'mean_util_pct', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:58:48, 0:00:05, [E_143_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.984484, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:58:53, 0:00:05, [E_144_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.909868, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'tot_trans_cnt_for_12m', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:58:58, 0:00:05, [E_145_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.909175, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'tot_trans_cnt_for_12m', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:59:02, 0:00:03, [E_146_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.960889, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['imcome_cat', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:59:06, 0:00:03, [E_147_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.970864, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age']
# [평  가] 2023-09-17 17:59:10, 0:00:04, [E_148_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.972950, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:59:14, 0:00:03, [E_149_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.893010, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:59:18, 0:00:03, [E_150_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.982456, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:59:22, 0:00:03, [E_151_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.950944, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:59:25, 0:00:03, [E_152_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.955273, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:59:29, 0:00:03, [E_153_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.969048, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:59:34, 0:00:04, [E_154_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.894379, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:59:37, 0:00:03, [E_155_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.900416, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:59:41, 0:00:03, [E_156_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.951441, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['tot_amt_ratio_q4_q1', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:59:45, 0:00:04, [E_157_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.983005, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 17:59:50, 0:00:04, [E_158_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.913192, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:59:54, 0:00:04, [E_159_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.913729, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 17:59:58, 0:00:04, [E_160_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.963569, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['mean_util_pct', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:00:02, 0:00:04, [E_161_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.915133, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 11), X_train_cnt: (7293, 28), drop_column: ['tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:00:07, 0:00:04, [E_162_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.974457, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 11), X_train_cnt: (8101, 26), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:00:11, 0:00:04, [E_163_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.982294, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 11), X_train_cnt: (8101, 26), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'age']
# [평  가] 2023-09-17 18:00:15, 0:00:04, [E_164_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.983010, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 11), X_train_cnt: (8101, 26), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'mean_open_to_buy']
# [평  가] 2023-09-17 18:00:19, 0:00:04, [E_165_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.945453, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 11), X_train_cnt: (8101, 26), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:00:24, 0:00:04, [E_166_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.972995, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 11), X_train_cnt: (8101, 26), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'age']
# [평  가] 2023-09-17 18:00:28, 0:00:04, [E_167_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.974788, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 11), X_train_cnt: (8101, 26), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 18:00:32, 0:00:04, [E_168_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.893695, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 11), X_train_cnt: (8101, 26), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:00:36, 0:00:04, [E_169_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.983228, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 11), X_train_cnt: (8101, 26), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 18:00:40, 0:00:04, [E_170_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.945316, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 11), X_train_cnt: (8101, 26), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:00:44, 0:00:04, [E_171_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.945940, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 11), X_train_cnt: (8101, 26), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:00:49, 0:00:04, [E_172_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.983352, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 11), X_train_cnt: (8101, 26), drop_column: ['sex', 'imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age']
# [평  가] 2023-09-17 18:00:53, 0:00:04, [E_173_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.982310, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 11), X_train_cnt: (8101, 26), drop_column: ['sex', 'imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 18:00:58, 0:00:04, [E_174_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.909385, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 11), X_train_cnt: (8101, 26), drop_column: ['sex', 'imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:01:02, 0:00:04, [E_175_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.988572, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 11), X_train_cnt: (8101, 26), drop_column: ['sex', 'imcome_cat', 'mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 18:01:07, 0:00:05, [E_176_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.957529, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 11), X_train_cnt: (8101, 26), drop_column: ['sex', 'imcome_cat', 'mean_util_pct', 'age', 'tot_trans_amt_for_12m']
# ...
# [평  가] 2023-09-17 18:04:17, 0:00:05, [E_205_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.895281, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 10), X_train_cnt: (7293, 27), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:04:24, 0:00:06, [E_206_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.948228, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 10), X_train_cnt: (7293, 27), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:04:29, 0:00:05, [E_207_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.984538, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 10), X_train_cnt: (7293, 27), drop_column: ['imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 18:04:35, 0:00:05, [E_208_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.909708, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 10), X_train_cnt: (7293, 27), drop_column: ['imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:04:43, 0:00:07, [E_209_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.911857, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 10), X_train_cnt: (7293, 27), drop_column: ['imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:04:48, 0:00:05, [E_210_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.961348, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 10), X_train_cnt: (7293, 27), drop_column: ['imcome_cat', 'mean_util_pct', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:04:53, 0:00:05, [E_211_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.910921, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 10), X_train_cnt: (7293, 27), drop_column: ['imcome_cat', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:04:58, 0:00:05, [E_212_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.969199, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 10), X_train_cnt: (7293, 27), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 18:05:03, 0:00:05, [E_213_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.893328, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 10), X_train_cnt: (7293, 27), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:05:08, 0:00:04, [E_214_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.898645, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 10), X_train_cnt: (7293, 27), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:05:15, 0:00:06, [E_215_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.952078, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 10), X_train_cnt: (7293, 27), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:05:23, 0:00:07, [E_216_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.897994, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 10), X_train_cnt: (7293, 27), drop_column: ['tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:05:28, 0:00:04, [E_217_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.914330, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 10), X_train_cnt: (7293, 27), drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:05:36, 0:00:07, [E_218_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.972509, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age']
# [평  가] 2023-09-17 18:05:41, 0:00:05, [E_219_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.973147, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 18:05:47, 0:00:05, [E_220_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.894630, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:05:54, 0:00:07, [E_221_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.981610, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 18:06:02, 0:00:07, [E_222_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.944461, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:06:10, 0:00:07, [E_223_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.946093, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:06:18, 0:00:08, [E_224_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.972725, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 18:06:26, 0:00:07, [E_225_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.894712, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:06:34, 0:00:08, [E_226_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.894766, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:06:43, 0:00:08, [E_227_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.946230, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:06:51, 0:00:08, [E_228_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.983207, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 18:07:00, 0:00:08, [E_229_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.909123, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:07:09, 0:00:08, [E_230_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.909538, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:07:14, 0:00:05, [E_231_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.957961, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'imcome_cat', 'mean_util_pct', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:07:20, 0:00:05, [E_232_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.911182, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'imcome_cat', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:07:26, 0:00:05, [E_233_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.972106, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 18:07:31, 0:00:05, [E_234_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.897119, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:07:36, 0:00:05, [E_235_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.898087, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:07:42, 0:00:05, [E_236_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.947600, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:07:50, 0:00:08, [E_237_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.896167, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:07:55, 0:00:05, [E_238_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.909700, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 10), X_train_cnt: (8101, 25), drop_column: ['sex', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:08:00, 0:00:04, [E_239_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.973894, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 9), X_train_cnt: (7293, 26), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 18:08:06, 0:00:05, [E_240_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.894320, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 9), X_train_cnt: (7293, 26), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:08:13, 0:00:06, [E_241_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.899387, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 9), X_train_cnt: (7293, 26), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:08:18, 0:00:04, [E_242_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.949335, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 9), X_train_cnt: (7293, 26), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:08:23, 0:00:04, [E_243_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.895051, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 9), X_train_cnt: (7293, 26), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:08:28, 0:00:04, [E_244_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.909234, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 9), X_train_cnt: (7293, 26), drop_column: ['imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:08:32, 0:00:04, [E_245_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.899171, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 9), X_train_cnt: (7293, 26), drop_column: ['tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:08:37, 0:00:04, [E_246_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.971343, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 9), X_train_cnt: (8101, 24), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 18:08:42, 0:00:05, [E_247_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.894820, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 9), X_train_cnt: (8101, 24), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:08:48, 0:00:05, [E_248_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.892147, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 9), X_train_cnt: (8101, 24), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:08:54, 0:00:06, [E_249_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.944697, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 9), X_train_cnt: (8101, 24), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:08:59, 0:00:05, [E_250_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.896332, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 9), X_train_cnt: (8101, 24), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:09:07, 0:00:08, [E_251_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.907346, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 9), X_train_cnt: (8101, 24), drop_column: ['sex', 'imcome_cat', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:09:12, 0:00:05, [E_252_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.896676, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 9), X_train_cnt: (8101, 24), drop_column: ['sex', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:09:17, 0:00:04, [E_253_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.894306, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 8), X_train_cnt: (7293, 25), drop_column: ['imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:09:22, 0:00:05, [E_254_1], best-type: [E_85_1], Best-AUC: 0.990331, AUC: 0.890214, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 8), X_train_cnt: (8101, 23), drop_column: ['sex', 'imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m', 'age', 'mean_open_to_buy', 'tot_trans_amt_for_12m']

# %%
print_eval_result(model_eval_comparison)
# Out:
# <style type="text/css">
# #T_11703_row0_col0, #T_11703_row0_col1, #T_11703_row0_col2, #T_11703_row0_col3, #T_11703_row0_col4, #T_11703_row1_col0, #T_11703_row1_col1, #T_11703_row1_col2, #T_11703_row1_col3, #T_11703_row1_col4, #T_11703_row2_col0, #T_11703_row2_col1, #T_11703_row2_col2, #T_11703_row2_col3, #T_11703_row2_col4, #T_11703_row3_col0, #T_11703_row3_col1, #T_11703_row3_col2, #T_11703_row3_col3, #T_11703_row3_col4, #T_11703_row4_col0, #T_11703_row4_col1, #T_11703_row4_col2, #T_11703_row4_col3, #T_11703_row4_col4, #T_11703_row5_col0, #T_11703_row5_col1, #T_11703_row5_col2, #T_11703_row5_col3, #T_11703_row5_col4, #T_11703_row6_col2, #T_11703_row6_col4, #T_11703_row7_col0, #T_11703_row7_col1, #T_11703_row7_col3, #T_11703_row7_col4, #T_11703_row8_col0, #T_11703_row8_col1, #T_11703_row8_col2, #T_11703_row8_col3, #T_11703_row9_col0, #T_11703_row9_col1, #T_11703_row9_col2, #T_11703_row9_col3 {
#   color: black;
# }
# #T_11703_row0_col6, #T_11703_row1_col6, #T_11703_row7_col5 {
#   background-color: yellow;
# }
# #T_11703_row6_col0, #T_11703_row6_col1, #T_11703_row6_col3, #T_11703_row7_col2, #T_11703_row8_col4, #T_11703_row9_col4 {
#   background-color: yellow;
#   color: black;
# }
# </style>
# <table id="T_11703">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11703_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_11703_level0_col1" class="col_heading level0 col1" >Accuracy-No</th>
#       <th id="T_11703_level0_col2" class="col_heading level0 col2" >Accuracy-Yes</th>
#       <th id="T_11703_level0_col3" class="col_heading level0 col3" >F1-Score</th>
#       <th id="T_11703_level0_col4" class="col_heading level0 col4" >CV AUC</th>
#       <th id="T_11703_level0_col5" class="col_heading level0 col5" >CV std</th>
#       <th id="T_11703_level0_col6" class="col_heading level0 col6" >AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11703_level0_row0" class="row_heading level0 row0" >LightGBM_E_85_1</th>
#       <td id="T_11703_row0_col0" class="data row0 col0" >96.25%</td>
#       <td id="T_11703_row0_col1" class="data row0 col1" >97.88%</td>
#       <td id="T_11703_row0_col2" class="data row0 col2" >87.77%</td>
#       <td id="T_11703_row0_col3" class="data row0 col3" >96.24%</td>
#       <td id="T_11703_row0_col4" class="data row0 col4" >99.22%</td>
#       <td id="T_11703_row0_col5" class="data row0 col5" >0.014537</td>
#       <td id="T_11703_row0_col6" class="data row0 col6" >0.990331</td>
#     </tr>
#     <tr>
#       <th id="T_11703_level0_row1" class="row_heading level0 row1" >LightGBM_E_140_1</th>
#       <td id="T_11703_row1_col0" class="data row1 col0" >96.25%</td>
#       <td id="T_11703_row1_col1" class="data row1 col1" >97.88%</td>
#       <td id="T_11703_row1_col2" class="data row1 col2" >87.77%</td>
#       <td id="T_11703_row1_col3" class="data row1 col3" >96.24%</td>
#       <td id="T_11703_row1_col4" class="data row1 col4" >99.22%</td>
#       <td id="T_11703_row1_col5" class="data row1 col5" >0.014537</td>
#       <td id="T_11703_row1_col6" class="data row1 col6" >0.990331</td>
#     </tr>
#     <tr>
#       <th id="T_11703_level0_row2" class="row_heading level0 row2" >LightGBM_E_3_1</th>
#       <td id="T_11703_row2_col0" class="data row2 col0" >96.25%</td>
#       <td id="T_11703_row2_col1" class="data row2 col1" >97.76%</td>
#       <td id="T_11703_row2_col2" class="data row2 col2" >88.38%</td>
#       <td id="T_11703_row2_col3" class="data row2 col3" >96.25%</td>
#       <td id="T_11703_row2_col4" class="data row2 col4" >99.27%</td>
#       <td id="T_11703_row2_col5" class="data row2 col5" >0.013735</td>
#       <td id="T_11703_row2_col6" class="data row2 col6" >0.990320</td>
#     </tr>
#     <tr>
#       <th id="T_11703_level0_row3" class="row_heading level0 row3" >LightGBM_E_16_1</th>
#       <td id="T_11703_row3_col0" class="data row3 col0" >96.25%</td>
#       <td id="T_11703_row3_col1" class="data row3 col1" >97.76%</td>
#       <td id="T_11703_row3_col2" class="data row3 col2" >88.38%</td>
#       <td id="T_11703_row3_col3" class="data row3 col3" >96.25%</td>
#       <td id="T_11703_row3_col4" class="data row3 col4" >99.27%</td>
#       <td id="T_11703_row3_col5" class="data row3 col5" >0.013735</td>
#       <td id="T_11703_row3_col6" class="data row3 col6" >0.990320</td>
#     </tr>
#     <tr>
#       <th id="T_11703_level0_row4" class="row_heading level0 row4" >LightGBM_E_6_1</th>
#       <td id="T_11703_row4_col0" class="data row4 col0" >96.30%</td>
#       <td id="T_11703_row4_col1" class="data row4 col1" >97.70%</td>
#       <td id="T_11703_row4_col2" class="data row4 col2" >88.99%</td>
#       <td id="T_11703_row4_col3" class="data row4 col3" >96.30%</td>
#       <td id="T_11703_row4_col4" class="data row4 col4" >99.20%</td>
#       <td id="T_11703_row4_col5" class="data row4 col5" >0.014922</td>
#       <td id="T_11703_row4_col6" class="data row4 col6" >0.989935</td>
#     </tr>
#     <tr>
#       <th id="T_11703_level0_row5" class="row_heading level0 row5" >LightGBM_E_19_1</th>
#       <td id="T_11703_row5_col0" class="data row5 col0" >96.30%</td>
#       <td id="T_11703_row5_col1" class="data row5 col1" >97.70%</td>
#       <td id="T_11703_row5_col2" class="data row5 col2" >88.99%</td>
#       <td id="T_11703_row5_col3" class="data row5 col3" >96.30%</td>
#       <td id="T_11703_row5_col4" class="data row5 col4" >99.20%</td>
#       <td id="T_11703_row5_col5" class="data row5 col5" >0.014922</td>
#       <td id="T_11703_row5_col6" class="data row5 col6" >0.989935</td>
#     </tr>
#     <tr>
#       <th id="T_11703_level0_row6" class="row_heading level0 row6" >LightGBM_E_27_1</th>
#       <td id="T_11703_row6_col0" class="data row6 col0" >96.54%</td>
#       <td id="T_11703_row6_col1" class="data row6 col1" >97.94%</td>
#       <td id="T_11703_row6_col2" class="data row6 col2" >89.30%</td>
#       <td id="T_11703_row6_col3" class="data row6 col3" >96.54%</td>
#       <td id="T_11703_row6_col4" class="data row6 col4" >99.23%</td>
#       <td id="T_11703_row6_col5" class="data row6 col5" >0.014449</td>
#       <td id="T_11703_row6_col6" class="data row6 col6" >0.989902</td>
#     </tr>
#     <tr>
#       <th id="T_11703_level0_row7" class="row_heading level0 row7" >LightGBM_E_54_1</th>
#       <td id="T_11703_row7_col0" class="data row7 col0" >96.30%</td>
#       <td id="T_11703_row7_col1" class="data row7 col1" >97.47%</td>
#       <td id="T_11703_row7_col2" class="data row7 col2" >90.21%</td>
#       <td id="T_11703_row7_col3" class="data row7 col3" >96.32%</td>
#       <td id="T_11703_row7_col4" class="data row7 col4" >99.18%</td>
#       <td id="T_11703_row7_col5" class="data row7 col5" >0.015490</td>
#       <td id="T_11703_row7_col6" class="data row7 col6" >0.989901</td>
#     </tr>
#     <tr>
#       <th id="T_11703_level0_row8" class="row_heading level0 row8" >LightGBM_E_8_1</th>
#       <td id="T_11703_row8_col0" class="data row8 col0" >96.25%</td>
#       <td id="T_11703_row8_col1" class="data row8 col1" >97.53%</td>
#       <td id="T_11703_row8_col2" class="data row8 col2" >89.60%</td>
#       <td id="T_11703_row8_col3" class="data row8 col3" >96.27%</td>
#       <td id="T_11703_row8_col4" class="data row8 col4" >99.39%</td>
#       <td id="T_11703_row8_col5" class="data row8 col5" >0.011514</td>
#       <td id="T_11703_row8_col6" class="data row8 col6" >0.989888</td>
#     </tr>
#     <tr>
#       <th id="T_11703_level0_row9" class="row_heading level0 row9" >LightGBM_E_0_1</th>
#       <td id="T_11703_row9_col0" class="data row9 col0" >96.25%</td>
#       <td id="T_11703_row9_col1" class="data row9 col1" >97.53%</td>
#       <td id="T_11703_row9_col2" class="data row9 col2" >89.60%</td>
#       <td id="T_11703_row9_col3" class="data row9 col3" >96.27%</td>
#       <td id="T_11703_row9_col4" class="data row9 col4" >99.39%</td>
#       <td id="T_11703_row9_col5" class="data row9 col5" >0.011514</td>
#       <td id="T_11703_row9_col6" class="data row9 col6" >0.989888</td>
#     </tr>
#   </tbody>
# </table>
