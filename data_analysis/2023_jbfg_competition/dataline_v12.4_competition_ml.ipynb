# %% [markdown]
# # JBFG Data Analysis Competition

# %%
# #!pip install watermark
# %load_ext watermark
# %watermark -a 'DataLine' -nmv --packages numpy,pandas,sklearn,imblearn,tensorflow,plotly,matplotlib,seaborn,missingno,lightgbm

# %% [markdown]
# #### 컬럼 데이터 및 Null 건수 확인

# %% [markdown]
# ## Machine Learning
# ***

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np
from itertools import combinations
import time
import datetime
import joblib

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from lightgbm import LGBMClassifier, LGBMRegressor
from xgboost import XGBClassifier

from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.feature_selection import RFE
from sklearn.model_selection import cross_val_score, StratifiedKFold, GridSearchCV

from imblearn.over_sampling import SMOTE

# %% [markdown]
# ### Function Definition

# %% [markdown]
# #### encode_onehot()

# %%
# 원-핫 인코딩 처리 
# ----------------
def encode_onehot(df):
    '''
        데이터프레임의 object type 컬럼을 원-핫 인코딩하는 함수
        
        Args:
            df (df) : DataFrame
        Return:
            DataFrame
    '''
    catcols = df.select_dtypes(exclude = ['int64','float64']).columns
    df = pd.get_dummies(df, columns = catcols)
    
    return df

# %% [markdown]
# #### proc_split_smote()

# %%
def proc_split_smote(X_new, y):
    #Model Training
    from sklearn.model_selection import train_test_split
    from imblearn.over_sampling import SMOTE

    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.25, stratify=y, random_state=0)

    sm = SMOTE(sampling_strategy='auto', random_state=42)
    X_train, y_train=sm.fit_resample(X_train,y_train)
    
    return X_train, y_train, X_test, y_test

# %% [markdown]
# #### proc_feature_split()

# %%
def proc_feature_split(X_data, y_data):
    #Model Training
    from sklearn.model_selection import train_test_split
    from imblearn.over_sampling import SMOTE

    # 전체 데이터 중 80%는 학습용 데이터, 20%는 테스트용 데이터 추출
    print(f'[proc_feature_split()] X_data: {X_data.shape}, y_data: {y_data.shape}')
    X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, stratify=y_data, random_state=0)


    # 위에서 만든 X_train, y_train을 다시 쪼개서 90%는 학습과 10%는 검증용 데이터로 분리  
    X_tr, X_val, y_tr, y_val= train_test_split(X_train, y_train, test_size=0.1, stratify=y_train, random_state=0)

    print(f'[proc_feature_split()] X_tr: {X_tr.shape}, y_tr: {y_tr.shape}, X_val: {X_val.shape}, y_val: {y_val.shape}, X_test: {X_test.shape}, y_test: {y_test.shape}')
    return X_tr, y_tr, X_val, y_val, X_test, y_test

# %% [markdown]
# #### proc_smote()

# %%
def proc_smote(X_data, y_data):

    sm = SMOTE(sampling_strategy='auto', random_state=42)
    X_data, y_data = sm.fit_resample(X_data, y_data)
    
    return X_data, y_data

# %% [markdown]
# #### proc_normalization()

# %%
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer

def proc_normalization(X_train, X_val, X_test, X_eval):
    scaler  = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val  = scaler.transform(X_val)
    X_test  = scaler.transform(X_test)
    X_eval  = scaler.transform(X_eval)
    
    return X_train, X_val, X_test, X_eval

# %% [markdown]
# #### select_feature()

# %%
# 중요 Feature 식별
# ----------------
def select_feature(df, y_labels, chosen_model):

    np.random.seed(42)    
    
    available_models = {
    'ExtraTrees': ExtraTreesClassifier(n_estimators=700),
    'RandomForest': RandomForestClassifier(n_estimators=700),
    'LGBMC': LGBMClassifier(n_estimators=700, random_state=42, boosting_type='GOSS'),
    'LGBMR': LGBMRegressor(),
    'Xg Boost':XGBClassifier(booster='gbtree', importance_type='gain', eval_metric='auc'),
    }

    # Create the selected model
    clf = available_models[chosen_model]

    clf = clf.fit(df, y_labels)                                     # Train

    if chosen_model == 'LGBMC' or chosen_model == 'LGBMR': 
        feature_importances = clf.booster_.feature_importance(importance_type="gain")
    else:        
        feature_importances = clf.feature_importances_


    chosen_model = SelectFromModel(clf, prefit=True)
    X_df = chosen_model.transform(df.values) 
    selected_feature_indices = chosen_model.get_support(indices=True)

    selected_columns = df.columns[selected_feature_indices]         # Get the indices of the selected features
    
    return X_df, selected_columns

# %% [markdown]
# #### fit_predict_eval()

# %%
# 예측 및 평가
# -----------
def fit_predict_eval(models, model_comparison, X_train, y_train, X_val, y_val, X_test, y_test):
   
    # 초기화
    # ------
    best_roc_auc = 0
    
    # Define Models
    # ------------- 
    # No: 1 origin
    # models = [
    #     ('LogisticRegression', LogisticRegression()),
    #     ('DecisionTree', DecisionTreeClassifier(criterion='entropy', random_state=0)),
    #     ('ExtraTrees', ExtraTreesClassifier(n_estimators=700)),
    #     ('KNN', KNeighborsClassifier(n_neighbors=5)),
    #     ('NaiveBayes', GaussianNB()),
    #     ('RandomForest', RandomForestClassifier(n_estimators=700, criterion='entropy', random_state=0)),
    #     ('LightGBM', LGBMClassifier(n_estimators=700, random_state=42, boosting_type='GOSS')),
    #     ('XgBoost', XGBClassifier(n_estimators=700, random_state=42, eval_metric='auc')),
    # ]

    
    # Model Fit and Testing
    # ---------------------
    for model_name, classifier in models:
        start_time = time.time()


        # 학습
        # ----            
        classifier.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)])
        
        
        # 학습된 모델 저장하기 - 필요한 경우 향후 사용할 예정
        # -----------------------------------------------
        # file_name = f'./models/{model_name}.pkl'
        # joblib.dump(classifier, file_name)


        # 예측
        # ---- 
        y_pred = classifier.predict(X_test)


        # 평가
        # ---- 
        accuracy = accuracy_score(y_test, y_pred)
        accuracy_class_0 = accuracy_score(y_test[y_test == 0], y_pred[y_test == 0])
        accuracy_class_1 = accuracy_score(y_test[y_test == 1], y_pred[y_test == 1], )

        precision = precision_score(y_test , y_pred)
        recall = recall_score(y_test , y_pred)
        f1 = f1_score(y_test, y_pred)
        
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
        auces = cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=skf, scoring="roc_auc")
        cv_auc = auces.mean()
        cv_std = auces.std()
        
        pred_proba = classifier.predict_proba(X_test)[:, 1]        
        roc_auc = roc_auc_score(y_test, pred_proba)
        
        
        # 예측 평가 결과 저장
        # -----------------
        model_comparison[f'{model_name}'] = [accuracy, accuracy_class_0, accuracy_class_1, precision, recall, f1, cv_auc, cv_std, roc_auc]
        
        
        # Best ROC_AUC Value Return
        # -------------------------
        if roc_auc > best_roc_auc:
            best_roc_auc = roc_auc
            
        
        # Print Log
        # ---------    
        cur_datetime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        end_time = time.time()
        delta_time = end_time - start_time
        print(f'Model Name: [{model_name:<18}], {cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]},  BEST AUC: {best_roc_auc:0.6f}, AUC: {roc_auc:0.6f}')

# %% [markdown]
# #### print_eval_result()

# %%
def print_eval_result(model_comparison):

    # # MODEL COMPARISSON
    # Model_com_df=pd.DataFrame(model_comparison).T
    # Model_com_df.columns=['Accuracy','Accuracy-0','Accuracy-1', 'Precision', 'Recall', 'F1-Score','CV AUC','CV std', 'AUC']
    # Model_com_df=Model_com_df.sort_values(by='AUC',ascending=False)
    # # display(Model_com_df.style.format("{:.2%}").background_gradient(cmap='magma'))

    Model_com_df = pd.DataFrame(model_comparison).T
    Model_com_df.columns = ['Accuracy', 'Accuracy-No', 'Accuracy-Yes', 'Precision', 'Recall', 'F1-Score', 'CV AUC', 'CV std', 'AUC']
    Model_com_df = Model_com_df.sort_values(by='AUC', ascending=False)

    def highlight_below_75(s):
        if s.name != 'CV std' and isinstance(s, pd.Series) and s.dtype == 'float64':
            return ['color: red' if value < 0.75 else 'color: black' for value in s]
        else:
            return ['color: black'] * len(s)

    # styled_df = Model_com_df.iloc[:10,:].style.highlight_max(axis=0).apply(highlight_below_75, subset=pd.IndexSlice[:, :'CV AUC']).format("{:.2%}", subset=pd.IndexSlice[:, :'CV AUC'])
    styled_df = Model_com_df.style.highlight_max(axis=0).apply(highlight_below_75, subset=pd.IndexSlice[:, :'CV AUC']).format("{:.2%}", subset=pd.IndexSlice[:, :'CV AUC'])
    display(styled_df)

# %% [markdown]
# #### data_transform()

# %%
def data_transform(df):

    # 데이터 변환
    # ------------------- 
    df = df.drop('cstno', axis=1)
    df = df.drop('sex', axis=1)
    df['imcome_cat']=df['imcome_cat'].replace({'Less than $40K':40000, '$40K - $60K':50000, '$60K - $80K':70000, '$80K - $120K':100000, '$120K +':120000, 'Unknown':63000})

   
    # 결측치 처리
    # ----------
    # df = df.fillna(df.mean(numeric_only=True))
    df = df.groupby(['marital_stat']).apply(lambda x: x.fillna(x.mean(numeric_only=True)))
    df = df.reset_index(drop=True)
    df.dropna(axis=0, inplace=True)


    # One-Hot Encoding
    # ----------------
    df = encode_onehot(df)     
    
    return df

# %% [markdown]
# #### test_transform()

# %%
def test_transform(source_df, eval_df):

    # 데이터 변환
    # -----------
    source_df = data_transform(source_df)
    eval_df = data_transform(eval_df)

        
    # 테스트 및 평가를 위한 데이터 분리
    # -------------------------------
    X_Features = source_df.drop(['is_churned'], axis=1)
    y_labels = source_df['is_churned']

    X_eval=eval_df.drop(['is_churned'], axis=1)
    y_eval=eval_df['is_churned']


    # 중요 Feature Column 선택
    # -----------------------
    X_Features_new, selected_columns = select_feature(X_Features, y_labels, 'RandomForest')
    X_eval = X_eval[selected_columns]


    # Train, Validation, Test 데이터 Split
    # ------------------------------------
    # X_train, y_train, X_test, y_test = proc_split_smote(X_Features_new, y_labels.values)
    X_train, y_train, X_val, y_val, X_test, y_test = proc_feature_split(X_Features_new, y_labels.values)


    # SMOTE 적용
    # ---------------------------------
    X_train, y_train = proc_smote(X_train, y_train)


    # Normalization ~ StandardScaler 적용
    # -----------------------------------
    X_train, X_val, X_test, X_eval = proc_normalization(X_train, X_val, X_test, X_eval.values) 
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_eval, y_eval

# %% [markdown]
# ### 학습 및 Test 평가

# %% [markdown]
# #### 데이터 로딩 및 초기화

# %%
# 경진대회를 위해 주최측에서 제공한 데이터(EDA 및 ML 학습을 위한 데이터)
bank_churner_df = pd.read_csv("./data/bank_churner.csv")


 # 평가를 위한 데이터 로드 - 평가자님 평가데이터 경로를 입력해 주세요!!! - 평가 결과는 평가결과 출력을 확인
eval_churner_df = pd.read_csv("./data/eval_churner.csv")

# %% [markdown]
# #### 초기화 및 전처리

# %%
# 평가결과 저장소 초기화
# --------------------
model_test_comparison = {}                        
model_eval_comparison = {}                        


# 사용할 모델 정의
models = [
    # ('LogisticRegression', LogisticRegression(random_state=42)),
    # ('DecisionTree', DecisionTreeClassifier(criterion='entropy', random_state=42)),
    # ('ExtraTrees', ExtraTreesClassifier(n_estimators=700, random_state=42)),
    # ('RandomForest', RandomForestClassifier(n_estimators=700, criterion='entropy', random_state=42)),
    # ('KNN', KNeighborsClassifier(n_neighbors=5)),
    # ('NaiveBayes', GaussianNB()),
    ('XgBoost', XGBClassifier(n_estimators=700, random_state=42, eval_metric='auc')),
    ('LightGBM', LGBMClassifier(n_estimators=700, random_state=42, boosting_type='GOSS')),
    # ('XgBoost', XGBClassifier(n_estimators=700, random_state=42, eval_metric='auc')),
    # ('LightGBM', LGBMClassifier(n_estimators=700, random_state=42, boosting_type='GOSS')),
    
]

# 전처리 
# -----
X_train, y_train, X_val, y_val, X_test, y_test, X_eval, y_eval = test_transform(bank_churner_df, eval_churner_df)
# Out:
# [proc_feature_split()] X_data: (8101, 13), y_data: (8101,)
# [proc_feature_split()] X_tr: (5832, 13), y_tr: (5832,), X_val: (648, 13), y_val: (648,), X_test: (1621, 13), y_test: (1621,)

# %% [markdown]
# #### 예측 및 결과

# %%
# Pridict 및 Test 평가
# --------------------
fit_predict_eval(models, model_test_comparison, X_train, y_train, X_val, y_val, X_test, y_test)

# print_eval_result(model_test_comparison)
# Out:
# [0]	validation_0-auc:0.94274	validation_1-auc:0.90440
# [1]	validation_0-auc:0.96669	validation_1-auc:0.91648
# [2]	validation_0-auc:0.97349	validation_1-auc:0.91967
# [3]	validation_0-auc:0.98001	validation_1-auc:0.93116
# [4]	validation_0-auc:0.98526	validation_1-auc:0.93675
# [5]	validation_0-auc:0.98938	validation_1-auc:0.94309
# [6]	validation_0-auc:0.99051	validation_1-auc:0.94785
# [7]	validation_0-auc:0.99197	validation_1-auc:0.94842
# [8]	validation_0-auc:0.99262	validation_1-auc:0.95158
# [9]	validation_0-auc:0.99350	validation_1-auc:0.95417
# [10]	validation_0-auc:0.99460	validation_1-auc:0.95583
# [11]	validation_0-auc:0.99525	validation_1-auc:0.95770
# [12]	validation_0-auc:0.99539	validation_1-auc:0.95993
# [13]	validation_0-auc:0.99568	validation_1-auc:0.96046
# [14]	validation_0-auc:0.99612	validation_1-auc:0.96400
# [15]	validation_0-auc:0.99643	validation_1-auc:0.96603
# [16]	validation_0-auc:0.99673	validation_1-auc:0.96651
# [17]	validation_0-auc:0.99703	validation_1-auc:0.96769
# [18]	validation_0-auc:0.99719	validation_1-auc:0.96939
# [19]	validation_0-auc:0.99735	validation_1-auc:0.96967
# [20]	validation_0-auc:0.99747	validation_1-auc:0.97016
# [21]	validation_0-auc:0.99751	validation_1-auc:0.97045
# [22]	validation_0-auc:0.99776	validation_1-auc:0.96986
# [23]	validation_0-auc:0.99786	validation_1-auc:0.97055
# [24]	validation_0-auc:0.99810	validation_1-auc:0.97076
# [25]	validation_0-auc:0.99819	validation_1-auc:0.97107
# [26]	validation_0-auc:0.99822	validation_1-auc:0.97151
# [27]	validation_0-auc:0.99844	validation_1-auc:0.97138
# [28]	validation_0-auc:0.99856	validation_1-auc:0.97179
# [29]	validation_0-auc:0.99871	validation_1-auc:0.97133
# [30]	validation_0-auc:0.99884	validation_1-auc:0.97133
# [31]	validation_0-auc:0.99892	validation_1-auc:0.97188
# [32]	validation_0-auc:0.99902	validation_1-auc:0.97137
# [33]	validation_0-auc:0.99916	validation_1-auc:0.97075
# [34]	validation_0-auc:0.99917	validation_1-auc:0.97126
# [35]	validation_0-auc:0.99918	validation_1-auc:0.97156
# [36]	validation_0-auc:0.99924	validation_1-auc:0.97188
# [37]	validation_0-auc:0.99930	validation_1-auc:0.97110
# [38]	validation_0-auc:0.99934	validation_1-auc:0.97163
# [39]	validation_0-auc:0.99936	validation_1-auc:0.97236
# [40]	validation_0-auc:0.99944	validation_1-auc:0.97283
# [41]	validation_0-auc:0.99949	validation_1-auc:0.97299
# [42]	validation_0-auc:0.99950	validation_1-auc:0.97282
# [43]	validation_0-auc:0.99954	validation_1-auc:0.97167
# [44]	validation_0-auc:0.99956	validation_1-auc:0.97223
# [45]	validation_0-auc:0.99958	validation_1-auc:0.97225
# [46]	validation_0-auc:0.99960	validation_1-auc:0.97250
# [47]	validation_0-auc:0.99962	validation_1-auc:0.97220
# [48]	validation_0-auc:0.99963	validation_1-auc:0.97237
# [49]	validation_0-auc:0.99965	validation_1-auc:0.97213
# [50]	validation_0-auc:0.99966	validation_1-auc:0.97133
# [51]	validation_0-auc:0.99967	validation_1-auc:0.97186
# [52]	validation_0-auc:0.99968	validation_1-auc:0.97195
# [53]	validation_0-auc:0.99968	validation_1-auc:0.97209
# [54]	validation_0-auc:0.99971	validation_1-auc:0.97149
# [55]	validation_0-auc:0.99972	validation_1-auc:0.97138
# [56]	validation_0-auc:0.99972	validation_1-auc:0.97161
# [57]	validation_0-auc:0.99974	validation_1-auc:0.97234
# [58]	validation_0-auc:0.99979	validation_1-auc:0.97246
# [59]	validation_0-auc:0.99982	validation_1-auc:0.97200
# [60]	validation_0-auc:0.99982	validation_1-auc:0.97119
# [61]	validation_0-auc:0.99984	validation_1-auc:0.97160
# [62]	validation_0-auc:0.99985	validation_1-auc:0.97156
# [63]	validation_0-auc:0.99987	validation_1-auc:0.97142
# [64]	validation_0-auc:0.99988	validation_1-auc:0.97122
# [65]	validation_0-auc:0.99990	validation_1-auc:0.97153
# [66]	validation_0-auc:0.99991	validation_1-auc:0.97161
# [67]	validation_0-auc:0.99993	validation_1-auc:0.97142
# [68]	validation_0-auc:0.99994	validation_1-auc:0.97163
# [69]	validation_0-auc:0.99994	validation_1-auc:0.97206
# [70]	validation_0-auc:0.99994	validation_1-auc:0.97177
# [71]	validation_0-auc:0.99995	validation_1-auc:0.97170
# [72]	validation_0-auc:0.99995	validation_1-auc:0.97137
# [73]	validation_0-auc:0.99996	validation_1-auc:0.97151
# [74]	validation_0-auc:0.99996	validation_1-auc:0.97059
# [75]	validation_0-auc:0.99997	validation_1-auc:0.97075
# [76]	validation_0-auc:0.99997	validation_1-auc:0.97110
# [77]	validation_0-auc:0.99998	validation_1-auc:0.97115
# [78]	validation_0-auc:0.99998	validation_1-auc:0.97101
# [79]	validation_0-auc:0.99999	validation_1-auc:0.97110
# [80]	validation_0-auc:0.99999	validation_1-auc:0.97135
# [81]	validation_0-auc:0.99999	validation_1-auc:0.97211
# [82]	validation_0-auc:0.99999	validation_1-auc:0.97186
# [83]	validation_0-auc:0.99999	validation_1-auc:0.97154
# [84]	validation_0-auc:0.99999	validation_1-auc:0.97213
# [85]	validation_0-auc:1.00000	validation_1-auc:0.97229
# [86]	validation_0-auc:1.00000	validation_1-auc:0.97244
# [87]	validation_0-auc:1.00000	validation_1-auc:0.97255
# [88]	validation_0-auc:1.00000	validation_1-auc:0.97225
# [89]	validation_0-auc:1.00000	validation_1-auc:0.97177
# [90]	validation_0-auc:1.00000	validation_1-auc:0.97181
# [91]	validation_0-auc:1.00000	validation_1-auc:0.97175
# [92]	validation_0-auc:1.00000	validation_1-auc:0.97216
# [93]	validation_0-auc:1.00000	validation_1-auc:0.97232
# [94]	validation_0-auc:1.00000	validation_1-auc:0.97274
# [95]	validation_0-auc:1.00000	validation_1-auc:0.97340
# [96]	validation_0-auc:1.00000	validation_1-auc:0.97301
# [97]	validation_0-auc:1.00000	validation_1-auc:0.97305
# [98]	validation_0-auc:1.00000	validation_1-auc:0.97310
# [99]	validation_0-auc:1.00000	validation_1-auc:0.97306
# [100]	validation_0-auc:1.00000	validation_1-auc:0.97312
# [101]	validation_0-auc:1.00000	validation_1-auc:0.97310
# [102]	validation_0-auc:1.00000	validation_1-auc:0.97335
# [103]	validation_0-auc:1.00000	validation_1-auc:0.97352
# [104]	validation_0-auc:1.00000	validation_1-auc:0.97361
# [105]	validation_0-auc:1.00000	validation_1-auc:0.97297
# [106]	validation_0-auc:1.00000	validation_1-auc:0.97324
# [107]	validation_0-auc:1.00000	validation_1-auc:0.97301
# [108]	validation_0-auc:1.00000	validation_1-auc:0.97313
# [109]	validation_0-auc:1.00000	validation_1-auc:0.97336
# [110]	validation_0-auc:1.00000	validation_1-auc:0.97373
# [111]	validation_0-auc:1.00000	validation_1-auc:0.97370
# [112]	validation_0-auc:1.00000	validation_1-auc:0.97386
# [113]	validation_0-auc:1.00000	validation_1-auc:0.97395
# [114]	validation_0-auc:1.00000	validation_1-auc:0.97393
# [115]	validation_0-auc:1.00000	validation_1-auc:0.97398
# [116]	validation_0-auc:1.00000	validation_1-auc:0.97381
# [117]	validation_0-auc:1.00000	validation_1-auc:0.97409
# [118]	validation_0-auc:1.00000	validation_1-auc:0.97416
# [119]	validation_0-auc:1.00000	validation_1-auc:0.97418
# [120]	validation_0-auc:1.00000	validation_1-auc:0.97400
# [121]	validation_0-auc:1.00000	validation_1-auc:0.97405
# [122]	validation_0-auc:1.00000	validation_1-auc:0.97405
# [123]	validation_0-auc:1.00000	validation_1-auc:0.97425
# [124]	validation_0-auc:1.00000	validation_1-auc:0.97437
# [125]	validation_0-auc:1.00000	validation_1-auc:0.97405
# [126]	validation_0-auc:1.00000	validation_1-auc:0.97402
# [127]	validation_0-auc:1.00000	validation_1-auc:0.97432
# [128]	validation_0-auc:1.00000	validation_1-auc:0.97448
# [129]	validation_0-auc:1.00000	validation_1-auc:0.97412
# [130]	validation_0-auc:1.00000	validation_1-auc:0.97449
# [131]	validation_0-auc:1.00000	validation_1-auc:0.97451
# [132]	validation_0-auc:1.00000	validation_1-auc:0.97439
# [133]	validation_0-auc:1.00000	validation_1-auc:0.97409
# [134]	validation_0-auc:1.00000	validation_1-auc:0.97393
# [135]	validation_0-auc:1.00000	validation_1-auc:0.97361
# [136]	validation_0-auc:1.00000	validation_1-auc:0.97361
# [137]	validation_0-auc:1.00000	validation_1-auc:0.97379
# [138]	validation_0-auc:1.00000	validation_1-auc:0.97377
# [139]	validation_0-auc:1.00000	validation_1-auc:0.97349
# [140]	validation_0-auc:1.00000	validation_1-auc:0.97354
# [141]	validation_0-auc:1.00000	validation_1-auc:0.97381
# [142]	validation_0-auc:1.00000	validation_1-auc:0.97373
# [143]	validation_0-auc:1.00000	validation_1-auc:0.97377
# [144]	validation_0-auc:1.00000	validation_1-auc:0.97388
# [145]	validation_0-auc:1.00000	validation_1-auc:0.97384
# [146]	validation_0-auc:1.00000	validation_1-auc:0.97412
# [147]	validation_0-auc:1.00000	validation_1-auc:0.97451
# [148]	validation_0-auc:1.00000	validation_1-auc:0.97457
# [149]	validation_0-auc:1.00000	validation_1-auc:0.97457
# [150]	validation_0-auc:1.00000	validation_1-auc:0.97453
# [151]	validation_0-auc:1.00000	validation_1-auc:0.97469
# [152]	validation_0-auc:1.00000	validation_1-auc:0.97464
# [153]	validation_0-auc:1.00000	validation_1-auc:0.97439
# [154]	validation_0-auc:1.00000	validation_1-auc:0.97451
# [155]	validation_0-auc:1.00000	validation_1-auc:0.97455
# [156]	validation_0-auc:1.00000	validation_1-auc:0.97425
# [157]	validation_0-auc:1.00000	validation_1-auc:0.97449
# [158]	validation_0-auc:1.00000	validation_1-auc:0.97439
# [159]	validation_0-auc:1.00000	validation_1-auc:0.97446
# [160]	validation_0-auc:1.00000	validation_1-auc:0.97465
# [161]	validation_0-auc:1.00000	validation_1-auc:0.97469
# [162]	validation_0-auc:1.00000	validation_1-auc:0.97472
# [163]	validation_0-auc:1.00000	validation_1-auc:0.97462
# [164]	validation_0-auc:1.00000	validation_1-auc:0.97451
# [165]	validation_0-auc:1.00000	validation_1-auc:0.97485
# [166]	validation_0-auc:1.00000	validation_1-auc:0.97497
# [167]	validation_0-auc:1.00000	validation_1-auc:0.97490
# [168]	validation_0-auc:1.00000	validation_1-auc:0.97495
# [169]	validation_0-auc:1.00000	validation_1-auc:0.97476
# [170]	validation_0-auc:1.00000	validation_1-auc:0.97506
# [171]	validation_0-auc:1.00000	validation_1-auc:0.97502
# [172]	validation_0-auc:1.00000	validation_1-auc:0.97501
# [173]	validation_0-auc:1.00000	validation_1-auc:0.97487
# [174]	validation_0-auc:1.00000	validation_1-auc:0.97499
# [175]	validation_0-auc:1.00000	validation_1-auc:0.97479
# [176]	validation_0-auc:1.00000	validation_1-auc:0.97479
# [177]	validation_0-auc:1.00000	validation_1-auc:0.97478
# [178]	validation_0-auc:1.00000	validation_1-auc:0.97464
# [179]	validation_0-auc:1.00000	validation_1-auc:0.97467
# [180]	validation_0-auc:1.00000	validation_1-auc:0.97453
# [181]	validation_0-auc:1.00000	validation_1-auc:0.97439
# [182]	validation_0-auc:1.00000	validation_1-auc:0.97442
# [183]	validation_0-auc:1.00000	validation_1-auc:0.97455
# [184]	validation_0-auc:1.00000	validation_1-auc:0.97448
# [185]	validation_0-auc:1.00000	validation_1-auc:0.97448
# [186]	validation_0-auc:1.00000	validation_1-auc:0.97441
# [187]	validation_0-auc:1.00000	validation_1-auc:0.97442
# [188]	validation_0-auc:1.00000	validation_1-auc:0.97444
# [189]	validation_0-auc:1.00000	validation_1-auc:0.97411
# [190]	validation_0-auc:1.00000	validation_1-auc:0.97412
# [191]	validation_0-auc:1.00000	validation_1-auc:0.97403
# [192]	validation_0-auc:1.00000	validation_1-auc:0.97416
# [193]	validation_0-auc:1.00000	validation_1-auc:0.97416
# [194]	validation_0-auc:1.00000	validation_1-auc:0.97395
# [195]	validation_0-auc:1.00000	validation_1-auc:0.97393
# [196]	validation_0-auc:1.00000	validation_1-auc:0.97398
# [197]	validation_0-auc:1.00000	validation_1-auc:0.97396
# [198]	validation_0-auc:1.00000	validation_1-auc:0.97388
# [199]	validation_0-auc:1.00000	validation_1-auc:0.97388
# [200]	validation_0-auc:1.00000	validation_1-auc:0.97395
# [201]	validation_0-auc:1.00000	validation_1-auc:0.97393
# [202]	validation_0-auc:1.00000	validation_1-auc:0.97366
# [203]	validation_0-auc:1.00000	validation_1-auc:0.97377
# [204]	validation_0-auc:1.00000	validation_1-auc:0.97350
# [205]	validation_0-auc:1.00000	validation_1-auc:0.97361
# [206]	validation_0-auc:1.00000	validation_1-auc:0.97368
# [207]	validation_0-auc:1.00000	validation_1-auc:0.97372
# [208]	validation_0-auc:1.00000	validation_1-auc:0.97372
# [209]	validation_0-auc:1.00000	validation_1-auc:0.97347
# [210]	validation_0-auc:1.00000	validation_1-auc:0.97358
# [211]	validation_0-auc:1.00000	validation_1-auc:0.97358
# [212]	validation_0-auc:1.00000	validation_1-auc:0.97365
# [213]	validation_0-auc:1.00000	validation_1-auc:0.97354
# [214]	validation_0-auc:1.00000	validation_1-auc:0.97340
# [215]	validation_0-auc:1.00000	validation_1-auc:0.97340
# [216]	validation_0-auc:1.00000	validation_1-auc:0.97326
# [217]	validation_0-auc:1.00000	validation_1-auc:0.97315
# [218]	validation_0-auc:1.00000	validation_1-auc:0.97320
# [219]	validation_0-auc:1.00000	validation_1-auc:0.97319
# [220]	validation_0-auc:1.00000	validation_1-auc:0.97327
# [221]	validation_0-auc:1.00000	validation_1-auc:0.97345
# [222]	validation_0-auc:1.00000	validation_1-auc:0.97352
# [223]	validation_0-auc:1.00000	validation_1-auc:0.97361
# [224]	validation_0-auc:1.00000	validation_1-auc:0.97363
# [225]	validation_0-auc:1.00000	validation_1-auc:0.97373
# [226]	validation_0-auc:1.00000	validation_1-auc:0.97368
# [227]	validation_0-auc:1.00000	validation_1-auc:0.97384
# [228]	validation_0-auc:1.00000	validation_1-auc:0.97384
# [229]	validation_0-auc:1.00000	validation_1-auc:0.97382
# [230]	validation_0-auc:1.00000	validation_1-auc:0.97379
# [231]	validation_0-auc:1.00000	validation_1-auc:0.97389
# [232]	validation_0-auc:1.00000	validation_1-auc:0.97389
# [233]	validation_0-auc:1.00000	validation_1-auc:0.97396
# [234]	validation_0-auc:1.00000	validation_1-auc:0.97389
# [235]	validation_0-auc:1.00000	validation_1-auc:0.97396
# [236]	validation_0-auc:1.00000	validation_1-auc:0.97381
# [237]	validation_0-auc:1.00000	validation_1-auc:0.97366
# [238]	validation_0-auc:1.00000	validation_1-auc:0.97356
# [239]	validation_0-auc:1.00000	validation_1-auc:0.97356
# [240]	validation_0-auc:1.00000	validation_1-auc:0.97352
# [241]	validation_0-auc:1.00000	validation_1-auc:0.97331
# [242]	validation_0-auc:1.00000	validation_1-auc:0.97340
# [243]	validation_0-auc:1.00000	validation_1-auc:0.97326
# [244]	validation_0-auc:1.00000	validation_1-auc:0.97331
# [245]	validation_0-auc:1.00000	validation_1-auc:0.97336
# [246]	validation_0-auc:1.00000	validation_1-auc:0.97343
# [247]	validation_0-auc:1.00000	validation_1-auc:0.97342
# [248]	validation_0-auc:1.00000	validation_1-auc:0.97326
# [249]	validation_0-auc:1.00000	validation_1-auc:0.97331
# [250]	validation_0-auc:1.00000	validation_1-auc:0.97340
# [251]	validation_0-auc:1.00000	validation_1-auc:0.97331
# [252]	validation_0-auc:1.00000	validation_1-auc:0.97342
# [253]	validation_0-auc:1.00000	validation_1-auc:0.97338
# [254]	validation_0-auc:1.00000	validation_1-auc:0.97343
# [255]	validation_0-auc:1.00000	validation_1-auc:0.97349
# [256]	validation_0-auc:1.00000	validation_1-auc:0.97342
# [257]	validation_0-auc:1.00000	validation_1-auc:0.97322
# [258]	validation_0-auc:1.00000	validation_1-auc:0.97354
# [259]	validation_0-auc:1.00000	validation_1-auc:0.97349
# [260]	validation_0-auc:1.00000	validation_1-auc:0.97349
# [261]	validation_0-auc:1.00000	validation_1-auc:0.97342
# [262]	validation_0-auc:1.00000	validation_1-auc:0.97356
# [263]	validation_0-auc:1.00000	validation_1-auc:0.97345
# [264]	validation_0-auc:1.00000	validation_1-auc:0.97338
# [265]	validation_0-auc:1.00000	validation_1-auc:0.97347
# [266]	validation_0-auc:1.00000	validation_1-auc:0.97338
# [267]	validation_0-auc:1.00000	validation_1-auc:0.97354
# [268]	validation_0-auc:1.00000	validation_1-auc:0.97358
# [269]	validation_0-auc:1.00000	validation_1-auc:0.97349
# [270]	validation_0-auc:1.00000	validation_1-auc:0.97350
# [271]	validation_0-auc:1.00000	validation_1-auc:0.97354
# [272]	validation_0-auc:1.00000	validation_1-auc:0.97349
# [273]	validation_0-auc:1.00000	validation_1-auc:0.97350
# [274]	validation_0-auc:1.00000	validation_1-auc:0.97345
# [275]	validation_0-auc:1.00000	validation_1-auc:0.97350
# [276]	validation_0-auc:1.00000	validation_1-auc:0.97335
# [277]	validation_0-auc:1.00000	validation_1-auc:0.97324
# [278]	validation_0-auc:1.00000	validation_1-auc:0.97324
# [279]	validation_0-auc:1.00000	validation_1-auc:0.97327
# [280]	validation_0-auc:1.00000	validation_1-auc:0.97335
# [281]	validation_0-auc:1.00000	validation_1-auc:0.97338
# [282]	validation_0-auc:1.00000	validation_1-auc:0.97342
# [283]	validation_0-auc:1.00000	validation_1-auc:0.97340
# [284]	validation_0-auc:1.00000	validation_1-auc:0.97329
# [285]	validation_0-auc:1.00000	validation_1-auc:0.97317
# [286]	validation_0-auc:1.00000	validation_1-auc:0.97327
# [287]	validation_0-auc:1.00000	validation_1-auc:0.97331
# [288]	validation_0-auc:1.00000	validation_1-auc:0.97333
# [289]	validation_0-auc:1.00000	validation_1-auc:0.97303
# [290]	validation_0-auc:1.00000	validation_1-auc:0.97274
# [291]	validation_0-auc:1.00000	validation_1-auc:0.97283
# [292]	validation_0-auc:1.00000	validation_1-auc:0.97285
# [293]	validation_0-auc:1.00000	validation_1-auc:0.97296
# [294]	validation_0-auc:1.00000	validation_1-auc:0.97282
# [295]	validation_0-auc:1.00000	validation_1-auc:0.97290
# [296]	validation_0-auc:1.00000	validation_1-auc:0.97285
# [297]	validation_0-auc:1.00000	validation_1-auc:0.97299
# [298]	validation_0-auc:1.00000	validation_1-auc:0.97278
# [299]	validation_0-auc:1.00000	validation_1-auc:0.97282
# [300]	validation_0-auc:1.00000	validation_1-auc:0.97257
# [301]	validation_0-auc:1.00000	validation_1-auc:0.97255
# [302]	validation_0-auc:1.00000	validation_1-auc:0.97251
# [303]	validation_0-auc:1.00000	validation_1-auc:0.97259
# [304]	validation_0-auc:1.00000	validation_1-auc:0.97264
# [305]	validation_0-auc:1.00000	validation_1-auc:0.97253
# [306]	validation_0-auc:1.00000	validation_1-auc:0.97262
# [307]	validation_0-auc:1.00000	validation_1-auc:0.97250
# [308]	validation_0-auc:1.00000	validation_1-auc:0.97255
# [309]	validation_0-auc:1.00000	validation_1-auc:0.97269
# [310]	validation_0-auc:1.00000	validation_1-auc:0.97269
# [311]	validation_0-auc:1.00000	validation_1-auc:0.97264
# [312]	validation_0-auc:1.00000	validation_1-auc:0.97259
# [313]	validation_0-auc:1.00000	validation_1-auc:0.97237
# [314]	validation_0-auc:1.00000	validation_1-auc:0.97241
# [315]	validation_0-auc:1.00000	validation_1-auc:0.97234
# [316]	validation_0-auc:1.00000	validation_1-auc:0.97229
# [317]	validation_0-auc:1.00000	validation_1-auc:0.97229
# [318]	validation_0-auc:1.00000	validation_1-auc:0.97221
# [319]	validation_0-auc:1.00000	validation_1-auc:0.97207
# [320]	validation_0-auc:1.00000	validation_1-auc:0.97206
# [321]	validation_0-auc:1.00000	validation_1-auc:0.97202
# [322]	validation_0-auc:1.00000	validation_1-auc:0.97211
# [323]	validation_0-auc:1.00000	validation_1-auc:0.97213
# [324]	validation_0-auc:1.00000	validation_1-auc:0.97223
# [325]	validation_0-auc:1.00000	validation_1-auc:0.97223
# [326]	validation_0-auc:1.00000	validation_1-auc:0.97216
# [327]	validation_0-auc:1.00000	validation_1-auc:0.97207
# [328]	validation_0-auc:1.00000	validation_1-auc:0.97195
# [329]	validation_0-auc:1.00000	validation_1-auc:0.97179
# [330]	validation_0-auc:1.00000	validation_1-auc:0.97213
# [331]	validation_0-auc:1.00000	validation_1-auc:0.97214
# [332]	validation_0-auc:1.00000	validation_1-auc:0.97227
# [333]	validation_0-auc:1.00000	validation_1-auc:0.97223
# [334]	validation_0-auc:1.00000	validation_1-auc:0.97223
# [335]	validation_0-auc:1.00000	validation_1-auc:0.97221
# [336]	validation_0-auc:1.00000	validation_1-auc:0.97211
# [337]	validation_0-auc:1.00000	validation_1-auc:0.97218
# [338]	validation_0-auc:1.00000	validation_1-auc:0.97227
# [339]	validation_0-auc:1.00000	validation_1-auc:0.97227
# [340]	validation_0-auc:1.00000	validation_1-auc:0.97229
# [341]	validation_0-auc:1.00000	validation_1-auc:0.97216
# [342]	validation_0-auc:1.00000	validation_1-auc:0.97218
# [343]	validation_0-auc:1.00000	validation_1-auc:0.97223
# [344]	validation_0-auc:1.00000	validation_1-auc:0.97216
# [345]	validation_0-auc:1.00000	validation_1-auc:0.97209
# [346]	validation_0-auc:1.00000	validation_1-auc:0.97193
# [347]	validation_0-auc:1.00000	validation_1-auc:0.97188
# [348]	validation_0-auc:1.00000	validation_1-auc:0.97193
# [349]	validation_0-auc:1.00000	validation_1-auc:0.97195
# [350]	validation_0-auc:1.00000	validation_1-auc:0.97193
# [351]	validation_0-auc:1.00000	validation_1-auc:0.97193
# [352]	validation_0-auc:1.00000	validation_1-auc:0.97193
# [353]	validation_0-auc:1.00000	validation_1-auc:0.97200
# [354]	validation_0-auc:1.00000	validation_1-auc:0.97200
# [355]	validation_0-auc:1.00000	validation_1-auc:0.97200
# [356]	validation_0-auc:1.00000	validation_1-auc:0.97195
# [357]	validation_0-auc:1.00000	validation_1-auc:0.97179
# [358]	validation_0-auc:1.00000	validation_1-auc:0.97170
# [359]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [360]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [361]	validation_0-auc:1.00000	validation_1-auc:0.97175
# [362]	validation_0-auc:1.00000	validation_1-auc:0.97160
# [363]	validation_0-auc:1.00000	validation_1-auc:0.97165
# [364]	validation_0-auc:1.00000	validation_1-auc:0.97172
# [365]	validation_0-auc:1.00000	validation_1-auc:0.97172
# [366]	validation_0-auc:1.00000	validation_1-auc:0.97167
# [367]	validation_0-auc:1.00000	validation_1-auc:0.97163
# [368]	validation_0-auc:1.00000	validation_1-auc:0.97161
# [369]	validation_0-auc:1.00000	validation_1-auc:0.97160
# [370]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [371]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [372]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [373]	validation_0-auc:1.00000	validation_1-auc:0.97149
# [374]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [375]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [376]	validation_0-auc:1.00000	validation_1-auc:0.97149
# [377]	validation_0-auc:1.00000	validation_1-auc:0.97137
# [378]	validation_0-auc:1.00000	validation_1-auc:0.97145
# [379]	validation_0-auc:1.00000	validation_1-auc:0.97151
# [380]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [381]	validation_0-auc:1.00000	validation_1-auc:0.97163
# [382]	validation_0-auc:1.00000	validation_1-auc:0.97158
# [383]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [384]	validation_0-auc:1.00000	validation_1-auc:0.97170
# [385]	validation_0-auc:1.00000	validation_1-auc:0.97168
# [386]	validation_0-auc:1.00000	validation_1-auc:0.97165
# [387]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [388]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [389]	validation_0-auc:1.00000	validation_1-auc:0.97153
# [390]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [391]	validation_0-auc:1.00000	validation_1-auc:0.97135
# [392]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [393]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [394]	validation_0-auc:1.00000	validation_1-auc:0.97133
# [395]	validation_0-auc:1.00000	validation_1-auc:0.97130
# [396]	validation_0-auc:1.00000	validation_1-auc:0.97135
# [397]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [398]	validation_0-auc:1.00000	validation_1-auc:0.97145
# [399]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [400]	validation_0-auc:1.00000	validation_1-auc:0.97145
# [401]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [402]	validation_0-auc:1.00000	validation_1-auc:0.97137
# [403]	validation_0-auc:1.00000	validation_1-auc:0.97137
# [404]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [405]	validation_0-auc:1.00000	validation_1-auc:0.97133
# [406]	validation_0-auc:1.00000	validation_1-auc:0.97137
# [407]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [408]	validation_0-auc:1.00000	validation_1-auc:0.97130
# [409]	validation_0-auc:1.00000	validation_1-auc:0.97135
# [410]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [411]	validation_0-auc:1.00000	validation_1-auc:0.97135
# [412]	validation_0-auc:1.00000	validation_1-auc:0.97133
# [413]	validation_0-auc:1.00000	validation_1-auc:0.97137
# [414]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [415]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [416]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [417]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [418]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [419]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [420]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [421]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [422]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [423]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [424]	validation_0-auc:1.00000	validation_1-auc:0.97151
# [425]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [426]	validation_0-auc:1.00000	validation_1-auc:0.97145
# [427]	validation_0-auc:1.00000	validation_1-auc:0.97137
# [428]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [429]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [430]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [431]	validation_0-auc:1.00000	validation_1-auc:0.97145
# [432]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [433]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [434]	validation_0-auc:1.00000	validation_1-auc:0.97158
# [435]	validation_0-auc:1.00000	validation_1-auc:0.97151
# [436]	validation_0-auc:1.00000	validation_1-auc:0.97153
# [437]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [438]	validation_0-auc:1.00000	validation_1-auc:0.97167
# [439]	validation_0-auc:1.00000	validation_1-auc:0.97161
# [440]	validation_0-auc:1.00000	validation_1-auc:0.97163
# [441]	validation_0-auc:1.00000	validation_1-auc:0.97165
# [442]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [443]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [444]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [445]	validation_0-auc:1.00000	validation_1-auc:0.97130
# [446]	validation_0-auc:1.00000	validation_1-auc:0.97122
# [447]	validation_0-auc:1.00000	validation_1-auc:0.97126
# [448]	validation_0-auc:1.00000	validation_1-auc:0.97121
# [449]	validation_0-auc:1.00000	validation_1-auc:0.97117
# [450]	validation_0-auc:1.00000	validation_1-auc:0.97117
# [451]	validation_0-auc:1.00000	validation_1-auc:0.97122
# [452]	validation_0-auc:1.00000	validation_1-auc:0.97124
# [453]	validation_0-auc:1.00000	validation_1-auc:0.97124
# [454]	validation_0-auc:1.00000	validation_1-auc:0.97122
# [455]	validation_0-auc:1.00000	validation_1-auc:0.97122
# [456]	validation_0-auc:1.00000	validation_1-auc:0.97117
# [457]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [458]	validation_0-auc:1.00000	validation_1-auc:0.97137
# [459]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [460]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [461]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [462]	validation_0-auc:1.00000	validation_1-auc:0.97153
# [463]	validation_0-auc:1.00000	validation_1-auc:0.97151
# [464]	validation_0-auc:1.00000	validation_1-auc:0.97149
# [465]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [466]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [467]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [468]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [469]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [470]	validation_0-auc:1.00000	validation_1-auc:0.97151
# [471]	validation_0-auc:1.00000	validation_1-auc:0.97151
# [472]	validation_0-auc:1.00000	validation_1-auc:0.97149
# [473]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [474]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [475]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [476]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [477]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [478]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [479]	validation_0-auc:1.00000	validation_1-auc:0.97161
# [480]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [481]	validation_0-auc:1.00000	validation_1-auc:0.97153
# [482]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [483]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [484]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [485]	validation_0-auc:1.00000	validation_1-auc:0.97145
# [486]	validation_0-auc:1.00000	validation_1-auc:0.97133
# [487]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [488]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [489]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [490]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [491]	validation_0-auc:1.00000	validation_1-auc:0.97149
# [492]	validation_0-auc:1.00000	validation_1-auc:0.97151
# [493]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [494]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [495]	validation_0-auc:1.00000	validation_1-auc:0.97131
# [496]	validation_0-auc:1.00000	validation_1-auc:0.97124
# [497]	validation_0-auc:1.00000	validation_1-auc:0.97128
# [498]	validation_0-auc:1.00000	validation_1-auc:0.97131
# [499]	validation_0-auc:1.00000	validation_1-auc:0.97128
# [500]	validation_0-auc:1.00000	validation_1-auc:0.97128
# [501]	validation_0-auc:1.00000	validation_1-auc:0.97124
# [502]	validation_0-auc:1.00000	validation_1-auc:0.97130
# [503]	validation_0-auc:1.00000	validation_1-auc:0.97126
# [504]	validation_0-auc:1.00000	validation_1-auc:0.97130
# [505]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [506]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [507]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [508]	validation_0-auc:1.00000	validation_1-auc:0.97130
# [509]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [510]	validation_0-auc:1.00000	validation_1-auc:0.97145
# [511]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [512]	validation_0-auc:1.00000	validation_1-auc:0.97149
# [513]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [514]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [515]	validation_0-auc:1.00000	validation_1-auc:0.97133
# [516]	validation_0-auc:1.00000	validation_1-auc:0.97128
# [517]	validation_0-auc:1.00000	validation_1-auc:0.97133
# [518]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [519]	validation_0-auc:1.00000	validation_1-auc:0.97122
# [520]	validation_0-auc:1.00000	validation_1-auc:0.97112
# [521]	validation_0-auc:1.00000	validation_1-auc:0.97117
# [522]	validation_0-auc:1.00000	validation_1-auc:0.97112
# [523]	validation_0-auc:1.00000	validation_1-auc:0.97108
# [524]	validation_0-auc:1.00000	validation_1-auc:0.97114
# [525]	validation_0-auc:1.00000	validation_1-auc:0.97108
# [526]	validation_0-auc:1.00000	validation_1-auc:0.97103
# [527]	validation_0-auc:1.00000	validation_1-auc:0.97110
# [528]	validation_0-auc:1.00000	validation_1-auc:0.97105
# [529]	validation_0-auc:1.00000	validation_1-auc:0.97107
# [530]	validation_0-auc:1.00000	validation_1-auc:0.97112
# [531]	validation_0-auc:1.00000	validation_1-auc:0.97105
# [532]	validation_0-auc:1.00000	validation_1-auc:0.97114
# [533]	validation_0-auc:1.00000	validation_1-auc:0.97107
# [534]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [535]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [536]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [537]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [538]	validation_0-auc:1.00000	validation_1-auc:0.97103
# [539]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [540]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [541]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [542]	validation_0-auc:1.00000	validation_1-auc:0.97110
# [543]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [544]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [545]	validation_0-auc:1.00000	validation_1-auc:0.97092
# [546]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [547]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [548]	validation_0-auc:1.00000	validation_1-auc:0.97087
# [549]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [550]	validation_0-auc:1.00000	validation_1-auc:0.97092
# [551]	validation_0-auc:1.00000	validation_1-auc:0.97082
# [552]	validation_0-auc:1.00000	validation_1-auc:0.97092
# [553]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [554]	validation_0-auc:1.00000	validation_1-auc:0.97099
# [555]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [556]	validation_0-auc:1.00000	validation_1-auc:0.97099
# [557]	validation_0-auc:1.00000	validation_1-auc:0.97105
# [558]	validation_0-auc:1.00000	validation_1-auc:0.97107
# [559]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [560]	validation_0-auc:1.00000	validation_1-auc:0.97099
# [561]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [562]	validation_0-auc:1.00000	validation_1-auc:0.97092
# [563]	validation_0-auc:1.00000	validation_1-auc:0.97096
# [564]	validation_0-auc:1.00000	validation_1-auc:0.97096
# [565]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [566]	validation_0-auc:1.00000	validation_1-auc:0.97103
# [567]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [568]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [569]	validation_0-auc:1.00000	validation_1-auc:0.97092
# [570]	validation_0-auc:1.00000	validation_1-auc:0.97092
# [571]	validation_0-auc:1.00000	validation_1-auc:0.97105
# [572]	validation_0-auc:1.00000	validation_1-auc:0.97110
# [573]	validation_0-auc:1.00000	validation_1-auc:0.97107
# [574]	validation_0-auc:1.00000	validation_1-auc:0.97108
# [575]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [576]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [577]	validation_0-auc:1.00000	validation_1-auc:0.97087
# [578]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [579]	validation_0-auc:1.00000	validation_1-auc:0.97105
# [580]	validation_0-auc:1.00000	validation_1-auc:0.97099
# [581]	validation_0-auc:1.00000	validation_1-auc:0.97099
# [582]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [583]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [584]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [585]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [586]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [587]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [588]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [589]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [590]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [591]	validation_0-auc:1.00000	validation_1-auc:0.97092
# [592]	validation_0-auc:1.00000	validation_1-auc:0.97103
# [593]	validation_0-auc:1.00000	validation_1-auc:0.97105
# [594]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [595]	validation_0-auc:1.00000	validation_1-auc:0.97105
# [596]	validation_0-auc:1.00000	validation_1-auc:0.97096
# [597]	validation_0-auc:1.00000	validation_1-auc:0.97089
# [598]	validation_0-auc:1.00000	validation_1-auc:0.97084
# [599]	validation_0-auc:1.00000	validation_1-auc:0.97089
# [600]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [601]	validation_0-auc:1.00000	validation_1-auc:0.97087
# [602]	validation_0-auc:1.00000	validation_1-auc:0.97096
# [603]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [604]	validation_0-auc:1.00000	validation_1-auc:0.97095
# [605]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [606]	validation_0-auc:1.00000	validation_1-auc:0.97087
# [607]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [608]	validation_0-auc:1.00000	validation_1-auc:0.97087
# [609]	validation_0-auc:1.00000	validation_1-auc:0.97089
# [610]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [611]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [612]	validation_0-auc:1.00000	validation_1-auc:0.97085
# [613]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [614]	validation_0-auc:1.00000	validation_1-auc:0.97085
# [615]	validation_0-auc:1.00000	validation_1-auc:0.97080
# [616]	validation_0-auc:1.00000	validation_1-auc:0.97084
# [617]	validation_0-auc:1.00000	validation_1-auc:0.97078
# [618]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [619]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [620]	validation_0-auc:1.00000	validation_1-auc:0.97080
# [621]	validation_0-auc:1.00000	validation_1-auc:0.97076
# [622]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [623]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [624]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [625]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [626]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [627]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [628]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [629]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [630]	validation_0-auc:1.00000	validation_1-auc:0.97076
# [631]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [632]	validation_0-auc:1.00000	validation_1-auc:0.97068
# [633]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [634]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [635]	validation_0-auc:1.00000	validation_1-auc:0.97068
# [636]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [637]	validation_0-auc:1.00000	validation_1-auc:0.97062
# [638]	validation_0-auc:1.00000	validation_1-auc:0.97064
# [639]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [640]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [641]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [642]	validation_0-auc:1.00000	validation_1-auc:0.97068
# [643]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [644]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [645]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [646]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [647]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [648]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [649]	validation_0-auc:1.00000	validation_1-auc:0.97068
# [650]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [651]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [652]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [653]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [654]	validation_0-auc:1.00000	validation_1-auc:0.97076
# [655]	validation_0-auc:1.00000	validation_1-auc:0.97076
# [656]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [657]	validation_0-auc:1.00000	validation_1-auc:0.97068
# [658]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [659]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [660]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [661]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [662]	validation_0-auc:1.00000	validation_1-auc:0.97082
# [663]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [664]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [665]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [666]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [667]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [668]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [669]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [670]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [671]	validation_0-auc:1.00000	validation_1-auc:0.97068
# [672]	validation_0-auc:1.00000	validation_1-auc:0.97061
# [673]	validation_0-auc:1.00000	validation_1-auc:0.97061
# [674]	validation_0-auc:1.00000	validation_1-auc:0.97062
# [675]	validation_0-auc:1.00000	validation_1-auc:0.97059
# [676]	validation_0-auc:1.00000	validation_1-auc:0.97055
# [677]	validation_0-auc:1.00000	validation_1-auc:0.97054
# [678]	validation_0-auc:1.00000	validation_1-auc:0.97050
# [679]	validation_0-auc:1.00000	validation_1-auc:0.97046
# [680]	validation_0-auc:1.00000	validation_1-auc:0.97054
# [681]	validation_0-auc:1.00000	validation_1-auc:0.97055
# [682]	validation_0-auc:1.00000	validation_1-auc:0.97061
# [683]	validation_0-auc:1.00000	validation_1-auc:0.97059
# [684]	validation_0-auc:1.00000	validation_1-auc:0.97062
# [685]	validation_0-auc:1.00000	validation_1-auc:0.97061
# [686]	validation_0-auc:1.00000	validation_1-auc:0.97059
# [687]	validation_0-auc:1.00000	validation_1-auc:0.97059
# [688]	validation_0-auc:1.00000	validation_1-auc:0.97059
# [689]	validation_0-auc:1.00000	validation_1-auc:0.97052
# [690]	validation_0-auc:1.00000	validation_1-auc:0.97057
# [691]	validation_0-auc:1.00000	validation_1-auc:0.97059
# [692]	validation_0-auc:1.00000	validation_1-auc:0.97064
# [693]	validation_0-auc:1.00000	validation_1-auc:0.97061
# [694]	validation_0-auc:1.00000	validation_1-auc:0.97061
# [695]	validation_0-auc:1.00000	validation_1-auc:0.97064
# [696]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [697]	validation_0-auc:1.00000	validation_1-auc:0.97064
# [698]	validation_0-auc:1.00000	validation_1-auc:0.97068
# [699]	validation_0-auc:1.00000	validation_1-auc:0.97054
# Model Name: [XgBoost           ], 2023-09-20 16:07:52, 0:00:16,  BEST AUC: 0.966306, AUC: 0.966306
# [1]	training's binary_logloss: 0.631645	valid_1's binary_logloss: 0.636219
# [2]	training's binary_logloss: 0.579096	valid_1's binary_logloss: 0.590489
# [3]	training's binary_logloss: 0.534514	valid_1's binary_logloss: 0.548616
# [4]	training's binary_logloss: 0.495037	valid_1's binary_logloss: 0.514227
# [5]	training's binary_logloss: 0.461619	valid_1's binary_logloss: 0.486265
# [6]	training's binary_logloss: 0.432438	valid_1's binary_logloss: 0.46028
# [7]	training's binary_logloss: 0.405636	valid_1's binary_logloss: 0.438045
# [8]	training's binary_logloss: 0.381892	valid_1's binary_logloss: 0.416585
# [9]	training's binary_logloss: 0.360803	valid_1's binary_logloss: 0.397352
# [10]	training's binary_logloss: 0.341154	valid_1's binary_logloss: 0.378582
# [11]	training's binary_logloss: 0.323402	valid_1's binary_logloss: 0.362409
# [12]	training's binary_logloss: 0.304603	valid_1's binary_logloss: 0.344715
# [13]	training's binary_logloss: 0.289652	valid_1's binary_logloss: 0.331613
# [14]	training's binary_logloss: 0.276725	valid_1's binary_logloss: 0.322193
# [15]	training's binary_logloss: 0.265339	valid_1's binary_logloss: 0.311784
# [16]	training's binary_logloss: 0.253707	valid_1's binary_logloss: 0.301144
# [17]	training's binary_logloss: 0.241805	valid_1's binary_logloss: 0.289979
# [18]	training's binary_logloss: 0.229419	valid_1's binary_logloss: 0.281446
# [19]	training's binary_logloss: 0.220312	valid_1's binary_logloss: 0.272843
# [20]	training's binary_logloss: 0.212821	valid_1's binary_logloss: 0.266867
# [21]	training's binary_logloss: 0.203942	valid_1's binary_logloss: 0.258224
# [22]	training's binary_logloss: 0.196798	valid_1's binary_logloss: 0.251027
# [23]	training's binary_logloss: 0.190199	valid_1's binary_logloss: 0.245583
# [24]	training's binary_logloss: 0.18316	valid_1's binary_logloss: 0.239721
# [25]	training's binary_logloss: 0.177789	valid_1's binary_logloss: 0.234556
# [26]	training's binary_logloss: 0.170732	valid_1's binary_logloss: 0.226987
# [27]	training's binary_logloss: 0.165805	valid_1's binary_logloss: 0.222157
# [28]	training's binary_logloss: 0.160183	valid_1's binary_logloss: 0.216494
# [29]	training's binary_logloss: 0.154479	valid_1's binary_logloss: 0.210038
# [30]	training's binary_logloss: 0.148366	valid_1's binary_logloss: 0.204644
# [31]	training's binary_logloss: 0.143184	valid_1's binary_logloss: 0.199761
# [32]	training's binary_logloss: 0.139577	valid_1's binary_logloss: 0.196502
# [33]	training's binary_logloss: 0.135222	valid_1's binary_logloss: 0.191046
# [34]	training's binary_logloss: 0.130848	valid_1's binary_logloss: 0.187978
# [35]	training's binary_logloss: 0.127572	valid_1's binary_logloss: 0.185634
# [36]	training's binary_logloss: 0.123543	valid_1's binary_logloss: 0.180698
# [37]	training's binary_logloss: 0.119801	valid_1's binary_logloss: 0.177229
# [38]	training's binary_logloss: 0.116155	valid_1's binary_logloss: 0.174474
# [39]	training's binary_logloss: 0.112584	valid_1's binary_logloss: 0.170781
# [40]	training's binary_logloss: 0.10936	valid_1's binary_logloss: 0.168282
# [41]	training's binary_logloss: 0.106815	valid_1's binary_logloss: 0.166508
# [42]	training's binary_logloss: 0.103996	valid_1's binary_logloss: 0.16429
# [43]	training's binary_logloss: 0.101447	valid_1's binary_logloss: 0.161323
# [44]	training's binary_logloss: 0.0987199	valid_1's binary_logloss: 0.159535
# [45]	training's binary_logloss: 0.0965521	valid_1's binary_logloss: 0.15739
# [46]	training's binary_logloss: 0.0940833	valid_1's binary_logloss: 0.155274
# [47]	training's binary_logloss: 0.0921906	valid_1's binary_logloss: 0.153955
# [48]	training's binary_logloss: 0.0902349	valid_1's binary_logloss: 0.151874
# [49]	training's binary_logloss: 0.0880436	valid_1's binary_logloss: 0.149647
# [50]	training's binary_logloss: 0.0862608	valid_1's binary_logloss: 0.148611
# [51]	training's binary_logloss: 0.0840687	valid_1's binary_logloss: 0.147132
# [52]	training's binary_logloss: 0.0820559	valid_1's binary_logloss: 0.14556
# [53]	training's binary_logloss: 0.0803956	valid_1's binary_logloss: 0.145016
# [54]	training's binary_logloss: 0.0789438	valid_1's binary_logloss: 0.144232
# [55]	training's binary_logloss: 0.0770474	valid_1's binary_logloss: 0.142127
# [56]	training's binary_logloss: 0.0751533	valid_1's binary_logloss: 0.141052
# [57]	training's binary_logloss: 0.0736944	valid_1's binary_logloss: 0.140069
# [58]	training's binary_logloss: 0.072215	valid_1's binary_logloss: 0.139178
# [59]	training's binary_logloss: 0.0709745	valid_1's binary_logloss: 0.137922
# [60]	training's binary_logloss: 0.069657	valid_1's binary_logloss: 0.137847
# [61]	training's binary_logloss: 0.0684026	valid_1's binary_logloss: 0.137052
# [62]	training's binary_logloss: 0.0671773	valid_1's binary_logloss: 0.136349
# [63]	training's binary_logloss: 0.0660774	valid_1's binary_logloss: 0.136165
# [64]	training's binary_logloss: 0.0650255	valid_1's binary_logloss: 0.135006
# [65]	training's binary_logloss: 0.0640603	valid_1's binary_logloss: 0.13433
# [66]	training's binary_logloss: 0.062711	valid_1's binary_logloss: 0.134002
# [67]	training's binary_logloss: 0.0615266	valid_1's binary_logloss: 0.133594
# [68]	training's binary_logloss: 0.0603785	valid_1's binary_logloss: 0.133654
# [69]	training's binary_logloss: 0.0595073	valid_1's binary_logloss: 0.132919
# [70]	training's binary_logloss: 0.0584588	valid_1's binary_logloss: 0.132095
# [71]	training's binary_logloss: 0.0575484	valid_1's binary_logloss: 0.131634
# [72]	training's binary_logloss: 0.0565936	valid_1's binary_logloss: 0.131009
# [73]	training's binary_logloss: 0.0557548	valid_1's binary_logloss: 0.130217
# [74]	training's binary_logloss: 0.0547556	valid_1's binary_logloss: 0.129487
# [75]	training's binary_logloss: 0.0536846	valid_1's binary_logloss: 0.129009
# [76]	training's binary_logloss: 0.0528475	valid_1's binary_logloss: 0.128838
# [77]	training's binary_logloss: 0.0521147	valid_1's binary_logloss: 0.128433
# [78]	training's binary_logloss: 0.0513823	valid_1's binary_logloss: 0.128469
# [79]	training's binary_logloss: 0.0504783	valid_1's binary_logloss: 0.127763
# [80]	training's binary_logloss: 0.049573	valid_1's binary_logloss: 0.127249
# [81]	training's binary_logloss: 0.0487405	valid_1's binary_logloss: 0.126494
# [82]	training's binary_logloss: 0.047952	valid_1's binary_logloss: 0.126313
# [83]	training's binary_logloss: 0.0471403	valid_1's binary_logloss: 0.12571
# [84]	training's binary_logloss: 0.0464716	valid_1's binary_logloss: 0.125162
# [85]	training's binary_logloss: 0.0457331	valid_1's binary_logloss: 0.124596
# [86]	training's binary_logloss: 0.0451162	valid_1's binary_logloss: 0.125055
# [87]	training's binary_logloss: 0.0442741	valid_1's binary_logloss: 0.125126
# [88]	training's binary_logloss: 0.0436151	valid_1's binary_logloss: 0.124644
# [89]	training's binary_logloss: 0.0429486	valid_1's binary_logloss: 0.125074
# [90]	training's binary_logloss: 0.0424038	valid_1's binary_logloss: 0.124732
# [91]	training's binary_logloss: 0.0418136	valid_1's binary_logloss: 0.124442
# [92]	training's binary_logloss: 0.0411859	valid_1's binary_logloss: 0.12461
# [93]	training's binary_logloss: 0.0405066	valid_1's binary_logloss: 0.124079
# [94]	training's binary_logloss: 0.0398904	valid_1's binary_logloss: 0.1241
# [95]	training's binary_logloss: 0.0392166	valid_1's binary_logloss: 0.124115
# [96]	training's binary_logloss: 0.0386478	valid_1's binary_logloss: 0.123913
# [97]	training's binary_logloss: 0.0380828	valid_1's binary_logloss: 0.12332
# [98]	training's binary_logloss: 0.0374598	valid_1's binary_logloss: 0.123842
# [99]	training's binary_logloss: 0.0369441	valid_1's binary_logloss: 0.123886
# [100]	training's binary_logloss: 0.0363628	valid_1's binary_logloss: 0.123811
# [101]	training's binary_logloss: 0.0359721	valid_1's binary_logloss: 0.12414
# [102]	training's binary_logloss: 0.0355273	valid_1's binary_logloss: 0.124035
# [103]	training's binary_logloss: 0.0350658	valid_1's binary_logloss: 0.124033
# [104]	training's binary_logloss: 0.034443	valid_1's binary_logloss: 0.124107
# [105]	training's binary_logloss: 0.0339605	valid_1's binary_logloss: 0.124743
# [106]	training's binary_logloss: 0.0334513	valid_1's binary_logloss: 0.124363
# [107]	training's binary_logloss: 0.0328605	valid_1's binary_logloss: 0.124628
# [108]	training's binary_logloss: 0.032441	valid_1's binary_logloss: 0.124338
# [109]	training's binary_logloss: 0.0319713	valid_1's binary_logloss: 0.123826
# [110]	training's binary_logloss: 0.0314312	valid_1's binary_logloss: 0.123976
# [111]	training's binary_logloss: 0.0309933	valid_1's binary_logloss: 0.12362
# [112]	training's binary_logloss: 0.0305564	valid_1's binary_logloss: 0.122938
# [113]	training's binary_logloss: 0.0300825	valid_1's binary_logloss: 0.123033
# [114]	training's binary_logloss: 0.0296081	valid_1's binary_logloss: 0.123694
# [115]	training's binary_logloss: 0.0292065	valid_1's binary_logloss: 0.123327
# ...
# [502]	training's binary_logloss: 0.000298301	valid_1's binary_logloss: 0.164309
# [503]	training's binary_logloss: 0.000295472	valid_1's binary_logloss: 0.164424
# [504]	training's binary_logloss: 0.000292011	valid_1's binary_logloss: 0.164403
# [505]	training's binary_logloss: 0.000288664	valid_1's binary_logloss: 0.164412
# [506]	training's binary_logloss: 0.000285444	valid_1's binary_logloss: 0.164648
# [507]	training's binary_logloss: 0.000282232	valid_1's binary_logloss: 0.164346
# [508]	training's binary_logloss: 0.00027877	valid_1's binary_logloss: 0.16449
# [509]	training's binary_logloss: 0.000275872	valid_1's binary_logloss: 0.164563
# [510]	training's binary_logloss: 0.000273272	valid_1's binary_logloss: 0.164412
# [511]	training's binary_logloss: 0.000270483	valid_1's binary_logloss: 0.164168
# [512]	training's binary_logloss: 0.000267387	valid_1's binary_logloss: 0.164471
# [513]	training's binary_logloss: 0.000263936	valid_1's binary_logloss: 0.164724
# [514]	training's binary_logloss: 0.000261235	valid_1's binary_logloss: 0.164689
# [515]	training's binary_logloss: 0.000258458	valid_1's binary_logloss: 0.164595
# [516]	training's binary_logloss: 0.000255379	valid_1's binary_logloss: 0.16466
# [517]	training's binary_logloss: 0.000252845	valid_1's binary_logloss: 0.165363
# [518]	training's binary_logloss: 0.000249852	valid_1's binary_logloss: 0.165643
# [519]	training's binary_logloss: 0.000247494	valid_1's binary_logloss: 0.165665
# [520]	training's binary_logloss: 0.000244608	valid_1's binary_logloss: 0.165844
# [521]	training's binary_logloss: 0.000242189	valid_1's binary_logloss: 0.166046
# [522]	training's binary_logloss: 0.000239505	valid_1's binary_logloss: 0.165995
# [523]	training's binary_logloss: 0.000236617	valid_1's binary_logloss: 0.165752
# [524]	training's binary_logloss: 0.000233862	valid_1's binary_logloss: 0.166319
# [525]	training's binary_logloss: 0.000231095	valid_1's binary_logloss: 0.166535
# [526]	training's binary_logloss: 0.000228622	valid_1's binary_logloss: 0.167017
# [527]	training's binary_logloss: 0.000225846	valid_1's binary_logloss: 0.167369
# [528]	training's binary_logloss: 0.000223507	valid_1's binary_logloss: 0.167538
# [529]	training's binary_logloss: 0.000221067	valid_1's binary_logloss: 0.16692
# [530]	training's binary_logloss: 0.000218115	valid_1's binary_logloss: 0.167099
# [531]	training's binary_logloss: 0.000215211	valid_1's binary_logloss: 0.167645
# [532]	training's binary_logloss: 0.000212623	valid_1's binary_logloss: 0.167777
# [533]	training's binary_logloss: 0.000210301	valid_1's binary_logloss: 0.167885
# [534]	training's binary_logloss: 0.000207992	valid_1's binary_logloss: 0.168674
# [535]	training's binary_logloss: 0.000205505	valid_1's binary_logloss: 0.168723
# [536]	training's binary_logloss: 0.00020319	valid_1's binary_logloss: 0.1691
# [537]	training's binary_logloss: 0.000200606	valid_1's binary_logloss: 0.169524
# [538]	training's binary_logloss: 0.000198253	valid_1's binary_logloss: 0.169894
# [539]	training's binary_logloss: 0.000196077	valid_1's binary_logloss: 0.170202
# [540]	training's binary_logloss: 0.000193888	valid_1's binary_logloss: 0.170127
# [541]	training's binary_logloss: 0.000191708	valid_1's binary_logloss: 0.170129
# [542]	training's binary_logloss: 0.000189793	valid_1's binary_logloss: 0.170474
# [543]	training's binary_logloss: 0.000187882	valid_1's binary_logloss: 0.170364
# [544]	training's binary_logloss: 0.000186037	valid_1's binary_logloss: 0.170839
# [545]	training's binary_logloss: 0.0001839	valid_1's binary_logloss: 0.170844
# [546]	training's binary_logloss: 0.000182267	valid_1's binary_logloss: 0.171343
# [547]	training's binary_logloss: 0.000180489	valid_1's binary_logloss: 0.171673
# [548]	training's binary_logloss: 0.000178796	valid_1's binary_logloss: 0.171933
# [549]	training's binary_logloss: 0.000176608	valid_1's binary_logloss: 0.172304
# [550]	training's binary_logloss: 0.000174884	valid_1's binary_logloss: 0.172256
# [551]	training's binary_logloss: 0.000172708	valid_1's binary_logloss: 0.172555
# [552]	training's binary_logloss: 0.000170978	valid_1's binary_logloss: 0.172824
# [553]	training's binary_logloss: 0.000169299	valid_1's binary_logloss: 0.17337
# [554]	training's binary_logloss: 0.000167189	valid_1's binary_logloss: 0.173735
# [555]	training's binary_logloss: 0.000165507	valid_1's binary_logloss: 0.174047
# [556]	training's binary_logloss: 0.00016354	valid_1's binary_logloss: 0.17424
# [557]	training's binary_logloss: 0.000161646	valid_1's binary_logloss: 0.174905
# [558]	training's binary_logloss: 0.000159851	valid_1's binary_logloss: 0.175552
# [559]	training's binary_logloss: 0.000158068	valid_1's binary_logloss: 0.175595
# [560]	training's binary_logloss: 0.000156364	valid_1's binary_logloss: 0.17597
# [561]	training's binary_logloss: 0.000154621	valid_1's binary_logloss: 0.176004
# [562]	training's binary_logloss: 0.00015283	valid_1's binary_logloss: 0.176299
# [563]	training's binary_logloss: 0.000151317	valid_1's binary_logloss: 0.176436
# [564]	training's binary_logloss: 0.000149582	valid_1's binary_logloss: 0.176687
# [565]	training's binary_logloss: 0.000147923	valid_1's binary_logloss: 0.17665
# [566]	training's binary_logloss: 0.000146062	valid_1's binary_logloss: 0.176668
# [567]	training's binary_logloss: 0.000144249	valid_1's binary_logloss: 0.17722
# [568]	training's binary_logloss: 0.000142889	valid_1's binary_logloss: 0.177611
# [569]	training's binary_logloss: 0.000140923	valid_1's binary_logloss: 0.177524
# [570]	training's binary_logloss: 0.000139091	valid_1's binary_logloss: 0.177708
# [571]	training's binary_logloss: 0.000137679	valid_1's binary_logloss: 0.177704
# [572]	training's binary_logloss: 0.00013645	valid_1's binary_logloss: 0.177353
# [573]	training's binary_logloss: 0.000134842	valid_1's binary_logloss: 0.177062
# [574]	training's binary_logloss: 0.000133126	valid_1's binary_logloss: 0.176856
# [575]	training's binary_logloss: 0.000131846	valid_1's binary_logloss: 0.177094
# [576]	training's binary_logloss: 0.000130485	valid_1's binary_logloss: 0.177144
# [577]	training's binary_logloss: 0.000129102	valid_1's binary_logloss: 0.177552
# [578]	training's binary_logloss: 0.00012757	valid_1's binary_logloss: 0.178009
# [579]	training's binary_logloss: 0.000126174	valid_1's binary_logloss: 0.178497
# [580]	training's binary_logloss: 0.000124838	valid_1's binary_logloss: 0.178386
# [581]	training's binary_logloss: 0.000123388	valid_1's binary_logloss: 0.178257
# [582]	training's binary_logloss: 0.000122043	valid_1's binary_logloss: 0.178526
# [583]	training's binary_logloss: 0.000120784	valid_1's binary_logloss: 0.178539
# [584]	training's binary_logloss: 0.000119223	valid_1's binary_logloss: 0.178523
# [585]	training's binary_logloss: 0.000117875	valid_1's binary_logloss: 0.178921
# [586]	training's binary_logloss: 0.000116681	valid_1's binary_logloss: 0.178934
# [587]	training's binary_logloss: 0.000115588	valid_1's binary_logloss: 0.17882
# [588]	training's binary_logloss: 0.000114306	valid_1's binary_logloss: 0.178573
# [589]	training's binary_logloss: 0.000112986	valid_1's binary_logloss: 0.178826
# [590]	training's binary_logloss: 0.00011182	valid_1's binary_logloss: 0.179172
# [591]	training's binary_logloss: 0.000110594	valid_1's binary_logloss: 0.179707
# [592]	training's binary_logloss: 0.000109209	valid_1's binary_logloss: 0.17984
# [593]	training's binary_logloss: 0.000107882	valid_1's binary_logloss: 0.17992
# [594]	training's binary_logloss: 0.000106582	valid_1's binary_logloss: 0.179923
# [595]	training's binary_logloss: 0.000105292	valid_1's binary_logloss: 0.180111
# [596]	training's binary_logloss: 0.000103891	valid_1's binary_logloss: 0.180811
# [597]	training's binary_logloss: 0.000102642	valid_1's binary_logloss: 0.181362
# [598]	training's binary_logloss: 0.000101496	valid_1's binary_logloss: 0.181607
# [599]	training's binary_logloss: 0.000100399	valid_1's binary_logloss: 0.181683
# [600]	training's binary_logloss: 9.92998e-05	valid_1's binary_logloss: 0.181736
# [601]	training's binary_logloss: 9.82413e-05	valid_1's binary_logloss: 0.181719
# [602]	training's binary_logloss: 9.71209e-05	valid_1's binary_logloss: 0.181609
# [603]	training's binary_logloss: 9.62387e-05	valid_1's binary_logloss: 0.182042
# [604]	training's binary_logloss: 9.5011e-05	valid_1's binary_logloss: 0.182302
# [605]	training's binary_logloss: 9.4049e-05	valid_1's binary_logloss: 0.18203
# [606]	training's binary_logloss: 9.30636e-05	valid_1's binary_logloss: 0.182369
# [607]	training's binary_logloss: 9.21597e-05	valid_1's binary_logloss: 0.18234
# [608]	training's binary_logloss: 9.10858e-05	valid_1's binary_logloss: 0.182584
# [609]	training's binary_logloss: 9.00506e-05	valid_1's binary_logloss: 0.1828
# [610]	training's binary_logloss: 8.91391e-05	valid_1's binary_logloss: 0.18305
# [611]	training's binary_logloss: 8.82175e-05	valid_1's binary_logloss: 0.183367
# [612]	training's binary_logloss: 8.70041e-05	valid_1's binary_logloss: 0.183272
# [613]	training's binary_logloss: 8.58409e-05	valid_1's binary_logloss: 0.183283
# [614]	training's binary_logloss: 8.48114e-05	valid_1's binary_logloss: 0.18324
# [615]	training's binary_logloss: 8.39911e-05	valid_1's binary_logloss: 0.183504
# [616]	training's binary_logloss: 8.28047e-05	valid_1's binary_logloss: 0.183825
# [617]	training's binary_logloss: 8.16995e-05	valid_1's binary_logloss: 0.183736
# [618]	training's binary_logloss: 8.07486e-05	valid_1's binary_logloss: 0.183739
# [619]	training's binary_logloss: 7.97388e-05	valid_1's binary_logloss: 0.184103
# [620]	training's binary_logloss: 7.87652e-05	valid_1's binary_logloss: 0.183701
# [621]	training's binary_logloss: 7.78076e-05	valid_1's binary_logloss: 0.183874
# [622]	training's binary_logloss: 7.67553e-05	valid_1's binary_logloss: 0.183817
# [623]	training's binary_logloss: 7.59223e-05	valid_1's binary_logloss: 0.18412
# [624]	training's binary_logloss: 7.51156e-05	valid_1's binary_logloss: 0.184544
# [625]	training's binary_logloss: 7.42141e-05	valid_1's binary_logloss: 0.184903
# [626]	training's binary_logloss: 7.34458e-05	valid_1's binary_logloss: 0.184656
# [627]	training's binary_logloss: 7.2766e-05	valid_1's binary_logloss: 0.185217
# [628]	training's binary_logloss: 7.18759e-05	valid_1's binary_logloss: 0.18547
# [629]	training's binary_logloss: 7.10397e-05	valid_1's binary_logloss: 0.18505
# [630]	training's binary_logloss: 7.02557e-05	valid_1's binary_logloss: 0.185219
# [631]	training's binary_logloss: 6.93012e-05	valid_1's binary_logloss: 0.185082
# [632]	training's binary_logloss: 6.86003e-05	valid_1's binary_logloss: 0.18533
# [633]	training's binary_logloss: 6.78197e-05	valid_1's binary_logloss: 0.18578
# [634]	training's binary_logloss: 6.71669e-05	valid_1's binary_logloss: 0.185711
# [635]	training's binary_logloss: 6.65025e-05	valid_1's binary_logloss: 0.185885
# [636]	training's binary_logloss: 6.57354e-05	valid_1's binary_logloss: 0.185827
# [637]	training's binary_logloss: 6.51121e-05	valid_1's binary_logloss: 0.186296
# [638]	training's binary_logloss: 6.4398e-05	valid_1's binary_logloss: 0.186753
# [639]	training's binary_logloss: 6.36983e-05	valid_1's binary_logloss: 0.187014
# [640]	training's binary_logloss: 6.29818e-05	valid_1's binary_logloss: 0.186866
# [641]	training's binary_logloss: 6.22306e-05	valid_1's binary_logloss: 0.187528
# [642]	training's binary_logloss: 6.15635e-05	valid_1's binary_logloss: 0.188024
# [643]	training's binary_logloss: 6.09859e-05	valid_1's binary_logloss: 0.187793
# [644]	training's binary_logloss: 6.0239e-05	valid_1's binary_logloss: 0.187677
# [645]	training's binary_logloss: 5.96129e-05	valid_1's binary_logloss: 0.187875
# [646]	training's binary_logloss: 5.89983e-05	valid_1's binary_logloss: 0.187956
# [647]	training's binary_logloss: 5.82139e-05	valid_1's binary_logloss: 0.188145
# [648]	training's binary_logloss: 5.76461e-05	valid_1's binary_logloss: 0.18834
# [649]	training's binary_logloss: 5.70042e-05	valid_1's binary_logloss: 0.188371
# [650]	training's binary_logloss: 5.61478e-05	valid_1's binary_logloss: 0.188524
# [651]	training's binary_logloss: 5.56014e-05	valid_1's binary_logloss: 0.188586
# [652]	training's binary_logloss: 5.50185e-05	valid_1's binary_logloss: 0.188813
# [653]	training's binary_logloss: 5.4425e-05	valid_1's binary_logloss: 0.188885
# [654]	training's binary_logloss: 5.37415e-05	valid_1's binary_logloss: 0.189824
# [655]	training's binary_logloss: 5.31091e-05	valid_1's binary_logloss: 0.189901
# [656]	training's binary_logloss: 5.25628e-05	valid_1's binary_logloss: 0.190444
# [657]	training's binary_logloss: 5.19743e-05	valid_1's binary_logloss: 0.190714
# [658]	training's binary_logloss: 5.14746e-05	valid_1's binary_logloss: 0.191034
# [659]	training's binary_logloss: 5.10576e-05	valid_1's binary_logloss: 0.191213
# [660]	training's binary_logloss: 5.04849e-05	valid_1's binary_logloss: 0.191202
# [661]	training's binary_logloss: 4.99599e-05	valid_1's binary_logloss: 0.191275
# [662]	training's binary_logloss: 4.944e-05	valid_1's binary_logloss: 0.191058
# [663]	training's binary_logloss: 4.89182e-05	valid_1's binary_logloss: 0.191032
# [664]	training's binary_logloss: 4.82646e-05	valid_1's binary_logloss: 0.190978
# [665]	training's binary_logloss: 4.77213e-05	valid_1's binary_logloss: 0.191087
# [666]	training's binary_logloss: 4.7186e-05	valid_1's binary_logloss: 0.19151
# [667]	training's binary_logloss: 4.65783e-05	valid_1's binary_logloss: 0.191603
# [668]	training's binary_logloss: 4.61415e-05	valid_1's binary_logloss: 0.19185
# [669]	training's binary_logloss: 4.56811e-05	valid_1's binary_logloss: 0.192375
# [670]	training's binary_logloss: 4.51418e-05	valid_1's binary_logloss: 0.192296
# [671]	training's binary_logloss: 4.46618e-05	valid_1's binary_logloss: 0.192224
# [672]	training's binary_logloss: 4.40509e-05	valid_1's binary_logloss: 0.192242
# [673]	training's binary_logloss: 4.36136e-05	valid_1's binary_logloss: 0.192175
# [674]	training's binary_logloss: 4.31418e-05	valid_1's binary_logloss: 0.191963
# [675]	training's binary_logloss: 4.26906e-05	valid_1's binary_logloss: 0.192076
# [676]	training's binary_logloss: 4.21848e-05	valid_1's binary_logloss: 0.192157
# [677]	training's binary_logloss: 4.16692e-05	valid_1's binary_logloss: 0.192582
# [678]	training's binary_logloss: 4.11107e-05	valid_1's binary_logloss: 0.192827
# [679]	training's binary_logloss: 4.06232e-05	valid_1's binary_logloss: 0.192775
# [680]	training's binary_logloss: 4.01966e-05	valid_1's binary_logloss: 0.192944
# [681]	training's binary_logloss: 3.97279e-05	valid_1's binary_logloss: 0.192689
# [682]	training's binary_logloss: 3.93806e-05	valid_1's binary_logloss: 0.192554
# [683]	training's binary_logloss: 3.8884e-05	valid_1's binary_logloss: 0.192926
# [684]	training's binary_logloss: 3.84105e-05	valid_1's binary_logloss: 0.193433
# [685]	training's binary_logloss: 3.80111e-05	valid_1's binary_logloss: 0.193633
# [686]	training's binary_logloss: 3.75986e-05	valid_1's binary_logloss: 0.193479
# [687]	training's binary_logloss: 3.71855e-05	valid_1's binary_logloss: 0.193685
# [688]	training's binary_logloss: 3.67251e-05	valid_1's binary_logloss: 0.19401
# [689]	training's binary_logloss: 3.63526e-05	valid_1's binary_logloss: 0.193755
# [690]	training's binary_logloss: 3.58439e-05	valid_1's binary_logloss: 0.194316
# [691]	training's binary_logloss: 3.53449e-05	valid_1's binary_logloss: 0.194623
# [692]	training's binary_logloss: 3.48901e-05	valid_1's binary_logloss: 0.194418
# [693]	training's binary_logloss: 3.45413e-05	valid_1's binary_logloss: 0.194281
# [694]	training's binary_logloss: 3.42309e-05	valid_1's binary_logloss: 0.194641
# [695]	training's binary_logloss: 3.38193e-05	valid_1's binary_logloss: 0.194868
# [696]	training's binary_logloss: 3.34044e-05	valid_1's binary_logloss: 0.195017
# [697]	training's binary_logloss: 3.30115e-05	valid_1's binary_logloss: 0.195173
# [698]	training's binary_logloss: 3.26633e-05	valid_1's binary_logloss: 0.19541
# [699]	training's binary_logloss: 3.22968e-05	valid_1's binary_logloss: 0.195855
# [700]	training's binary_logloss: 3.19045e-05	valid_1's binary_logloss: 0.195707
# Model Name: [LightGBM          ], 2023-09-20 16:08:01, 0:00:08,  BEST AUC: 0.973001, AUC: 0.973001

# %%
print_eval_result(model_test_comparison)
# Out:
# <style type="text/css">
# #T_d3b3a_row0_col0, #T_d3b3a_row0_col1, #T_d3b3a_row0_col2, #T_d3b3a_row0_col3, #T_d3b3a_row0_col4, #T_d3b3a_row0_col5, #T_d3b3a_row0_col6, #T_d3b3a_row1_col1 {
#   background-color: yellow;
#   color: black;
# }
# #T_d3b3a_row0_col8, #T_d3b3a_row1_col7 {
#   background-color: yellow;
# }
# #T_d3b3a_row1_col0, #T_d3b3a_row1_col2, #T_d3b3a_row1_col3, #T_d3b3a_row1_col4, #T_d3b3a_row1_col5, #T_d3b3a_row1_col6 {
#   color: black;
# }
# </style>
# <table id="T_d3b3a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3b3a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d3b3a_level0_col1" class="col_heading level0 col1" >Accuracy-No</th>
#       <th id="T_d3b3a_level0_col2" class="col_heading level0 col2" >Accuracy-Yes</th>
#       <th id="T_d3b3a_level0_col3" class="col_heading level0 col3" >Precision</th>
#       <th id="T_d3b3a_level0_col4" class="col_heading level0 col4" >Recall</th>
#       <th id="T_d3b3a_level0_col5" class="col_heading level0 col5" >F1-Score</th>
#       <th id="T_d3b3a_level0_col6" class="col_heading level0 col6" >CV AUC</th>
#       <th id="T_d3b3a_level0_col7" class="col_heading level0 col7" >CV std</th>
#       <th id="T_d3b3a_level0_col8" class="col_heading level0 col8" >AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3b3a_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_d3b3a_row0_col0" class="data row0 col0" >94.02%</td>
#       <td id="T_d3b3a_row0_col1" class="data row0 col1" >97.35%</td>
#       <td id="T_d3b3a_row0_col2" class="data row0 col2" >76.54%</td>
#       <td id="T_d3b3a_row0_col3" class="data row0 col3" >84.68%</td>
#       <td id="T_d3b3a_row0_col4" class="data row0 col4" >76.54%</td>
#       <td id="T_d3b3a_row0_col5" class="data row0 col5" >80.40%</td>
#       <td id="T_d3b3a_row0_col6" class="data row0 col6" >99.66%</td>
#       <td id="T_d3b3a_row0_col7" class="data row0 col7" >0.000522</td>
#       <td id="T_d3b3a_row0_col8" class="data row0 col8" >0.973001</td>
#     </tr>
#     <tr>
#       <th id="T_d3b3a_level0_row1" class="row_heading level0 row1" >XgBoost</th>
#       <td id="T_d3b3a_row1_col0" class="data row1 col0" >93.95%</td>
#       <td id="T_d3b3a_row1_col1" class="data row1 col1" >97.35%</td>
#       <td id="T_d3b3a_row1_col2" class="data row1 col2" >76.15%</td>
#       <td id="T_d3b3a_row1_col3" class="data row1 col3" >84.62%</td>
#       <td id="T_d3b3a_row1_col4" class="data row1 col4" >76.15%</td>
#       <td id="T_d3b3a_row1_col5" class="data row1 col5" >80.16%</td>
#       <td id="T_d3b3a_row1_col6" class="data row1 col6" >99.57%</td>
#       <td id="T_d3b3a_row1_col7" class="data row1 col7" >0.000776</td>
#       <td id="T_d3b3a_row1_col8" class="data row1 col8" >0.966306</td>
#     </tr>
#   </tbody>
# </table>

# %%
print_eval_result(model_test_comparison)
# Out:
# <style type="text/css">
# #T_76dfb_row0_col0, #T_76dfb_row0_col1, #T_76dfb_row0_col2, #T_76dfb_row0_col3, #T_76dfb_row0_col4, #T_76dfb_row0_col5, #T_76dfb_row0_col6, #T_76dfb_row1_col1 {
#   background-color: yellow;
#   color: black;
# }
# #T_76dfb_row0_col8, #T_76dfb_row1_col7 {
#   background-color: yellow;
# }
# #T_76dfb_row1_col0, #T_76dfb_row1_col2, #T_76dfb_row1_col3, #T_76dfb_row1_col4, #T_76dfb_row1_col5, #T_76dfb_row1_col6 {
#   color: black;
# }
# </style>
# <table id="T_76dfb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76dfb_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_76dfb_level0_col1" class="col_heading level0 col1" >Accuracy-No</th>
#       <th id="T_76dfb_level0_col2" class="col_heading level0 col2" >Accuracy-Yes</th>
#       <th id="T_76dfb_level0_col3" class="col_heading level0 col3" >Precision</th>
#       <th id="T_76dfb_level0_col4" class="col_heading level0 col4" >Recall</th>
#       <th id="T_76dfb_level0_col5" class="col_heading level0 col5" >F1-Score</th>
#       <th id="T_76dfb_level0_col6" class="col_heading level0 col6" >CV AUC</th>
#       <th id="T_76dfb_level0_col7" class="col_heading level0 col7" >CV std</th>
#       <th id="T_76dfb_level0_col8" class="col_heading level0 col8" >AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76dfb_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_76dfb_row0_col0" class="data row0 col0" >94.02%</td>
#       <td id="T_76dfb_row0_col1" class="data row0 col1" >97.35%</td>
#       <td id="T_76dfb_row0_col2" class="data row0 col2" >76.54%</td>
#       <td id="T_76dfb_row0_col3" class="data row0 col3" >84.68%</td>
#       <td id="T_76dfb_row0_col4" class="data row0 col4" >76.54%</td>
#       <td id="T_76dfb_row0_col5" class="data row0 col5" >80.40%</td>
#       <td id="T_76dfb_row0_col6" class="data row0 col6" >99.66%</td>
#       <td id="T_76dfb_row0_col7" class="data row0 col7" >0.000522</td>
#       <td id="T_76dfb_row0_col8" class="data row0 col8" >0.973001</td>
#     </tr>
#     <tr>
#       <th id="T_76dfb_level0_row1" class="row_heading level0 row1" >XgBoost</th>
#       <td id="T_76dfb_row1_col0" class="data row1 col0" >93.95%</td>
#       <td id="T_76dfb_row1_col1" class="data row1 col1" >97.35%</td>
#       <td id="T_76dfb_row1_col2" class="data row1 col2" >76.15%</td>
#       <td id="T_76dfb_row1_col3" class="data row1 col3" >84.62%</td>
#       <td id="T_76dfb_row1_col4" class="data row1 col4" >76.15%</td>
#       <td id="T_76dfb_row1_col5" class="data row1 col5" >80.16%</td>
#       <td id="T_76dfb_row1_col6" class="data row1 col6" >99.57%</td>
#       <td id="T_76dfb_row1_col7" class="data row1 col7" >0.000776</td>
#       <td id="T_76dfb_row1_col8" class="data row1 col8" >0.966306</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 평가자 확인 - Hidden Data 적용 후 결과 확인

# %%
# 예측 및 평가 수행
# fit_predict_eval(models, model_eval_comparison, X_train, y_train, X_eval, y_eval)
fit_predict_eval(models, model_eval_comparison, X_train, y_train, X_val, y_val, X_eval, y_eval)

#print_eval_result(model_eval_comparison)
# Out:
# [0]	validation_0-auc:0.94274	validation_1-auc:0.90440
# [1]	validation_0-auc:0.96669	validation_1-auc:0.91648
# [2]	validation_0-auc:0.97349	validation_1-auc:0.91967
# [3]	validation_0-auc:0.98001	validation_1-auc:0.93116
# [4]	validation_0-auc:0.98526	validation_1-auc:0.93675
# [5]	validation_0-auc:0.98938	validation_1-auc:0.94309
# [6]	validation_0-auc:0.99051	validation_1-auc:0.94785
# [7]	validation_0-auc:0.99197	validation_1-auc:0.94842
# [8]	validation_0-auc:0.99262	validation_1-auc:0.95158
# [9]	validation_0-auc:0.99350	validation_1-auc:0.95417
# [10]	validation_0-auc:0.99460	validation_1-auc:0.95583
# [11]	validation_0-auc:0.99525	validation_1-auc:0.95770
# [12]	validation_0-auc:0.99539	validation_1-auc:0.95993
# [13]	validation_0-auc:0.99568	validation_1-auc:0.96046
# [14]	validation_0-auc:0.99612	validation_1-auc:0.96400
# [15]	validation_0-auc:0.99643	validation_1-auc:0.96603
# [16]	validation_0-auc:0.99673	validation_1-auc:0.96651
# [17]	validation_0-auc:0.99703	validation_1-auc:0.96769
# [18]	validation_0-auc:0.99719	validation_1-auc:0.96939
# [19]	validation_0-auc:0.99735	validation_1-auc:0.96967
# [20]	validation_0-auc:0.99747	validation_1-auc:0.97016
# [21]	validation_0-auc:0.99751	validation_1-auc:0.97045
# [22]	validation_0-auc:0.99776	validation_1-auc:0.96986
# [23]	validation_0-auc:0.99786	validation_1-auc:0.97055
# [24]	validation_0-auc:0.99810	validation_1-auc:0.97076
# [25]	validation_0-auc:0.99819	validation_1-auc:0.97107
# [26]	validation_0-auc:0.99822	validation_1-auc:0.97151
# [27]	validation_0-auc:0.99844	validation_1-auc:0.97138
# [28]	validation_0-auc:0.99856	validation_1-auc:0.97179
# [29]	validation_0-auc:0.99871	validation_1-auc:0.97133
# [30]	validation_0-auc:0.99884	validation_1-auc:0.97133
# [31]	validation_0-auc:0.99892	validation_1-auc:0.97188
# [32]	validation_0-auc:0.99902	validation_1-auc:0.97137
# [33]	validation_0-auc:0.99916	validation_1-auc:0.97075
# [34]	validation_0-auc:0.99917	validation_1-auc:0.97126
# [35]	validation_0-auc:0.99918	validation_1-auc:0.97156
# [36]	validation_0-auc:0.99924	validation_1-auc:0.97188
# [37]	validation_0-auc:0.99930	validation_1-auc:0.97110
# [38]	validation_0-auc:0.99934	validation_1-auc:0.97163
# [39]	validation_0-auc:0.99936	validation_1-auc:0.97236
# [40]	validation_0-auc:0.99944	validation_1-auc:0.97283
# [41]	validation_0-auc:0.99949	validation_1-auc:0.97299
# [42]	validation_0-auc:0.99950	validation_1-auc:0.97282
# [43]	validation_0-auc:0.99954	validation_1-auc:0.97167
# [44]	validation_0-auc:0.99956	validation_1-auc:0.97223
# [45]	validation_0-auc:0.99958	validation_1-auc:0.97225
# [46]	validation_0-auc:0.99960	validation_1-auc:0.97250
# [47]	validation_0-auc:0.99962	validation_1-auc:0.97220
# [48]	validation_0-auc:0.99963	validation_1-auc:0.97237
# [49]	validation_0-auc:0.99965	validation_1-auc:0.97213
# [50]	validation_0-auc:0.99966	validation_1-auc:0.97133
# [51]	validation_0-auc:0.99967	validation_1-auc:0.97186
# [52]	validation_0-auc:0.99968	validation_1-auc:0.97195
# [53]	validation_0-auc:0.99968	validation_1-auc:0.97209
# [54]	validation_0-auc:0.99971	validation_1-auc:0.97149
# [55]	validation_0-auc:0.99972	validation_1-auc:0.97138
# [56]	validation_0-auc:0.99972	validation_1-auc:0.97161
# [57]	validation_0-auc:0.99974	validation_1-auc:0.97234
# [58]	validation_0-auc:0.99979	validation_1-auc:0.97246
# [59]	validation_0-auc:0.99982	validation_1-auc:0.97200
# [60]	validation_0-auc:0.99982	validation_1-auc:0.97119
# [61]	validation_0-auc:0.99984	validation_1-auc:0.97160
# [62]	validation_0-auc:0.99985	validation_1-auc:0.97156
# [63]	validation_0-auc:0.99987	validation_1-auc:0.97142
# [64]	validation_0-auc:0.99988	validation_1-auc:0.97122
# [65]	validation_0-auc:0.99990	validation_1-auc:0.97153
# [66]	validation_0-auc:0.99991	validation_1-auc:0.97161
# [67]	validation_0-auc:0.99993	validation_1-auc:0.97142
# [68]	validation_0-auc:0.99994	validation_1-auc:0.97163
# [69]	validation_0-auc:0.99994	validation_1-auc:0.97206
# [70]	validation_0-auc:0.99994	validation_1-auc:0.97177
# [71]	validation_0-auc:0.99995	validation_1-auc:0.97170
# [72]	validation_0-auc:0.99995	validation_1-auc:0.97137
# [73]	validation_0-auc:0.99996	validation_1-auc:0.97151
# [74]	validation_0-auc:0.99996	validation_1-auc:0.97059
# [75]	validation_0-auc:0.99997	validation_1-auc:0.97075
# [76]	validation_0-auc:0.99997	validation_1-auc:0.97110
# [77]	validation_0-auc:0.99998	validation_1-auc:0.97115
# [78]	validation_0-auc:0.99998	validation_1-auc:0.97101
# [79]	validation_0-auc:0.99999	validation_1-auc:0.97110
# [80]	validation_0-auc:0.99999	validation_1-auc:0.97135
# [81]	validation_0-auc:0.99999	validation_1-auc:0.97211
# [82]	validation_0-auc:0.99999	validation_1-auc:0.97186
# [83]	validation_0-auc:0.99999	validation_1-auc:0.97154
# [84]	validation_0-auc:0.99999	validation_1-auc:0.97213
# [85]	validation_0-auc:1.00000	validation_1-auc:0.97229
# [86]	validation_0-auc:1.00000	validation_1-auc:0.97244
# [87]	validation_0-auc:1.00000	validation_1-auc:0.97255
# [88]	validation_0-auc:1.00000	validation_1-auc:0.97225
# [89]	validation_0-auc:1.00000	validation_1-auc:0.97177
# [90]	validation_0-auc:1.00000	validation_1-auc:0.97181
# [91]	validation_0-auc:1.00000	validation_1-auc:0.97175
# [92]	validation_0-auc:1.00000	validation_1-auc:0.97216
# [93]	validation_0-auc:1.00000	validation_1-auc:0.97232
# [94]	validation_0-auc:1.00000	validation_1-auc:0.97274
# [95]	validation_0-auc:1.00000	validation_1-auc:0.97340
# [96]	validation_0-auc:1.00000	validation_1-auc:0.97301
# [97]	validation_0-auc:1.00000	validation_1-auc:0.97305
# [98]	validation_0-auc:1.00000	validation_1-auc:0.97310
# [99]	validation_0-auc:1.00000	validation_1-auc:0.97306
# [100]	validation_0-auc:1.00000	validation_1-auc:0.97312
# [101]	validation_0-auc:1.00000	validation_1-auc:0.97310
# [102]	validation_0-auc:1.00000	validation_1-auc:0.97335
# [103]	validation_0-auc:1.00000	validation_1-auc:0.97352
# [104]	validation_0-auc:1.00000	validation_1-auc:0.97361
# [105]	validation_0-auc:1.00000	validation_1-auc:0.97297
# [106]	validation_0-auc:1.00000	validation_1-auc:0.97324
# [107]	validation_0-auc:1.00000	validation_1-auc:0.97301
# [108]	validation_0-auc:1.00000	validation_1-auc:0.97313
# [109]	validation_0-auc:1.00000	validation_1-auc:0.97336
# [110]	validation_0-auc:1.00000	validation_1-auc:0.97373
# [111]	validation_0-auc:1.00000	validation_1-auc:0.97370
# [112]	validation_0-auc:1.00000	validation_1-auc:0.97386
# [113]	validation_0-auc:1.00000	validation_1-auc:0.97395
# [114]	validation_0-auc:1.00000	validation_1-auc:0.97393
# [115]	validation_0-auc:1.00000	validation_1-auc:0.97398
# [116]	validation_0-auc:1.00000	validation_1-auc:0.97381
# [117]	validation_0-auc:1.00000	validation_1-auc:0.97409
# [118]	validation_0-auc:1.00000	validation_1-auc:0.97416
# [119]	validation_0-auc:1.00000	validation_1-auc:0.97418
# [120]	validation_0-auc:1.00000	validation_1-auc:0.97400
# [121]	validation_0-auc:1.00000	validation_1-auc:0.97405
# [122]	validation_0-auc:1.00000	validation_1-auc:0.97405
# [123]	validation_0-auc:1.00000	validation_1-auc:0.97425
# [124]	validation_0-auc:1.00000	validation_1-auc:0.97437
# [125]	validation_0-auc:1.00000	validation_1-auc:0.97405
# [126]	validation_0-auc:1.00000	validation_1-auc:0.97402
# [127]	validation_0-auc:1.00000	validation_1-auc:0.97432
# [128]	validation_0-auc:1.00000	validation_1-auc:0.97448
# [129]	validation_0-auc:1.00000	validation_1-auc:0.97412
# [130]	validation_0-auc:1.00000	validation_1-auc:0.97449
# [131]	validation_0-auc:1.00000	validation_1-auc:0.97451
# [132]	validation_0-auc:1.00000	validation_1-auc:0.97439
# [133]	validation_0-auc:1.00000	validation_1-auc:0.97409
# [134]	validation_0-auc:1.00000	validation_1-auc:0.97393
# [135]	validation_0-auc:1.00000	validation_1-auc:0.97361
# [136]	validation_0-auc:1.00000	validation_1-auc:0.97361
# [137]	validation_0-auc:1.00000	validation_1-auc:0.97379
# [138]	validation_0-auc:1.00000	validation_1-auc:0.97377
# [139]	validation_0-auc:1.00000	validation_1-auc:0.97349
# [140]	validation_0-auc:1.00000	validation_1-auc:0.97354
# [141]	validation_0-auc:1.00000	validation_1-auc:0.97381
# [142]	validation_0-auc:1.00000	validation_1-auc:0.97373
# [143]	validation_0-auc:1.00000	validation_1-auc:0.97377
# [144]	validation_0-auc:1.00000	validation_1-auc:0.97388
# [145]	validation_0-auc:1.00000	validation_1-auc:0.97384
# [146]	validation_0-auc:1.00000	validation_1-auc:0.97412
# [147]	validation_0-auc:1.00000	validation_1-auc:0.97451
# [148]	validation_0-auc:1.00000	validation_1-auc:0.97457
# [149]	validation_0-auc:1.00000	validation_1-auc:0.97457
# [150]	validation_0-auc:1.00000	validation_1-auc:0.97453
# [151]	validation_0-auc:1.00000	validation_1-auc:0.97469
# [152]	validation_0-auc:1.00000	validation_1-auc:0.97464
# [153]	validation_0-auc:1.00000	validation_1-auc:0.97439
# [154]	validation_0-auc:1.00000	validation_1-auc:0.97451
# [155]	validation_0-auc:1.00000	validation_1-auc:0.97455
# [156]	validation_0-auc:1.00000	validation_1-auc:0.97425
# [157]	validation_0-auc:1.00000	validation_1-auc:0.97449
# [158]	validation_0-auc:1.00000	validation_1-auc:0.97439
# [159]	validation_0-auc:1.00000	validation_1-auc:0.97446
# [160]	validation_0-auc:1.00000	validation_1-auc:0.97465
# [161]	validation_0-auc:1.00000	validation_1-auc:0.97469
# [162]	validation_0-auc:1.00000	validation_1-auc:0.97472
# [163]	validation_0-auc:1.00000	validation_1-auc:0.97462
# [164]	validation_0-auc:1.00000	validation_1-auc:0.97451
# [165]	validation_0-auc:1.00000	validation_1-auc:0.97485
# [166]	validation_0-auc:1.00000	validation_1-auc:0.97497
# [167]	validation_0-auc:1.00000	validation_1-auc:0.97490
# [168]	validation_0-auc:1.00000	validation_1-auc:0.97495
# [169]	validation_0-auc:1.00000	validation_1-auc:0.97476
# [170]	validation_0-auc:1.00000	validation_1-auc:0.97506
# [171]	validation_0-auc:1.00000	validation_1-auc:0.97502
# [172]	validation_0-auc:1.00000	validation_1-auc:0.97501
# [173]	validation_0-auc:1.00000	validation_1-auc:0.97487
# [174]	validation_0-auc:1.00000	validation_1-auc:0.97499
# [175]	validation_0-auc:1.00000	validation_1-auc:0.97479
# [176]	validation_0-auc:1.00000	validation_1-auc:0.97479
# [177]	validation_0-auc:1.00000	validation_1-auc:0.97478
# [178]	validation_0-auc:1.00000	validation_1-auc:0.97464
# [179]	validation_0-auc:1.00000	validation_1-auc:0.97467
# [180]	validation_0-auc:1.00000	validation_1-auc:0.97453
# [181]	validation_0-auc:1.00000	validation_1-auc:0.97439
# [182]	validation_0-auc:1.00000	validation_1-auc:0.97442
# [183]	validation_0-auc:1.00000	validation_1-auc:0.97455
# [184]	validation_0-auc:1.00000	validation_1-auc:0.97448
# [185]	validation_0-auc:1.00000	validation_1-auc:0.97448
# [186]	validation_0-auc:1.00000	validation_1-auc:0.97441
# [187]	validation_0-auc:1.00000	validation_1-auc:0.97442
# [188]	validation_0-auc:1.00000	validation_1-auc:0.97444
# [189]	validation_0-auc:1.00000	validation_1-auc:0.97411
# [190]	validation_0-auc:1.00000	validation_1-auc:0.97412
# [191]	validation_0-auc:1.00000	validation_1-auc:0.97403
# [192]	validation_0-auc:1.00000	validation_1-auc:0.97416
# [193]	validation_0-auc:1.00000	validation_1-auc:0.97416
# [194]	validation_0-auc:1.00000	validation_1-auc:0.97395
# [195]	validation_0-auc:1.00000	validation_1-auc:0.97393
# [196]	validation_0-auc:1.00000	validation_1-auc:0.97398
# [197]	validation_0-auc:1.00000	validation_1-auc:0.97396
# [198]	validation_0-auc:1.00000	validation_1-auc:0.97388
# [199]	validation_0-auc:1.00000	validation_1-auc:0.97388
# [200]	validation_0-auc:1.00000	validation_1-auc:0.97395
# [201]	validation_0-auc:1.00000	validation_1-auc:0.97393
# [202]	validation_0-auc:1.00000	validation_1-auc:0.97366
# [203]	validation_0-auc:1.00000	validation_1-auc:0.97377
# [204]	validation_0-auc:1.00000	validation_1-auc:0.97350
# [205]	validation_0-auc:1.00000	validation_1-auc:0.97361
# [206]	validation_0-auc:1.00000	validation_1-auc:0.97368
# [207]	validation_0-auc:1.00000	validation_1-auc:0.97372
# [208]	validation_0-auc:1.00000	validation_1-auc:0.97372
# [209]	validation_0-auc:1.00000	validation_1-auc:0.97347
# [210]	validation_0-auc:1.00000	validation_1-auc:0.97358
# [211]	validation_0-auc:1.00000	validation_1-auc:0.97358
# [212]	validation_0-auc:1.00000	validation_1-auc:0.97365
# [213]	validation_0-auc:1.00000	validation_1-auc:0.97354
# [214]	validation_0-auc:1.00000	validation_1-auc:0.97340
# [215]	validation_0-auc:1.00000	validation_1-auc:0.97340
# [216]	validation_0-auc:1.00000	validation_1-auc:0.97326
# [217]	validation_0-auc:1.00000	validation_1-auc:0.97315
# [218]	validation_0-auc:1.00000	validation_1-auc:0.97320
# [219]	validation_0-auc:1.00000	validation_1-auc:0.97319
# [220]	validation_0-auc:1.00000	validation_1-auc:0.97327
# [221]	validation_0-auc:1.00000	validation_1-auc:0.97345
# [222]	validation_0-auc:1.00000	validation_1-auc:0.97352
# [223]	validation_0-auc:1.00000	validation_1-auc:0.97361
# [224]	validation_0-auc:1.00000	validation_1-auc:0.97363
# [225]	validation_0-auc:1.00000	validation_1-auc:0.97373
# [226]	validation_0-auc:1.00000	validation_1-auc:0.97368
# [227]	validation_0-auc:1.00000	validation_1-auc:0.97384
# [228]	validation_0-auc:1.00000	validation_1-auc:0.97384
# [229]	validation_0-auc:1.00000	validation_1-auc:0.97382
# [230]	validation_0-auc:1.00000	validation_1-auc:0.97379
# [231]	validation_0-auc:1.00000	validation_1-auc:0.97389
# [232]	validation_0-auc:1.00000	validation_1-auc:0.97389
# [233]	validation_0-auc:1.00000	validation_1-auc:0.97396
# [234]	validation_0-auc:1.00000	validation_1-auc:0.97389
# [235]	validation_0-auc:1.00000	validation_1-auc:0.97396
# [236]	validation_0-auc:1.00000	validation_1-auc:0.97381
# [237]	validation_0-auc:1.00000	validation_1-auc:0.97366
# [238]	validation_0-auc:1.00000	validation_1-auc:0.97356
# [239]	validation_0-auc:1.00000	validation_1-auc:0.97356
# [240]	validation_0-auc:1.00000	validation_1-auc:0.97352
# [241]	validation_0-auc:1.00000	validation_1-auc:0.97331
# [242]	validation_0-auc:1.00000	validation_1-auc:0.97340
# [243]	validation_0-auc:1.00000	validation_1-auc:0.97326
# [244]	validation_0-auc:1.00000	validation_1-auc:0.97331
# [245]	validation_0-auc:1.00000	validation_1-auc:0.97336
# [246]	validation_0-auc:1.00000	validation_1-auc:0.97343
# [247]	validation_0-auc:1.00000	validation_1-auc:0.97342
# [248]	validation_0-auc:1.00000	validation_1-auc:0.97326
# [249]	validation_0-auc:1.00000	validation_1-auc:0.97331
# [250]	validation_0-auc:1.00000	validation_1-auc:0.97340
# [251]	validation_0-auc:1.00000	validation_1-auc:0.97331
# [252]	validation_0-auc:1.00000	validation_1-auc:0.97342
# [253]	validation_0-auc:1.00000	validation_1-auc:0.97338
# [254]	validation_0-auc:1.00000	validation_1-auc:0.97343
# [255]	validation_0-auc:1.00000	validation_1-auc:0.97349
# [256]	validation_0-auc:1.00000	validation_1-auc:0.97342
# [257]	validation_0-auc:1.00000	validation_1-auc:0.97322
# [258]	validation_0-auc:1.00000	validation_1-auc:0.97354
# [259]	validation_0-auc:1.00000	validation_1-auc:0.97349
# [260]	validation_0-auc:1.00000	validation_1-auc:0.97349
# [261]	validation_0-auc:1.00000	validation_1-auc:0.97342
# [262]	validation_0-auc:1.00000	validation_1-auc:0.97356
# [263]	validation_0-auc:1.00000	validation_1-auc:0.97345
# [264]	validation_0-auc:1.00000	validation_1-auc:0.97338
# [265]	validation_0-auc:1.00000	validation_1-auc:0.97347
# [266]	validation_0-auc:1.00000	validation_1-auc:0.97338
# [267]	validation_0-auc:1.00000	validation_1-auc:0.97354
# [268]	validation_0-auc:1.00000	validation_1-auc:0.97358
# [269]	validation_0-auc:1.00000	validation_1-auc:0.97349
# [270]	validation_0-auc:1.00000	validation_1-auc:0.97350
# [271]	validation_0-auc:1.00000	validation_1-auc:0.97354
# [272]	validation_0-auc:1.00000	validation_1-auc:0.97349
# [273]	validation_0-auc:1.00000	validation_1-auc:0.97350
# [274]	validation_0-auc:1.00000	validation_1-auc:0.97345
# [275]	validation_0-auc:1.00000	validation_1-auc:0.97350
# [276]	validation_0-auc:1.00000	validation_1-auc:0.97335
# [277]	validation_0-auc:1.00000	validation_1-auc:0.97324
# [278]	validation_0-auc:1.00000	validation_1-auc:0.97324
# [279]	validation_0-auc:1.00000	validation_1-auc:0.97327
# [280]	validation_0-auc:1.00000	validation_1-auc:0.97335
# [281]	validation_0-auc:1.00000	validation_1-auc:0.97338
# [282]	validation_0-auc:1.00000	validation_1-auc:0.97342
# [283]	validation_0-auc:1.00000	validation_1-auc:0.97340
# [284]	validation_0-auc:1.00000	validation_1-auc:0.97329
# [285]	validation_0-auc:1.00000	validation_1-auc:0.97317
# [286]	validation_0-auc:1.00000	validation_1-auc:0.97327
# [287]	validation_0-auc:1.00000	validation_1-auc:0.97331
# [288]	validation_0-auc:1.00000	validation_1-auc:0.97333
# [289]	validation_0-auc:1.00000	validation_1-auc:0.97303
# [290]	validation_0-auc:1.00000	validation_1-auc:0.97274
# [291]	validation_0-auc:1.00000	validation_1-auc:0.97283
# [292]	validation_0-auc:1.00000	validation_1-auc:0.97285
# [293]	validation_0-auc:1.00000	validation_1-auc:0.97296
# [294]	validation_0-auc:1.00000	validation_1-auc:0.97282
# [295]	validation_0-auc:1.00000	validation_1-auc:0.97290
# [296]	validation_0-auc:1.00000	validation_1-auc:0.97285
# [297]	validation_0-auc:1.00000	validation_1-auc:0.97299
# [298]	validation_0-auc:1.00000	validation_1-auc:0.97278
# [299]	validation_0-auc:1.00000	validation_1-auc:0.97282
# [300]	validation_0-auc:1.00000	validation_1-auc:0.97257
# [301]	validation_0-auc:1.00000	validation_1-auc:0.97255
# [302]	validation_0-auc:1.00000	validation_1-auc:0.97251
# [303]	validation_0-auc:1.00000	validation_1-auc:0.97259
# [304]	validation_0-auc:1.00000	validation_1-auc:0.97264
# [305]	validation_0-auc:1.00000	validation_1-auc:0.97253
# [306]	validation_0-auc:1.00000	validation_1-auc:0.97262
# [307]	validation_0-auc:1.00000	validation_1-auc:0.97250
# [308]	validation_0-auc:1.00000	validation_1-auc:0.97255
# [309]	validation_0-auc:1.00000	validation_1-auc:0.97269
# [310]	validation_0-auc:1.00000	validation_1-auc:0.97269
# [311]	validation_0-auc:1.00000	validation_1-auc:0.97264
# [312]	validation_0-auc:1.00000	validation_1-auc:0.97259
# [313]	validation_0-auc:1.00000	validation_1-auc:0.97237
# [314]	validation_0-auc:1.00000	validation_1-auc:0.97241
# [315]	validation_0-auc:1.00000	validation_1-auc:0.97234
# [316]	validation_0-auc:1.00000	validation_1-auc:0.97229
# [317]	validation_0-auc:1.00000	validation_1-auc:0.97229
# [318]	validation_0-auc:1.00000	validation_1-auc:0.97221
# [319]	validation_0-auc:1.00000	validation_1-auc:0.97207
# [320]	validation_0-auc:1.00000	validation_1-auc:0.97206
# [321]	validation_0-auc:1.00000	validation_1-auc:0.97202
# [322]	validation_0-auc:1.00000	validation_1-auc:0.97211
# [323]	validation_0-auc:1.00000	validation_1-auc:0.97213
# [324]	validation_0-auc:1.00000	validation_1-auc:0.97223
# [325]	validation_0-auc:1.00000	validation_1-auc:0.97223
# [326]	validation_0-auc:1.00000	validation_1-auc:0.97216
# [327]	validation_0-auc:1.00000	validation_1-auc:0.97207
# [328]	validation_0-auc:1.00000	validation_1-auc:0.97195
# [329]	validation_0-auc:1.00000	validation_1-auc:0.97179
# [330]	validation_0-auc:1.00000	validation_1-auc:0.97213
# [331]	validation_0-auc:1.00000	validation_1-auc:0.97214
# [332]	validation_0-auc:1.00000	validation_1-auc:0.97227
# [333]	validation_0-auc:1.00000	validation_1-auc:0.97223
# [334]	validation_0-auc:1.00000	validation_1-auc:0.97223
# [335]	validation_0-auc:1.00000	validation_1-auc:0.97221
# [336]	validation_0-auc:1.00000	validation_1-auc:0.97211
# [337]	validation_0-auc:1.00000	validation_1-auc:0.97218
# [338]	validation_0-auc:1.00000	validation_1-auc:0.97227
# [339]	validation_0-auc:1.00000	validation_1-auc:0.97227
# [340]	validation_0-auc:1.00000	validation_1-auc:0.97229
# [341]	validation_0-auc:1.00000	validation_1-auc:0.97216
# [342]	validation_0-auc:1.00000	validation_1-auc:0.97218
# [343]	validation_0-auc:1.00000	validation_1-auc:0.97223
# [344]	validation_0-auc:1.00000	validation_1-auc:0.97216
# [345]	validation_0-auc:1.00000	validation_1-auc:0.97209
# [346]	validation_0-auc:1.00000	validation_1-auc:0.97193
# [347]	validation_0-auc:1.00000	validation_1-auc:0.97188
# [348]	validation_0-auc:1.00000	validation_1-auc:0.97193
# [349]	validation_0-auc:1.00000	validation_1-auc:0.97195
# [350]	validation_0-auc:1.00000	validation_1-auc:0.97193
# [351]	validation_0-auc:1.00000	validation_1-auc:0.97193
# [352]	validation_0-auc:1.00000	validation_1-auc:0.97193
# [353]	validation_0-auc:1.00000	validation_1-auc:0.97200
# [354]	validation_0-auc:1.00000	validation_1-auc:0.97200
# [355]	validation_0-auc:1.00000	validation_1-auc:0.97200
# [356]	validation_0-auc:1.00000	validation_1-auc:0.97195
# [357]	validation_0-auc:1.00000	validation_1-auc:0.97179
# [358]	validation_0-auc:1.00000	validation_1-auc:0.97170
# [359]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [360]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [361]	validation_0-auc:1.00000	validation_1-auc:0.97175
# [362]	validation_0-auc:1.00000	validation_1-auc:0.97160
# [363]	validation_0-auc:1.00000	validation_1-auc:0.97165
# [364]	validation_0-auc:1.00000	validation_1-auc:0.97172
# [365]	validation_0-auc:1.00000	validation_1-auc:0.97172
# [366]	validation_0-auc:1.00000	validation_1-auc:0.97167
# [367]	validation_0-auc:1.00000	validation_1-auc:0.97163
# [368]	validation_0-auc:1.00000	validation_1-auc:0.97161
# [369]	validation_0-auc:1.00000	validation_1-auc:0.97160
# [370]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [371]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [372]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [373]	validation_0-auc:1.00000	validation_1-auc:0.97149
# [374]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [375]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [376]	validation_0-auc:1.00000	validation_1-auc:0.97149
# [377]	validation_0-auc:1.00000	validation_1-auc:0.97137
# [378]	validation_0-auc:1.00000	validation_1-auc:0.97145
# [379]	validation_0-auc:1.00000	validation_1-auc:0.97151
# [380]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [381]	validation_0-auc:1.00000	validation_1-auc:0.97163
# [382]	validation_0-auc:1.00000	validation_1-auc:0.97158
# [383]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [384]	validation_0-auc:1.00000	validation_1-auc:0.97170
# [385]	validation_0-auc:1.00000	validation_1-auc:0.97168
# [386]	validation_0-auc:1.00000	validation_1-auc:0.97165
# [387]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [388]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [389]	validation_0-auc:1.00000	validation_1-auc:0.97153
# [390]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [391]	validation_0-auc:1.00000	validation_1-auc:0.97135
# [392]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [393]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [394]	validation_0-auc:1.00000	validation_1-auc:0.97133
# [395]	validation_0-auc:1.00000	validation_1-auc:0.97130
# [396]	validation_0-auc:1.00000	validation_1-auc:0.97135
# [397]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [398]	validation_0-auc:1.00000	validation_1-auc:0.97145
# [399]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [400]	validation_0-auc:1.00000	validation_1-auc:0.97145
# [401]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [402]	validation_0-auc:1.00000	validation_1-auc:0.97137
# [403]	validation_0-auc:1.00000	validation_1-auc:0.97137
# [404]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [405]	validation_0-auc:1.00000	validation_1-auc:0.97133
# [406]	validation_0-auc:1.00000	validation_1-auc:0.97137
# [407]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [408]	validation_0-auc:1.00000	validation_1-auc:0.97130
# [409]	validation_0-auc:1.00000	validation_1-auc:0.97135
# [410]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [411]	validation_0-auc:1.00000	validation_1-auc:0.97135
# [412]	validation_0-auc:1.00000	validation_1-auc:0.97133
# [413]	validation_0-auc:1.00000	validation_1-auc:0.97137
# [414]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [415]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [416]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [417]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [418]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [419]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [420]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [421]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [422]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [423]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [424]	validation_0-auc:1.00000	validation_1-auc:0.97151
# [425]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [426]	validation_0-auc:1.00000	validation_1-auc:0.97145
# [427]	validation_0-auc:1.00000	validation_1-auc:0.97137
# [428]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [429]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [430]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [431]	validation_0-auc:1.00000	validation_1-auc:0.97145
# [432]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [433]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [434]	validation_0-auc:1.00000	validation_1-auc:0.97158
# [435]	validation_0-auc:1.00000	validation_1-auc:0.97151
# [436]	validation_0-auc:1.00000	validation_1-auc:0.97153
# [437]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [438]	validation_0-auc:1.00000	validation_1-auc:0.97167
# [439]	validation_0-auc:1.00000	validation_1-auc:0.97161
# [440]	validation_0-auc:1.00000	validation_1-auc:0.97163
# [441]	validation_0-auc:1.00000	validation_1-auc:0.97165
# [442]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [443]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [444]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [445]	validation_0-auc:1.00000	validation_1-auc:0.97130
# [446]	validation_0-auc:1.00000	validation_1-auc:0.97122
# [447]	validation_0-auc:1.00000	validation_1-auc:0.97126
# [448]	validation_0-auc:1.00000	validation_1-auc:0.97121
# [449]	validation_0-auc:1.00000	validation_1-auc:0.97117
# [450]	validation_0-auc:1.00000	validation_1-auc:0.97117
# [451]	validation_0-auc:1.00000	validation_1-auc:0.97122
# [452]	validation_0-auc:1.00000	validation_1-auc:0.97124
# [453]	validation_0-auc:1.00000	validation_1-auc:0.97124
# [454]	validation_0-auc:1.00000	validation_1-auc:0.97122
# [455]	validation_0-auc:1.00000	validation_1-auc:0.97122
# [456]	validation_0-auc:1.00000	validation_1-auc:0.97117
# [457]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [458]	validation_0-auc:1.00000	validation_1-auc:0.97137
# [459]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [460]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [461]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [462]	validation_0-auc:1.00000	validation_1-auc:0.97153
# [463]	validation_0-auc:1.00000	validation_1-auc:0.97151
# [464]	validation_0-auc:1.00000	validation_1-auc:0.97149
# [465]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [466]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [467]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [468]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [469]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [470]	validation_0-auc:1.00000	validation_1-auc:0.97151
# [471]	validation_0-auc:1.00000	validation_1-auc:0.97151
# [472]	validation_0-auc:1.00000	validation_1-auc:0.97149
# [473]	validation_0-auc:1.00000	validation_1-auc:0.97147
# [474]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [475]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [476]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [477]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [478]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [479]	validation_0-auc:1.00000	validation_1-auc:0.97161
# [480]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [481]	validation_0-auc:1.00000	validation_1-auc:0.97153
# [482]	validation_0-auc:1.00000	validation_1-auc:0.97154
# [483]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [484]	validation_0-auc:1.00000	validation_1-auc:0.97156
# [485]	validation_0-auc:1.00000	validation_1-auc:0.97145
# [486]	validation_0-auc:1.00000	validation_1-auc:0.97133
# [487]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [488]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [489]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [490]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [491]	validation_0-auc:1.00000	validation_1-auc:0.97149
# [492]	validation_0-auc:1.00000	validation_1-auc:0.97151
# [493]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [494]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [495]	validation_0-auc:1.00000	validation_1-auc:0.97131
# [496]	validation_0-auc:1.00000	validation_1-auc:0.97124
# [497]	validation_0-auc:1.00000	validation_1-auc:0.97128
# [498]	validation_0-auc:1.00000	validation_1-auc:0.97131
# [499]	validation_0-auc:1.00000	validation_1-auc:0.97128
# [500]	validation_0-auc:1.00000	validation_1-auc:0.97128
# [501]	validation_0-auc:1.00000	validation_1-auc:0.97124
# [502]	validation_0-auc:1.00000	validation_1-auc:0.97130
# [503]	validation_0-auc:1.00000	validation_1-auc:0.97126
# [504]	validation_0-auc:1.00000	validation_1-auc:0.97130
# [505]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [506]	validation_0-auc:1.00000	validation_1-auc:0.97144
# [507]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [508]	validation_0-auc:1.00000	validation_1-auc:0.97130
# [509]	validation_0-auc:1.00000	validation_1-auc:0.97138
# [510]	validation_0-auc:1.00000	validation_1-auc:0.97145
# [511]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [512]	validation_0-auc:1.00000	validation_1-auc:0.97149
# [513]	validation_0-auc:1.00000	validation_1-auc:0.97142
# [514]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [515]	validation_0-auc:1.00000	validation_1-auc:0.97133
# [516]	validation_0-auc:1.00000	validation_1-auc:0.97128
# [517]	validation_0-auc:1.00000	validation_1-auc:0.97133
# [518]	validation_0-auc:1.00000	validation_1-auc:0.97140
# [519]	validation_0-auc:1.00000	validation_1-auc:0.97122
# [520]	validation_0-auc:1.00000	validation_1-auc:0.97112
# [521]	validation_0-auc:1.00000	validation_1-auc:0.97117
# [522]	validation_0-auc:1.00000	validation_1-auc:0.97112
# [523]	validation_0-auc:1.00000	validation_1-auc:0.97108
# [524]	validation_0-auc:1.00000	validation_1-auc:0.97114
# [525]	validation_0-auc:1.00000	validation_1-auc:0.97108
# [526]	validation_0-auc:1.00000	validation_1-auc:0.97103
# [527]	validation_0-auc:1.00000	validation_1-auc:0.97110
# [528]	validation_0-auc:1.00000	validation_1-auc:0.97105
# [529]	validation_0-auc:1.00000	validation_1-auc:0.97107
# [530]	validation_0-auc:1.00000	validation_1-auc:0.97112
# [531]	validation_0-auc:1.00000	validation_1-auc:0.97105
# [532]	validation_0-auc:1.00000	validation_1-auc:0.97114
# [533]	validation_0-auc:1.00000	validation_1-auc:0.97107
# [534]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [535]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [536]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [537]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [538]	validation_0-auc:1.00000	validation_1-auc:0.97103
# [539]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [540]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [541]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [542]	validation_0-auc:1.00000	validation_1-auc:0.97110
# [543]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [544]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [545]	validation_0-auc:1.00000	validation_1-auc:0.97092
# [546]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [547]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [548]	validation_0-auc:1.00000	validation_1-auc:0.97087
# [549]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [550]	validation_0-auc:1.00000	validation_1-auc:0.97092
# [551]	validation_0-auc:1.00000	validation_1-auc:0.97082
# [552]	validation_0-auc:1.00000	validation_1-auc:0.97092
# [553]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [554]	validation_0-auc:1.00000	validation_1-auc:0.97099
# [555]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [556]	validation_0-auc:1.00000	validation_1-auc:0.97099
# [557]	validation_0-auc:1.00000	validation_1-auc:0.97105
# [558]	validation_0-auc:1.00000	validation_1-auc:0.97107
# [559]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [560]	validation_0-auc:1.00000	validation_1-auc:0.97099
# [561]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [562]	validation_0-auc:1.00000	validation_1-auc:0.97092
# [563]	validation_0-auc:1.00000	validation_1-auc:0.97096
# [564]	validation_0-auc:1.00000	validation_1-auc:0.97096
# [565]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [566]	validation_0-auc:1.00000	validation_1-auc:0.97103
# [567]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [568]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [569]	validation_0-auc:1.00000	validation_1-auc:0.97092
# [570]	validation_0-auc:1.00000	validation_1-auc:0.97092
# [571]	validation_0-auc:1.00000	validation_1-auc:0.97105
# [572]	validation_0-auc:1.00000	validation_1-auc:0.97110
# [573]	validation_0-auc:1.00000	validation_1-auc:0.97107
# [574]	validation_0-auc:1.00000	validation_1-auc:0.97108
# [575]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [576]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [577]	validation_0-auc:1.00000	validation_1-auc:0.97087
# [578]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [579]	validation_0-auc:1.00000	validation_1-auc:0.97105
# [580]	validation_0-auc:1.00000	validation_1-auc:0.97099
# [581]	validation_0-auc:1.00000	validation_1-auc:0.97099
# [582]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [583]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [584]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [585]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [586]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [587]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [588]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [589]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [590]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [591]	validation_0-auc:1.00000	validation_1-auc:0.97092
# [592]	validation_0-auc:1.00000	validation_1-auc:0.97103
# [593]	validation_0-auc:1.00000	validation_1-auc:0.97105
# [594]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [595]	validation_0-auc:1.00000	validation_1-auc:0.97105
# [596]	validation_0-auc:1.00000	validation_1-auc:0.97096
# [597]	validation_0-auc:1.00000	validation_1-auc:0.97089
# [598]	validation_0-auc:1.00000	validation_1-auc:0.97084
# [599]	validation_0-auc:1.00000	validation_1-auc:0.97089
# [600]	validation_0-auc:1.00000	validation_1-auc:0.97101
# [601]	validation_0-auc:1.00000	validation_1-auc:0.97087
# [602]	validation_0-auc:1.00000	validation_1-auc:0.97096
# [603]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [604]	validation_0-auc:1.00000	validation_1-auc:0.97095
# [605]	validation_0-auc:1.00000	validation_1-auc:0.97094
# [606]	validation_0-auc:1.00000	validation_1-auc:0.97087
# [607]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [608]	validation_0-auc:1.00000	validation_1-auc:0.97087
# [609]	validation_0-auc:1.00000	validation_1-auc:0.97089
# [610]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [611]	validation_0-auc:1.00000	validation_1-auc:0.97098
# [612]	validation_0-auc:1.00000	validation_1-auc:0.97085
# [613]	validation_0-auc:1.00000	validation_1-auc:0.97091
# [614]	validation_0-auc:1.00000	validation_1-auc:0.97085
# [615]	validation_0-auc:1.00000	validation_1-auc:0.97080
# [616]	validation_0-auc:1.00000	validation_1-auc:0.97084
# [617]	validation_0-auc:1.00000	validation_1-auc:0.97078
# [618]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [619]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [620]	validation_0-auc:1.00000	validation_1-auc:0.97080
# [621]	validation_0-auc:1.00000	validation_1-auc:0.97076
# [622]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [623]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [624]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [625]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [626]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [627]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [628]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [629]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [630]	validation_0-auc:1.00000	validation_1-auc:0.97076
# [631]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [632]	validation_0-auc:1.00000	validation_1-auc:0.97068
# [633]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [634]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [635]	validation_0-auc:1.00000	validation_1-auc:0.97068
# [636]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [637]	validation_0-auc:1.00000	validation_1-auc:0.97062
# [638]	validation_0-auc:1.00000	validation_1-auc:0.97064
# [639]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [640]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [641]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [642]	validation_0-auc:1.00000	validation_1-auc:0.97068
# [643]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [644]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [645]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [646]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [647]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [648]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [649]	validation_0-auc:1.00000	validation_1-auc:0.97068
# [650]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [651]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [652]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [653]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [654]	validation_0-auc:1.00000	validation_1-auc:0.97076
# [655]	validation_0-auc:1.00000	validation_1-auc:0.97076
# [656]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [657]	validation_0-auc:1.00000	validation_1-auc:0.97068
# [658]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [659]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [660]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [661]	validation_0-auc:1.00000	validation_1-auc:0.97073
# [662]	validation_0-auc:1.00000	validation_1-auc:0.97082
# [663]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [664]	validation_0-auc:1.00000	validation_1-auc:0.97075
# [665]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [666]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [667]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [668]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [669]	validation_0-auc:1.00000	validation_1-auc:0.97071
# [670]	validation_0-auc:1.00000	validation_1-auc:0.97069
# [671]	validation_0-auc:1.00000	validation_1-auc:0.97068
# [672]	validation_0-auc:1.00000	validation_1-auc:0.97061
# [673]	validation_0-auc:1.00000	validation_1-auc:0.97061
# [674]	validation_0-auc:1.00000	validation_1-auc:0.97062
# [675]	validation_0-auc:1.00000	validation_1-auc:0.97059
# [676]	validation_0-auc:1.00000	validation_1-auc:0.97055
# [677]	validation_0-auc:1.00000	validation_1-auc:0.97054
# [678]	validation_0-auc:1.00000	validation_1-auc:0.97050
# [679]	validation_0-auc:1.00000	validation_1-auc:0.97046
# [680]	validation_0-auc:1.00000	validation_1-auc:0.97054
# [681]	validation_0-auc:1.00000	validation_1-auc:0.97055
# [682]	validation_0-auc:1.00000	validation_1-auc:0.97061
# [683]	validation_0-auc:1.00000	validation_1-auc:0.97059
# [684]	validation_0-auc:1.00000	validation_1-auc:0.97062
# [685]	validation_0-auc:1.00000	validation_1-auc:0.97061
# [686]	validation_0-auc:1.00000	validation_1-auc:0.97059
# [687]	validation_0-auc:1.00000	validation_1-auc:0.97059
# [688]	validation_0-auc:1.00000	validation_1-auc:0.97059
# [689]	validation_0-auc:1.00000	validation_1-auc:0.97052
# [690]	validation_0-auc:1.00000	validation_1-auc:0.97057
# [691]	validation_0-auc:1.00000	validation_1-auc:0.97059
# [692]	validation_0-auc:1.00000	validation_1-auc:0.97064
# [693]	validation_0-auc:1.00000	validation_1-auc:0.97061
# [694]	validation_0-auc:1.00000	validation_1-auc:0.97061
# [695]	validation_0-auc:1.00000	validation_1-auc:0.97064
# [696]	validation_0-auc:1.00000	validation_1-auc:0.97066
# [697]	validation_0-auc:1.00000	validation_1-auc:0.97064
# [698]	validation_0-auc:1.00000	validation_1-auc:0.97068
# [699]	validation_0-auc:1.00000	validation_1-auc:0.97054
# Model Name: [XgBoost           ], 2023-09-20 16:08:17, 0:00:15,  BEST AUC: 0.987188, AUC: 0.987188
# [1]	training's binary_logloss: 0.631645	valid_1's binary_logloss: 0.636219
# [2]	training's binary_logloss: 0.579096	valid_1's binary_logloss: 0.590489
# [3]	training's binary_logloss: 0.534514	valid_1's binary_logloss: 0.548616
# [4]	training's binary_logloss: 0.495037	valid_1's binary_logloss: 0.514227
# [5]	training's binary_logloss: 0.461619	valid_1's binary_logloss: 0.486265
# [6]	training's binary_logloss: 0.432438	valid_1's binary_logloss: 0.46028
# [7]	training's binary_logloss: 0.405636	valid_1's binary_logloss: 0.438045
# [8]	training's binary_logloss: 0.381892	valid_1's binary_logloss: 0.416585
# [9]	training's binary_logloss: 0.360803	valid_1's binary_logloss: 0.397352
# [10]	training's binary_logloss: 0.341154	valid_1's binary_logloss: 0.378582
# [11]	training's binary_logloss: 0.323402	valid_1's binary_logloss: 0.362409
# [12]	training's binary_logloss: 0.304603	valid_1's binary_logloss: 0.344715
# [13]	training's binary_logloss: 0.289652	valid_1's binary_logloss: 0.331613
# [14]	training's binary_logloss: 0.276725	valid_1's binary_logloss: 0.322193
# [15]	training's binary_logloss: 0.265339	valid_1's binary_logloss: 0.311784
# [16]	training's binary_logloss: 0.253707	valid_1's binary_logloss: 0.301144
# [17]	training's binary_logloss: 0.241805	valid_1's binary_logloss: 0.289979
# [18]	training's binary_logloss: 0.229419	valid_1's binary_logloss: 0.281446
# [19]	training's binary_logloss: 0.220312	valid_1's binary_logloss: 0.272843
# [20]	training's binary_logloss: 0.212821	valid_1's binary_logloss: 0.266867
# [21]	training's binary_logloss: 0.203942	valid_1's binary_logloss: 0.258224
# [22]	training's binary_logloss: 0.196798	valid_1's binary_logloss: 0.251027
# [23]	training's binary_logloss: 0.190199	valid_1's binary_logloss: 0.245583
# [24]	training's binary_logloss: 0.18316	valid_1's binary_logloss: 0.239721
# [25]	training's binary_logloss: 0.177789	valid_1's binary_logloss: 0.234556
# [26]	training's binary_logloss: 0.170732	valid_1's binary_logloss: 0.226987
# [27]	training's binary_logloss: 0.165805	valid_1's binary_logloss: 0.222157
# [28]	training's binary_logloss: 0.160183	valid_1's binary_logloss: 0.216494
# [29]	training's binary_logloss: 0.154479	valid_1's binary_logloss: 0.210038
# [30]	training's binary_logloss: 0.148366	valid_1's binary_logloss: 0.204644
# [31]	training's binary_logloss: 0.143184	valid_1's binary_logloss: 0.199761
# [32]	training's binary_logloss: 0.139577	valid_1's binary_logloss: 0.196502
# [33]	training's binary_logloss: 0.135222	valid_1's binary_logloss: 0.191046
# [34]	training's binary_logloss: 0.130848	valid_1's binary_logloss: 0.187978
# [35]	training's binary_logloss: 0.127572	valid_1's binary_logloss: 0.185634
# [36]	training's binary_logloss: 0.123543	valid_1's binary_logloss: 0.180698
# [37]	training's binary_logloss: 0.119801	valid_1's binary_logloss: 0.177229
# [38]	training's binary_logloss: 0.116155	valid_1's binary_logloss: 0.174474
# [39]	training's binary_logloss: 0.112584	valid_1's binary_logloss: 0.170781
# [40]	training's binary_logloss: 0.10936	valid_1's binary_logloss: 0.168282
# [41]	training's binary_logloss: 0.106815	valid_1's binary_logloss: 0.166508
# [42]	training's binary_logloss: 0.103996	valid_1's binary_logloss: 0.16429
# [43]	training's binary_logloss: 0.101447	valid_1's binary_logloss: 0.161323
# [44]	training's binary_logloss: 0.0987199	valid_1's binary_logloss: 0.159535
# [45]	training's binary_logloss: 0.0965521	valid_1's binary_logloss: 0.15739
# [46]	training's binary_logloss: 0.0940833	valid_1's binary_logloss: 0.155274
# [47]	training's binary_logloss: 0.0921906	valid_1's binary_logloss: 0.153955
# [48]	training's binary_logloss: 0.0902349	valid_1's binary_logloss: 0.151874
# [49]	training's binary_logloss: 0.0880436	valid_1's binary_logloss: 0.149647
# [50]	training's binary_logloss: 0.0862608	valid_1's binary_logloss: 0.148611
# [51]	training's binary_logloss: 0.0840687	valid_1's binary_logloss: 0.147132
# [52]	training's binary_logloss: 0.0820559	valid_1's binary_logloss: 0.14556
# [53]	training's binary_logloss: 0.0803956	valid_1's binary_logloss: 0.145016
# [54]	training's binary_logloss: 0.0789438	valid_1's binary_logloss: 0.144232
# [55]	training's binary_logloss: 0.0770474	valid_1's binary_logloss: 0.142127
# [56]	training's binary_logloss: 0.0751533	valid_1's binary_logloss: 0.141052
# [57]	training's binary_logloss: 0.0736944	valid_1's binary_logloss: 0.140069
# [58]	training's binary_logloss: 0.072215	valid_1's binary_logloss: 0.139178
# [59]	training's binary_logloss: 0.0709745	valid_1's binary_logloss: 0.137922
# [60]	training's binary_logloss: 0.069657	valid_1's binary_logloss: 0.137847
# [61]	training's binary_logloss: 0.0684026	valid_1's binary_logloss: 0.137052
# [62]	training's binary_logloss: 0.0671773	valid_1's binary_logloss: 0.136349
# [63]	training's binary_logloss: 0.0660774	valid_1's binary_logloss: 0.136165
# [64]	training's binary_logloss: 0.0650255	valid_1's binary_logloss: 0.135006
# [65]	training's binary_logloss: 0.0640603	valid_1's binary_logloss: 0.13433
# [66]	training's binary_logloss: 0.062711	valid_1's binary_logloss: 0.134002
# [67]	training's binary_logloss: 0.0615266	valid_1's binary_logloss: 0.133594
# [68]	training's binary_logloss: 0.0603785	valid_1's binary_logloss: 0.133654
# [69]	training's binary_logloss: 0.0595073	valid_1's binary_logloss: 0.132919
# [70]	training's binary_logloss: 0.0584588	valid_1's binary_logloss: 0.132095
# [71]	training's binary_logloss: 0.0575484	valid_1's binary_logloss: 0.131634
# [72]	training's binary_logloss: 0.0565936	valid_1's binary_logloss: 0.131009
# [73]	training's binary_logloss: 0.0557548	valid_1's binary_logloss: 0.130217
# [74]	training's binary_logloss: 0.0547556	valid_1's binary_logloss: 0.129487
# [75]	training's binary_logloss: 0.0536846	valid_1's binary_logloss: 0.129009
# [76]	training's binary_logloss: 0.0528475	valid_1's binary_logloss: 0.128838
# [77]	training's binary_logloss: 0.0521147	valid_1's binary_logloss: 0.128433
# [78]	training's binary_logloss: 0.0513823	valid_1's binary_logloss: 0.128469
# [79]	training's binary_logloss: 0.0504783	valid_1's binary_logloss: 0.127763
# [80]	training's binary_logloss: 0.049573	valid_1's binary_logloss: 0.127249
# [81]	training's binary_logloss: 0.0487405	valid_1's binary_logloss: 0.126494
# [82]	training's binary_logloss: 0.047952	valid_1's binary_logloss: 0.126313
# [83]	training's binary_logloss: 0.0471403	valid_1's binary_logloss: 0.12571
# [84]	training's binary_logloss: 0.0464716	valid_1's binary_logloss: 0.125162
# [85]	training's binary_logloss: 0.0457331	valid_1's binary_logloss: 0.124596
# [86]	training's binary_logloss: 0.0451162	valid_1's binary_logloss: 0.125055
# [87]	training's binary_logloss: 0.0442741	valid_1's binary_logloss: 0.125126
# [88]	training's binary_logloss: 0.0436151	valid_1's binary_logloss: 0.124644
# [89]	training's binary_logloss: 0.0429486	valid_1's binary_logloss: 0.125074
# [90]	training's binary_logloss: 0.0424038	valid_1's binary_logloss: 0.124732
# [91]	training's binary_logloss: 0.0418136	valid_1's binary_logloss: 0.124442
# [92]	training's binary_logloss: 0.0411859	valid_1's binary_logloss: 0.12461
# [93]	training's binary_logloss: 0.0405066	valid_1's binary_logloss: 0.124079
# [94]	training's binary_logloss: 0.0398904	valid_1's binary_logloss: 0.1241
# [95]	training's binary_logloss: 0.0392166	valid_1's binary_logloss: 0.124115
# [96]	training's binary_logloss: 0.0386478	valid_1's binary_logloss: 0.123913
# [97]	training's binary_logloss: 0.0380828	valid_1's binary_logloss: 0.12332
# [98]	training's binary_logloss: 0.0374598	valid_1's binary_logloss: 0.123842
# [99]	training's binary_logloss: 0.0369441	valid_1's binary_logloss: 0.123886
# [100]	training's binary_logloss: 0.0363628	valid_1's binary_logloss: 0.123811
# [101]	training's binary_logloss: 0.0359721	valid_1's binary_logloss: 0.12414
# [102]	training's binary_logloss: 0.0355273	valid_1's binary_logloss: 0.124035
# [103]	training's binary_logloss: 0.0350658	valid_1's binary_logloss: 0.124033
# [104]	training's binary_logloss: 0.034443	valid_1's binary_logloss: 0.124107
# [105]	training's binary_logloss: 0.0339605	valid_1's binary_logloss: 0.124743
# [106]	training's binary_logloss: 0.0334513	valid_1's binary_logloss: 0.124363
# [107]	training's binary_logloss: 0.0328605	valid_1's binary_logloss: 0.124628
# [108]	training's binary_logloss: 0.032441	valid_1's binary_logloss: 0.124338
# [109]	training's binary_logloss: 0.0319713	valid_1's binary_logloss: 0.123826
# [110]	training's binary_logloss: 0.0314312	valid_1's binary_logloss: 0.123976
# [111]	training's binary_logloss: 0.0309933	valid_1's binary_logloss: 0.12362
# [112]	training's binary_logloss: 0.0305564	valid_1's binary_logloss: 0.122938
# [113]	training's binary_logloss: 0.0300825	valid_1's binary_logloss: 0.123033
# [114]	training's binary_logloss: 0.0296081	valid_1's binary_logloss: 0.123694
# [115]	training's binary_logloss: 0.0292065	valid_1's binary_logloss: 0.123327
# ...
# [502]	training's binary_logloss: 0.000298301	valid_1's binary_logloss: 0.164309
# [503]	training's binary_logloss: 0.000295472	valid_1's binary_logloss: 0.164424
# [504]	training's binary_logloss: 0.000292011	valid_1's binary_logloss: 0.164403
# [505]	training's binary_logloss: 0.000288664	valid_1's binary_logloss: 0.164412
# [506]	training's binary_logloss: 0.000285444	valid_1's binary_logloss: 0.164648
# [507]	training's binary_logloss: 0.000282232	valid_1's binary_logloss: 0.164346
# [508]	training's binary_logloss: 0.00027877	valid_1's binary_logloss: 0.16449
# [509]	training's binary_logloss: 0.000275872	valid_1's binary_logloss: 0.164563
# [510]	training's binary_logloss: 0.000273272	valid_1's binary_logloss: 0.164412
# [511]	training's binary_logloss: 0.000270483	valid_1's binary_logloss: 0.164168
# [512]	training's binary_logloss: 0.000267387	valid_1's binary_logloss: 0.164471
# [513]	training's binary_logloss: 0.000263936	valid_1's binary_logloss: 0.164724
# [514]	training's binary_logloss: 0.000261235	valid_1's binary_logloss: 0.164689
# [515]	training's binary_logloss: 0.000258458	valid_1's binary_logloss: 0.164595
# [516]	training's binary_logloss: 0.000255379	valid_1's binary_logloss: 0.16466
# [517]	training's binary_logloss: 0.000252845	valid_1's binary_logloss: 0.165363
# [518]	training's binary_logloss: 0.000249852	valid_1's binary_logloss: 0.165643
# [519]	training's binary_logloss: 0.000247494	valid_1's binary_logloss: 0.165665
# [520]	training's binary_logloss: 0.000244608	valid_1's binary_logloss: 0.165844
# [521]	training's binary_logloss: 0.000242189	valid_1's binary_logloss: 0.166046
# [522]	training's binary_logloss: 0.000239505	valid_1's binary_logloss: 0.165995
# [523]	training's binary_logloss: 0.000236617	valid_1's binary_logloss: 0.165752
# [524]	training's binary_logloss: 0.000233862	valid_1's binary_logloss: 0.166319
# [525]	training's binary_logloss: 0.000231095	valid_1's binary_logloss: 0.166535
# [526]	training's binary_logloss: 0.000228622	valid_1's binary_logloss: 0.167017
# [527]	training's binary_logloss: 0.000225846	valid_1's binary_logloss: 0.167369
# [528]	training's binary_logloss: 0.000223507	valid_1's binary_logloss: 0.167538
# [529]	training's binary_logloss: 0.000221067	valid_1's binary_logloss: 0.16692
# [530]	training's binary_logloss: 0.000218115	valid_1's binary_logloss: 0.167099
# [531]	training's binary_logloss: 0.000215211	valid_1's binary_logloss: 0.167645
# [532]	training's binary_logloss: 0.000212623	valid_1's binary_logloss: 0.167777
# [533]	training's binary_logloss: 0.000210301	valid_1's binary_logloss: 0.167885
# [534]	training's binary_logloss: 0.000207992	valid_1's binary_logloss: 0.168674
# [535]	training's binary_logloss: 0.000205505	valid_1's binary_logloss: 0.168723
# [536]	training's binary_logloss: 0.00020319	valid_1's binary_logloss: 0.1691
# [537]	training's binary_logloss: 0.000200606	valid_1's binary_logloss: 0.169524
# [538]	training's binary_logloss: 0.000198253	valid_1's binary_logloss: 0.169894
# [539]	training's binary_logloss: 0.000196077	valid_1's binary_logloss: 0.170202
# [540]	training's binary_logloss: 0.000193888	valid_1's binary_logloss: 0.170127
# [541]	training's binary_logloss: 0.000191708	valid_1's binary_logloss: 0.170129
# [542]	training's binary_logloss: 0.000189793	valid_1's binary_logloss: 0.170474
# [543]	training's binary_logloss: 0.000187882	valid_1's binary_logloss: 0.170364
# [544]	training's binary_logloss: 0.000186037	valid_1's binary_logloss: 0.170839
# [545]	training's binary_logloss: 0.0001839	valid_1's binary_logloss: 0.170844
# [546]	training's binary_logloss: 0.000182267	valid_1's binary_logloss: 0.171343
# [547]	training's binary_logloss: 0.000180489	valid_1's binary_logloss: 0.171673
# [548]	training's binary_logloss: 0.000178796	valid_1's binary_logloss: 0.171933
# [549]	training's binary_logloss: 0.000176608	valid_1's binary_logloss: 0.172304
# [550]	training's binary_logloss: 0.000174884	valid_1's binary_logloss: 0.172256
# [551]	training's binary_logloss: 0.000172708	valid_1's binary_logloss: 0.172555
# [552]	training's binary_logloss: 0.000170978	valid_1's binary_logloss: 0.172824
# [553]	training's binary_logloss: 0.000169299	valid_1's binary_logloss: 0.17337
# [554]	training's binary_logloss: 0.000167189	valid_1's binary_logloss: 0.173735
# [555]	training's binary_logloss: 0.000165507	valid_1's binary_logloss: 0.174047
# [556]	training's binary_logloss: 0.00016354	valid_1's binary_logloss: 0.17424
# [557]	training's binary_logloss: 0.000161646	valid_1's binary_logloss: 0.174905
# [558]	training's binary_logloss: 0.000159851	valid_1's binary_logloss: 0.175552
# [559]	training's binary_logloss: 0.000158068	valid_1's binary_logloss: 0.175595
# [560]	training's binary_logloss: 0.000156364	valid_1's binary_logloss: 0.17597
# [561]	training's binary_logloss: 0.000154621	valid_1's binary_logloss: 0.176004
# [562]	training's binary_logloss: 0.00015283	valid_1's binary_logloss: 0.176299
# [563]	training's binary_logloss: 0.000151317	valid_1's binary_logloss: 0.176436
# [564]	training's binary_logloss: 0.000149582	valid_1's binary_logloss: 0.176687
# [565]	training's binary_logloss: 0.000147923	valid_1's binary_logloss: 0.17665
# [566]	training's binary_logloss: 0.000146062	valid_1's binary_logloss: 0.176668
# [567]	training's binary_logloss: 0.000144249	valid_1's binary_logloss: 0.17722
# [568]	training's binary_logloss: 0.000142889	valid_1's binary_logloss: 0.177611
# [569]	training's binary_logloss: 0.000140923	valid_1's binary_logloss: 0.177524
# [570]	training's binary_logloss: 0.000139091	valid_1's binary_logloss: 0.177708
# [571]	training's binary_logloss: 0.000137679	valid_1's binary_logloss: 0.177704
# [572]	training's binary_logloss: 0.00013645	valid_1's binary_logloss: 0.177353
# [573]	training's binary_logloss: 0.000134842	valid_1's binary_logloss: 0.177062
# [574]	training's binary_logloss: 0.000133126	valid_1's binary_logloss: 0.176856
# [575]	training's binary_logloss: 0.000131846	valid_1's binary_logloss: 0.177094
# [576]	training's binary_logloss: 0.000130485	valid_1's binary_logloss: 0.177144
# [577]	training's binary_logloss: 0.000129102	valid_1's binary_logloss: 0.177552
# [578]	training's binary_logloss: 0.00012757	valid_1's binary_logloss: 0.178009
# [579]	training's binary_logloss: 0.000126174	valid_1's binary_logloss: 0.178497
# [580]	training's binary_logloss: 0.000124838	valid_1's binary_logloss: 0.178386
# [581]	training's binary_logloss: 0.000123388	valid_1's binary_logloss: 0.178257
# [582]	training's binary_logloss: 0.000122043	valid_1's binary_logloss: 0.178526
# [583]	training's binary_logloss: 0.000120784	valid_1's binary_logloss: 0.178539
# [584]	training's binary_logloss: 0.000119223	valid_1's binary_logloss: 0.178523
# [585]	training's binary_logloss: 0.000117875	valid_1's binary_logloss: 0.178921
# [586]	training's binary_logloss: 0.000116681	valid_1's binary_logloss: 0.178934
# [587]	training's binary_logloss: 0.000115588	valid_1's binary_logloss: 0.17882
# [588]	training's binary_logloss: 0.000114306	valid_1's binary_logloss: 0.178573
# [589]	training's binary_logloss: 0.000112986	valid_1's binary_logloss: 0.178826
# [590]	training's binary_logloss: 0.00011182	valid_1's binary_logloss: 0.179172
# [591]	training's binary_logloss: 0.000110594	valid_1's binary_logloss: 0.179707
# [592]	training's binary_logloss: 0.000109209	valid_1's binary_logloss: 0.17984
# [593]	training's binary_logloss: 0.000107882	valid_1's binary_logloss: 0.17992
# [594]	training's binary_logloss: 0.000106582	valid_1's binary_logloss: 0.179923
# [595]	training's binary_logloss: 0.000105292	valid_1's binary_logloss: 0.180111
# [596]	training's binary_logloss: 0.000103891	valid_1's binary_logloss: 0.180811
# [597]	training's binary_logloss: 0.000102642	valid_1's binary_logloss: 0.181362
# [598]	training's binary_logloss: 0.000101496	valid_1's binary_logloss: 0.181607
# [599]	training's binary_logloss: 0.000100399	valid_1's binary_logloss: 0.181683
# [600]	training's binary_logloss: 9.92998e-05	valid_1's binary_logloss: 0.181736
# [601]	training's binary_logloss: 9.82413e-05	valid_1's binary_logloss: 0.181719
# [602]	training's binary_logloss: 9.71209e-05	valid_1's binary_logloss: 0.181609
# [603]	training's binary_logloss: 9.62387e-05	valid_1's binary_logloss: 0.182042
# [604]	training's binary_logloss: 9.5011e-05	valid_1's binary_logloss: 0.182302
# [605]	training's binary_logloss: 9.4049e-05	valid_1's binary_logloss: 0.18203
# [606]	training's binary_logloss: 9.30636e-05	valid_1's binary_logloss: 0.182369
# [607]	training's binary_logloss: 9.21597e-05	valid_1's binary_logloss: 0.18234
# [608]	training's binary_logloss: 9.10858e-05	valid_1's binary_logloss: 0.182584
# [609]	training's binary_logloss: 9.00506e-05	valid_1's binary_logloss: 0.1828
# [610]	training's binary_logloss: 8.91391e-05	valid_1's binary_logloss: 0.18305
# [611]	training's binary_logloss: 8.82175e-05	valid_1's binary_logloss: 0.183367
# [612]	training's binary_logloss: 8.70041e-05	valid_1's binary_logloss: 0.183272
# [613]	training's binary_logloss: 8.58409e-05	valid_1's binary_logloss: 0.183283
# [614]	training's binary_logloss: 8.48114e-05	valid_1's binary_logloss: 0.18324
# [615]	training's binary_logloss: 8.39911e-05	valid_1's binary_logloss: 0.183504
# [616]	training's binary_logloss: 8.28047e-05	valid_1's binary_logloss: 0.183825
# [617]	training's binary_logloss: 8.16995e-05	valid_1's binary_logloss: 0.183736
# [618]	training's binary_logloss: 8.07486e-05	valid_1's binary_logloss: 0.183739
# [619]	training's binary_logloss: 7.97388e-05	valid_1's binary_logloss: 0.184103
# [620]	training's binary_logloss: 7.87652e-05	valid_1's binary_logloss: 0.183701
# [621]	training's binary_logloss: 7.78076e-05	valid_1's binary_logloss: 0.183874
# [622]	training's binary_logloss: 7.67553e-05	valid_1's binary_logloss: 0.183817
# [623]	training's binary_logloss: 7.59223e-05	valid_1's binary_logloss: 0.18412
# [624]	training's binary_logloss: 7.51156e-05	valid_1's binary_logloss: 0.184544
# [625]	training's binary_logloss: 7.42141e-05	valid_1's binary_logloss: 0.184903
# [626]	training's binary_logloss: 7.34458e-05	valid_1's binary_logloss: 0.184656
# [627]	training's binary_logloss: 7.2766e-05	valid_1's binary_logloss: 0.185217
# [628]	training's binary_logloss: 7.18759e-05	valid_1's binary_logloss: 0.18547
# [629]	training's binary_logloss: 7.10397e-05	valid_1's binary_logloss: 0.18505
# [630]	training's binary_logloss: 7.02557e-05	valid_1's binary_logloss: 0.185219
# [631]	training's binary_logloss: 6.93012e-05	valid_1's binary_logloss: 0.185082
# [632]	training's binary_logloss: 6.86003e-05	valid_1's binary_logloss: 0.18533
# [633]	training's binary_logloss: 6.78197e-05	valid_1's binary_logloss: 0.18578
# [634]	training's binary_logloss: 6.71669e-05	valid_1's binary_logloss: 0.185711
# [635]	training's binary_logloss: 6.65025e-05	valid_1's binary_logloss: 0.185885
# [636]	training's binary_logloss: 6.57354e-05	valid_1's binary_logloss: 0.185827
# [637]	training's binary_logloss: 6.51121e-05	valid_1's binary_logloss: 0.186296
# [638]	training's binary_logloss: 6.4398e-05	valid_1's binary_logloss: 0.186753
# [639]	training's binary_logloss: 6.36983e-05	valid_1's binary_logloss: 0.187014
# [640]	training's binary_logloss: 6.29818e-05	valid_1's binary_logloss: 0.186866
# [641]	training's binary_logloss: 6.22306e-05	valid_1's binary_logloss: 0.187528
# [642]	training's binary_logloss: 6.15635e-05	valid_1's binary_logloss: 0.188024
# [643]	training's binary_logloss: 6.09859e-05	valid_1's binary_logloss: 0.187793
# [644]	training's binary_logloss: 6.0239e-05	valid_1's binary_logloss: 0.187677
# [645]	training's binary_logloss: 5.96129e-05	valid_1's binary_logloss: 0.187875
# [646]	training's binary_logloss: 5.89983e-05	valid_1's binary_logloss: 0.187956
# [647]	training's binary_logloss: 5.82139e-05	valid_1's binary_logloss: 0.188145
# [648]	training's binary_logloss: 5.76461e-05	valid_1's binary_logloss: 0.18834
# [649]	training's binary_logloss: 5.70042e-05	valid_1's binary_logloss: 0.188371
# [650]	training's binary_logloss: 5.61478e-05	valid_1's binary_logloss: 0.188524
# [651]	training's binary_logloss: 5.56014e-05	valid_1's binary_logloss: 0.188586
# [652]	training's binary_logloss: 5.50185e-05	valid_1's binary_logloss: 0.188813
# [653]	training's binary_logloss: 5.4425e-05	valid_1's binary_logloss: 0.188885
# [654]	training's binary_logloss: 5.37415e-05	valid_1's binary_logloss: 0.189824
# [655]	training's binary_logloss: 5.31091e-05	valid_1's binary_logloss: 0.189901
# [656]	training's binary_logloss: 5.25628e-05	valid_1's binary_logloss: 0.190444
# [657]	training's binary_logloss: 5.19743e-05	valid_1's binary_logloss: 0.190714
# [658]	training's binary_logloss: 5.14746e-05	valid_1's binary_logloss: 0.191034
# [659]	training's binary_logloss: 5.10576e-05	valid_1's binary_logloss: 0.191213
# [660]	training's binary_logloss: 5.04849e-05	valid_1's binary_logloss: 0.191202
# [661]	training's binary_logloss: 4.99599e-05	valid_1's binary_logloss: 0.191275
# [662]	training's binary_logloss: 4.944e-05	valid_1's binary_logloss: 0.191058
# [663]	training's binary_logloss: 4.89182e-05	valid_1's binary_logloss: 0.191032
# [664]	training's binary_logloss: 4.82646e-05	valid_1's binary_logloss: 0.190978
# [665]	training's binary_logloss: 4.77213e-05	valid_1's binary_logloss: 0.191087
# [666]	training's binary_logloss: 4.7186e-05	valid_1's binary_logloss: 0.19151
# [667]	training's binary_logloss: 4.65783e-05	valid_1's binary_logloss: 0.191603
# [668]	training's binary_logloss: 4.61415e-05	valid_1's binary_logloss: 0.19185
# [669]	training's binary_logloss: 4.56811e-05	valid_1's binary_logloss: 0.192375
# [670]	training's binary_logloss: 4.51418e-05	valid_1's binary_logloss: 0.192296
# [671]	training's binary_logloss: 4.46618e-05	valid_1's binary_logloss: 0.192224
# [672]	training's binary_logloss: 4.40509e-05	valid_1's binary_logloss: 0.192242
# [673]	training's binary_logloss: 4.36136e-05	valid_1's binary_logloss: 0.192175
# [674]	training's binary_logloss: 4.31418e-05	valid_1's binary_logloss: 0.191963
# [675]	training's binary_logloss: 4.26906e-05	valid_1's binary_logloss: 0.192076
# [676]	training's binary_logloss: 4.21848e-05	valid_1's binary_logloss: 0.192157
# [677]	training's binary_logloss: 4.16692e-05	valid_1's binary_logloss: 0.192582
# [678]	training's binary_logloss: 4.11107e-05	valid_1's binary_logloss: 0.192827
# [679]	training's binary_logloss: 4.06232e-05	valid_1's binary_logloss: 0.192775
# [680]	training's binary_logloss: 4.01966e-05	valid_1's binary_logloss: 0.192944
# [681]	training's binary_logloss: 3.97279e-05	valid_1's binary_logloss: 0.192689
# [682]	training's binary_logloss: 3.93806e-05	valid_1's binary_logloss: 0.192554
# [683]	training's binary_logloss: 3.8884e-05	valid_1's binary_logloss: 0.192926
# [684]	training's binary_logloss: 3.84105e-05	valid_1's binary_logloss: 0.193433
# [685]	training's binary_logloss: 3.80111e-05	valid_1's binary_logloss: 0.193633
# [686]	training's binary_logloss: 3.75986e-05	valid_1's binary_logloss: 0.193479
# [687]	training's binary_logloss: 3.71855e-05	valid_1's binary_logloss: 0.193685
# [688]	training's binary_logloss: 3.67251e-05	valid_1's binary_logloss: 0.19401
# [689]	training's binary_logloss: 3.63526e-05	valid_1's binary_logloss: 0.193755
# [690]	training's binary_logloss: 3.58439e-05	valid_1's binary_logloss: 0.194316
# [691]	training's binary_logloss: 3.53449e-05	valid_1's binary_logloss: 0.194623
# [692]	training's binary_logloss: 3.48901e-05	valid_1's binary_logloss: 0.194418
# [693]	training's binary_logloss: 3.45413e-05	valid_1's binary_logloss: 0.194281
# [694]	training's binary_logloss: 3.42309e-05	valid_1's binary_logloss: 0.194641
# [695]	training's binary_logloss: 3.38193e-05	valid_1's binary_logloss: 0.194868
# [696]	training's binary_logloss: 3.34044e-05	valid_1's binary_logloss: 0.195017
# [697]	training's binary_logloss: 3.30115e-05	valid_1's binary_logloss: 0.195173
# [698]	training's binary_logloss: 3.26633e-05	valid_1's binary_logloss: 0.19541
# [699]	training's binary_logloss: 3.22968e-05	valid_1's binary_logloss: 0.195855
# [700]	training's binary_logloss: 3.19045e-05	valid_1's binary_logloss: 0.195707
# Model Name: [LightGBM          ], 2023-09-20 16:08:22, 0:00:04,  BEST AUC: 0.989892, AUC: 0.989892

# %%
print_eval_result(model_eval_comparison)
# Out:
# <style type="text/css">
# #T_8e046_row0_col0, #T_8e046_row0_col1, #T_8e046_row0_col3, #T_8e046_row0_col5, #T_8e046_row0_col6, #T_8e046_row1_col2, #T_8e046_row1_col4 {
#   background-color: yellow;
#   color: black;
# }
# #T_8e046_row0_col2, #T_8e046_row0_col4, #T_8e046_row1_col0, #T_8e046_row1_col1, #T_8e046_row1_col3, #T_8e046_row1_col5, #T_8e046_row1_col6 {
#   color: black;
# }
# #T_8e046_row0_col8, #T_8e046_row1_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_8e046">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e046_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_8e046_level0_col1" class="col_heading level0 col1" >Accuracy-No</th>
#       <th id="T_8e046_level0_col2" class="col_heading level0 col2" >Accuracy-Yes</th>
#       <th id="T_8e046_level0_col3" class="col_heading level0 col3" >Precision</th>
#       <th id="T_8e046_level0_col4" class="col_heading level0 col4" >Recall</th>
#       <th id="T_8e046_level0_col5" class="col_heading level0 col5" >F1-Score</th>
#       <th id="T_8e046_level0_col6" class="col_heading level0 col6" >CV AUC</th>
#       <th id="T_8e046_level0_col7" class="col_heading level0 col7" >CV std</th>
#       <th id="T_8e046_level0_col8" class="col_heading level0 col8" >AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e046_level0_row0" class="row_heading level0 row0" >LightGBM</th>
#       <td id="T_8e046_row0_col0" class="data row0 col0" >96.45%</td>
#       <td id="T_8e046_row0_col1" class="data row0 col1" >98.06%</td>
#       <td id="T_8e046_row0_col2" class="data row0 col2" >88.07%</td>
#       <td id="T_8e046_row0_col3" class="data row0 col3" >89.72%</td>
#       <td id="T_8e046_row0_col4" class="data row0 col4" >88.07%</td>
#       <td id="T_8e046_row0_col5" class="data row0 col5" >88.89%</td>
#       <td id="T_8e046_row0_col6" class="data row0 col6" >99.66%</td>
#       <td id="T_8e046_row0_col7" class="data row0 col7" >0.000522</td>
#       <td id="T_8e046_row0_col8" class="data row0 col8" >0.989892</td>
#     </tr>
#     <tr>
#       <th id="T_8e046_level0_row1" class="row_heading level0 row1" >XgBoost</th>
#       <td id="T_8e046_row1_col0" class="data row1 col0" >95.80%</td>
#       <td id="T_8e046_row1_col1" class="data row1 col1" >96.82%</td>
#       <td id="T_8e046_row1_col2" class="data row1 col2" >90.52%</td>
#       <td id="T_8e046_row1_col3" class="data row1 col3" >84.57%</td>
#       <td id="T_8e046_row1_col4" class="data row1 col4" >90.52%</td>
#       <td id="T_8e046_row1_col5" class="data row1 col5" >87.44%</td>
#       <td id="T_8e046_row1_col6" class="data row1 col6" >99.57%</td>
#       <td id="T_8e046_row1_col7" class="data row1 col7" >0.000776</td>
#       <td id="T_8e046_row1_col8" class="data row1 col8" >0.987188</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 전처리 방법 및 각종 튜닝값 적용을 위한 상세 테스트

# %% [markdown]
# ##### Machine Learning시 중요 컬럼 선택 관련 Classifier 선택
# - ExtraTrees, RandomForest 사용시 다른 Classifier 보다 좋은 결과를 보여서 RandomForest 선택

# %%
def select_feature_model():
    models = ['ExtraTrees', 'RandomForest', 'LGBMC', 'LGBMR', 'Xg Boost']
    for model in models: 
        start_time = time.time()

        bank_churner_df = pd.read_csv("./data/bank_churner.csv")        
        eval_churner_df = pd.read_csv("./data/test_churner.csv")


        # 데이터 변환
        # -----------
        bank_churner_df = data_transform(bank_churner_df)
        eval_churner_df = data_transform(eval_churner_df)


        # 테스트 및 평가를 위한 데이터 분리
        # -------------------------------
        X_Features = bank_churner_df.drop(['is_churned'],axis=1)
        y_labels = bank_churner_df['is_churned']

        X_eval=eval_churner_df.drop(['is_churned'],axis=1)
        y_eval=eval_churner_df['is_churned']


        # 중요 Feature Column 선택
        # -----------------------
        X_Features_new, selected_columns = select_feature(X_Features, y_labels, model)
        X_eval = X_eval[selected_columns]
        

        # 로그 출력
        # --------
        cur_datetime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        end_time = time.time()
        delta_time = end_time - start_time
        
        # print(f'{cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, model: {model}, X_Features_new: {X_Features_new.shape}, X_eval: {X_eval.shape}, selected_columns_len: {len(selected_columns)}, selected_columns: {selected_columns}')
        print(f'{cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, model: {model}, X_Features_new: {X_Features_new.shape}, X_eval: {X_eval.shape}, selected_columns_len: {len(selected_columns)}')

select_feature_model()
# Out:
# 2023-09-20 16:08:27, 0:00:05, model: ExtraTrees, X_Features_new: (8101, 13), X_eval: (840, 13), selected_columns_len: 13
# 2023-09-20 16:08:38, 0:00:10, model: RandomForest, X_Features_new: (8101, 13), X_eval: (840, 13), selected_columns_len: 13
# 2023-09-20 16:08:39, 0:00:00, model: LGBMC, X_Features_new: (8101, 11), X_eval: (840, 11), selected_columns_len: 11
# 2023-09-20 16:08:39, 0:00:00, model: LGBMR, X_Features_new: (8101, 12), X_eval: (840, 12), selected_columns_len: 12
# 2023-09-20 16:08:39, 0:00:00, model: Xg Boost, X_Features_new: (8101, 9), X_eval: (840, 9), selected_columns_len: 9

# %% [markdown]
# #### Light GBM 파라미터 튜닝
# - Light GBM을 이용한 경우 좋은 결과가 있어 파라미터 튜닝을 세부적으로 수행 함.
#     - 튜닝 파라미터 결과 : learning_rate: 0.14061, max_depth: 106, min_child_samples: 64, num_leaves: 41, 'subsample': 0.94623
# - 튜닝을 진행했지만 이전보다 좋은 결과가 나오지 않음
#     - 튜닝 적용후 ROC AUC: 0.9892

# %% [markdown]
# ##### Best 튜닝 파라미터 적용하여 결과 확인

# %%
# 튜닝 파라미터 적용 값
# -------------------
best = {'learning_rate': 0.1406105325029019, 'max_depth': 106.0, 'min_child_samples': 64.0, 'num_leaves': 41.0, 'subsample': 0.9462293554201169}


lgbm_clf =  LGBMClassifier(n_estimators=700, num_leaves=int(best['num_leaves']),
                           max_depth=int(best['max_depth']),
                           min_child_samples=int(best['min_child_samples']), 
                           subsample=round(best['subsample'], 5),
                           learning_rate=round(best['learning_rate'], 5)
                          )


# evaluation metric을 auc로, early stopping은 100 으로 설정하고 학습 수행.
# --------------------------------------------------------------------- 
lgbm_clf.fit(X_train, y_train, early_stopping_rounds=100, 
            eval_metric="auc",eval_set=[(X_train, y_train), (X_test, y_test)])

lgbm_roc_score = roc_auc_score(y_eval, lgbm_clf.predict_proba(X_eval)[:,1])
print('ROC AUC: {0:.4f}'.format(lgbm_roc_score))
# Out:
# [1]	training's auc: 0.94588	training's binary_logloss: 0.607012	valid_1's auc: 0.857291	valid_1's binary_logloss: 0.619282
# [2]	training's auc: 0.963884	training's binary_logloss: 0.539007	valid_1's auc: 0.87605	valid_1's binary_logloss: 0.561484
# [3]	training's auc: 0.966936	training's binary_logloss: 0.48501	valid_1's auc: 0.888617	valid_1's binary_logloss: 0.515248
# [4]	training's auc: 0.972102	training's binary_logloss: 0.438911	valid_1's auc: 0.892627	valid_1's binary_logloss: 0.475665
# [5]	training's auc: 0.975532	training's binary_logloss: 0.3996	valid_1's auc: 0.893993	valid_1's binary_logloss: 0.445122
# [6]	training's auc: 0.978245	training's binary_logloss: 0.36582	valid_1's auc: 0.896436	valid_1's binary_logloss: 0.416254
# [7]	training's auc: 0.980964	training's binary_logloss: 0.337229	valid_1's auc: 0.906429	valid_1's binary_logloss: 0.392575
# [8]	training's auc: 0.98273	training's binary_logloss: 0.313159	valid_1's auc: 0.910621	valid_1's binary_logloss: 0.373133
# [9]	training's auc: 0.985112	training's binary_logloss: 0.289337	valid_1's auc: 0.914575	valid_1's binary_logloss: 0.35348
# [10]	training's auc: 0.987421	training's binary_logloss: 0.266808	valid_1's auc: 0.919595	valid_1's binary_logloss: 0.334827
# [11]	training's auc: 0.9884	training's binary_logloss: 0.249226	valid_1's auc: 0.920837	valid_1's binary_logloss: 0.321149
# [12]	training's auc: 0.989205	training's binary_logloss: 0.23558	valid_1's auc: 0.923341	valid_1's binary_logloss: 0.311921
# [13]	training's auc: 0.990637	training's binary_logloss: 0.218347	valid_1's auc: 0.929335	valid_1's binary_logloss: 0.295631
# [14]	training's auc: 0.99154	training's binary_logloss: 0.204891	valid_1's auc: 0.934338	valid_1's binary_logloss: 0.282733
# [15]	training's auc: 0.992377	training's binary_logloss: 0.1922	valid_1's auc: 0.936027	valid_1's binary_logloss: 0.272737
# [16]	training's auc: 0.993121	training's binary_logloss: 0.180477	valid_1's auc: 0.938478	valid_1's binary_logloss: 0.263632
# [17]	training's auc: 0.993854	training's binary_logloss: 0.16926	valid_1's auc: 0.940493	valid_1's binary_logloss: 0.255002
# [18]	training's auc: 0.994454	training's binary_logloss: 0.158955	valid_1's auc: 0.941988	valid_1's binary_logloss: 0.24775
# [19]	training's auc: 0.994836	training's binary_logloss: 0.15024	valid_1's auc: 0.943831	valid_1's binary_logloss: 0.240325
# [20]	training's auc: 0.995457	training's binary_logloss: 0.141298	valid_1's auc: 0.948641	valid_1's binary_logloss: 0.23094
# [21]	training's auc: 0.995766	training's binary_logloss: 0.134386	valid_1's auc: 0.949313	valid_1's binary_logloss: 0.225937
# [22]	training's auc: 0.996187	training's binary_logloss: 0.126847	valid_1's auc: 0.952083	valid_1's binary_logloss: 0.218926
# [23]	training's auc: 0.996542	training's binary_logloss: 0.120254	valid_1's auc: 0.954886	valid_1's binary_logloss: 0.212222
# [24]	training's auc: 0.996865	training's binary_logloss: 0.114298	valid_1's auc: 0.956211	valid_1's binary_logloss: 0.207085
# [25]	training's auc: 0.997102	training's binary_logloss: 0.109142	valid_1's auc: 0.95724	valid_1's binary_logloss: 0.203232
# [26]	training's auc: 0.997363	training's binary_logloss: 0.103821	valid_1's auc: 0.958096	valid_1's binary_logloss: 0.19984
# [27]	training's auc: 0.997544	training's binary_logloss: 0.0992811	valid_1's auc: 0.958209	valid_1's binary_logloss: 0.197263
# [28]	training's auc: 0.997718	training's binary_logloss: 0.0953996	valid_1's auc: 0.959281	valid_1's binary_logloss: 0.19395
# [29]	training's auc: 0.997915	training's binary_logloss: 0.0918856	valid_1's auc: 0.959781	valid_1's binary_logloss: 0.191411
# [30]	training's auc: 0.998098	training's binary_logloss: 0.0887001	valid_1's auc: 0.960823	valid_1's binary_logloss: 0.188271
# [31]	training's auc: 0.998255	training's binary_logloss: 0.0848615	valid_1's auc: 0.961024	valid_1's binary_logloss: 0.186195
# [32]	training's auc: 0.998375	training's binary_logloss: 0.0818716	valid_1's auc: 0.961584	valid_1's binary_logloss: 0.183741
# [33]	training's auc: 0.998501	training's binary_logloss: 0.0789205	valid_1's auc: 0.962528	valid_1's binary_logloss: 0.180833
# [34]	training's auc: 0.998623	training's binary_logloss: 0.0761175	valid_1's auc: 0.963706	valid_1's binary_logloss: 0.178293
# [35]	training's auc: 0.998752	training's binary_logloss: 0.0730844	valid_1's auc: 0.964147	valid_1's binary_logloss: 0.176658
# [36]	training's auc: 0.998845	training's binary_logloss: 0.0707416	valid_1's auc: 0.964788	valid_1's binary_logloss: 0.174361
# [37]	training's auc: 0.998942	training's binary_logloss: 0.0681764	valid_1's auc: 0.965255	valid_1's binary_logloss: 0.172821
# [38]	training's auc: 0.999004	training's binary_logloss: 0.0659812	valid_1's auc: 0.965404	valid_1's binary_logloss: 0.1714
# [39]	training's auc: 0.999063	training's binary_logloss: 0.0638934	valid_1's auc: 0.965817	valid_1's binary_logloss: 0.170196
# [40]	training's auc: 0.999133	training's binary_logloss: 0.0617325	valid_1's auc: 0.966832	valid_1's binary_logloss: 0.168035
# [41]	training's auc: 0.999208	training's binary_logloss: 0.0597691	valid_1's auc: 0.967043	valid_1's binary_logloss: 0.166742
# [42]	training's auc: 0.99927	training's binary_logloss: 0.0579156	valid_1's auc: 0.967866	valid_1's binary_logloss: 0.164804
# [43]	training's auc: 0.999327	training's binary_logloss: 0.056129	valid_1's auc: 0.968072	valid_1's binary_logloss: 0.164035
# [44]	training's auc: 0.99938	training's binary_logloss: 0.0545133	valid_1's auc: 0.96827	valid_1's binary_logloss: 0.162891
# [45]	training's auc: 0.999422	training's binary_logloss: 0.0528506	valid_1's auc: 0.968352	valid_1's binary_logloss: 0.162266
# [46]	training's auc: 0.999469	training's binary_logloss: 0.0513941	valid_1's auc: 0.968623	valid_1's binary_logloss: 0.161484
# [47]	training's auc: 0.999523	training's binary_logloss: 0.0497303	valid_1's auc: 0.968784	valid_1's binary_logloss: 0.16092
# [48]	training's auc: 0.999564	training's binary_logloss: 0.0483096	valid_1's auc: 0.969084	valid_1's binary_logloss: 0.160084
# [49]	training's auc: 0.99961	training's binary_logloss: 0.0466903	valid_1's auc: 0.969073	valid_1's binary_logloss: 0.159771
# [50]	training's auc: 0.999642	training's binary_logloss: 0.0453927	valid_1's auc: 0.969236	valid_1's binary_logloss: 0.159703
# [51]	training's auc: 0.999677	training's binary_logloss: 0.0440841	valid_1's auc: 0.969465	valid_1's binary_logloss: 0.159237
# [52]	training's auc: 0.999706	training's binary_logloss: 0.0428714	valid_1's auc: 0.969527	valid_1's binary_logloss: 0.158981
# [53]	training's auc: 0.999732	training's binary_logloss: 0.0418732	valid_1's auc: 0.969123	valid_1's binary_logloss: 0.159662
# [54]	training's auc: 0.999758	training's binary_logloss: 0.0408433	valid_1's auc: 0.969211	valid_1's binary_logloss: 0.159457
# [55]	training's auc: 0.999781	training's binary_logloss: 0.0397488	valid_1's auc: 0.969073	valid_1's binary_logloss: 0.159893
# [56]	training's auc: 0.999807	training's binary_logloss: 0.0386769	valid_1's auc: 0.969177	valid_1's binary_logloss: 0.159964
# [57]	training's auc: 0.999824	training's binary_logloss: 0.0376503	valid_1's auc: 0.969163	valid_1's binary_logloss: 0.159776
# c:\Users\USER\anaconda3\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [58]	training's auc: 0.999846	training's binary_logloss: 0.0366085	valid_1's auc: 0.968976	valid_1's binary_logloss: 0.159879
# [59]	training's auc: 0.999863	training's binary_logloss: 0.0355083	valid_1's auc: 0.968863	valid_1's binary_logloss: 0.159945
# [60]	training's auc: 0.999879	training's binary_logloss: 0.0345254	valid_1's auc: 0.969056	valid_1's binary_logloss: 0.159145
# [61]	training's auc: 0.999894	training's binary_logloss: 0.0336383	valid_1's auc: 0.969287	valid_1's binary_logloss: 0.158673
# [62]	training's auc: 0.999903	training's binary_logloss: 0.0328285	valid_1's auc: 0.969378	valid_1's binary_logloss: 0.158461
# [63]	training's auc: 0.999917	training's binary_logloss: 0.0319397	valid_1's auc: 0.969412	valid_1's binary_logloss: 0.158527
# [64]	training's auc: 0.999923	training's binary_logloss: 0.0311673	valid_1's auc: 0.969316	valid_1's binary_logloss: 0.158621
# [65]	training's auc: 0.999936	training's binary_logloss: 0.0303873	valid_1's auc: 0.969451	valid_1's binary_logloss: 0.158447
# [66]	training's auc: 0.999947	training's binary_logloss: 0.0295797	valid_1's auc: 0.969598	valid_1's binary_logloss: 0.158243
# [67]	training's auc: 0.999953	training's binary_logloss: 0.0287994	valid_1's auc: 0.969669	valid_1's binary_logloss: 0.157976
# [68]	training's auc: 0.999958	training's binary_logloss: 0.0281664	valid_1's auc: 0.969624	valid_1's binary_logloss: 0.158282
# [69]	training's auc: 0.999964	training's binary_logloss: 0.0275065	valid_1's auc: 0.969886	valid_1's binary_logloss: 0.157936
# [70]	training's auc: 0.999968	training's binary_logloss: 0.0268255	valid_1's auc: 0.970087	valid_1's binary_logloss: 0.157728
# [71]	training's auc: 0.999974	training's binary_logloss: 0.0261743	valid_1's auc: 0.969847	valid_1's binary_logloss: 0.158403
# [72]	training's auc: 0.999977	training's binary_logloss: 0.0255066	valid_1's auc: 0.969985	valid_1's binary_logloss: 0.158122
# [73]	training's auc: 0.99998	training's binary_logloss: 0.0247208	valid_1's auc: 0.970053	valid_1's binary_logloss: 0.158049
# [74]	training's auc: 0.999983	training's binary_logloss: 0.0241128	valid_1's auc: 0.970559	valid_1's binary_logloss: 0.156854
# [75]	training's auc: 0.999986	training's binary_logloss: 0.0235421	valid_1's auc: 0.970573	valid_1's binary_logloss: 0.156609
# [76]	training's auc: 0.999988	training's binary_logloss: 0.0229921	valid_1's auc: 0.970669	valid_1's binary_logloss: 0.156753
# [77]	training's auc: 0.999989	training's binary_logloss: 0.022445	valid_1's auc: 0.970712	valid_1's binary_logloss: 0.156586
# [78]	training's auc: 0.999992	training's binary_logloss: 0.0218214	valid_1's auc: 0.970615	valid_1's binary_logloss: 0.156443
# [79]	training's auc: 0.999993	training's binary_logloss: 0.0212612	valid_1's auc: 0.970539	valid_1's binary_logloss: 0.156879
# [80]	training's auc: 0.999994	training's binary_logloss: 0.0207918	valid_1's auc: 0.970819	valid_1's binary_logloss: 0.156472
# [81]	training's auc: 0.999995	training's binary_logloss: 0.0202971	valid_1's auc: 0.970977	valid_1's binary_logloss: 0.155752
# [82]	training's auc: 0.999996	training's binary_logloss: 0.0197362	valid_1's auc: 0.970847	valid_1's binary_logloss: 0.155689
# [83]	training's auc: 0.999996	training's binary_logloss: 0.0192864	valid_1's auc: 0.970898	valid_1's binary_logloss: 0.155961
# [84]	training's auc: 0.999998	training's binary_logloss: 0.0188033	valid_1's auc: 0.970957	valid_1's binary_logloss: 0.156206
# [85]	training's auc: 0.999998	training's binary_logloss: 0.0182824	valid_1's auc: 0.971045	valid_1's binary_logloss: 0.156019
# [86]	training's auc: 0.999999	training's binary_logloss: 0.0178825	valid_1's auc: 0.97122	valid_1's binary_logloss: 0.155783
# [87]	training's auc: 0.999999	training's binary_logloss: 0.0174144	valid_1's auc: 0.971268	valid_1's binary_logloss: 0.156439
# [88]	training's auc: 1	training's binary_logloss: 0.0169532	valid_1's auc: 0.971158	valid_1's binary_logloss: 0.15681
# [89]	training's auc: 1	training's binary_logloss: 0.0165101	valid_1's auc: 0.971542	valid_1's binary_logloss: 0.156595
# [90]	training's auc: 1	training's binary_logloss: 0.016066	valid_1's auc: 0.971404	valid_1's binary_logloss: 0.157364
# [91]	training's auc: 1	training's binary_logloss: 0.0156752	valid_1's auc: 0.971274	valid_1's binary_logloss: 0.158058
# [92]	training's auc: 1	training's binary_logloss: 0.0153212	valid_1's auc: 0.971483	valid_1's binary_logloss: 0.15826
# [93]	training's auc: 1	training's binary_logloss: 0.0149888	valid_1's auc: 0.971771	valid_1's binary_logloss: 0.157961
# [94]	training's auc: 1	training's binary_logloss: 0.0146383	valid_1's auc: 0.971811	valid_1's binary_logloss: 0.157609
# [95]	training's auc: 1	training's binary_logloss: 0.0142968	valid_1's auc: 0.971743	valid_1's binary_logloss: 0.157734
# [96]	training's auc: 1	training's binary_logloss: 0.0139208	valid_1's auc: 0.971709	valid_1's binary_logloss: 0.157968
# [97]	training's auc: 1	training's binary_logloss: 0.0135842	valid_1's auc: 0.971836	valid_1's binary_logloss: 0.158342
# [98]	training's auc: 1	training's binary_logloss: 0.0133118	valid_1's auc: 0.971791	valid_1's binary_logloss: 0.158132
# [99]	training's auc: 1	training's binary_logloss: 0.0129873	valid_1's auc: 0.971788	valid_1's binary_logloss: 0.15842
# [100]	training's auc: 1	training's binary_logloss: 0.0126738	valid_1's auc: 0.971509	valid_1's binary_logloss: 0.159202
# [101]	training's auc: 1	training's binary_logloss: 0.0123255	valid_1's auc: 0.971531	valid_1's binary_logloss: 0.159429
# [102]	training's auc: 1	training's binary_logloss: 0.0120469	valid_1's auc: 0.971376	valid_1's binary_logloss: 0.159846
# [103]	training's auc: 1	training's binary_logloss: 0.0117514	valid_1's auc: 0.971367	valid_1's binary_logloss: 0.160193
# [104]	training's auc: 1	training's binary_logloss: 0.0114738	valid_1's auc: 0.971398	valid_1's binary_logloss: 0.160483
# [105]	training's auc: 1	training's binary_logloss: 0.0112308	valid_1's auc: 0.971494	valid_1's binary_logloss: 0.160668
# [106]	training's auc: 1	training's binary_logloss: 0.010956	valid_1's auc: 0.971559	valid_1's binary_logloss: 0.160693
# [107]	training's auc: 1	training's binary_logloss: 0.0106796	valid_1's auc: 0.971619	valid_1's binary_logloss: 0.160879
# [108]	training's auc: 1	training's binary_logloss: 0.0104657	valid_1's auc: 0.971757	valid_1's binary_logloss: 0.160503
# [109]	training's auc: 1	training's binary_logloss: 0.010188	valid_1's auc: 0.971709	valid_1's binary_logloss: 0.16066
# [110]	training's auc: 1	training's binary_logloss: 0.00996238	valid_1's auc: 0.971605	valid_1's binary_logloss: 0.161258
# [111]	training's auc: 1	training's binary_logloss: 0.00975711	valid_1's auc: 0.97165	valid_1's binary_logloss: 0.161496
# [112]	training's auc: 1	training's binary_logloss: 0.00952843	valid_1's auc: 0.971701	valid_1's binary_logloss: 0.161626
# [113]	training's auc: 1	training's binary_logloss: 0.00928345	valid_1's auc: 0.971788	valid_1's binary_logloss: 0.161632
# [114]	training's auc: 1	training's binary_logloss: 0.00904819	valid_1's auc: 0.971757	valid_1's binary_logloss: 0.162044
# [115]	training's auc: 1	training's binary_logloss: 0.00887004	valid_1's auc: 0.971726	valid_1's binary_logloss: 0.162035
# [116]	training's auc: 1	training's binary_logloss: 0.00869672	valid_1's auc: 0.971794	valid_1's binary_logloss: 0.162089
# [117]	training's auc: 1	training's binary_logloss: 0.00851515	valid_1's auc: 0.971935	valid_1's binary_logloss: 0.161871
# [118]	training's auc: 1	training's binary_logloss: 0.00833541	valid_1's auc: 0.972017	valid_1's binary_logloss: 0.16217
# [119]	training's auc: 1	training's binary_logloss: 0.00815199	valid_1's auc: 0.971947	valid_1's binary_logloss: 0.162712
# [120]	training's auc: 1	training's binary_logloss: 0.00796622	valid_1's auc: 0.972009	valid_1's binary_logloss: 0.162697
# [121]	training's auc: 1	training's binary_logloss: 0.00779863	valid_1's auc: 0.971808	valid_1's binary_logloss: 0.163486
# [122]	training's auc: 1	training's binary_logloss: 0.00764485	valid_1's auc: 0.971955	valid_1's binary_logloss: 0.163266
# [123]	training's auc: 1	training's binary_logloss: 0.00749944	valid_1's auc: 0.972048	valid_1's binary_logloss: 0.163534
# [124]	training's auc: 1	training's binary_logloss: 0.00735637	valid_1's auc: 0.972119	valid_1's binary_logloss: 0.163383
# [125]	training's auc: 1	training's binary_logloss: 0.0071861	valid_1's auc: 0.972074	valid_1's binary_logloss: 0.16358
# [126]	training's auc: 1	training's binary_logloss: 0.0070354	valid_1's auc: 0.972345	valid_1's binary_logloss: 0.163503
# [127]	training's auc: 1	training's binary_logloss: 0.00687668	valid_1's auc: 0.972339	valid_1's binary_logloss: 0.163756
# [128]	training's auc: 1	training's binary_logloss: 0.00672034	valid_1's auc: 0.972382	valid_1's binary_logloss: 0.163866
# [129]	training's auc: 1	training's binary_logloss: 0.00658234	valid_1's auc: 0.972452	valid_1's binary_logloss: 0.164008
# [130]	training's auc: 1	training's binary_logloss: 0.00643088	valid_1's auc: 0.972543	valid_1's binary_logloss: 0.163827
# [131]	training's auc: 1	training's binary_logloss: 0.00627454	valid_1's auc: 0.972475	valid_1's binary_logloss: 0.164482
# [132]	training's auc: 1	training's binary_logloss: 0.0061312	valid_1's auc: 0.972356	valid_1's binary_logloss: 0.165365
# [133]	training's auc: 1	training's binary_logloss: 0.00600317	valid_1's auc: 0.972221	valid_1's binary_logloss: 0.166092
# [134]	training's auc: 1	training's binary_logloss: 0.00585311	valid_1's auc: 0.972221	valid_1's binary_logloss: 0.166364
# [135]	training's auc: 1	training's binary_logloss: 0.00573896	valid_1's auc: 0.972283	valid_1's binary_logloss: 0.166485
# [136]	training's auc: 1	training's binary_logloss: 0.00560721	valid_1's auc: 0.9723	valid_1's binary_logloss: 0.166858
# [137]	training's auc: 1	training's binary_logloss: 0.00547873	valid_1's auc: 0.972441	valid_1's binary_logloss: 0.166872
# [138]	training's auc: 1	training's binary_logloss: 0.00537034	valid_1's auc: 0.972413	valid_1's binary_logloss: 0.166837
# [139]	training's auc: 1	training's binary_logloss: 0.0052503	valid_1's auc: 0.972404	valid_1's binary_logloss: 0.167155
# [140]	training's auc: 1	training's binary_logloss: 0.00513447	valid_1's auc: 0.972359	valid_1's binary_logloss: 0.167659
# [141]	training's auc: 1	training's binary_logloss: 0.00503428	valid_1's auc: 0.972435	valid_1's binary_logloss: 0.167494
# [142]	training's auc: 1	training's binary_logloss: 0.00492731	valid_1's auc: 0.972512	valid_1's binary_logloss: 0.167425
# [143]	training's auc: 1	training's binary_logloss: 0.0048212	valid_1's auc: 0.972636	valid_1's binary_logloss: 0.167737
# [144]	training's auc: 1	training's binary_logloss: 0.00471072	valid_1's auc: 0.972746	valid_1's binary_logloss: 0.16777
# [145]	training's auc: 1	training's binary_logloss: 0.00460567	valid_1's auc: 0.972746	valid_1's binary_logloss: 0.168106
# [146]	training's auc: 1	training's binary_logloss: 0.00450187	valid_1's auc: 0.972851	valid_1's binary_logloss: 0.168263
# [147]	training's auc: 1	training's binary_logloss: 0.00440886	valid_1's auc: 0.972856	valid_1's binary_logloss: 0.168677
# [148]	training's auc: 1	training's binary_logloss: 0.00431557	valid_1's auc: 0.972941	valid_1's binary_logloss: 0.16882
# [149]	training's auc: 1	training's binary_logloss: 0.00422093	valid_1's auc: 0.972938	valid_1's binary_logloss: 0.168977
# [150]	training's auc: 1	training's binary_logloss: 0.00413379	valid_1's auc: 0.972848	valid_1's binary_logloss: 0.169631
# [151]	training's auc: 1	training's binary_logloss: 0.00404938	valid_1's auc: 0.972961	valid_1's binary_logloss: 0.169703
# [152]	training's auc: 1	training's binary_logloss: 0.00395548	valid_1's auc: 0.973015	valid_1's binary_logloss: 0.170105
# [153]	training's auc: 1	training's binary_logloss: 0.00387777	valid_1's auc: 0.97302	valid_1's binary_logloss: 0.170578
# [154]	training's auc: 1	training's binary_logloss: 0.00378503	valid_1's auc: 0.973108	valid_1's binary_logloss: 0.170552
# [155]	training's auc: 1	training's binary_logloss: 0.00371076	valid_1's auc: 0.97304	valid_1's binary_logloss: 0.170792
# [156]	training's auc: 1	training's binary_logloss: 0.00362143	valid_1's auc: 0.973116	valid_1's binary_logloss: 0.170889
# [157]	training's auc: 1	training's binary_logloss: 0.00353489	valid_1's auc: 0.972967	valid_1's binary_logloss: 0.171636
# [158]	training's auc: 1	training's binary_logloss: 0.00345831	valid_1's auc: 0.972837	valid_1's binary_logloss: 0.172703
# [159]	training's auc: 1	training's binary_logloss: 0.00338821	valid_1's auc: 0.972797	valid_1's binary_logloss: 0.17308
# [160]	training's auc: 1	training's binary_logloss: 0.00332029	valid_1's auc: 0.972893	valid_1's binary_logloss: 0.173172
# [161]	training's auc: 1	training's binary_logloss: 0.00325511	valid_1's auc: 0.97293	valid_1's binary_logloss: 0.173651
# [162]	training's auc: 1	training's binary_logloss: 0.00319549	valid_1's auc: 0.972899	valid_1's binary_logloss: 0.173899
# [163]	training's auc: 1	training's binary_logloss: 0.00313757	valid_1's auc: 0.972885	valid_1's binary_logloss: 0.174349
# [164]	training's auc: 1	training's binary_logloss: 0.00305786	valid_1's auc: 0.972755	valid_1's binary_logloss: 0.174947
# [165]	training's auc: 1	training's binary_logloss: 0.00298439	valid_1's auc: 0.972803	valid_1's binary_logloss: 0.175551
# [166]	training's auc: 1	training's binary_logloss: 0.00292776	valid_1's auc: 0.972862	valid_1's binary_logloss: 0.175643
# [167]	training's auc: 1	training's binary_logloss: 0.00286817	valid_1's auc: 0.973043	valid_1's binary_logloss: 0.175679
# [168]	training's auc: 1	training's binary_logloss: 0.00281189	valid_1's auc: 0.973148	valid_1's binary_logloss: 0.175708
# [169]	training's auc: 1	training's binary_logloss: 0.00275943	valid_1's auc: 0.973145	valid_1's binary_logloss: 0.176341
# [170]	training's auc: 1	training's binary_logloss: 0.002692	valid_1's auc: 0.973156	valid_1's binary_logloss: 0.176698
# [171]	training's auc: 1	training's binary_logloss: 0.00262991	valid_1's auc: 0.97317	valid_1's binary_logloss: 0.177069
# [172]	training's auc: 1	training's binary_logloss: 0.00257159	valid_1's auc: 0.973204	valid_1's binary_logloss: 0.177146
# [173]	training's auc: 1	training's binary_logloss: 0.00252044	valid_1's auc: 0.973263	valid_1's binary_logloss: 0.177317
# [174]	training's auc: 1	training's binary_logloss: 0.00247337	valid_1's auc: 0.973343	valid_1's binary_logloss: 0.177363
# [175]	training's auc: 1	training's binary_logloss: 0.00241821	valid_1's auc: 0.973221	valid_1's binary_logloss: 0.177995
# [176]	training's auc: 1	training's binary_logloss: 0.00236907	valid_1's auc: 0.973244	valid_1's binary_logloss: 0.178452
# [177]	training's auc: 1	training's binary_logloss: 0.00231252	valid_1's auc: 0.973159	valid_1's binary_logloss: 0.178906
# [178]	training's auc: 1	training's binary_logloss: 0.0022691	valid_1's auc: 0.973187	valid_1's binary_logloss: 0.178648
# [179]	training's auc: 1	training's binary_logloss: 0.00222686	valid_1's auc: 0.97315	valid_1's binary_logloss: 0.178902
# [180]	training's auc: 1	training's binary_logloss: 0.00218287	valid_1's auc: 0.973035	valid_1's binary_logloss: 0.179333
# [181]	training's auc: 1	training's binary_logloss: 0.00214193	valid_1's auc: 0.972995	valid_1's binary_logloss: 0.179963
# [182]	training's auc: 1	training's binary_logloss: 0.00209964	valid_1's auc: 0.972831	valid_1's binary_logloss: 0.180583
# ROC AUC: 0.9881

# %%
fit_df = pd.read_csv("./data/bank_churner.csv") # 학습을 위한 데이터 로드
eval_df = pd.read_csv("./data/eval_churner.csv") # 평가를 위한 데이터 로드 - 평가데이터 경로를 입력해 주세요!!!

# 전처리 
# -----
X_train, y_train, X_val, y_val, X_test, y_test, X_eval, y_eval = test_transform(bank_churner_df, eval_churner_df)
# X_tr, y_tr, X_val, y_val, X_eval, y_eval = test_transform(bank_churner_df, eval_churner_df)

# print(X_tr, y_tr, X_val, y_val, X_eval, y_eval)
# Out:
# [proc_feature_split()] X_data: (8101, 13), y_data: (8101,)
# [proc_feature_split()] X_tr: (5832, 13), y_tr: (5832,), X_val: (648, 13), y_val: (648,), X_test: (1621, 13), y_test: (1621,)

# %%
from lightgbm import LGBMClassifier

lgbm_clf = LGBMClassifier(n_estimators=700)

# eval_set=[(X_tr, y_tr), (X_val, y_val)]
# lgbm_clf.fit(X_tr, y_tr, early_stopping_rounds=100, eval_metric="auc", eval_set=eval_set)

eval_set=[(X_train, y_train), (X_val, y_val)]
lgbm_clf.fit(X_train, y_train, early_stopping_rounds=100, eval_metric="auc", eval_set=eval_set)

lgbm_roc_score = roc_auc_score(y_eval, lgbm_clf.predict_proba(X_eval)[:,1])
print('ROC AUC: {0:.4f}'.format(lgbm_roc_score))
# Out:
# c:\Users\USER\anaconda3\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	training's auc: 0.933513	training's binary_logloss: 0.631645	valid_1's auc: 0.879887	valid_1's binary_logloss: 0.636219
# [2]	training's auc: 0.959314	training's binary_logloss: 0.579096	valid_1's auc: 0.900673	valid_1's binary_logloss: 0.590489
# [3]	training's auc: 0.96131	training's binary_logloss: 0.534514	valid_1's auc: 0.908486	valid_1's binary_logloss: 0.548616
# [4]	training's auc: 0.966823	training's binary_logloss: 0.495037	valid_1's auc: 0.912472	valid_1's binary_logloss: 0.514227
# [5]	training's auc: 0.971551	training's binary_logloss: 0.461619	valid_1's auc: 0.914275	valid_1's binary_logloss: 0.486265
# [6]	training's auc: 0.973584	training's binary_logloss: 0.432438	valid_1's auc: 0.919851	valid_1's binary_logloss: 0.46028
# [7]	training's auc: 0.977224	training's binary_logloss: 0.405636	valid_1's auc: 0.920258	valid_1's binary_logloss: 0.438045
# [8]	training's auc: 0.978906	training's binary_logloss: 0.381892	valid_1's auc: 0.922326	valid_1's binary_logloss: 0.416585
# [9]	training's auc: 0.98054	training's binary_logloss: 0.360803	valid_1's auc: 0.927876	valid_1's binary_logloss: 0.397352
# [10]	training's auc: 0.982298	training's binary_logloss: 0.341154	valid_1's auc: 0.930421	valid_1's binary_logloss: 0.378582
# [11]	training's auc: 0.983543	training's binary_logloss: 0.323059	valid_1's auc: 0.931658	valid_1's binary_logloss: 0.362846
# [12]	training's auc: 0.984524	training's binary_logloss: 0.307356	valid_1's auc: 0.935149	valid_1's binary_logloss: 0.346951
# [13]	training's auc: 0.985377	training's binary_logloss: 0.29299	valid_1's auc: 0.935176	valid_1's binary_logloss: 0.334542
# [14]	training's auc: 0.986242	training's binary_logloss: 0.279596	valid_1's auc: 0.936307	valid_1's binary_logloss: 0.322888
# [15]	training's auc: 0.987796	training's binary_logloss: 0.264481	valid_1's auc: 0.942599	valid_1's binary_logloss: 0.308163
# [16]	training's auc: 0.988955	training's binary_logloss: 0.251072	valid_1's auc: 0.94518	valid_1's binary_logloss: 0.295192
# [17]	training's auc: 0.989834	training's binary_logloss: 0.239022	valid_1's auc: 0.945816	valid_1's binary_logloss: 0.285086
# [18]	training's auc: 0.990527	training's binary_logloss: 0.227801	valid_1's auc: 0.947752	valid_1's binary_logloss: 0.274587
# [19]	training's auc: 0.991249	training's binary_logloss: 0.21738	valid_1's auc: 0.948547	valid_1's binary_logloss: 0.266053
# [20]	training's auc: 0.991794	training's binary_logloss: 0.207748	valid_1's auc: 0.950863	valid_1's binary_logloss: 0.256453
# [21]	training's auc: 0.992279	training's binary_logloss: 0.199153	valid_1's auc: 0.952206	valid_1's binary_logloss: 0.248329
# [22]	training's auc: 0.992791	training's binary_logloss: 0.190285	valid_1's auc: 0.953072	valid_1's binary_logloss: 0.240099
# [23]	training's auc: 0.9932	training's binary_logloss: 0.183234	valid_1's auc: 0.953903	valid_1's binary_logloss: 0.233825
# [24]	training's auc: 0.993488	training's binary_logloss: 0.17696	valid_1's auc: 0.954822	valid_1's binary_logloss: 0.228408
# [25]	training's auc: 0.993891	training's binary_logloss: 0.169945	valid_1's auc: 0.955511	valid_1's binary_logloss: 0.222421
# [26]	training's auc: 0.994283	training's binary_logloss: 0.162741	valid_1's auc: 0.956254	valid_1's binary_logloss: 0.216156
# [27]	training's auc: 0.994546	training's binary_logloss: 0.157343	valid_1's auc: 0.957455	valid_1's binary_logloss: 0.211115
# [28]	training's auc: 0.994783	training's binary_logloss: 0.152351	valid_1's auc: 0.957738	valid_1's binary_logloss: 0.207552
# [29]	training's auc: 0.995127	training's binary_logloss: 0.146739	valid_1's auc: 0.958958	valid_1's binary_logloss: 0.201612
# [30]	training's auc: 0.99535	training's binary_logloss: 0.141863	valid_1's auc: 0.959842	valid_1's binary_logloss: 0.196731
# [31]	training's auc: 0.99561	training's binary_logloss: 0.137433	valid_1's auc: 0.961026	valid_1's binary_logloss: 0.19295
# [32]	training's auc: 0.99583	training's binary_logloss: 0.133012	valid_1's auc: 0.962723	valid_1's binary_logloss: 0.187885
# [33]	training's auc: 0.996019	training's binary_logloss: 0.129165	valid_1's auc: 0.96366	valid_1's binary_logloss: 0.184376
# [34]	training's auc: 0.996232	training's binary_logloss: 0.12497	valid_1's auc: 0.965586	valid_1's binary_logloss: 0.179074
# [35]	training's auc: 0.996411	training's binary_logloss: 0.121949	valid_1's auc: 0.96594	valid_1's binary_logloss: 0.1766
# [36]	training's auc: 0.996606	training's binary_logloss: 0.11836	valid_1's auc: 0.967407	valid_1's binary_logloss: 0.172449
# [37]	training's auc: 0.996781	training's binary_logloss: 0.114786	valid_1's auc: 0.968184	valid_1's binary_logloss: 0.169468
# [38]	training's auc: 0.996952	training's binary_logloss: 0.111308	valid_1's auc: 0.968396	valid_1's binary_logloss: 0.167302
# [39]	training's auc: 0.997092	training's binary_logloss: 0.108534	valid_1's auc: 0.967654	valid_1's binary_logloss: 0.165174
# [40]	training's auc: 0.997263	training's binary_logloss: 0.105669	valid_1's auc: 0.96875	valid_1's binary_logloss: 0.162169
# [41]	training's auc: 0.997348	training's binary_logloss: 0.103146	valid_1's auc: 0.968732	valid_1's binary_logloss: 0.160001
# [42]	training's auc: 0.997479	training's binary_logloss: 0.10045	valid_1's auc: 0.968396	valid_1's binary_logloss: 0.158523
# [43]	training's auc: 0.997613	training's binary_logloss: 0.0976483	valid_1's auc: 0.968856	valid_1's binary_logloss: 0.155008
# [44]	training's auc: 0.99773	training's binary_logloss: 0.0949829	valid_1's auc: 0.968715	valid_1's binary_logloss: 0.153165
# [45]	training's auc: 0.997823	training's binary_logloss: 0.0925154	valid_1's auc: 0.969475	valid_1's binary_logloss: 0.150635
# [46]	training's auc: 0.997928	training's binary_logloss: 0.0905466	valid_1's auc: 0.968909	valid_1's binary_logloss: 0.149318
# [47]	training's auc: 0.998021	training's binary_logloss: 0.0879329	valid_1's auc: 0.969157	valid_1's binary_logloss: 0.147957
# [48]	training's auc: 0.998093	training's binary_logloss: 0.0862753	valid_1's auc: 0.96829	valid_1's binary_logloss: 0.147069
# [49]	training's auc: 0.998187	training's binary_logloss: 0.084324	valid_1's auc: 0.96875	valid_1's binary_logloss: 0.145091
# [50]	training's auc: 0.998275	training's binary_logloss: 0.0825087	valid_1's auc: 0.968944	valid_1's binary_logloss: 0.143661
# [51]	training's auc: 0.998343	training's binary_logloss: 0.0808471	valid_1's auc: 0.969581	valid_1's binary_logloss: 0.142102
# [52]	training's auc: 0.998418	training's binary_logloss: 0.0790543	valid_1's auc: 0.970323	valid_1's binary_logloss: 0.140739
# [53]	training's auc: 0.99848	training's binary_logloss: 0.0776542	valid_1's auc: 0.970553	valid_1's binary_logloss: 0.139207
# [54]	training's auc: 0.99854	training's binary_logloss: 0.0760607	valid_1's auc: 0.971189	valid_1's binary_logloss: 0.138243
# [55]	training's auc: 0.998578	training's binary_logloss: 0.0747602	valid_1's auc: 0.971313	valid_1's binary_logloss: 0.137646
# [56]	training's auc: 0.998647	training's binary_logloss: 0.0731171	valid_1's auc: 0.971578	valid_1's binary_logloss: 0.135588
# [57]	training's auc: 0.998711	training's binary_logloss: 0.0716778	valid_1's auc: 0.971631	valid_1's binary_logloss: 0.134336
# [58]	training's auc: 0.998766	training's binary_logloss: 0.0702777	valid_1's auc: 0.971914	valid_1's binary_logloss: 0.133789
# [59]	training's auc: 0.998827	training's binary_logloss: 0.069006	valid_1's auc: 0.972709	valid_1's binary_logloss: 0.132139
# [60]	training's auc: 0.998889	training's binary_logloss: 0.0677605	valid_1's auc: 0.972444	valid_1's binary_logloss: 0.131385
# [61]	training's auc: 0.998946	training's binary_logloss: 0.0665079	valid_1's auc: 0.972904	valid_1's binary_logloss: 0.130861
# [62]	training's auc: 0.998989	training's binary_logloss: 0.0653475	valid_1's auc: 0.972462	valid_1's binary_logloss: 0.130084
# [63]	training's auc: 0.999035	training's binary_logloss: 0.0638318	valid_1's auc: 0.972639	valid_1's binary_logloss: 0.128814
# [64]	training's auc: 0.999081	training's binary_logloss: 0.0626204	valid_1's auc: 0.97308	valid_1's binary_logloss: 0.127502
# [65]	training's auc: 0.999132	training's binary_logloss: 0.0613965	valid_1's auc: 0.973628	valid_1's binary_logloss: 0.126712
# [66]	training's auc: 0.999183	training's binary_logloss: 0.0602206	valid_1's auc: 0.973416	valid_1's binary_logloss: 0.126734
# [67]	training's auc: 0.999227	training's binary_logloss: 0.0590975	valid_1's auc: 0.973487	valid_1's binary_logloss: 0.125857
# [68]	training's auc: 0.999259	training's binary_logloss: 0.0581176	valid_1's auc: 0.972868	valid_1's binary_logloss: 0.125919
# [69]	training's auc: 0.999297	training's binary_logloss: 0.0571606	valid_1's auc: 0.972974	valid_1's binary_logloss: 0.126348
# [70]	training's auc: 0.999336	training's binary_logloss: 0.0560946	valid_1's auc: 0.972939	valid_1's binary_logloss: 0.125784
# [71]	training's auc: 0.999364	training's binary_logloss: 0.0551817	valid_1's auc: 0.973434	valid_1's binary_logloss: 0.125204
# [72]	training's auc: 0.999397	training's binary_logloss: 0.0542483	valid_1's auc: 0.973787	valid_1's binary_logloss: 0.124728
# [73]	training's auc: 0.999433	training's binary_logloss: 0.0533756	valid_1's auc: 0.973805	valid_1's binary_logloss: 0.124439
# [74]	training's auc: 0.99945	training's binary_logloss: 0.0526153	valid_1's auc: 0.973487	valid_1's binary_logloss: 0.124273
# [75]	training's auc: 0.999482	training's binary_logloss: 0.0516619	valid_1's auc: 0.973628	valid_1's binary_logloss: 0.123553
# [76]	training's auc: 0.999512	training's binary_logloss: 0.0508821	valid_1's auc: 0.973805	valid_1's binary_logloss: 0.123145
# [77]	training's auc: 0.999533	training's binary_logloss: 0.0500655	valid_1's auc: 0.974194	valid_1's binary_logloss: 0.122268
# [78]	training's auc: 0.999555	training's binary_logloss: 0.0492701	valid_1's auc: 0.973929	valid_1's binary_logloss: 0.122323
# [79]	training's auc: 0.999576	training's binary_logloss: 0.0485794	valid_1's auc: 0.974229	valid_1's binary_logloss: 0.121232
# [80]	training's auc: 0.999597	training's binary_logloss: 0.0478813	valid_1's auc: 0.97453	valid_1's binary_logloss: 0.120764
# [81]	training's auc: 0.999621	training's binary_logloss: 0.0470652	valid_1's auc: 0.974671	valid_1's binary_logloss: 0.12016
# [82]	training's auc: 0.999641	training's binary_logloss: 0.0463314	valid_1's auc: 0.974813	valid_1's binary_logloss: 0.119899
# [83]	training's auc: 0.999657	training's binary_logloss: 0.0456622	valid_1's auc: 0.974406	valid_1's binary_logloss: 0.119674
# [84]	training's auc: 0.999673	training's binary_logloss: 0.0450248	valid_1's auc: 0.974707	valid_1's binary_logloss: 0.118613
# [85]	training's auc: 0.999689	training's binary_logloss: 0.0442924	valid_1's auc: 0.975148	valid_1's binary_logloss: 0.118254
# [86]	training's auc: 0.999701	training's binary_logloss: 0.0436416	valid_1's auc: 0.975166	valid_1's binary_logloss: 0.117841
# [87]	training's auc: 0.999714	training's binary_logloss: 0.0431041	valid_1's auc: 0.975325	valid_1's binary_logloss: 0.117463
# [88]	training's auc: 0.999723	training's binary_logloss: 0.0425432	valid_1's auc: 0.974901	valid_1's binary_logloss: 0.117366
# [89]	training's auc: 0.999743	training's binary_logloss: 0.0419613	valid_1's auc: 0.975148	valid_1's binary_logloss: 0.116984
# [90]	training's auc: 0.999754	training's binary_logloss: 0.04132	valid_1's auc: 0.974883	valid_1's binary_logloss: 0.116721
# [91]	training's auc: 0.999779	training's binary_logloss: 0.0405744	valid_1's auc: 0.974742	valid_1's binary_logloss: 0.116636
# [92]	training's auc: 0.999792	training's binary_logloss: 0.0399925	valid_1's auc: 0.974972	valid_1's binary_logloss: 0.116282
# [93]	training's auc: 0.9998	training's binary_logloss: 0.0394961	valid_1's auc: 0.974989	valid_1's binary_logloss: 0.116414
# [94]	training's auc: 0.999807	training's binary_logloss: 0.0390052	valid_1's auc: 0.97506	valid_1's binary_logloss: 0.116283
# [95]	training's auc: 0.999824	training's binary_logloss: 0.0383726	valid_1's auc: 0.975166	valid_1's binary_logloss: 0.116237
# [96]	training's auc: 0.999833	training's binary_logloss: 0.0377963	valid_1's auc: 0.975378	valid_1's binary_logloss: 0.116006
# [97]	training's auc: 0.999842	training's binary_logloss: 0.0372693	valid_1's auc: 0.975714	valid_1's binary_logloss: 0.115127
# [98]	training's auc: 0.999856	training's binary_logloss: 0.0366532	valid_1's auc: 0.975714	valid_1's binary_logloss: 0.115286
# [99]	training's auc: 0.999864	training's binary_logloss: 0.0361566	valid_1's auc: 0.975785	valid_1's binary_logloss: 0.11519
# [100]	training's auc: 0.999875	training's binary_logloss: 0.0356049	valid_1's auc: 0.975537	valid_1's binary_logloss: 0.115357
# [101]	training's auc: 0.999883	training's binary_logloss: 0.0350426	valid_1's auc: 0.975325	valid_1's binary_logloss: 0.115728
# [102]	training's auc: 0.999892	training's binary_logloss: 0.0345456	valid_1's auc: 0.975608	valid_1's binary_logloss: 0.114978
# [103]	training's auc: 0.999903	training's binary_logloss: 0.0340044	valid_1's auc: 0.975467	valid_1's binary_logloss: 0.114921
# [104]	training's auc: 0.999912	training's binary_logloss: 0.0334932	valid_1's auc: 0.975749	valid_1's binary_logloss: 0.114334
# [105]	training's auc: 0.999916	training's binary_logloss: 0.033197	valid_1's auc: 0.975749	valid_1's binary_logloss: 0.114316
# [106]	training's auc: 0.99992	training's binary_logloss: 0.032798	valid_1's auc: 0.975396	valid_1's binary_logloss: 0.114325
# [107]	training's auc: 0.999925	training's binary_logloss: 0.0323454	valid_1's auc: 0.975502	valid_1's binary_logloss: 0.114478
# [108]	training's auc: 0.99993	training's binary_logloss: 0.0318949	valid_1's auc: 0.975979	valid_1's binary_logloss: 0.113814
# [109]	training's auc: 0.999939	training's binary_logloss: 0.0312638	valid_1's auc: 0.975732	valid_1's binary_logloss: 0.113921
# [110]	training's auc: 0.999944	training's binary_logloss: 0.0308649	valid_1's auc: 0.975749	valid_1's binary_logloss: 0.11383
# [111]	training's auc: 0.999946	training's binary_logloss: 0.0304824	valid_1's auc: 0.975838	valid_1's binary_logloss: 0.113664
# [112]	training's auc: 0.999952	training's binary_logloss: 0.029999	valid_1's auc: 0.975926	valid_1's binary_logloss: 0.113278
# [113]	training's auc: 0.999954	training's binary_logloss: 0.0295904	valid_1's auc: 0.975979	valid_1's binary_logloss: 0.113003
# [114]	training's auc: 0.999959	training's binary_logloss: 0.0291645	valid_1's auc: 0.975979	valid_1's binary_logloss: 0.113026
# [115]	training's auc: 0.999961	training's binary_logloss: 0.0287761	valid_1's auc: 0.975909	valid_1's binary_logloss: 0.113414
# [116]	training's auc: 0.999965	training's binary_logloss: 0.0283688	valid_1's auc: 0.976191	valid_1's binary_logloss: 0.112935
# [117]	training's auc: 0.99997	training's binary_logloss: 0.0279097	valid_1's auc: 0.976174	valid_1's binary_logloss: 0.112881
# [118]	training's auc: 0.999972	training's binary_logloss: 0.0276288	valid_1's auc: 0.976103	valid_1's binary_logloss: 0.11307
# [119]	training's auc: 0.999973	training's binary_logloss: 0.0273279	valid_1's auc: 0.975997	valid_1's binary_logloss: 0.113242
# [120]	training's auc: 0.999975	training's binary_logloss: 0.0269228	valid_1's auc: 0.976209	valid_1's binary_logloss: 0.113062
# [121]	training's auc: 0.999977	training's binary_logloss: 0.0265179	valid_1's auc: 0.976068	valid_1's binary_logloss: 0.113194
# [122]	training's auc: 0.999978	training's binary_logloss: 0.0262067	valid_1's auc: 0.976121	valid_1's binary_logloss: 0.113346
# [123]	training's auc: 0.999979	training's binary_logloss: 0.0258861	valid_1's auc: 0.976191	valid_1's binary_logloss: 0.113265
# [124]	training's auc: 0.99998	training's binary_logloss: 0.0256633	valid_1's auc: 0.976244	valid_1's binary_logloss: 0.113442
# [125]	training's auc: 0.999981	training's binary_logloss: 0.0252514	valid_1's auc: 0.976103	valid_1's binary_logloss: 0.113545
# [126]	training's auc: 0.999983	training's binary_logloss: 0.0249203	valid_1's auc: 0.976244	valid_1's binary_logloss: 0.11307
# [127]	training's auc: 0.999984	training's binary_logloss: 0.0247079	valid_1's auc: 0.976032	valid_1's binary_logloss: 0.113156
# [128]	training's auc: 0.999985	training's binary_logloss: 0.0242701	valid_1's auc: 0.975997	valid_1's binary_logloss: 0.112958
# [129]	training's auc: 0.999987	training's binary_logloss: 0.0239251	valid_1's auc: 0.975873	valid_1's binary_logloss: 0.11319
# [130]	training's auc: 0.999989	training's binary_logloss: 0.0235872	valid_1's auc: 0.975979	valid_1's binary_logloss: 0.113091
# [131]	training's auc: 0.99999	training's binary_logloss: 0.0232707	valid_1's auc: 0.975997	valid_1's binary_logloss: 0.11294
# [132]	training's auc: 0.99999	training's binary_logloss: 0.0229523	valid_1's auc: 0.976297	valid_1's binary_logloss: 0.112226
# [133]	training's auc: 0.999992	training's binary_logloss: 0.0225412	valid_1's auc: 0.976527	valid_1's binary_logloss: 0.111547
# [134]	training's auc: 0.999993	training's binary_logloss: 0.0222301	valid_1's auc: 0.976456	valid_1's binary_logloss: 0.111781
# [135]	training's auc: 0.999994	training's binary_logloss: 0.0218278	valid_1's auc: 0.976545	valid_1's binary_logloss: 0.111751
# [136]	training's auc: 0.999995	training's binary_logloss: 0.0215822	valid_1's auc: 0.976456	valid_1's binary_logloss: 0.112044
# [137]	training's auc: 0.999995	training's binary_logloss: 0.0213461	valid_1's auc: 0.976545	valid_1's binary_logloss: 0.112219
# [138]	training's auc: 0.999995	training's binary_logloss: 0.0211267	valid_1's auc: 0.976439	valid_1's binary_logloss: 0.112502
# [139]	training's auc: 0.999996	training's binary_logloss: 0.0208255	valid_1's auc: 0.976244	valid_1's binary_logloss: 0.11299
# [140]	training's auc: 0.999997	training's binary_logloss: 0.0205135	valid_1's auc: 0.976068	valid_1's binary_logloss: 0.113191
# [141]	training's auc: 0.999997	training's binary_logloss: 0.0201902	valid_1's auc: 0.976085	valid_1's binary_logloss: 0.113363
# [142]	training's auc: 0.999998	training's binary_logloss: 0.0199199	valid_1's auc: 0.976174	valid_1's binary_logloss: 0.113332
# [143]	training's auc: 0.999998	training's binary_logloss: 0.0196348	valid_1's auc: 0.976085	valid_1's binary_logloss: 0.11373
# [144]	training's auc: 0.999998	training's binary_logloss: 0.019296	valid_1's auc: 0.976315	valid_1's binary_logloss: 0.113616
# [145]	training's auc: 0.999999	training's binary_logloss: 0.0190478	valid_1's auc: 0.976227	valid_1's binary_logloss: 0.113312
# [146]	training's auc: 0.999999	training's binary_logloss: 0.0187833	valid_1's auc: 0.976227	valid_1's binary_logloss: 0.113562
# [147]	training's auc: 0.999999	training's binary_logloss: 0.0185828	valid_1's auc: 0.976403	valid_1's binary_logloss: 0.113793
# [148]	training's auc: 0.999999	training's binary_logloss: 0.0183304	valid_1's auc: 0.976439	valid_1's binary_logloss: 0.113234
# [149]	training's auc: 0.999999	training's binary_logloss: 0.0181287	valid_1's auc: 0.976439	valid_1's binary_logloss: 0.113689
# [150]	training's auc: 0.999999	training's binary_logloss: 0.0178826	valid_1's auc: 0.976474	valid_1's binary_logloss: 0.113818
# [151]	training's auc: 0.999999	training's binary_logloss: 0.0176161	valid_1's auc: 0.976333	valid_1's binary_logloss: 0.114011
# [152]	training's auc: 0.999999	training's binary_logloss: 0.0173611	valid_1's auc: 0.976333	valid_1's binary_logloss: 0.11385
# [153]	training's auc: 0.999999	training's binary_logloss: 0.017154	valid_1's auc: 0.976403	valid_1's binary_logloss: 0.113662
# [154]	training's auc: 1	training's binary_logloss: 0.0169632	valid_1's auc: 0.976562	valid_1's binary_logloss: 0.113416
# [155]	training's auc: 1	training's binary_logloss: 0.0167509	valid_1's auc: 0.976651	valid_1's binary_logloss: 0.113133
# [156]	training's auc: 1	training's binary_logloss: 0.0165259	valid_1's auc: 0.976722	valid_1's binary_logloss: 0.112841
# [157]	training's auc: 1	training's binary_logloss: 0.0163313	valid_1's auc: 0.976651	valid_1's binary_logloss: 0.113107
# [158]	training's auc: 1	training's binary_logloss: 0.016053	valid_1's auc: 0.976739	valid_1's binary_logloss: 0.113258
# [159]	training's auc: 1	training's binary_logloss: 0.0158713	valid_1's auc: 0.976863	valid_1's binary_logloss: 0.112982
# [160]	training's auc: 1	training's binary_logloss: 0.0156698	valid_1's auc: 0.97658	valid_1's binary_logloss: 0.113477
# [161]	training's auc: 1	training's binary_logloss: 0.0154229	valid_1's auc: 0.976722	valid_1's binary_logloss: 0.113433
# [162]	training's auc: 1	training's binary_logloss: 0.0152708	valid_1's auc: 0.976775	valid_1's binary_logloss: 0.113643
# [163]	training's auc: 1	training's binary_logloss: 0.0150876	valid_1's auc: 0.976898	valid_1's binary_logloss: 0.113545
# [164]	training's auc: 1	training's binary_logloss: 0.0148686	valid_1's auc: 0.976934	valid_1's binary_logloss: 0.113505
# [165]	training's auc: 1	training's binary_logloss: 0.0146272	valid_1's auc: 0.977004	valid_1's binary_logloss: 0.113117
# [166]	training's auc: 1	training's binary_logloss: 0.0144651	valid_1's auc: 0.977093	valid_1's binary_logloss: 0.112722
# [167]	training's auc: 1	training's binary_logloss: 0.0142982	valid_1's auc: 0.977216	valid_1's binary_logloss: 0.112637
# [168]	training's auc: 1	training's binary_logloss: 0.0141238	valid_1's auc: 0.976845	valid_1's binary_logloss: 0.112995
# [169]	training's auc: 1	training's binary_logloss: 0.0139701	valid_1's auc: 0.976881	valid_1's binary_logloss: 0.112753
# [170]	training's auc: 1	training's binary_logloss: 0.0137862	valid_1's auc: 0.977004	valid_1's binary_logloss: 0.11253
# [171]	training's auc: 1	training's binary_logloss: 0.0136522	valid_1's auc: 0.977093	valid_1's binary_logloss: 0.112376
# [172]	training's auc: 1	training's binary_logloss: 0.013505	valid_1's auc: 0.977093	valid_1's binary_logloss: 0.112287
# [173]	training's auc: 1	training's binary_logloss: 0.0133474	valid_1's auc: 0.977287	valid_1's binary_logloss: 0.112221
# [174]	training's auc: 1	training's binary_logloss: 0.0132004	valid_1's auc: 0.977305	valid_1's binary_logloss: 0.112262
# [175]	training's auc: 1	training's binary_logloss: 0.0130491	valid_1's auc: 0.977146	valid_1's binary_logloss: 0.112193
# [176]	training's auc: 1	training's binary_logloss: 0.012931	valid_1's auc: 0.977323	valid_1's binary_logloss: 0.112016
# [177]	training's auc: 1	training's binary_logloss: 0.0128073	valid_1's auc: 0.977429	valid_1's binary_logloss: 0.11192
# [178]	training's auc: 1	training's binary_logloss: 0.012602	valid_1's auc: 0.977376	valid_1's binary_logloss: 0.112103
# [179]	training's auc: 1	training's binary_logloss: 0.0124502	valid_1's auc: 0.977163	valid_1's binary_logloss: 0.112439
# [180]	training's auc: 1	training's binary_logloss: 0.0122851	valid_1's auc: 0.977199	valid_1's binary_logloss: 0.112274
# [181]	training's auc: 1	training's binary_logloss: 0.0121427	valid_1's auc: 0.976704	valid_1's binary_logloss: 0.112936
# [182]	training's auc: 1	training's binary_logloss: 0.0120186	valid_1's auc: 0.976651	valid_1's binary_logloss: 0.113422
# [183]	training's auc: 1	training's binary_logloss: 0.0118702	valid_1's auc: 0.976863	valid_1's binary_logloss: 0.113174
# [184]	training's auc: 1	training's binary_logloss: 0.0116938	valid_1's auc: 0.976704	valid_1's binary_logloss: 0.113533
# [185]	training's auc: 1	training's binary_logloss: 0.0115778	valid_1's auc: 0.97681	valid_1's binary_logloss: 0.113592
# [186]	training's auc: 1	training's binary_logloss: 0.0114247	valid_1's auc: 0.976598	valid_1's binary_logloss: 0.113868
# [187]	training's auc: 1	training's binary_logloss: 0.011301	valid_1's auc: 0.976686	valid_1's binary_logloss: 0.113974
# [188]	training's auc: 1	training's binary_logloss: 0.0111231	valid_1's auc: 0.976403	valid_1's binary_logloss: 0.11393
# [189]	training's auc: 1	training's binary_logloss: 0.0109667	valid_1's auc: 0.976297	valid_1's binary_logloss: 0.113762
# [190]	training's auc: 1	training's binary_logloss: 0.0108244	valid_1's auc: 0.976386	valid_1's binary_logloss: 0.114064
# [191]	training's auc: 1	training's binary_logloss: 0.0106939	valid_1's auc: 0.976209	valid_1's binary_logloss: 0.114716
# [192]	training's auc: 1	training's binary_logloss: 0.0105502	valid_1's auc: 0.976138	valid_1's binary_logloss: 0.114926
# [193]	training's auc: 1	training's binary_logloss: 0.0104392	valid_1's auc: 0.976386	valid_1's binary_logloss: 0.114572
# [194]	training's auc: 1	training's binary_logloss: 0.0103261	valid_1's auc: 0.976262	valid_1's binary_logloss: 0.114921
# [195]	training's auc: 1	training's binary_logloss: 0.0101821	valid_1's auc: 0.976121	valid_1's binary_logloss: 0.115347
# [196]	training's auc: 1	training's binary_logloss: 0.0100305	valid_1's auc: 0.976121	valid_1's binary_logloss: 0.115505
# [197]	training's auc: 1	training's binary_logloss: 0.00993726	valid_1's auc: 0.976297	valid_1's binary_logloss: 0.115904
# [198]	training's auc: 1	training's binary_logloss: 0.00981815	valid_1's auc: 0.976527	valid_1's binary_logloss: 0.115534
# [199]	training's auc: 1	training's binary_logloss: 0.00969942	valid_1's auc: 0.976562	valid_1's binary_logloss: 0.115706
# [200]	training's auc: 1	training's binary_logloss: 0.0095553	valid_1's auc: 0.976474	valid_1's binary_logloss: 0.115832
# [201]	training's auc: 1	training's binary_logloss: 0.0094616	valid_1's auc: 0.976456	valid_1's binary_logloss: 0.115789
# [202]	training's auc: 1	training's binary_logloss: 0.00935562	valid_1's auc: 0.976474	valid_1's binary_logloss: 0.115678
# [203]	training's auc: 1	training's binary_logloss: 0.00921983	valid_1's auc: 0.976333	valid_1's binary_logloss: 0.11598
# [204]	training's auc: 1	training's binary_logloss: 0.00910138	valid_1's auc: 0.97635	valid_1's binary_logloss: 0.115867
# [205]	training's auc: 1	training's binary_logloss: 0.0090088	valid_1's auc: 0.976545	valid_1's binary_logloss: 0.116035
# [206]	training's auc: 1	training's binary_logloss: 0.00885149	valid_1's auc: 0.976527	valid_1's binary_logloss: 0.115917
# [207]	training's auc: 1	training's binary_logloss: 0.00875383	valid_1's auc: 0.976545	valid_1's binary_logloss: 0.116229
# [208]	training's auc: 1	training's binary_logloss: 0.0086293	valid_1's auc: 0.976456	valid_1's binary_logloss: 0.116144
# [209]	training's auc: 1	training's binary_logloss: 0.008536	valid_1's auc: 0.976722	valid_1's binary_logloss: 0.115622
# [210]	training's auc: 1	training's binary_logloss: 0.00844659	valid_1's auc: 0.976722	valid_1's binary_logloss: 0.115962
# [211]	training's auc: 1	training's binary_logloss: 0.00833508	valid_1's auc: 0.976757	valid_1's binary_logloss: 0.115869
# [212]	training's auc: 1	training's binary_logloss: 0.00824164	valid_1's auc: 0.976792	valid_1's binary_logloss: 0.116155
# [213]	training's auc: 1	training's binary_logloss: 0.0081458	valid_1's auc: 0.976828	valid_1's binary_logloss: 0.11608
# [214]	training's auc: 1	training's binary_logloss: 0.00801208	valid_1's auc: 0.976775	valid_1's binary_logloss: 0.116212
# [215]	training's auc: 1	training's binary_logloss: 0.00791517	valid_1's auc: 0.976492	valid_1's binary_logloss: 0.116698
# [216]	training's auc: 1	training's binary_logloss: 0.00782114	valid_1's auc: 0.976527	valid_1's binary_logloss: 0.116726
# [217]	training's auc: 1	training's binary_logloss: 0.00772282	valid_1's auc: 0.976368	valid_1's binary_logloss: 0.117031
# [218]	training's auc: 1	training's binary_logloss: 0.00762968	valid_1's auc: 0.976103	valid_1's binary_logloss: 0.117355
# [219]	training's auc: 1	training's binary_logloss: 0.00755992	valid_1's auc: 0.976068	valid_1's binary_logloss: 0.117656
# [220]	training's auc: 1	training's binary_logloss: 0.00744079	valid_1's auc: 0.976138	valid_1's binary_logloss: 0.117524
# [221]	training's auc: 1	training's binary_logloss: 0.00736493	valid_1's auc: 0.976191	valid_1's binary_logloss: 0.117539
# [222]	training's auc: 1	training's binary_logloss: 0.0072693	valid_1's auc: 0.976156	valid_1's binary_logloss: 0.117664
# [223]	training's auc: 1	training's binary_logloss: 0.00715012	valid_1's auc: 0.976103	valid_1's binary_logloss: 0.117919
# [224]	training's auc: 1	training's binary_logloss: 0.00706376	valid_1's auc: 0.976103	valid_1's binary_logloss: 0.118275
# [225]	training's auc: 1	training's binary_logloss: 0.00697674	valid_1's auc: 0.976103	valid_1's binary_logloss: 0.1187
# [226]	training's auc: 1	training's binary_logloss: 0.00688724	valid_1's auc: 0.97605	valid_1's binary_logloss: 0.119223
# [227]	training's auc: 1	training's binary_logloss: 0.00678122	valid_1's auc: 0.976068	valid_1's binary_logloss: 0.119382
# [228]	training's auc: 1	training's binary_logloss: 0.00667543	valid_1's auc: 0.97605	valid_1's binary_logloss: 0.119535
# [229]	training's auc: 1	training's binary_logloss: 0.00658063	valid_1's auc: 0.975944	valid_1's binary_logloss: 0.11978
# [230]	training's auc: 1	training's binary_logloss: 0.00651128	valid_1's auc: 0.975909	valid_1's binary_logloss: 0.119488
# [231]	training's auc: 1	training's binary_logloss: 0.00642079	valid_1's auc: 0.976156	valid_1's binary_logloss: 0.119314
# [232]	training's auc: 1	training's binary_logloss: 0.00633384	valid_1's auc: 0.975979	valid_1's binary_logloss: 0.119753
# [233]	training's auc: 1	training's binary_logloss: 0.00624976	valid_1's auc: 0.97605	valid_1's binary_logloss: 0.120078
# ROC AUC: 0.9897

# %%
from hyperopt import hp

lgbm_search_space = {'num_leaves': hp.quniform('num_leaves', 32, 64, 1),
                     'max_depth': hp.quniform('max_depth', 100, 160, 1),
                     'min_child_samples': hp.quniform('min_child_samples', 60, 100, 1),
                     'subsample': hp.uniform('subsample', 0.7, 1),
                     'learning_rate': hp.uniform('learning_rate', 0.01, 0.2)
                    }

# %%
from sklearn.model_selection import KFold
# X_Features = X_tr
# y_labels = y_tr
# print(X_Features, y_labels)

def objective_func(search_space):
    lgbm_clf =  LGBMClassifier(n_estimators=100, num_leaves=int(search_space['num_leaves']),
                               max_depth=int(search_space['max_depth']),
                               min_child_samples=int(search_space['min_child_samples']), 
                               subsample=search_space['subsample'],
                               learning_rate=search_space['learning_rate'])

    roc_auc_list = []
    
    kf = KFold(n_splits=3)
    # X_train을 다시 학습과 검증용 데이터로 분리
    # for tr_index, val_index in kf.split(X_Features):
    #     # kf.split(X_train)으로 추출된 학습과 검증 index값으로 학습과 검증 데이터 세트 분리 
    #     X_tr, y_tr = X_Features[tr_index], y_labels[tr_index]
    #     X_val, y_val = X_Features[val_index], y_labels[val_index]

    for tr_index, val_index in kf.split(X_train):
        # kf.split(X_train)으로 추출된 학습과 검증 index값으로 학습과 검증 데이터 세트 분리 
        X_tr, y_tr = X_train[tr_index], y_train[tr_index]
        X_val, y_val = X_train[val_index], y_train[val_index]


        # SMOTE 적용
        # ----------
        # sm = SMOTE(sampling_strategy='auto', random_state=42)
        # X_tr, y_tr=sm.fit_resample(X_tr,y_tr)

        # early stopping은 30회로 설정하고 추출된 학습과 검증 데이터로 XGBClassifier 학습 수행. 
        # lgbm_clf.fit(X_tr, y_tr, early_stopping_rounds=30, eval_metric="auc",
        lgbm_clf.fit(X_tr, y_tr, eval_metric="auc", eval_set=[(X_tr, y_tr), (X_val, y_val)])

        # 1로 예측한 확률값 추출후 roc auc 계산하고 평균 roc auc 계산을 위해 list에 결과값 담음.
        score = roc_auc_score(y_eval, lgbm_clf.predict_proba(X_eval)[:, 1]) 
        roc_auc_list.append(score)
    
    # 3개 k-fold로 계산된 roc_auc값의 평균값을 반환하되, 
    # HyperOpt는 목적함수의 최소값을 위한 입력값을 찾으므로 -1을 곱한 뒤 반환.
    return -1*np.mean(roc_auc_list)

# %%
from hyperopt import fmin, tpe, Trials

trials = Trials()

# fmin()함수를 호출. max_evals지정된 횟수만큼 반복 후 목적함수의 최소값을 가지는 최적 입력값 추출. 
best = fmin(fn=objective_func, space=lgbm_search_space, algo=tpe.suggest,
            max_evals=50, # 최대 반복 횟수를 지정합니다.
            trials=trials, rstate=np.random.default_rng(seed=30))

print('best:', best)
# Out:
# [1]	training's auc: 0.943504	training's binary_logloss: 0.618982	valid_1's auc: 0.842872	valid_1's binary_logloss: 0.976606
# [2]	training's auc: 0.954962	training's binary_logloss: 0.605175	valid_1's auc: 0.861091	valid_1's binary_logloss: 0.953254
# [3]	training's auc: 0.956844	training's binary_logloss: 0.592302	valid_1's auc: 0.865379	valid_1's binary_logloss: 0.931703
# [4]	training's auc: 0.956996	training's binary_logloss: 0.58005	valid_1's auc: 0.866222	valid_1's binary_logloss: 0.91113
# [5]	training's auc: 0.958359	training's binary_logloss: 0.568078	valid_1's auc: 0.869261	valid_1's binary_logloss: 0.891713
# [6]	training's auc: 0.962108	training's binary_logloss: 0.555967	valid_1's auc: 0.872135	valid_1's binary_logloss: 0.872018
# [7]	training's auc: 0.962644	training's binary_logloss: 0.545036	valid_1's auc: 0.873407	valid_1's binary_logloss: 0.854698
# [8]	training's auc: 0.964182	training's binary_logloss: 0.53391	valid_1's auc: 0.874588	valid_1's binary_logloss: 0.83674
# [9]	training's auc: 0.965614	training's binary_logloss: 0.523092	valid_1's auc: 0.875801	valid_1's binary_logloss: 0.819343
# [10]	training's auc: 0.96627	training's binary_logloss: 0.513298	valid_1's auc: 0.876883	valid_1's binary_logloss: 0.803989
# [11]	training's auc: 0.966757	training's binary_logloss: 0.503328	valid_1's auc: 0.877764	valid_1's binary_logloss: 0.788017
# [12]	training's auc: 0.967051	training's binary_logloss: 0.494331	valid_1's auc: 0.879691	valid_1's binary_logloss: 0.773807
# [13]	training's auc: 0.967409	training's binary_logloss: 0.485585	valid_1's auc: 0.879819	valid_1's binary_logloss: 0.760016
# [14]	training's auc: 0.967589	training's binary_logloss: 0.477282	valid_1's auc: 0.879357	valid_1's binary_logloss: 0.74719
# [15]	training's auc: 0.968784	training's binary_logloss: 0.469146	valid_1's auc: 0.881223	valid_1's binary_logloss: 0.734878
# [16]	training's auc: 0.969206	training's binary_logloss: 0.461218	valid_1's auc: 0.883184	valid_1's binary_logloss: 0.722727
# [17]	training's auc: 0.969931	training's binary_logloss: 0.453347	valid_1's auc: 0.887197	valid_1's binary_logloss: 0.710769
# [18]	training's auc: 0.970428	training's binary_logloss: 0.445974	valid_1's auc: 0.887654	valid_1's binary_logloss: 0.699706
# [19]	training's auc: 0.97101	training's binary_logloss: 0.438802	valid_1's auc: 0.889132	valid_1's binary_logloss: 0.689129
# [20]	training's auc: 0.972438	training's binary_logloss: 0.431662	valid_1's auc: 0.894296	valid_1's binary_logloss: 0.678141
# [21]	training's auc: 0.973051	training's binary_logloss: 0.424947	valid_1's auc: 0.893829	valid_1's binary_logloss: 0.668219
# [22]	training's auc: 0.973804	training's binary_logloss: 0.418202	valid_1's auc: 0.896502	valid_1's binary_logloss: 0.657866
# [23]	training's auc: 0.974116	training's binary_logloss: 0.41162	valid_1's auc: 0.895855	valid_1's binary_logloss: 0.648312
# [24]	training's auc: 0.974866	training's binary_logloss: 0.405301	valid_1's auc: 0.899399	valid_1's binary_logloss: 0.638853
# [25]	training's auc: 0.975237	training's binary_logloss: 0.399248	valid_1's auc: 0.899917	valid_1's binary_logloss: 0.630054
# [26]	training's auc: 0.97583	training's binary_logloss: 0.393251	valid_1's auc: 0.902582	valid_1's binary_logloss: 0.621108
# [27]	training's auc: 0.976244	training's binary_logloss: 0.387327	valid_1's auc: 0.902266	valid_1's binary_logloss: 0.612554
# [28]	training's auc: 0.976993	training's binary_logloss: 0.38151	valid_1's auc: 0.904579	valid_1's binary_logloss: 0.603958
# [29]	training's auc: 0.977513	training's binary_logloss: 0.376159	valid_1's auc: 0.905969	valid_1's binary_logloss: 0.596108
# [30]	training's auc: 0.978006	training's binary_logloss: 0.370655	valid_1's auc: 0.908026	valid_1's binary_logloss: 0.587726
# [31]	training's auc: 0.978246	training's binary_logloss: 0.36524	valid_1's auc: 0.907501	valid_1's binary_logloss: 0.580025
# [32]	training's auc: 0.979016	training's binary_logloss: 0.359738	valid_1's auc: 0.909249	valid_1's binary_logloss: 0.572293
# [33]	training's auc: 0.979794	training's binary_logloss: 0.354347	valid_1's auc: 0.911212	valid_1's binary_logloss: 0.564251
# [34]	training's auc: 0.980269	training's binary_logloss: 0.349254	valid_1's auc: 0.912704	valid_1's binary_logloss: 0.556703
# [35]	training's auc: 0.980543	training's binary_logloss: 0.344427	valid_1's auc: 0.912771	valid_1's binary_logloss: 0.549862
# [36]	training's auc: 0.981045	training's binary_logloss: 0.339655	valid_1's auc: 0.914096	valid_1's binary_logloss: 0.543084
# [37]	training's auc: 0.981378	training's binary_logloss: 0.334787	valid_1's auc: 0.914448	valid_1's binary_logloss: 0.536096
# [38]	training's auc: 0.981858	training's binary_logloss: 0.330013	valid_1's auc: 0.915621	valid_1's binary_logloss: 0.52942
# [39]	training's auc: 0.982343	training's binary_logloss: 0.325125	valid_1's auc: 0.915939	valid_1's binary_logloss: 0.522302
# [40]	training's auc: 0.982794	training's binary_logloss: 0.320376	valid_1's auc: 0.916874	valid_1's binary_logloss: 0.515499
# [41]	training's auc: 0.983093	training's binary_logloss: 0.316172	valid_1's auc: 0.917653	valid_1's binary_logloss: 0.509732
# [42]	training's auc: 0.983613	training's binary_logloss: 0.311732	valid_1's auc: 0.918419	valid_1's binary_logloss: 0.503529
# [43]	training's auc: 0.9841	training's binary_logloss: 0.307315	valid_1's auc: 0.920278	valid_1's binary_logloss: 0.49711
# [44]	training's auc: 0.984571	training's binary_logloss: 0.3029	valid_1's auc: 0.921103	valid_1's binary_logloss: 0.490969
# [45]	training's auc: 0.984743	training's binary_logloss: 0.299028	valid_1's auc: 0.92095	valid_1's binary_logloss: 0.48573
# [46]	training's auc: 0.985182	training's binary_logloss: 0.294798	valid_1's auc: 0.921705	valid_1's binary_logloss: 0.479983
# [47]	training's auc: 0.985513	training's binary_logloss: 0.290693	valid_1's auc: 0.922443	valid_1's binary_logloss: 0.474169
# [48]	training's auc: 0.985825	training's binary_logloss: 0.286944	valid_1's auc: 0.923095	valid_1's binary_logloss: 0.469135
# [49]	training's auc: 0.986263	training's binary_logloss: 0.282942	valid_1's auc: 0.924639	valid_1's binary_logloss: 0.463455
# [50]	training's auc: 0.986634	training's binary_logloss: 0.279093	valid_1's auc: 0.925398	valid_1's binary_logloss: 0.458259
# [51]	training's auc: 0.986925	training's binary_logloss: 0.275411	valid_1's auc: 0.925893	valid_1's binary_logloss: 0.453339
# [52]	training's auc: 0.987294	training's binary_logloss: 0.27174	valid_1's auc: 0.926476	valid_1's binary_logloss: 0.448213
# [53]	training's auc: 0.987568	training's binary_logloss: 0.26821	valid_1's auc: 0.926918	valid_1's binary_logloss: 0.443516
# [54]	training's auc: 0.987886	training's binary_logloss: 0.264672	valid_1's auc: 0.927409	valid_1's binary_logloss: 0.438744
# [55]	training's auc: 0.988116	training's binary_logloss: 0.261367	valid_1's auc: 0.927701	valid_1's binary_logloss: 0.434395
# [56]	training's auc: 0.988474	training's binary_logloss: 0.257708	valid_1's auc: 0.928281	valid_1's binary_logloss: 0.429372
# [57]	training's auc: 0.988759	training's binary_logloss: 0.254343	valid_1's auc: 0.92952	valid_1's binary_logloss: 0.424541
# [58]	training's auc: 0.98903	training's binary_logloss: 0.251198	valid_1's auc: 0.929738	valid_1's binary_logloss: 0.420553
# [59]	training's auc: 0.989328	training's binary_logloss: 0.247778	valid_1's auc: 0.930382	valid_1's binary_logloss: 0.415939
# [60]	training's auc: 0.989505	training's binary_logloss: 0.244946	valid_1's auc: 0.930672	valid_1's binary_logloss: 0.412303
# [61]	training's auc: 0.989905	training's binary_logloss: 0.241373	valid_1's auc: 0.931418	valid_1's binary_logloss: 0.407561
# [62]	training's auc: 0.990012	training's binary_logloss: 0.238779	valid_1's auc: 0.931535	valid_1's binary_logloss: 0.404284
# [63]	training's auc: 0.990211	training's binary_logloss: 0.235816	valid_1's auc: 0.932293	valid_1's binary_logloss: 0.400271
# [64]	training's auc: 0.990415	training's binary_logloss: 0.232995	valid_1's auc: 0.932711	valid_1's binary_logloss: 0.396517
# [65]	training's auc: 0.990748	training's binary_logloss: 0.229838	valid_1's auc: 0.933615	valid_1's binary_logloss: 0.392175
# [66]	training's auc: 0.990933	training's binary_logloss: 0.22718	valid_1's auc: 0.933802	valid_1's binary_logloss: 0.388995
# [67]	training's auc: 0.991239	training's binary_logloss: 0.224053	valid_1's auc: 0.934373	valid_1's binary_logloss: 0.384873
# [68]	training's auc: 0.991483	training's binary_logloss: 0.221146	valid_1's auc: 0.934875	valid_1's binary_logloss: 0.381045
# [69]	training's auc: 0.991735	training's binary_logloss: 0.218156	valid_1's auc: 0.935356	valid_1's binary_logloss: 0.377028
# [70]	training's auc: 0.991913	training's binary_logloss: 0.215395	valid_1's auc: 0.935665	valid_1's binary_logloss: 0.373421
# [71]	training's auc: 0.992049	training's binary_logloss: 0.213049	valid_1's auc: 0.936084	valid_1's binary_logloss: 0.370368
# [72]	training's auc: 0.99228	training's binary_logloss: 0.21023	valid_1's auc: 0.937254	valid_1's binary_logloss: 0.366321
# [73]	training's auc: 0.992359	training's binary_logloss: 0.208123	valid_1's auc: 0.937531	valid_1's binary_logloss: 0.363581
# [74]	training's auc: 0.992556	training's binary_logloss: 0.205446	valid_1's auc: 0.937958	valid_1's binary_logloss: 0.360026
# [75]	training's auc: 0.992707	training's binary_logloss: 0.203099	valid_1's auc: 0.938491	valid_1's binary_logloss: 0.356869
# [76]	training's auc: 0.992909	training's binary_logloss: 0.200415	valid_1's auc: 0.938862	valid_1's binary_logloss: 0.35341
# [77]	training's auc: 0.993057	training's binary_logloss: 0.197925	valid_1's auc: 0.939162	valid_1's binary_logloss: 0.350185
# [78]	training's auc: 0.993212	training's binary_logloss: 0.195614	valid_1's auc: 0.939494	valid_1's binary_logloss: 0.347398
# [79]	training's auc: 0.993356	training's binary_logloss: 0.193185	valid_1's auc: 0.939786	valid_1's binary_logloss: 0.344199
# [80]	training's auc: 0.993432	training's binary_logloss: 0.1913	valid_1's auc: 0.940032	valid_1's binary_logloss: 0.341849
# [81]	training's auc: 0.993561	training's binary_logloss: 0.189097	valid_1's auc: 0.940192	valid_1's binary_logloss: 0.339091
# [82]	training's auc: 0.993689	training's binary_logloss: 0.186994	valid_1's auc: 0.940493	valid_1's binary_logloss: 0.336565
# [83]	training's auc: 0.993821	training's binary_logloss: 0.184729	valid_1's auc: 0.940751	valid_1's binary_logloss: 0.33357
# [84]	training's auc: 0.994005	training's binary_logloss: 0.18244	valid_1's auc: 0.941979	valid_1's binary_logloss: 0.330143
# [85]	training's auc: 0.994137	training's binary_logloss: 0.180258	valid_1's auc: 0.942359	valid_1's binary_logloss: 0.327293
# [86]	training's auc: 0.994219	training's binary_logloss: 0.17842	valid_1's auc: 0.942395	valid_1's binary_logloss: 0.32521
# [87]	training's auc: 0.994324	training's binary_logloss: 0.176764	valid_1's auc: 0.942838	valid_1's binary_logloss: 0.322984
# [88]	training's auc: 0.99444	training's binary_logloss: 0.174615	valid_1's auc: 0.943153	valid_1's binary_logloss: 0.320264
# [89]	training's auc: 0.99453	training's binary_logloss: 0.17277	valid_1's auc: 0.943272	valid_1's binary_logloss: 0.318104
# [90]	training's auc: 0.994627	training's binary_logloss: 0.170799	valid_1's auc: 0.943448	valid_1's binary_logloss: 0.315496
# [91]	training's auc: 0.994726	training's binary_logloss: 0.169179	valid_1's auc: 0.943849	valid_1's binary_logloss: 0.313376
# [92]	training's auc: 0.994804	training's binary_logloss: 0.1673	valid_1's auc: 0.944002	valid_1's binary_logloss: 0.311061
# [93]	training's auc: 0.994896	training's binary_logloss: 0.165554	valid_1's auc: 0.944111	valid_1's binary_logloss: 0.309055
# [94]	training's auc: 0.995026	training's binary_logloss: 0.163595	valid_1's auc: 0.945176	valid_1's binary_logloss: 0.306132
# [95]	training's auc: 0.99512	training's binary_logloss: 0.162175	valid_1's auc: 0.945811	valid_1's binary_logloss: 0.304081
# [96]	training's auc: 0.99516	training's binary_logloss: 0.160785	valid_1's auc: 0.94586	valid_1's binary_logloss: 0.302517
# [97]	training's auc: 0.995245	training's binary_logloss: 0.1591	valid_1's auc: 0.946369	valid_1's binary_logloss: 0.300286
# [98]	training's auc: 0.995339	training's binary_logloss: 0.157296	valid_1's auc: 0.946599	valid_1's binary_logloss: 0.29799
# [99]	training's auc: 0.995417	training's binary_logloss: 0.15592	valid_1's auc: 0.94686	valid_1's binary_logloss: 0.296181
# [100]	training's auc: 0.995518	training's binary_logloss: 0.154222	valid_1's auc: 0.94709	valid_1's binary_logloss: 0.294094
# [1]	training's auc: 0.945857	training's binary_logloss: 0.666047	valid_1's auc: 0.913793	valid_1's binary_logloss: 0.739658
# [2]	training's auc: 0.948042	training's binary_logloss: 0.65208	valid_1's auc: 0.917054	valid_1's binary_logloss: 0.724524
# [3]	training's auc: 0.956385	training's binary_logloss: 0.638189	valid_1's auc: 0.924692	valid_1's binary_logloss: 0.709966
# [4]	training's auc: 0.956385	training's binary_logloss: 0.625496	valid_1's auc: 0.925025	valid_1's binary_logloss: 0.696287
# [5]	training's auc: 0.956361	training's binary_logloss: 0.613202	valid_1's auc: 0.926136	valid_1's binary_logloss: 0.683247
# [6]	training's auc: 0.958721	training's binary_logloss: 0.601115	valid_1's auc: 0.927572	valid_1's binary_logloss: 0.670588
# [7]	training's auc: 0.959681	training's binary_logloss: 0.58941	valid_1's auc: 0.928188	valid_1's binary_logloss: 0.658434
# [8]	training's auc: 0.959628	training's binary_logloss: 0.578617	valid_1's auc: 0.928526	valid_1's binary_logloss: 0.646921
# [9]	training's auc: 0.961705	training's binary_logloss: 0.567585	valid_1's auc: 0.930698	valid_1's binary_logloss: 0.635546
# [10]	training's auc: 0.961838	training's binary_logloss: 0.557492	valid_1's auc: 0.931351	valid_1's binary_logloss: 0.624893
# [11]	training's auc: 0.96284	training's binary_logloss: 0.547373	valid_1's auc: 0.932745	valid_1's binary_logloss: 0.614448
# [12]	training's auc: 0.963804	training's binary_logloss: 0.537958	valid_1's auc: 0.933847	valid_1's binary_logloss: 0.604644
# [13]	training's auc: 0.964846	training's binary_logloss: 0.528455	valid_1's auc: 0.935147	valid_1's binary_logloss: 0.59481
# [14]	training's auc: 0.965551	training's binary_logloss: 0.519435	valid_1's auc: 0.936198	valid_1's binary_logloss: 0.58554
# [15]	training's auc: 0.96577	training's binary_logloss: 0.511069	valid_1's auc: 0.936667	valid_1's binary_logloss: 0.576922
# [16]	training's auc: 0.967124	training's binary_logloss: 0.502445	valid_1's auc: 0.938455	valid_1's binary_logloss: 0.567954
# [17]	training's auc: 0.967799	training's binary_logloss: 0.494383	valid_1's auc: 0.939432	valid_1's binary_logloss: 0.559694
# [18]	training's auc: 0.968572	training's binary_logloss: 0.48618	valid_1's auc: 0.940481	valid_1's binary_logloss: 0.551379
# [19]	training's auc: 0.969215	training's binary_logloss: 0.478253	valid_1's auc: 0.941431	valid_1's binary_logloss: 0.543229
# [20]	training's auc: 0.969846	training's binary_logloss: 0.470748	valid_1's auc: 0.942013	valid_1's binary_logloss: 0.535683
# [21]	training's auc: 0.971264	training's binary_logloss: 0.463435	valid_1's auc: 0.944258	valid_1's binary_logloss: 0.528283
# [22]	training's auc: 0.971915	training's binary_logloss: 0.456119	valid_1's auc: 0.944903	valid_1's binary_logloss: 0.520934
# [23]	training's auc: 0.972539	training's binary_logloss: 0.448857	valid_1's auc: 0.945547	valid_1's binary_logloss: 0.513565
# [24]	training's auc: 0.973506	training's binary_logloss: 0.442182	valid_1's auc: 0.946912	valid_1's binary_logloss: 0.50684
# [25]	training's auc: 0.974061	training's binary_logloss: 0.435253	valid_1's auc: 0.947502	valid_1's binary_logloss: 0.499793
# [26]	training's auc: 0.974322	training's binary_logloss: 0.428824	valid_1's auc: 0.947709	valid_1's binary_logloss: 0.49331
# [27]	training's auc: 0.97501	training's binary_logloss: 0.422632	valid_1's auc: 0.948694	valid_1's binary_logloss: 0.487032
# [28]	training's auc: 0.97548	training's binary_logloss: 0.416315	valid_1's auc: 0.9489	valid_1's binary_logloss: 0.480828
# [29]	training's auc: 0.975866	training's binary_logloss: 0.410219	valid_1's auc: 0.949197	valid_1's binary_logloss: 0.474845
# [30]	training's auc: 0.976443	training's binary_logloss: 0.404608	valid_1's auc: 0.950059	valid_1's binary_logloss: 0.469316
# [31]	training's auc: 0.97705	training's binary_logloss: 0.398559	valid_1's auc: 0.950961	valid_1's binary_logloss: 0.46325
# [32]	training's auc: 0.977467	training's binary_logloss: 0.393264	valid_1's auc: 0.951432	valid_1's binary_logloss: 0.458065
# [33]	training's auc: 0.977808	training's binary_logloss: 0.387871	valid_1's auc: 0.951746	valid_1's binary_logloss: 0.452824
# [34]	training's auc: 0.978105	training's binary_logloss: 0.382611	valid_1's auc: 0.952106	valid_1's binary_logloss: 0.447601
# [35]	training's auc: 0.978775	training's binary_logloss: 0.377533	valid_1's auc: 0.952694	valid_1's binary_logloss: 0.442762
# [36]	training's auc: 0.979285	training's binary_logloss: 0.372389	valid_1's auc: 0.953551	valid_1's binary_logloss: 0.437652
# [37]	training's auc: 0.979534	training's binary_logloss: 0.367791	valid_1's auc: 0.953826	valid_1's binary_logloss: 0.433221
# [38]	training's auc: 0.979885	training's binary_logloss: 0.362969	valid_1's auc: 0.954232	valid_1's binary_logloss: 0.428642
# [39]	training's auc: 0.980431	training's binary_logloss: 0.358248	valid_1's auc: 0.954832	valid_1's binary_logloss: 0.424206
# [40]	training's auc: 0.980658	training's binary_logloss: 0.353801	valid_1's auc: 0.955127	valid_1's binary_logloss: 0.419935
# [41]	training's auc: 0.981118	training's binary_logloss: 0.349087	valid_1's auc: 0.95577	valid_1's binary_logloss: 0.415327
# [42]	training's auc: 0.981692	training's binary_logloss: 0.344486	valid_1's auc: 0.956378	valid_1's binary_logloss: 0.411048
# [43]	training's auc: 0.981902	training's binary_logloss: 0.340079	valid_1's auc: 0.956711	valid_1's binary_logloss: 0.406666
# [44]	training's auc: 0.98252	training's binary_logloss: 0.335272	valid_1's auc: 0.957415	valid_1's binary_logloss: 0.40214
# [45]	training's auc: 0.982914	training's binary_logloss: 0.330943	valid_1's auc: 0.958321	valid_1's binary_logloss: 0.397858
# [46]	training's auc: 0.983364	training's binary_logloss: 0.326573	valid_1's auc: 0.958671	valid_1's binary_logloss: 0.393789
# [47]	training's auc: 0.983674	training's binary_logloss: 0.322337	valid_1's auc: 0.958997	valid_1's binary_logloss: 0.389688
# [48]	training's auc: 0.984115	training's binary_logloss: 0.318142	valid_1's auc: 0.959509	valid_1's binary_logloss: 0.385735
# [49]	training's auc: 0.984352	training's binary_logloss: 0.314468	valid_1's auc: 0.959761	valid_1's binary_logloss: 0.382278
# [50]	training's auc: 0.984778	training's binary_logloss: 0.310262	valid_1's auc: 0.960271	valid_1's binary_logloss: 0.378186
# [51]	training's auc: 0.985164	training's binary_logloss: 0.306296	valid_1's auc: 0.960814	valid_1's binary_logloss: 0.374342
# [52]	training's auc: 0.985446	training's binary_logloss: 0.302459	valid_1's auc: 0.961014	valid_1's binary_logloss: 0.370792
# [53]	training's auc: 0.985746	training's binary_logloss: 0.298581	valid_1's auc: 0.961331	valid_1's binary_logloss: 0.367103
# [54]	training's auc: 0.9861	training's binary_logloss: 0.294798	valid_1's auc: 0.961954	valid_1's binary_logloss: 0.363421
# [55]	training's auc: 0.986482	training's binary_logloss: 0.290969	valid_1's auc: 0.962648	valid_1's binary_logloss: 0.359701
# [56]	training's auc: 0.986677	training's binary_logloss: 0.287449	valid_1's auc: 0.962872	valid_1's binary_logloss: 0.35641
# [57]	training's auc: 0.986745	training's binary_logloss: 0.284413	valid_1's auc: 0.96302	valid_1's binary_logloss: 0.353461
# [58]	training's auc: 0.986947	training's binary_logloss: 0.28111	valid_1's auc: 0.963191	valid_1's binary_logloss: 0.350405
# [59]	training's auc: 0.987243	training's binary_logloss: 0.27762	valid_1's auc: 0.96358	valid_1's binary_logloss: 0.347048
# [60]	training's auc: 0.987492	training's binary_logloss: 0.274297	valid_1's auc: 0.964092	valid_1's binary_logloss: 0.343824
# [61]	training's auc: 0.987678	training's binary_logloss: 0.271253	valid_1's auc: 0.964321	valid_1's binary_logloss: 0.340984
# [62]	training's auc: 0.987688	training's binary_logloss: 0.268543	valid_1's auc: 0.964364	valid_1's binary_logloss: 0.338444
# [63]	training's auc: 0.987915	training's binary_logloss: 0.265479	valid_1's auc: 0.964807	valid_1's binary_logloss: 0.335539
# [64]	training's auc: 0.988284	training's binary_logloss: 0.262041	valid_1's auc: 0.965233	valid_1's binary_logloss: 0.332339
# [65]	training's auc: 0.988421	training's binary_logloss: 0.259265	valid_1's auc: 0.965391	valid_1's binary_logloss: 0.329792
# [66]	training's auc: 0.988733	training's binary_logloss: 0.255964	valid_1's auc: 0.965777	valid_1's binary_logloss: 0.326677
# [67]	training's auc: 0.988892	training's binary_logloss: 0.253181	valid_1's auc: 0.965916	valid_1's binary_logloss: 0.324106
# [68]	training's auc: 0.989142	training's binary_logloss: 0.250186	valid_1's auc: 0.96624	valid_1's binary_logloss: 0.321285
# [69]	training's auc: 0.989368	training's binary_logloss: 0.247285	valid_1's auc: 0.966677	valid_1's binary_logloss: 0.318399
# [70]	training's auc: 0.989623	training's binary_logloss: 0.244311	valid_1's auc: 0.967001	valid_1's binary_logloss: 0.315623
# [71]	training's auc: 0.989724	training's binary_logloss: 0.241887	valid_1's auc: 0.967116	valid_1's binary_logloss: 0.313418
# [72]	training's auc: 0.989971	training's binary_logloss: 0.238918	valid_1's auc: 0.967371	valid_1's binary_logloss: 0.310687
# [73]	training's auc: 0.990111	training's binary_logloss: 0.236644	valid_1's auc: 0.967671	valid_1's binary_logloss: 0.308503
# [74]	training's auc: 0.990331	training's binary_logloss: 0.233811	valid_1's auc: 0.967928	valid_1's binary_logloss: 0.305909
# [75]	training's auc: 0.990575	training's binary_logloss: 0.231192	valid_1's auc: 0.968409	valid_1's binary_logloss: 0.303207
# [76]	training's auc: 0.990776	training's binary_logloss: 0.228513	valid_1's auc: 0.968625	valid_1's binary_logloss: 0.300795
# [77]	training's auc: 0.990869	training's binary_logloss: 0.226331	valid_1's auc: 0.968774	valid_1's binary_logloss: 0.298745
# [78]	training's auc: 0.991052	training's binary_logloss: 0.223683	valid_1's auc: 0.968993	valid_1's binary_logloss: 0.296325
# [79]	training's auc: 0.991225	training's binary_logloss: 0.221418	valid_1's auc: 0.969502	valid_1's binary_logloss: 0.293902
# [80]	training's auc: 0.991467	training's binary_logloss: 0.21867	valid_1's auc: 0.969902	valid_1's binary_logloss: 0.291291
# [81]	training's auc: 0.991547	training's binary_logloss: 0.216645	valid_1's auc: 0.970107	valid_1's binary_logloss: 0.289289
# [82]	training's auc: 0.991758	training's binary_logloss: 0.21402	valid_1's auc: 0.970419	valid_1's binary_logloss: 0.286867
# [83]	training's auc: 0.991948	training's binary_logloss: 0.21163	valid_1's auc: 0.970793	valid_1's binary_logloss: 0.284434
# [84]	training's auc: 0.992025	training's binary_logloss: 0.209689	valid_1's auc: 0.970955	valid_1's binary_logloss: 0.282547
# [85]	training's auc: 0.992209	training's binary_logloss: 0.20718	valid_1's auc: 0.971261	valid_1's binary_logloss: 0.280196
# [86]	training's auc: 0.992428	training's binary_logloss: 0.204731	valid_1's auc: 0.971778	valid_1's binary_logloss: 0.277611
# [87]	training's auc: 0.99258	training's binary_logloss: 0.20236	valid_1's auc: 0.972172	valid_1's binary_logloss: 0.275142
# [88]	training's auc: 0.992708	training's binary_logloss: 0.200234	valid_1's auc: 0.972405	valid_1's binary_logloss: 0.273039
# [89]	training's auc: 0.992808	training's binary_logloss: 0.198415	valid_1's auc: 0.972519	valid_1's binary_logloss: 0.271361
# [90]	training's auc: 0.992982	training's binary_logloss: 0.196233	valid_1's auc: 0.97295	valid_1's binary_logloss: 0.269052
# [91]	training's auc: 0.993068	training's binary_logloss: 0.194513	valid_1's auc: 0.973106	valid_1's binary_logloss: 0.26745
# [92]	training's auc: 0.993216	training's binary_logloss: 0.192307	valid_1's auc: 0.973268	valid_1's binary_logloss: 0.265439
# [93]	training's auc: 0.993346	training's binary_logloss: 0.190439	valid_1's auc: 0.973612	valid_1's binary_logloss: 0.263535
# [94]	training's auc: 0.993461	training's binary_logloss: 0.188402	valid_1's auc: 0.973922	valid_1's binary_logloss: 0.26143
# [95]	training's auc: 0.993578	training's binary_logloss: 0.186448	valid_1's auc: 0.974231	valid_1's binary_logloss: 0.259338
# [96]	training's auc: 0.993754	training's binary_logloss: 0.18408	valid_1's auc: 0.974496	valid_1's binary_logloss: 0.257104
# [97]	training's auc: 0.993881	training's binary_logloss: 0.182017	valid_1's auc: 0.974691	valid_1's binary_logloss: 0.255228
# [98]	training's auc: 0.993985	training's binary_logloss: 0.180201	valid_1's auc: 0.974971	valid_1's binary_logloss: 0.253307
# [99]	training's auc: 0.994085	training's binary_logloss: 0.178348	valid_1's auc: 0.975206	valid_1's binary_logloss: 0.251404
# [100]	training's auc: 0.994229	training's binary_logloss: 0.176167	valid_1's auc: 0.975453	valid_1's binary_logloss: 0.249343
# [1]	training's auc: 0.933697	training's binary_logloss: 0.549426	valid_1's auc: 1	valid_1's binary_logloss: 1.34426
# [2]	training's auc: 0.933728	training's binary_logloss: 0.537379	valid_1's auc: 1	valid_1's binary_logloss: 1.30559
# [3]	training's auc: 0.936959	training's binary_logloss: 0.526067	valid_1's auc: 1	valid_1's binary_logloss: 1.27001
# [4]	training's auc: 0.938019	training's binary_logloss: 0.515596	valid_1's auc: 1	valid_1's binary_logloss: 1.23784
# [5]	training's auc: 0.941268	training's binary_logloss: 0.505614	valid_1's auc: 1	valid_1's binary_logloss: 1.20686
# [6]	training's auc: 0.941603	training's binary_logloss: 0.496317	valid_1's auc: 1	valid_1's binary_logloss: 1.17823
# [7]	training's auc: 0.941984	training's binary_logloss: 0.487285	valid_1's auc: 1	valid_1's binary_logloss: 1.1517
# [8]	training's auc: 0.94226	training's binary_logloss: 0.479003	valid_1's auc: 1	valid_1's binary_logloss: 1.12653
# [9]	training's auc: 0.942735	training's binary_logloss: 0.470947	valid_1's auc: 1	valid_1's binary_logloss: 1.103
# [10]	training's auc: 0.944484	training's binary_logloss: 0.462941	valid_1's auc: 1	valid_1's binary_logloss: 1.07767
# [11]	training's auc: 0.944675	training's binary_logloss: 0.455607	valid_1's auc: 1	valid_1's binary_logloss: 1.0554
# [12]	training's auc: 0.945119	training's binary_logloss: 0.448432	valid_1's auc: 1	valid_1's binary_logloss: 1.03448
# [13]	training's auc: 0.945563	training's binary_logloss: 0.441701	valid_1's auc: 1	valid_1's binary_logloss: 1.0152
# [14]	training's auc: 0.946573	training's binary_logloss: 0.434983	valid_1's auc: 1	valid_1's binary_logloss: 0.995021
# [15]	training's auc: 0.946925	training's binary_logloss: 0.428687	valid_1's auc: 1	valid_1's binary_logloss: 0.976736
# [16]	training's auc: 0.947324	training's binary_logloss: 0.422502	valid_1's auc: 1	valid_1's binary_logloss: 0.958822
# [17]	training's auc: 0.94775	training's binary_logloss: 0.416733	valid_1's auc: 1	valid_1's binary_logloss: 0.942382
# [18]	training's auc: 0.947939	training's binary_logloss: 0.410984	valid_1's auc: 1	valid_1's binary_logloss: 0.92651
# [19]	training's auc: 0.948337	training's binary_logloss: 0.405534	valid_1's auc: 1	valid_1's binary_logloss: 0.911387
# [20]	training's auc: 0.949185	training's binary_logloss: 0.400341	valid_1's auc: 1	valid_1's binary_logloss: 0.896798
# [21]	training's auc: 0.951394	training's binary_logloss: 0.394695	valid_1's auc: 1	valid_1's binary_logloss: 0.881662
# [22]	training's auc: 0.953077	training's binary_logloss: 0.389727	valid_1's auc: 1	valid_1's binary_logloss: 0.867417
# [23]	training's auc: 0.954166	training's binary_logloss: 0.384297	valid_1's auc: 1	valid_1's binary_logloss: 0.853082
# [24]	training's auc: 0.954982	training's binary_logloss: 0.379102	valid_1's auc: 1	valid_1's binary_logloss: 0.839332
# [25]	training's auc: 0.9561	training's binary_logloss: 0.374641	valid_1's auc: 1	valid_1's binary_logloss: 0.826482
# [26]	training's auc: 0.956812	training's binary_logloss: 0.369819	valid_1's auc: 1	valid_1's binary_logloss: 0.813721
# [27]	training's auc: 0.957657	training's binary_logloss: 0.365214	valid_1's auc: 1	valid_1's binary_logloss: 0.801372
# [28]	training's auc: 0.958109	training's binary_logloss: 0.360707	valid_1's auc: 1	valid_1's binary_logloss: 0.789766
# [29]	training's auc: 0.9586	training's binary_logloss: 0.356849	valid_1's auc: 1	valid_1's binary_logloss: 0.778338
# [30]	training's auc: 0.959245	training's binary_logloss: 0.352594	valid_1's auc: 1	valid_1's binary_logloss: 0.767534
# [31]	training's auc: 0.959864	training's binary_logloss: 0.348478	valid_1's auc: 1	valid_1's binary_logloss: 0.756807
# [32]	training's auc: 0.960343	training's binary_logloss: 0.344774	valid_1's auc: 1	valid_1's binary_logloss: 0.746772
# [33]	training's auc: 0.960792	training's binary_logloss: 0.340805	valid_1's auc: 1	valid_1's binary_logloss: 0.736844
# [34]	training's auc: 0.961092	training's binary_logloss: 0.3369	valid_1's auc: 1	valid_1's binary_logloss: 0.727162
# [35]	training's auc: 0.961747	training's binary_logloss: 0.333313	valid_1's auc: 1	valid_1's binary_logloss: 0.717446
# [36]	training's auc: 0.961984	training's binary_logloss: 0.329774	valid_1's auc: 1	valid_1's binary_logloss: 0.708208
# [37]	training's auc: 0.962623	training's binary_logloss: 0.326168	valid_1's auc: 1	valid_1's binary_logloss: 0.698913
# [38]	training's auc: 0.963651	training's binary_logloss: 0.322658	valid_1's auc: 1	valid_1's binary_logloss: 0.688123
# [39]	training's auc: 0.96446	training's binary_logloss: 0.319205	valid_1's auc: 1	valid_1's binary_logloss: 0.677641
# [40]	training's auc: 0.964825	training's binary_logloss: 0.315856	valid_1's auc: 1	valid_1's binary_logloss: 0.669394
# [41]	training's auc: 0.965585	training's binary_logloss: 0.312552	valid_1's auc: 1	valid_1's binary_logloss: 0.659017
# [42]	training's auc: 0.966189	training's binary_logloss: 0.309362	valid_1's auc: 1	valid_1's binary_logloss: 0.648735
# [43]	training's auc: 0.966985	training's binary_logloss: 0.305858	valid_1's auc: 1	valid_1's binary_logloss: 0.638511
# [44]	training's auc: 0.967494	training's binary_logloss: 0.30287	valid_1's auc: 1	valid_1's binary_logloss: 0.628957
# [45]	training's auc: 0.968492	training's binary_logloss: 0.299228	valid_1's auc: 1	valid_1's binary_logloss: 0.619098
# [46]	training's auc: 0.968882	training's binary_logloss: 0.296425	valid_1's auc: 1	valid_1's binary_logloss: 0.610205
# [47]	training's auc: 0.969644	training's binary_logloss: 0.292981	valid_1's auc: 1	valid_1's binary_logloss: 0.601002
# [48]	training's auc: 0.970098	training's binary_logloss: 0.29018	valid_1's auc: 1	valid_1's binary_logloss: 0.591712
# [49]	training's auc: 0.97058	training's binary_logloss: 0.28727	valid_1's auc: 1	valid_1's binary_logloss: 0.58351
# [50]	training's auc: 0.971015	training's binary_logloss: 0.284473	valid_1's auc: 1	valid_1's binary_logloss: 0.575617
# [51]	training's auc: 0.971382	training's binary_logloss: 0.281733	valid_1's auc: 1	valid_1's binary_logloss: 0.567967
# [52]	training's auc: 0.971836	training's binary_logloss: 0.278983	valid_1's auc: 1	valid_1's binary_logloss: 0.559532
# [53]	training's auc: 0.972216	training's binary_logloss: 0.276334	valid_1's auc: 1	valid_1's binary_logloss: 0.551492
# [54]	training's auc: 0.972558	training's binary_logloss: 0.273802	valid_1's auc: 1	valid_1's binary_logloss: 0.544688
# [55]	training's auc: 0.972929	training's binary_logloss: 0.271217	valid_1's auc: 1	valid_1's binary_logloss: 0.536924
# [56]	training's auc: 0.973241	training's binary_logloss: 0.268782	valid_1's auc: 1	valid_1's binary_logloss: 0.529536
# [57]	training's auc: 0.973572	training's binary_logloss: 0.266273	valid_1's auc: 1	valid_1's binary_logloss: 0.522097
# [58]	training's auc: 0.973825	training's binary_logloss: 0.263958	valid_1's auc: 1	valid_1's binary_logloss: 0.515198
# [59]	training's auc: 0.974181	training's binary_logloss: 0.261586	valid_1's auc: 1	valid_1's binary_logloss: 0.508167
# [60]	training's auc: 0.974448	training's binary_logloss: 0.25935	valid_1's auc: 1	valid_1's binary_logloss: 0.501571
# [61]	training's auc: 0.974655	training's binary_logloss: 0.257209	valid_1's auc: 1	valid_1's binary_logloss: 0.495939
# [62]	training's auc: 0.975105	training's binary_logloss: 0.254798	valid_1's auc: 1	valid_1's binary_logloss: 0.488701
# [63]	training's auc: 0.975468	training's binary_logloss: 0.252604	valid_1's auc: 1	valid_1's binary_logloss: 0.482759
# [64]	training's auc: 0.97596	training's binary_logloss: 0.250265	valid_1's auc: 1	valid_1's binary_logloss: 0.476426
# [65]	training's auc: 0.976373	training's binary_logloss: 0.247859	valid_1's auc: 1	valid_1's binary_logloss: 0.46974
# [66]	training's auc: 0.976685	training's binary_logloss: 0.245937	valid_1's auc: 1	valid_1's binary_logloss: 0.465609
# [67]	training's auc: 0.977079	training's binary_logloss: 0.243679	valid_1's auc: 1	valid_1's binary_logloss: 0.458614
# [68]	training's auc: 0.977494	training's binary_logloss: 0.24155	valid_1's auc: 1	valid_1's binary_logloss: 0.452994
# [69]	training's auc: 0.977931	training's binary_logloss: 0.239211	valid_1's auc: 1	valid_1's binary_logloss: 0.446844
# [70]	training's auc: 0.978253	training's binary_logloss: 0.237126	valid_1's auc: 1	valid_1's binary_logloss: 0.441292
# [71]	training's auc: 0.978641	training's binary_logloss: 0.235043	valid_1's auc: 1	valid_1's binary_logloss: 0.435832
# [72]	training's auc: 0.978984	training's binary_logloss: 0.232855	valid_1's auc: 1	valid_1's binary_logloss: 0.430369
# [73]	training's auc: 0.979234	training's binary_logloss: 0.231022	valid_1's auc: 1	valid_1's binary_logloss: 0.425362
# [74]	training's auc: 0.979577	training's binary_logloss: 0.229083	valid_1's auc: 1	valid_1's binary_logloss: 0.420178
# [75]	training's auc: 0.979884	training's binary_logloss: 0.227118	valid_1's auc: 1	valid_1's binary_logloss: 0.414341
# [76]	training's auc: 0.980297	training's binary_logloss: 0.224864	valid_1's auc: 1	valid_1's binary_logloss: 0.409661
# [77]	training's auc: 0.980612	training's binary_logloss: 0.222911	valid_1's auc: 1	valid_1's binary_logloss: 0.404149
# [78]	training's auc: 0.980904	training's binary_logloss: 0.220921	valid_1's auc: 1	valid_1's binary_logloss: 0.400089
# [79]	training's auc: 0.981213	training's binary_logloss: 0.218971	valid_1's auc: 1	valid_1's binary_logloss: 0.396201
# [80]	training's auc: 0.981456	training's binary_logloss: 0.217254	valid_1's auc: 1	valid_1's binary_logloss: 0.392068
# [81]	training's auc: 0.981716	training's binary_logloss: 0.215387	valid_1's auc: 1	valid_1's binary_logloss: 0.388382
# [82]	training's auc: 0.982021	training's binary_logloss: 0.213432	valid_1's auc: 1	valid_1's binary_logloss: 0.383834
# [83]	training's auc: 0.982291	training's binary_logloss: 0.211703	valid_1's auc: 1	valid_1's binary_logloss: 0.379771
# [84]	training's auc: 0.982587	training's binary_logloss: 0.209771	valid_1's auc: 1	valid_1's binary_logloss: 0.375779
# [85]	training's auc: 0.982848	training's binary_logloss: 0.207937	valid_1's auc: 1	valid_1's binary_logloss: 0.371913
# [86]	training's auc: 0.983107	training's binary_logloss: 0.20625	valid_1's auc: 1	valid_1's binary_logloss: 0.367122
# [87]	training's auc: 0.983339	training's binary_logloss: 0.204495	valid_1's auc: 1	valid_1's binary_logloss: 0.363452
# [88]	training's auc: 0.983534	training's binary_logloss: 0.202936	valid_1's auc: 1	valid_1's binary_logloss: 0.359907
# [89]	training's auc: 0.983786	training's binary_logloss: 0.201293	valid_1's auc: 1	valid_1's binary_logloss: 0.356663
# [90]	training's auc: 0.984023	training's binary_logloss: 0.199808	valid_1's auc: 1	valid_1's binary_logloss: 0.353174
# [91]	training's auc: 0.984238	training's binary_logloss: 0.198234	valid_1's auc: 1	valid_1's binary_logloss: 0.350103
# [92]	training's auc: 0.984429	training's binary_logloss: 0.196707	valid_1's auc: 1	valid_1's binary_logloss: 0.346993
# [93]	training's auc: 0.984666	training's binary_logloss: 0.195146	valid_1's auc: 1	valid_1's binary_logloss: 0.343584
# [94]	training's auc: 0.984915	training's binary_logloss: 0.19349	valid_1's auc: 1	valid_1's binary_logloss: 0.340435
# [95]	training's auc: 0.985158	training's binary_logloss: 0.191861	valid_1's auc: 1	valid_1's binary_logloss: 0.337512
# [96]	training's auc: 0.985331	training's binary_logloss: 0.190457	valid_1's auc: 1	valid_1's binary_logloss: 0.334526
# [97]	training's auc: 0.985559	training's binary_logloss: 0.188792	valid_1's auc: 1	valid_1's binary_logloss: 0.331331
# [98]	training's auc: 0.98576	training's binary_logloss: 0.187204	valid_1's auc: 1	valid_1's binary_logloss: 0.32852
# [99]	training's auc: 0.986028	training's binary_logloss: 0.185678	valid_1's auc: 1	valid_1's binary_logloss: 0.324438
# [100]	training's auc: 0.986212	training's binary_logloss: 0.184316	valid_1's auc: 1	valid_1's binary_logloss: 0.32109
# [1]	training's auc: 0.950599	training's binary_logloss: 0.558972	valid_1's auc: 0.841799	valid_1's binary_logloss: 0.876112
# [2]	training's auc: 0.96199	training's binary_logloss: 0.500671	valid_1's auc: 0.865206	valid_1's binary_logloss: 0.78347
# [3]	training's auc: 0.971186	training's binary_logloss: 0.450286	valid_1's auc: 0.878735	valid_1's binary_logloss: 0.703623
# [4]	training's auc: 0.976712	training's binary_logloss: 0.409681	valid_1's auc: 0.903175	valid_1's binary_logloss: 0.643148
# [5]	training's auc: 0.97894	training's binary_logloss: 0.376418	valid_1's auc: 0.905813	valid_1's binary_logloss: 0.595263
# [6]	training's auc: 0.982188	training's binary_logloss: 0.346542	valid_1's auc: 0.91352	valid_1's binary_logloss: 0.553144
# [7]	training's auc: 0.984495	training's binary_logloss: 0.320304	valid_1's auc: 0.917374	valid_1's binary_logloss: 0.516445
# [8]	training's auc: 0.986075	training's binary_logloss: 0.297163	valid_1's auc: 0.923114	valid_1's binary_logloss: 0.482825
# [9]	training's auc: 0.987789	training's binary_logloss: 0.275593	valid_1's auc: 0.923943	valid_1's binary_logloss: 0.454608
# [10]	training's auc: 0.989135	training's binary_logloss: 0.256835	valid_1's auc: 0.926923	valid_1's binary_logloss: 0.430409
# [11]	training's auc: 0.990731	training's binary_logloss: 0.238399	valid_1's auc: 0.930471	valid_1's binary_logloss: 0.405871
# [12]	training's auc: 0.991568	training's binary_logloss: 0.223194	valid_1's auc: 0.932377	valid_1's binary_logloss: 0.385609
# [13]	training's auc: 0.992428	training's binary_logloss: 0.208337	valid_1's auc: 0.933953	valid_1's binary_logloss: 0.366462
# [14]	training's auc: 0.993499	training's binary_logloss: 0.194724	valid_1's auc: 0.935951	valid_1's binary_logloss: 0.349398
# [15]	training's auc: 0.994373	training's binary_logloss: 0.181694	valid_1's auc: 0.938134	valid_1's binary_logloss: 0.33221
# [16]	training's auc: 0.9953	training's binary_logloss: 0.169004	valid_1's auc: 0.944471	valid_1's binary_logloss: 0.313811
# [17]	training's auc: 0.995781	training's binary_logloss: 0.159995	valid_1's auc: 0.945723	valid_1's binary_logloss: 0.302596
# [18]	training's auc: 0.996154	training's binary_logloss: 0.150487	valid_1's auc: 0.946422	valid_1's binary_logloss: 0.290626
# [19]	training's auc: 0.996405	training's binary_logloss: 0.142401	valid_1's auc: 0.946304	valid_1's binary_logloss: 0.28197
# [20]	training's auc: 0.996929	training's binary_logloss: 0.133474	valid_1's auc: 0.948116	valid_1's binary_logloss: 0.271367
# [21]	training's auc: 0.997262	training's binary_logloss: 0.125675	valid_1's auc: 0.949083	valid_1's binary_logloss: 0.262264
# [22]	training's auc: 0.997637	training's binary_logloss: 0.118633	valid_1's auc: 0.951606	valid_1's binary_logloss: 0.253297
# [23]	training's auc: 0.997961	training's binary_logloss: 0.111417	valid_1's auc: 0.955059	valid_1's binary_logloss: 0.24334
# [24]	training's auc: 0.998236	training's binary_logloss: 0.104178	valid_1's auc: 0.957746	valid_1's binary_logloss: 0.233531
# [25]	training's auc: 0.998417	training's binary_logloss: 0.0990003	valid_1's auc: 0.958843	valid_1's binary_logloss: 0.22758
# [26]	training's auc: 0.998618	training's binary_logloss: 0.0937583	valid_1's auc: 0.960146	valid_1's binary_logloss: 0.221834
# [27]	training's auc: 0.998774	training's binary_logloss: 0.0892233	valid_1's auc: 0.961287	valid_1's binary_logloss: 0.216627
# [28]	training's auc: 0.998923	training's binary_logloss: 0.0845161	valid_1's auc: 0.962129	valid_1's binary_logloss: 0.211256
# [29]	training's auc: 0.999038	training's binary_logloss: 0.0800753	valid_1's auc: 0.962961	valid_1's binary_logloss: 0.205839
# [30]	training's auc: 0.999141	training's binary_logloss: 0.0761272	valid_1's auc: 0.964299	valid_1's binary_logloss: 0.200653
# [31]	training's auc: 0.999234	training's binary_logloss: 0.07241	valid_1's auc: 0.965522	valid_1's binary_logloss: 0.195807
# [32]	training's auc: 0.999332	training's binary_logloss: 0.0684376	valid_1's auc: 0.965738	valid_1's binary_logloss: 0.19215
# [33]	training's auc: 0.999403	training's binary_logloss: 0.0652282	valid_1's auc: 0.96697	valid_1's binary_logloss: 0.187789
# [34]	training's auc: 0.999466	training's binary_logloss: 0.0621754	valid_1's auc: 0.967597	valid_1's binary_logloss: 0.184284
# [35]	training's auc: 0.999543	training's binary_logloss: 0.0588006	valid_1's auc: 0.968655	valid_1's binary_logloss: 0.179901
# [36]	training's auc: 0.999602	training's binary_logloss: 0.0562349	valid_1's auc: 0.969038	valid_1's binary_logloss: 0.177487
# [37]	training's auc: 0.999658	training's binary_logloss: 0.0537776	valid_1's auc: 0.969852	valid_1's binary_logloss: 0.174719
# [38]	training's auc: 0.999711	training's binary_logloss: 0.0512038	valid_1's auc: 0.970365	valid_1's binary_logloss: 0.172357
# [39]	training's auc: 0.99975	training's binary_logloss: 0.0489808	valid_1's auc: 0.970631	valid_1's binary_logloss: 0.170327
# [40]	training's auc: 0.999781	training's binary_logloss: 0.0466853	valid_1's auc: 0.970965	valid_1's binary_logloss: 0.16782
# [41]	training's auc: 0.999813	training's binary_logloss: 0.0445091	valid_1's auc: 0.971289	valid_1's binary_logloss: 0.16582
# [42]	training's auc: 0.999836	training's binary_logloss: 0.0424264	valid_1's auc: 0.971771	valid_1's binary_logloss: 0.163463
# [43]	training's auc: 0.999862	training's binary_logloss: 0.0406287	valid_1's auc: 0.972255	valid_1's binary_logloss: 0.161875
# [44]	training's auc: 0.99989	training's binary_logloss: 0.03864	valid_1's auc: 0.972621	valid_1's binary_logloss: 0.159593
# [45]	training's auc: 0.999917	training's binary_logloss: 0.0369756	valid_1's auc: 0.972997	valid_1's binary_logloss: 0.158028
# [46]	training's auc: 0.999935	training's binary_logloss: 0.0353449	valid_1's auc: 0.973271	valid_1's binary_logloss: 0.156229
# [47]	training's auc: 0.999948	training's binary_logloss: 0.0337855	valid_1's auc: 0.973486	valid_1's binary_logloss: 0.155154
# [48]	training's auc: 0.999959	training's binary_logloss: 0.0324861	valid_1's auc: 0.9736	valid_1's binary_logloss: 0.154404
# [49]	training's auc: 0.999965	training's binary_logloss: 0.0311073	valid_1's auc: 0.973782	valid_1's binary_logloss: 0.153148
# [50]	training's auc: 0.999974	training's binary_logloss: 0.029817	valid_1's auc: 0.973948	valid_1's binary_logloss: 0.152317
# [51]	training's auc: 0.999981	training's binary_logloss: 0.028447	valid_1's auc: 0.974281	valid_1's binary_logloss: 0.151283
# [52]	training's auc: 0.999988	training's binary_logloss: 0.0271883	valid_1's auc: 0.9743	valid_1's binary_logloss: 0.150013
# [53]	training's auc: 0.999991	training's binary_logloss: 0.026146	valid_1's auc: 0.974237	valid_1's binary_logloss: 0.14971
# [54]	training's auc: 0.999993	training's binary_logloss: 0.025043	valid_1's auc: 0.974451	valid_1's binary_logloss: 0.14867
# [55]	training's auc: 0.999996	training's binary_logloss: 0.0240313	valid_1's auc: 0.974511	valid_1's binary_logloss: 0.148197
# [56]	training's auc: 0.999997	training's binary_logloss: 0.0230644	valid_1's auc: 0.974828	valid_1's binary_logloss: 0.147032
# [57]	training's auc: 0.999998	training's binary_logloss: 0.0221454	valid_1's auc: 0.975006	valid_1's binary_logloss: 0.146246
# [58]	training's auc: 0.999999	training's binary_logloss: 0.0212013	valid_1's auc: 0.97508	valid_1's binary_logloss: 0.145533
# [59]	training's auc: 1	training's binary_logloss: 0.0203558	valid_1's auc: 0.975374	valid_1's binary_logloss: 0.144349
# [60]	training's auc: 1	training's binary_logloss: 0.0195271	valid_1's auc: 0.975381	valid_1's binary_logloss: 0.144056
# [61]	training's auc: 1	training's binary_logloss: 0.0187746	valid_1's auc: 0.975604	valid_1's binary_logloss: 0.143321
# [62]	training's auc: 1	training's binary_logloss: 0.0180479	valid_1's auc: 0.975545	valid_1's binary_logloss: 0.143446
# [63]	training's auc: 1	training's binary_logloss: 0.0172941	valid_1's auc: 0.975756	valid_1's binary_logloss: 0.142826
# [64]	training's auc: 1	training's binary_logloss: 0.0165942	valid_1's auc: 0.975677	valid_1's binary_logloss: 0.142466
# [65]	training's auc: 1	training's binary_logloss: 0.0159151	valid_1's auc: 0.975926	valid_1's binary_logloss: 0.141745
# [66]	training's auc: 1	training's binary_logloss: 0.0153066	valid_1's auc: 0.975857	valid_1's binary_logloss: 0.141777
# [67]	training's auc: 1	training's binary_logloss: 0.0147079	valid_1's auc: 0.976118	valid_1's binary_logloss: 0.14102
# [68]	training's auc: 1	training's binary_logloss: 0.0141205	valid_1's auc: 0.976238	valid_1's binary_logloss: 0.140582
# [69]	training's auc: 1	training's binary_logloss: 0.013471	valid_1's auc: 0.976226	valid_1's binary_logloss: 0.139919
# [70]	training's auc: 1	training's binary_logloss: 0.0129454	valid_1's auc: 0.976345	valid_1's binary_logloss: 0.139647
# [71]	training's auc: 1	training's binary_logloss: 0.0124433	valid_1's auc: 0.976306	valid_1's binary_logloss: 0.13913
# [72]	training's auc: 1	training's binary_logloss: 0.0119824	valid_1's auc: 0.976541	valid_1's binary_logloss: 0.138521
# [73]	training's auc: 1	training's binary_logloss: 0.011518	valid_1's auc: 0.97655	valid_1's binary_logloss: 0.138216
# [74]	training's auc: 1	training's binary_logloss: 0.0110601	valid_1's auc: 0.976477	valid_1's binary_logloss: 0.138245
# [75]	training's auc: 1	training's binary_logloss: 0.0106261	valid_1's auc: 0.976572	valid_1's binary_logloss: 0.138069
# [76]	training's auc: 1	training's binary_logloss: 0.0102267	valid_1's auc: 0.976722	valid_1's binary_logloss: 0.137845
# [77]	training's auc: 1	training's binary_logloss: 0.00980935	valid_1's auc: 0.976907	valid_1's binary_logloss: 0.13743
# [78]	training's auc: 1	training's binary_logloss: 0.00944247	valid_1's auc: 0.977135	valid_1's binary_logloss: 0.137255
# [79]	training's auc: 1	training's binary_logloss: 0.00904054	valid_1's auc: 0.977159	valid_1's binary_logloss: 0.137089
# [80]	training's auc: 1	training's binary_logloss: 0.0086592	valid_1's auc: 0.977101	valid_1's binary_logloss: 0.137282
# [81]	training's auc: 1	training's binary_logloss: 0.00833252	valid_1's auc: 0.977189	valid_1's binary_logloss: 0.1371
# [82]	training's auc: 1	training's binary_logloss: 0.00802753	valid_1's auc: 0.977138	valid_1's binary_logloss: 0.137507
# [83]	training's auc: 1	training's binary_logloss: 0.0077223	valid_1's auc: 0.977296	valid_1's binary_logloss: 0.136987
# [84]	training's auc: 1	training's binary_logloss: 0.00739273	valid_1's auc: 0.977268	valid_1's binary_logloss: 0.137018
# [85]	training's auc: 1	training's binary_logloss: 0.00711391	valid_1's auc: 0.977332	valid_1's binary_logloss: 0.136873
# [86]	training's auc: 1	training's binary_logloss: 0.00683922	valid_1's auc: 0.977199	valid_1's binary_logloss: 0.137387
# [87]	training's auc: 1	training's binary_logloss: 0.00658921	valid_1's auc: 0.977103	valid_1's binary_logloss: 0.137896
# [88]	training's auc: 1	training's binary_logloss: 0.00634789	valid_1's auc: 0.977246	valid_1's binary_logloss: 0.137651
# [89]	training's auc: 1	training's binary_logloss: 0.00610247	valid_1's auc: 0.977192	valid_1's binary_logloss: 0.138074
# [90]	training's auc: 1	training's binary_logloss: 0.00587286	valid_1's auc: 0.977263	valid_1's binary_logloss: 0.137865
# [91]	training's auc: 1	training's binary_logloss: 0.00565377	valid_1's auc: 0.97714	valid_1's binary_logloss: 0.138072
# [92]	training's auc: 1	training's binary_logloss: 0.00544911	valid_1's auc: 0.977288	valid_1's binary_logloss: 0.137839
# ...
# [67]	training's auc: 1	training's binary_logloss: 0.0068046	valid_1's auc: 0.99221	valid_1's binary_logloss: 0.107178
# [68]	training's auc: 1	training's binary_logloss: 0.00642341	valid_1's auc: 0.9923	valid_1's binary_logloss: 0.106875
# [69]	training's auc: 1	training's binary_logloss: 0.00612892	valid_1's auc: 0.992292	valid_1's binary_logloss: 0.106956
# [70]	training's auc: 1	training's binary_logloss: 0.00583523	valid_1's auc: 0.992384	valid_1's binary_logloss: 0.106637
# [71]	training's auc: 1	training's binary_logloss: 0.00553846	valid_1's auc: 0.992437	valid_1's binary_logloss: 0.106595
# [72]	training's auc: 1	training's binary_logloss: 0.00525974	valid_1's auc: 0.992547	valid_1's binary_logloss: 0.106029
# [73]	training's auc: 1	training's binary_logloss: 0.00499842	valid_1's auc: 0.992542	valid_1's binary_logloss: 0.106265
# [74]	training's auc: 1	training's binary_logloss: 0.00479257	valid_1's auc: 0.992522	valid_1's binary_logloss: 0.106792
# [75]	training's auc: 1	training's binary_logloss: 0.00456992	valid_1's auc: 0.992534	valid_1's binary_logloss: 0.107119
# [76]	training's auc: 1	training's binary_logloss: 0.00432066	valid_1's auc: 0.992582	valid_1's binary_logloss: 0.107149
# [77]	training's auc: 1	training's binary_logloss: 0.00409451	valid_1's auc: 0.992539	valid_1's binary_logloss: 0.107221
# [78]	training's auc: 1	training's binary_logloss: 0.00390239	valid_1's auc: 0.992651	valid_1's binary_logloss: 0.106741
# [79]	training's auc: 1	training's binary_logloss: 0.00372589	valid_1's auc: 0.99264	valid_1's binary_logloss: 0.107147
# [80]	training's auc: 1	training's binary_logloss: 0.00355144	valid_1's auc: 0.992705	valid_1's binary_logloss: 0.107076
# [81]	training's auc: 1	training's binary_logloss: 0.00336023	valid_1's auc: 0.992701	valid_1's binary_logloss: 0.107483
# [82]	training's auc: 1	training's binary_logloss: 0.00318854	valid_1's auc: 0.992696	valid_1's binary_logloss: 0.107769
# [83]	training's auc: 1	training's binary_logloss: 0.00304973	valid_1's auc: 0.992674	valid_1's binary_logloss: 0.108081
# [84]	training's auc: 1	training's binary_logloss: 0.00292232	valid_1's auc: 0.992689	valid_1's binary_logloss: 0.108451
# [85]	training's auc: 1	training's binary_logloss: 0.00278683	valid_1's auc: 0.99269	valid_1's binary_logloss: 0.108575
# [86]	training's auc: 1	training's binary_logloss: 0.00264743	valid_1's auc: 0.992673	valid_1's binary_logloss: 0.10884
# [87]	training's auc: 1	training's binary_logloss: 0.00252896	valid_1's auc: 0.992679	valid_1's binary_logloss: 0.109337
# [88]	training's auc: 1	training's binary_logloss: 0.00241311	valid_1's auc: 0.992646	valid_1's binary_logloss: 0.109994
# [89]	training's auc: 1	training's binary_logloss: 0.00229465	valid_1's auc: 0.992585	valid_1's binary_logloss: 0.110703
# [90]	training's auc: 1	training's binary_logloss: 0.0022	valid_1's auc: 0.992562	valid_1's binary_logloss: 0.110927
# [91]	training's auc: 1	training's binary_logloss: 0.00210641	valid_1's auc: 0.992572	valid_1's binary_logloss: 0.111156
# [92]	training's auc: 1	training's binary_logloss: 0.00200543	valid_1's auc: 0.992633	valid_1's binary_logloss: 0.111266
# [93]	training's auc: 1	training's binary_logloss: 0.00191002	valid_1's auc: 0.992686	valid_1's binary_logloss: 0.111006
# [94]	training's auc: 1	training's binary_logloss: 0.00180672	valid_1's auc: 0.99269	valid_1's binary_logloss: 0.111035
# [95]	training's auc: 1	training's binary_logloss: 0.00172421	valid_1's auc: 0.992675	valid_1's binary_logloss: 0.111739
# [96]	training's auc: 1	training's binary_logloss: 0.00164422	valid_1's auc: 0.992575	valid_1's binary_logloss: 0.112326
# [97]	training's auc: 1	training's binary_logloss: 0.00156023	valid_1's auc: 0.992594	valid_1's binary_logloss: 0.112785
# [98]	training's auc: 1	training's binary_logloss: 0.00148993	valid_1's auc: 0.992642	valid_1's binary_logloss: 0.11281
# [99]	training's auc: 1	training's binary_logloss: 0.00141997	valid_1's auc: 0.992722	valid_1's binary_logloss: 0.112691
# [100]	training's auc: 1	training's binary_logloss: 0.00134442	valid_1's auc: 0.992789	valid_1's binary_logloss: 0.112781
# [1]	training's auc: 0.939884	training's binary_logloss: 0.464645	valid_1's auc: 1	valid_1's binary_logloss: 1.0649
# [2]	training's auc: 0.947598	training's binary_logloss: 0.409632	valid_1's auc: 1	valid_1's binary_logloss: 0.908797
# [3]	training's auc: 0.952541	training's binary_logloss: 0.367248	valid_1's auc: 1	valid_1's binary_logloss: 0.788274
# [4]	training's auc: 0.961321	training's binary_logloss: 0.331558	valid_1's auc: 1	valid_1's binary_logloss: 0.679449
# [5]	training's auc: 0.9648	training's binary_logloss: 0.30329	valid_1's auc: 1	valid_1's binary_logloss: 0.612458
# [6]	training's auc: 0.969734	training's binary_logloss: 0.277866	valid_1's auc: 1	valid_1's binary_logloss: 0.536978
# [7]	training's auc: 0.97342	training's binary_logloss: 0.256825	valid_1's auc: 1	valid_1's binary_logloss: 0.471813
# [8]	training's auc: 0.976395	training's binary_logloss: 0.238694	valid_1's auc: 1	valid_1's binary_logloss: 0.429114
# [9]	training's auc: 0.979968	training's binary_logloss: 0.220444	valid_1's auc: 1	valid_1's binary_logloss: 0.386299
# [10]	training's auc: 0.983161	training's binary_logloss: 0.202702	valid_1's auc: 1	valid_1's binary_logloss: 0.354205
# [11]	training's auc: 0.984849	training's binary_logloss: 0.191113	valid_1's auc: 1	valid_1's binary_logloss: 0.324655
# [12]	training's auc: 0.986348	training's binary_logloss: 0.180739	valid_1's auc: 1	valid_1's binary_logloss: 0.305487
# [13]	training's auc: 0.988158	training's binary_logloss: 0.16846	valid_1's auc: 1	valid_1's binary_logloss: 0.285011
# [14]	training's auc: 0.989782	training's binary_logloss: 0.157356	valid_1's auc: 1	valid_1's binary_logloss: 0.267345
# [15]	training's auc: 0.990761	training's binary_logloss: 0.148835	valid_1's auc: 1	valid_1's binary_logloss: 0.247807
# [16]	training's auc: 0.991769	training's binary_logloss: 0.141292	valid_1's auc: 1	valid_1's binary_logloss: 0.234793
# [17]	training's auc: 0.992686	training's binary_logloss: 0.133595	valid_1's auc: 1	valid_1's binary_logloss: 0.223063
# [18]	training's auc: 0.993501	training's binary_logloss: 0.126161	valid_1's auc: 1	valid_1's binary_logloss: 0.209875
# [19]	training's auc: 0.994385	training's binary_logloss: 0.119346	valid_1's auc: 1	valid_1's binary_logloss: 0.192065
# [20]	training's auc: 0.995011	training's binary_logloss: 0.113555	valid_1's auc: 1	valid_1's binary_logloss: 0.180303
# [21]	training's auc: 0.995567	training's binary_logloss: 0.107998	valid_1's auc: 1	valid_1's binary_logloss: 0.172954
# [22]	training's auc: 0.99612	training's binary_logloss: 0.10282	valid_1's auc: 1	valid_1's binary_logloss: 0.167388
# [23]	training's auc: 0.996675	training's binary_logloss: 0.0976469	valid_1's auc: 1	valid_1's binary_logloss: 0.16152
# [24]	training's auc: 0.997095	training's binary_logloss: 0.0933119	valid_1's auc: 1	valid_1's binary_logloss: 0.157199
# [25]	training's auc: 0.997393	training's binary_logloss: 0.0892288	valid_1's auc: 1	valid_1's binary_logloss: 0.152621
# [26]	training's auc: 0.997747	training's binary_logloss: 0.0853434	valid_1's auc: 1	valid_1's binary_logloss: 0.148275
# [27]	training's auc: 0.998096	training's binary_logloss: 0.0814997	valid_1's auc: 1	valid_1's binary_logloss: 0.140863
# [28]	training's auc: 0.998308	training's binary_logloss: 0.0780214	valid_1's auc: 1	valid_1's binary_logloss: 0.137169
# [29]	training's auc: 0.998517	training's binary_logloss: 0.0748985	valid_1's auc: 1	valid_1's binary_logloss: 0.132941
# [30]	training's auc: 0.998771	training's binary_logloss: 0.0711595	valid_1's auc: 1	valid_1's binary_logloss: 0.127286
# [31]	training's auc: 0.999002	training's binary_logloss: 0.0673277	valid_1's auc: 1	valid_1's binary_logloss: 0.120579
# [32]	training's auc: 0.999185	training's binary_logloss: 0.0644155	valid_1's auc: 1	valid_1's binary_logloss: 0.117027
# [33]	training's auc: 0.999336	training's binary_logloss: 0.0612864	valid_1's auc: 1	valid_1's binary_logloss: 0.108982
# [34]	training's auc: 0.999433	training's binary_logloss: 0.0588236	valid_1's auc: 1	valid_1's binary_logloss: 0.104876
# [35]	training's auc: 0.999531	training's binary_logloss: 0.0563425	valid_1's auc: 1	valid_1's binary_logloss: 0.104279
# [36]	training's auc: 0.999621	training's binary_logloss: 0.0540694	valid_1's auc: 1	valid_1's binary_logloss: 0.102563
# [37]	training's auc: 0.999678	training's binary_logloss: 0.051781	valid_1's auc: 1	valid_1's binary_logloss: 0.102691
# [38]	training's auc: 0.999745	training's binary_logloss: 0.0493568	valid_1's auc: 1	valid_1's binary_logloss: 0.0974354
# [39]	training's auc: 0.999793	training's binary_logloss: 0.0471087	valid_1's auc: 1	valid_1's binary_logloss: 0.0952646
# [40]	training's auc: 0.999837	training's binary_logloss: 0.0452317	valid_1's auc: 1	valid_1's binary_logloss: 0.0943372
# [41]	training's auc: 0.999871	training's binary_logloss: 0.0433926	valid_1's auc: 1	valid_1's binary_logloss: 0.0913051
# [42]	training's auc: 0.999897	training's binary_logloss: 0.0416186	valid_1's auc: 1	valid_1's binary_logloss: 0.0891756
# [43]	training's auc: 0.999911	training's binary_logloss: 0.04014	valid_1's auc: 1	valid_1's binary_logloss: 0.0877586
# [44]	training's auc: 0.999938	training's binary_logloss: 0.0383996	valid_1's auc: 1	valid_1's binary_logloss: 0.0855711
# [45]	training's auc: 0.999951	training's binary_logloss: 0.0366703	valid_1's auc: 1	valid_1's binary_logloss: 0.084581
# [46]	training's auc: 0.999965	training's binary_logloss: 0.0353799	valid_1's auc: 1	valid_1's binary_logloss: 0.0845107
# [47]	training's auc: 0.999975	training's binary_logloss: 0.0339543	valid_1's auc: 1	valid_1's binary_logloss: 0.0834939
# [48]	training's auc: 0.999982	training's binary_logloss: 0.0325404	valid_1's auc: 1	valid_1's binary_logloss: 0.0822335
# [49]	training's auc: 0.999983	training's binary_logloss: 0.0313628	valid_1's auc: 1	valid_1's binary_logloss: 0.0823778
# [50]	training's auc: 0.999986	training's binary_logloss: 0.030098	valid_1's auc: 1	valid_1's binary_logloss: 0.0815221
# [51]	training's auc: 0.999989	training's binary_logloss: 0.0288783	valid_1's auc: 1	valid_1's binary_logloss: 0.0801697
# [52]	training's auc: 0.999991	training's binary_logloss: 0.0278118	valid_1's auc: 1	valid_1's binary_logloss: 0.079675
# [53]	training's auc: 0.999992	training's binary_logloss: 0.0266825	valid_1's auc: 1	valid_1's binary_logloss: 0.0764936
# [54]	training's auc: 0.999995	training's binary_logloss: 0.0255991	valid_1's auc: 1	valid_1's binary_logloss: 0.0755206
# [55]	training's auc: 0.999996	training's binary_logloss: 0.0246023	valid_1's auc: 1	valid_1's binary_logloss: 0.075277
# [56]	training's auc: 0.999998	training's binary_logloss: 0.0235198	valid_1's auc: 1	valid_1's binary_logloss: 0.0718744
# [57]	training's auc: 0.999999	training's binary_logloss: 0.0225526	valid_1's auc: 1	valid_1's binary_logloss: 0.0714073
# [58]	training's auc: 0.999999	training's binary_logloss: 0.0216807	valid_1's auc: 1	valid_1's binary_logloss: 0.0706891
# [59]	training's auc: 1	training's binary_logloss: 0.0208363	valid_1's auc: 1	valid_1's binary_logloss: 0.0704645
# [60]	training's auc: 1	training's binary_logloss: 0.0201394	valid_1's auc: 1	valid_1's binary_logloss: 0.0702126
# [61]	training's auc: 1	training's binary_logloss: 0.0192868	valid_1's auc: 1	valid_1's binary_logloss: 0.0686513
# [62]	training's auc: 1	training's binary_logloss: 0.0187194	valid_1's auc: 1	valid_1's binary_logloss: 0.0688045
# [63]	training's auc: 1	training's binary_logloss: 0.0179839	valid_1's auc: 1	valid_1's binary_logloss: 0.0680938
# [64]	training's auc: 1	training's binary_logloss: 0.0173356	valid_1's auc: 1	valid_1's binary_logloss: 0.0691698
# [65]	training's auc: 1	training's binary_logloss: 0.0166231	valid_1's auc: 1	valid_1's binary_logloss: 0.0685705
# [66]	training's auc: 1	training's binary_logloss: 0.0159212	valid_1's auc: 1	valid_1's binary_logloss: 0.0654254
# [67]	training's auc: 1	training's binary_logloss: 0.0153194	valid_1's auc: 1	valid_1's binary_logloss: 0.0641571
# [68]	training's auc: 1	training's binary_logloss: 0.0147783	valid_1's auc: 1	valid_1's binary_logloss: 0.0641581
# [69]	training's auc: 1	training's binary_logloss: 0.0141358	valid_1's auc: 1	valid_1's binary_logloss: 0.0640597
# [70]	training's auc: 1	training's binary_logloss: 0.0135689	valid_1's auc: 1	valid_1's binary_logloss: 0.0643005
# [71]	training's auc: 1	training's binary_logloss: 0.0130971	valid_1's auc: 1	valid_1's binary_logloss: 0.0639034
# [72]	training's auc: 1	training's binary_logloss: 0.0126017	valid_1's auc: 1	valid_1's binary_logloss: 0.0638344
# [73]	training's auc: 1	training's binary_logloss: 0.0121354	valid_1's auc: 1	valid_1's binary_logloss: 0.0634594
# [74]	training's auc: 1	training's binary_logloss: 0.0116814	valid_1's auc: 1	valid_1's binary_logloss: 0.0635617
# [75]	training's auc: 1	training's binary_logloss: 0.0112562	valid_1's auc: 1	valid_1's binary_logloss: 0.0637702
# [76]	training's auc: 1	training's binary_logloss: 0.0108591	valid_1's auc: 1	valid_1's binary_logloss: 0.0637432
# [77]	training's auc: 1	training's binary_logloss: 0.0104496	valid_1's auc: 1	valid_1's binary_logloss: 0.0638102
# [78]	training's auc: 1	training's binary_logloss: 0.0100776	valid_1's auc: 1	valid_1's binary_logloss: 0.0629111
# [79]	training's auc: 1	training's binary_logloss: 0.00967149	valid_1's auc: 1	valid_1's binary_logloss: 0.0619548
# [80]	training's auc: 1	training's binary_logloss: 0.00934054	valid_1's auc: 1	valid_1's binary_logloss: 0.0618495
# [81]	training's auc: 1	training's binary_logloss: 0.00898134	valid_1's auc: 1	valid_1's binary_logloss: 0.0616563
# [82]	training's auc: 1	training's binary_logloss: 0.00865242	valid_1's auc: 1	valid_1's binary_logloss: 0.061315
# [83]	training's auc: 1	training's binary_logloss: 0.00828819	valid_1's auc: 1	valid_1's binary_logloss: 0.061679
# [84]	training's auc: 1	training's binary_logloss: 0.00798589	valid_1's auc: 1	valid_1's binary_logloss: 0.061318
# [85]	training's auc: 1	training's binary_logloss: 0.00771935	valid_1's auc: 1	valid_1's binary_logloss: 0.0614461
# [86]	training's auc: 1	training's binary_logloss: 0.00741473	valid_1's auc: 1	valid_1's binary_logloss: 0.0593848
# [87]	training's auc: 1	training's binary_logloss: 0.00715456	valid_1's auc: 1	valid_1's binary_logloss: 0.0589987
# [88]	training's auc: 1	training's binary_logloss: 0.00685743	valid_1's auc: 1	valid_1's binary_logloss: 0.0592725
# [89]	training's auc: 1	training's binary_logloss: 0.00663606	valid_1's auc: 1	valid_1's binary_logloss: 0.0593363
# [90]	training's auc: 1	training's binary_logloss: 0.00639823	valid_1's auc: 1	valid_1's binary_logloss: 0.0594091
# [91]	training's auc: 1	training's binary_logloss: 0.00617495	valid_1's auc: 1	valid_1's binary_logloss: 0.0594581
# [92]	training's auc: 1	training's binary_logloss: 0.00597368	valid_1's auc: 1	valid_1's binary_logloss: 0.0591116
# [93]	training's auc: 1	training's binary_logloss: 0.00576252	valid_1's auc: 1	valid_1's binary_logloss: 0.059057
# [94]	training's auc: 1	training's binary_logloss: 0.00553037	valid_1's auc: 1	valid_1's binary_logloss: 0.0594527
# [95]	training's auc: 1	training's binary_logloss: 0.00532641	valid_1's auc: 1	valid_1's binary_logloss: 0.0589515
# [96]	training's auc: 1	training's binary_logloss: 0.00512802	valid_1's auc: 1	valid_1's binary_logloss: 0.0586531
# [97]	training's auc: 1	training's binary_logloss: 0.00494199	valid_1's auc: 1	valid_1's binary_logloss: 0.059063
# [98]	training's auc: 1	training's binary_logloss: 0.0047984	valid_1's auc: 1	valid_1's binary_logloss: 0.0592546
# [99]	training's auc: 1	training's binary_logloss: 0.00460459	valid_1's auc: 1	valid_1's binary_logloss: 0.0593119
# [100]	training's auc: 1	training's binary_logloss: 0.0044412	valid_1's auc: 1	valid_1's binary_logloss: 0.0596377
# 100%|██████████| 50/50 [01:11<00:00,  1.43s/trial, best loss: -0.9872462004693053]
# best: {'learning_rate': 0.15111497818337352, 'max_depth': 131.0, 'min_child_samples': 67.0, 'num_leaves': 32.0, 'subsample': 0.70303541080796}

# %% [markdown]
# #### 전처리 테스트1

# %%
def test_transform_pre1(df, drop_column, groupby_column):
    df = df.drop('cstno', axis=1)

    for col_name in drop_column:
        df = df.drop(col_name, axis=1)

    if 'imcome_cat' not in drop_column:
        df['imcome_cat']=df['imcome_cat'].replace({'Less than $40K':40000, '$40K - $60K':50000, '$60K - $80K':70000, '$80K - $120K':100000, '$120K +':120000, 'Unknown':63000})

    df = df.groupby(groupby_column).apply(lambda x: x.fillna(x.mean(numeric_only=True)))
    df = df.reset_index(drop=True)
    df.dropna(axis=0, inplace=True)
        
    df = encode_onehot(df)

    return df


def proc_null_groupby_test():
    from itertools import combinations

    model_comparison = {}  #Dictionary to store the comparison metrics of models
    model_eval_comparison = {}                        


    # 전처리 테스트 함수
    # -----------------
    # def drop_null_column_pre(df, drop_list):
    #     for col_name in drop_list:
    #         df = df.drop(col_name, axis=1)

    #     return df


            
    # 전처리 테스트 예측
    # -----------------

    # 데이터 로드 및 고객번호 삭제
    fit_df = pd.read_csv("./data/bank_churner.csv") # 학습을 위한 데이터 로드
    eval_df = pd.read_csv("./data/test_churner.csv")
    tot_cnt = fit_df.shape

    fit_df_org = fit_df.copy()
    eval_df_org = eval_df.copy()
    fit_df = fit_df.drop('cstno', axis=1)

    fit_df_columns = fit_df.columns
    best_auc = 0

    # 결측치 및 다중공선성 처리
    # -----------------------
    result_list = []
    drop_target_columns = ['sex','imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m','age','mean_open_to_buy','tot_trans_amt_for_12m']
    for j in range(1, len(drop_target_columns)+1):
        for i in combinations(drop_target_columns, j):
            result_list.append(list(i))

    # result_list = [['sex'], ['sex', 'age']]

    for drop_no, drop_column in enumerate(result_list):
        for group_no, groupby_column in enumerate(fit_df_columns):
            start_time = time.time()
            if groupby_column == 'is_churned' or groupby_column in drop_column:
                continue

            fit_df = fit_df_org
            eval_df = eval_df_org
            tot_cnt = fit_df.shape
            
            # print(f'drop_column: {drop_column}, groupby_column: {groupby_column}')
            
        # -----------------------------------------------------------------------------------    
            # 평가 for Competition
            # -----------------------------------------------------------------------------------

            # 전처리 단계
            # -----------
            fit_df = test_transform_pre1(fit_df, drop_column, groupby_column)
            eval_df = test_transform_pre1(eval_df, drop_column, groupby_column)
            after_drop_cnt = len(fit_df)
            
            
            # 평가를 위한 데이터 분리
            # ---------------------
            X_train=fit_df.drop(['is_churned'],axis=1)
            y_train=fit_df['is_churned']
            
            X_eval=eval_df.drop(['is_churned'],axis=1)
            y_eval=eval_df['is_churned']


            # 중요 Feature Column 선택
            # -----------------------
            X_new, selected_columns = select_feature(X_train, y_train, 'ExtraTrees')
            X_eval = X_eval[selected_columns]


            # Train and Test 데이터 생성 및 가공
            # ---------------------------------
            X_train, y_train, X_test_temp, y_test_temp = proc_smote(X_new, y_train)
            after_smote_cnt = X_train.shape

            # Evaluation 데이터 생성 및 가공
            # ---------------------------------
            X_train, X_eval = proc_normalization(X_train, X_eval.values)   


            # 최종 평가
            # --------
            proc_type='E'
            # eval_auc = fit_predict(proc_type, drop_no, model_eval_comparison, X_train_for_evaluation, y_train_for_evaluation, X_eval, y_eval)
            eval_auc = fit_predict_eval(proc_type, drop_no, group_no, model_eval_comparison, X_train, y_train, X_eval, y_eval)
            
            if eval_auc > best_auc:
                best_type = f'{proc_type}_{drop_no}_{group_no}'
                best_auc = eval_auc
                


            # 최종 평가 로그 출력
            # ------------------
            cur_datetime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
            end_time = time.time()
            delta_time = end_time - start_time
            # print(f'[평  가] {cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, AUC: {test_auc:0.6f}, 처리 건수: {len(eval_df)}, 최종 평가 건수: {len(X_eval)}')
            print(f'[테스트] {cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, [G{proc_type}_{drop_no}_{group_no}], best-type: [{best_type}], Best-AUC: {best_auc:0.6f}, AUC: {eval_auc:0.6f}, tot_cnt: {tot_cnt}, after_drop_cnt: {after_drop_cnt}, after_smote_cnt: {after_smote_cnt}, groupby_column: {groupby_column}, drop_column: {drop_column}')

            # print_eval_result(model_eval_comparison)


# 테스트시 아래의 주석 풀고 실행
# ----------------------------
# proc_null_groupby_test()

# %% [markdown]
# #### 전처리 테스트2

# %%
def proc_null_drop_test():
    from itertools import combinations

    model_comparison = {}  #Dictionary to store the comparison metrics of models
    model_eval_comparison = {}                        

    def test_transform_pre2(df, drop_list):
        
        # 데이터 변환
        # ---------- 
        df = df.drop('cstno', axis=1)


        # 결측치 처리
        # -----------
        for col_name in drop_list:
            df = df.drop(col_name, axis=1)

        if 'imcome_cat' not in drop_list:
            df['imcome_cat']=df['imcome_cat'].replace({'Less than $40K':40000, '$40K - $60K':50000, '$60K - $80K':70000, '$80K - $120K':100000, '$120K +':120000, 'Unknown':63000})

        df = df.fillna(df.mean(numeric_only=True))
        df = df.reset_index(drop=True)
        df.dropna(axis=0, inplace=True)
            

        # One-Hot Encoding
        # ----------------
        df = encode_onehot(df)  
    
        return df

            
    # -----------
    # 예측
    # -----------

    # 데이터 로드 및 고객번호 삭제
    fit_df = pd.read_csv("./data/bank_churner.csv") # 학습을 위한 데이터 로드
    eval_df = pd.read_csv("./data/test_churner.csv")
    tot_cnt = fit_df.shape

    fit_df_org = fit_df.copy()
    eval_df_org = eval_df.copy()

    best_auc = 0

    # Null 처리
    result_list = []
    drop_target_columns = ['sex','imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m','age','mean_open_to_buy','tot_trans_amt_for_12m']
    for j in range(1, len(drop_target_columns)+1):
        for i in combinations(drop_target_columns, j):
            result_list.append(list(i))

    # result_list = [['sex'], ['sex', 'age', 'imcome_cat']]

    for drop_no, drop_column in enumerate(result_list):
        start_time = time.time()

        fit_df = fit_df_org
        eval_df = eval_df_org
        
        # -----------------------------------------------------------------------------------    
        # 평가 for Competition
        # -----------------------------------------------------------------------------------

        # 전처리 단계
        # -----------
        fit_df = test_transform_pre2(fit_df, drop_column)
        eval_df = test_transform_pre2(eval_df, drop_column)
        after_drop_cnt = len(fit_df)
        
        
        # 평가를 위한 데이터 분리
        # ---------------------
        X_train=fit_df.drop(['is_churned'],axis=1)
        y_train=fit_df['is_churned']
        X_train_cnt = X_train.shape
        
        X_eval=eval_df.drop(['is_churned'],axis=1)
        y_eval=eval_df['is_churned']


        # 중요 Feature Column 선택
        # -----------------------
        X_new, selected_columns = select_feature(X_train, y_train, 'ExtraTrees')
        X_eval = X_eval[selected_columns]


        # Train and Test 데이터 생성 및 가공
        # ---------------------------------
        X_train, y_train, X_test_temp, y_test_temp = proc_smote(X_new, y_train)
        after_smote_cnt = X_train.shape

        # Evaluation 데이터 생성 및 가공
        # ---------------------------------
        X_train, X_eval = proc_normalization(X_train, X_eval.values)   


        # 최종 평가
        # --------
        proc_type='E'
        group_no=1
        # eval_auc = fit_predict(proc_type, drop_no, model_eval_comparison, X_train_for_evaluation, y_train_for_evaluation, X_eval, y_eval)
        eval_auc = fit_predict_eval(proc_type, drop_no, group_no, model_eval_comparison, X_train, y_train, X_eval, y_eval)
        
        if eval_auc > best_auc:
            best_type = f'{proc_type}_{drop_no}_{group_no}'
            best_auc = eval_auc
            


        # 최종 평가 로그 출력
        # ------------------
        cur_datetime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        end_time = time.time()
        delta_time = end_time - start_time
        # print(f'[평  가] {cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, AUC: {test_auc:0.6f}, 처리 건수: {len(eval_df)}, 최종 평가 건수: {len(X_eval)}')
        print(f'[테스트] {cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, [{proc_type}_{drop_no}_{group_no}], best-type: [{best_type}], Best-AUC: {best_auc:0.6f}, AUC: {eval_auc:0.6f}, tot_cnt: {tot_cnt}, after_drop_cnt: {after_drop_cnt}, after_smote_cnt: {after_smote_cnt}, X_train_cnt: {X_train_cnt}, drop_column: {drop_column}')


        # print_eval_result(model_eval_comparison)


# 테스트시 아래의 주석 풀고 실행
# ----------------------------
# proc_null_drop_test()
