# %% [markdown]
# # JBFG Data Analysis Competition

# %%
#!pip install watermark
# %load_ext watermark
# %watermark -a 'DataLine' -nmv --packages numpy,pandas,sklearn,imblearn,tensorflow,plotly,matplotlib,seaborn,missingno,lightgbm
# Out:
# Author: DataLine
#
# Python implementation: CPython
# Python version       : 3.9.18
# IPython version      : 8.15.0
#
# numpy     : 1.24.3
# pandas    : 2.0.3
# sklearn   : 1.3.0
# imblearn  : 0.0
# tensorflow: 2.10.0
# plotly    : 5.9.0
# matplotlib: 3.7.2
# seaborn   : 0.12.2
# missingno : 0.5.1
# lightgbm  : 3.3.5
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 165 Stepping 3, GenuineIntel
# CPU cores   : 12
# Architecture: 64bit

# %%
import imblearn

# %% [markdown]
# #### 컬럼 데이터 및 Null 건수 확인

# %%
"""
# 데이터 포맷 함수
# ---------------
def change_format(df, column, format):
    '''
    데이터프레임의 지정된 컬럼에 컴마, 백분율로 변경하여 데이터프레임을 반환하는 함수
        Args:
            df (df) : DataFrame
            column (str) : column of DataFrame
            format (str) : 'comma' | 'percent'
        Return:
            DataFrame
    '''
    if format == 'comma':
        df[column] = df[column].apply(lambda x: f"{x:,}")
    elif format == 'percent':
        df[column] = df[column].apply(lambda x: f"{x:.2%}")
        
    return df


# 데이터프레임의 특정 컬럼에 대한 건수, Null, Percent 표시
# -----------------------------------------------------
def count_column_na_count(df, column):
    '''
    데이터프레임의 특정 컬럼에 대한 건수, Null, Percent를 출력하는 함수
        Args:
            df (df) : DataFrame
            column (str) : column of DataFrame
        Return:
            None
    '''
    column_na_counts = df[column].size, df[column].count(), df[column].isnull().sum()
    column_na_counts_df = pd.Series(column_na_counts).to_frame().T
    column_na_counts_df.columns = ['tot_counts', 'data_counts', 'null_counts']
    column_na_counts_df['data_percents'] = column_na_counts_df['data_counts'].values/column_na_counts_df['tot_counts'].values
    column_na_counts_df['null_percents'] = column_na_counts_df['null_counts'].values/column_na_counts_df['tot_counts'].values


    column_na_counts_df = change_format(column_na_counts_df, 'tot_counts', 'comma')
    column_na_counts_df = change_format(column_na_counts_df, 'data_counts','comma')
    column_na_counts_df = change_format(column_na_counts_df, 'null_counts','comma')
    column_na_counts_df = change_format(column_na_counts_df, 'data_percents', 'percent')
    column_na_counts_df = change_format(column_na_counts_df, 'null_percents', 'percent')

    print(column_na_counts_df.to_string(index=False))
    print('-'*70)


def count_column_data_count(df, column):
    ''' 
    '''
    # column_data_countcounts = df.groupby(column)['is_churned'].value_counts().unstack()


    column_counts = df.groupby(column)['is_churned'].value_counts().unstack()
    column_counts = column_counts.rename(columns={0: 'exist_counts', 1: 'churned_counts'})
    column_counts['total_counts'] =  column_counts['exist_counts'] + column_counts['churned_counts']
    column_counts = column_counts.fillna(0)

    column_percents = df.groupby(column)['is_churned'].value_counts(normalize=True).unstack()
    column_percents = column_percents.rename(columns={0: 'exist_percents', 1: 'churned_percents'})
    column_percents = column_percents.fillna(0)


    column_count_percent = pd.concat([column_counts, column_percents], axis=1)
    column_count_percent = column_count_percent.reset_index()
    column_count_percent = column_count_percent.sort_values(by='churned_percents', ascending=False)

    
    column_count_percent = change_format(column_count_percent, 'exist_counts', 'comma')
    column_count_percent = change_format(column_count_percent, 'churned_counts', 'comma')
    column_count_percent = change_format(column_count_percent, 'total_counts', 'comma')
    column_count_percent = change_format(column_count_percent, 'exist_percents', 'percent')
    column_count_percent = change_format(column_count_percent, 'churned_percents', 'percent')
    

    print(column_count_percent.to_string(index=False))

"""
# Out:
# '\n# 데이터 포맷 함수\n# ---------------\ndef change_format(df, column, format):\n    \'\'\'\n    데이터프레임의 지정된 컬럼에 컴마, 백분율로 변경하여 데이터프레임을 반환하는 함수\n        Args:\n            df (df) : DataFrame\n            column (str) : column of DataFrame\n            format (str) : \'comma\' | \'percent\'\n        Return:\n            DataFrame\n    \'\'\'\n    if format == \'comma\':\n        df[column] = df[column].apply(lambda x: f"{x:,}")\n    elif format == \'percent\':\n        df[column] = df[column].apply(lambda x: f"{x:.2%}")\n        \n    return df\n\n\n# 데이터프레임의 특정 컬럼에 대한 건수, Null, Percent 표시\n# -----------------------------------------------------\ndef count_column_na_count(df, column):\n    \'\'\'\n    데이터프레임의 특정 컬럼에 대한 건수, Null, Percent를 출력하는 함수\n        Args:\n            df (df) : DataFrame\n            column (str) : column of DataFrame\n        Return:\n            None\n    \'\'\'\n    column_na_counts = df[column].size, df[column].count(), df[column].isnull().sum()\n    column_na_counts_df = pd.Series(column_na_counts).to_frame().T\n    column_na_counts_df.columns = [\'tot_counts\', \'data_counts\', \'null_counts\']\n    column_na_counts_df[\'data_percents\'] = column_na_counts_df[\'data_counts\'].values/column_na_counts_df[\'tot_counts\'].values\n    column_na_counts_df[\'null_percents\'] = column_na_counts_df[\'null_counts\'].values/column_na_counts_df[\'tot_counts\'].values\n\n\n    column_na_counts_df = change_format(column_na_counts_df, \'tot_counts\', \'comma\')\n    column_na_counts_df = change_format(column_na_counts_df, \'data_counts\',\'comma\')\n    column_na_counts_df = change_format(column_na_counts_df, \'null_counts\',\'comma\')\n    column_na_counts_df = change_format(column_na_counts_df, \'data_percents\', \'percent\')\n    column_na_counts_df = change_format(column_na_counts_df, \'null_percents\', \'percent\')\n\n    print(column_na_counts_df.to_string(index=False))\n    print(\'-\'*70)\n\n\ndef count_column_data_count(df, column):\n    \'\'\' \n    \'\'\'\n    # column_data_countcounts = df.groupby(column)[\'is_churned\'].value_counts().unstack()\n\n\n    column_counts = df.groupby(column)[\'is_churned\'].value_counts().unstack()\n    column_counts = column_counts.rename(columns={0: \'exist_counts\', 1: \'churned_counts\'})\n    column_counts[\'total_counts\'] =  column_counts[\'exist_counts\'] + column_counts[\'churned_counts\']\n    column_counts = column_counts.fillna(0)\n\n    column_percents = df.groupby(column)[\'is_churned\'].value_counts(normalize=True).unstack()\n    column_percents = column_percents.rename(columns={0: \'exist_percents\', 1: \'churned_percents\'})\n    column_percents = column_percents.fillna(0)\n\n\n    column_count_percent = pd.concat([column_counts, column_percents], axis=1)\n    column_count_percent = column_count_percent.reset_index()\n    column_count_percent = column_count_percent.sort_values(by=\'churned_percents\', ascending=False)\n\n    \n    column_count_percent = change_format(column_count_percent, \'exist_counts\', \'comma\')\n    column_count_percent = change_format(column_count_percent, \'churned_counts\', \'comma\')\n    column_count_percent = change_format(column_count_percent, \'total_counts\', \'comma\')\n    column_count_percent = change_format(column_count_percent, \'exist_percents\', \'percent\')\n    column_count_percent = change_format(column_count_percent, \'churned_percents\', \'percent\')\n    \n\n    print(column_count_percent.to_string(index=False))\n\n'

# %% [markdown]
# ## Machine Learning
# ***

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np
from itertools import combinations
import time
import datetime
import joblib

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from lightgbm import LGBMClassifier, LGBMRegressor
from xgboost import XGBClassifier

from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.feature_selection import RFE
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Function Definition

# %% [markdown]
# #### tot_column_count()

# %%
"""
def tot_column_counts(df):
    ''' 
    '''
    data_counts = df.count()
    null_counts = df.isnull().sum()
    tot_counts_df = pd.concat([data_counts, null_counts], axis=1)
    tot_counts_df = tot_counts_df.rename(columns={0: 'data_counts', 1: 'null_counts'})
    tot_counts_df.insert(0,'tot_counts', tot_counts_df['data_counts'] + tot_counts_df['null_counts'])
    tot_counts_df['data_percents'] = tot_counts_df['data_counts'].values / tot_counts_df['tot_counts'].values
    tot_counts_df['null_percents'] = tot_counts_df['null_counts'].values / tot_counts_df['tot_counts'].values
    tot_counts_df = tot_counts_df.sort_values(by='null_percents', ascending=False)

    tot_counts_df = change_format(tot_counts_df, 'tot_counts', 'comma')
    tot_counts_df = change_format(tot_counts_df, 'data_counts','comma')
    tot_counts_df = change_format(tot_counts_df, 'null_counts','comma')
    tot_counts_df = change_format(tot_counts_df, 'data_percents', 'percent')
    tot_counts_df = change_format(tot_counts_df, 'null_percents', 'percent')

    tot_counts_df = tot_counts_df.reset_index()

    print(tot_counts_df.to_string(index=False))
    
"""
# Out:
# "\ndef tot_column_counts(df):\n    ''' \n    '''\n    data_counts = df.count()\n    null_counts = df.isnull().sum()\n    tot_counts_df = pd.concat([data_counts, null_counts], axis=1)\n    tot_counts_df = tot_counts_df.rename(columns={0: 'data_counts', 1: 'null_counts'})\n    tot_counts_df.insert(0,'tot_counts', tot_counts_df['data_counts'] + tot_counts_df['null_counts'])\n    tot_counts_df['data_percents'] = tot_counts_df['data_counts'].values / tot_counts_df['tot_counts'].values\n    tot_counts_df['null_percents'] = tot_counts_df['null_counts'].values / tot_counts_df['tot_counts'].values\n    tot_counts_df = tot_counts_df.sort_values(by='null_percents', ascending=False)\n\n    tot_counts_df = change_format(tot_counts_df, 'tot_counts', 'comma')\n    tot_counts_df = change_format(tot_counts_df, 'data_counts','comma')\n    tot_counts_df = change_format(tot_counts_df, 'null_counts','comma')\n    tot_counts_df = change_format(tot_counts_df, 'data_percents', 'percent')\n    tot_counts_df = change_format(tot_counts_df, 'null_percents', 'percent')\n\n    tot_counts_df = tot_counts_df.reset_index()\n\n    print(tot_counts_df.to_string(index=False))\n    \n"

# %% [markdown]
# #### drop_null_column()

# %%
# 데이터프레임의 특정컬럼을 리스트로 받아 삭제
def drop_null_column(df, drop_list):
    '''
        데이터프레임의 특정컬럼을 리스트로 받아 삭제후 반환하는 함수
        
        Args:
            df (df) : DataFrame
            drop_list (list) : 삭제대상 컬럼의 List 
        Return:
            DataFrame
    '''
    for col_name in drop_list:
        # print(col_name, type(col_name))
        df = df.drop(col_name, axis=1)
    df.dropna(axis=0, inplace=True)

    return df

# %% [markdown]
# #### encode_onehot()

# %%
# 원-핫 인코딩 처리 
# ----------------
def encode_onehot(df):
    '''
        데이터프레임의 object type 컬럼을 원-핫 인코딩하는 함수
        
        Args:
            df (df) : DataFrame
        Return:
            DataFrame
    '''
    catcols = df.select_dtypes(exclude = ['int64','float64']).columns
    df = pd.get_dummies(df, columns = catcols)
    
    return df

# %% [markdown]
# #### select_feature()

# %%
# 중요 Feature 식별
# ----------------
def select_feature(df, y, chosen_model):

    np.random.seed(42)    
    
    available_models = {
    'ExtraTrees': ExtraTreesClassifier(n_estimators=100),
    'RandomForest': RandomForestClassifier(n_estimators=100),
    'KNN': KNeighborsClassifier(n_neighbors=5),
    'RFE': RFE(estimator=RandomForestClassifier(n_estimators=100), n_features_to_select=13),
    'LGBMC': LGBMClassifier(),
    'LGBMR': LGBMRegressor(),
    'Xg Boost':XGBClassifier(booster='gbtree', importance_type='gain', eval_metric='auc'),
    }

    # Create the selected model
    clf = available_models[chosen_model]

    clf = clf.fit(df.values, y)                                     # Train

    if chosen_model == 'LGBMC' or chosen_model == 'LGBMR': 
        feature_importances = clf.booster_.feature_importance(importance_type="gain")
    else:        
        feature_importances = clf.feature_importances_


    chosen_model = SelectFromModel(clf, prefit=True)
    X_df = chosen_model.transform(df.values) 
    selected_feature_indices = chosen_model.get_support(indices=True)

    selected_columns = df.columns[selected_feature_indices]         # Get the indices of the selected features
    
    return X_df, selected_columns

# %% [markdown]
# #### proc_smote()

# %%
def proc_smote(X_new, y):
    #Model Training
    from sklearn.model_selection import train_test_split
    from imblearn.over_sampling import SMOTE

    X_train,X_test,y_train,y_test=train_test_split(X_new,y,test_size=0.25,stratify=y,random_state=0)

    sm = SMOTE(sampling_strategy='auto', random_state=42)
    X_train, y_train=sm.fit_resample(X_train,y_train)
    
    return X_train, y_train, X_test, y_test

# %% [markdown]
# #### proc_normalization()

# %%
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer

def proc_normalization(X_train, X_test):
    scaler=StandardScaler()
    # scaler = QuantileTransformer()
    # scaler = PowerTransformer()
    X_train=scaler.fit_transform(X_train)
    X_test=scaler.transform(X_test)
    
    return X_train, X_test

# %% [markdown]
# #### fit_predict_eval()

# %%
# 예측 및 평가
# -----------
def fit_predict_eval(proc_type, drop_no, group_no, model_comparison, X_train, y_train, X_test, y_test):
    
    # 초기화
    # ------
    best_roc_auc = 0
    
    # Define Models
    # ------------- 
    models = [
        # ('LogisticRegression', LogisticRegression()),
        # ('DecisionTree', DecisionTreeClassifier(criterion='entropy', random_state=0)),
        # ('KNN', KNeighborsClassifier(n_neighbors=5)),
        # ('NaiveBayes', GaussianNB()),
        # ('RandomForest', RandomForestClassifier(n_estimators=700, criterion='entropy', random_state=0)),
        ('LightGBM', LGBMClassifier(n_estimators=700, random_state=42, boosting_type='GOSS')),
        # ('XgBoost', XGBClassifier(n_estimators=700, random_state=42, use_label_encoder=False,  eval_metric='auc')),
        # ('Xg Boost', XGBClassifier(n_estimators=700, random_state=42, use_label_encoder=False, eval_metric='logloss')),        
        # ('ExtraTrees', ExtraTreesClassifier(n_estimators=700)),
        # ('SVM', SVC(kernel='linear')),
        # ('LASSO', Lasso(alpha=0.01)),
    ]


    # Model Fit and Testing
    # ---------------------
    for model_name, classifier in models:
        start_time = time.time()

        # 학습
        # ----            
        classifier.fit(X_train, y_train)            # Fit
        
        # 학습된 모델 저장
        # ---------------
        # file_name = f'./models/{model_name}.pkl'
        # print
        # joblib.dump(classifier, file_name)

        # 평가
        # ---- 
        y_pred = classifier.predict(X_test)         # Test
        pred_proba = classifier.predict_proba(X_test)[:, 1]

        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average='weighted')
        
        accuracies = cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=5, scoring="roc_auc")
        # accuracies = cross_val_score(estimator=classifier, X=X_test, y=y_test, cv=5, scoring="recall")
        cv_auc = accuracies.mean()
        cv_std = accuracies.std()
        
        accuracy_class_0 = accuracy_score(y_test[y_test == 0], y_pred[y_test == 0])
        accuracy_class_1 = accuracy_score(y_test[y_test == 1], y_pred[y_test == 1], )
        
        roc_auc = roc_auc_score(y_test, pred_proba)
        
        
        # Collect Result
        # --------------
        model_comparison[f'{model_name}_{proc_type}_{drop_no}_{group_no}'] = [accuracy, accuracy_class_0, accuracy_class_1, f1, cv_auc, cv_std, roc_auc]
        
        
        # Best ROC_AUC Value Return
        # -------------------------
        if roc_auc > best_roc_auc:
            best_roc_auc = roc_auc

        cur_datetime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        end_time = time.time()
        delta_time = end_time - start_time
        # print(f'[테스트] {cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, [{proc_type}_{drop_no}], Model Name: {model_name:<18}, BEST AUC: {best_roc_auc:0.6f}, AUC: {roc_auc:0.6f}')

    return best_roc_auc

# %% [markdown]
# #### print_eval_result()

# %%
def print_eval_result(model_comparison):

    # # MODEL COMPARISSON
    # Model_com_df=pd.DataFrame(model_comparison).T
    # Model_com_df.columns=['Model Accuracy','Model Accuracy-0','Model Accuracy-1','Model F1-Score','CV Accuracy','CV std', 'AUC']
    # Model_com_df=Model_com_df.sort_values(by='AUC',ascending=False)
    # # display(Model_com_df.style.format("{:.2%}").background_gradient(cmap='magma'))

    Model_com_df = pd.DataFrame(model_comparison).T
    Model_com_df.columns = ['Accuracy', 'Accuracy-No', 'Accuracy-Yes', 'F1-Score', 'CV AUC', 'CV std', 'AUC']
    Model_com_df = Model_com_df.sort_values(by='AUC', ascending=False)

    def highlight_below_75(s):
        if s.name != 'CV std' and isinstance(s, pd.Series) and s.dtype == 'float64':
            return ['color: red' if value < 0.75 else 'color: black' for value in s]
        else:
            return ['color: black'] * len(s)

    styled_df = Model_com_df.iloc[:10,:].style.highlight_max(axis=0).apply(highlight_below_75, subset=pd.IndexSlice[:, :'CV AUC']).format("{:.2%}", subset=pd.IndexSlice[:, :'CV AUC'])
    display(styled_df)

# %% [markdown]
# #### test_transform()

# %%
def test_transform(df):
    
    # 데이터 변환
    # ------------------- 
    df = df.drop('cstno', axis=1)
    df = df.drop('sex', axis=1)
    # after_drop_cnt=len(df)
    df['imcome_cat']=df['imcome_cat'].replace({'Less than $40K':40000, '$40K - $60K':50000, '$60K - $80K':70000, '$80K - $120K':100000, '$120K +':120000, 'Unknown':63000})

    
    # 결측치 처리
    # ----------
    df = df.fillna(df.mean(numeric_only=True))
    df.dropna(axis=0, inplace=True)
    # after_drop_cnt=len(df)
    
    # One-Hot Encoding
    # ----------------
    df = encode_onehot(df)  
   
    return df

# %% [markdown]
# ### 학습 및 Test 단계

# %% [markdown]
# #### 데이터 로딩

# %%
ml_churner_df = pd.read_csv("./data/bank_churner.csv")
tot_cnt = len(ml_churner_df)

# %% [markdown]
# #### 예측 및 결과

# %%
# 결과 저장소 초기화
# -----------------
model_comparison = {}  #Dictionary to store the comparison metrics of models
model_eval_comparison = {}       
drop_no = 1

# %%
'''
# 결과 저장소 초기화
# -----------------
model_comparison = {}  #Dictionary to store the comparison metrics of models
model_eval_comparison = {}                        
drop_no = 1
start_time = time.time()


ml_churner_df = test_transform(ml_churner_df)
after_drop_cnt = len(ml_churner_df)

# ML 데이터 분리
# --------------
X=ml_churner_df.drop(['is_churned'],axis=1)
y=ml_churner_df['is_churned']


# 중요 Feature Column 선택
# -----------------------
# X_new, selected_columns = select_feature(X, y, 'Xg Boost')
X_new, selected_columns = select_feature(X, y, 'ExtraTrees')


# Train and Test 데이터 생성 및 가공
# ---------------------------------
X_train, y_train, X_test, y_test = proc_smote(X_new, y)
X_train_for_normalization = X_train.copy()
after_smote_cnt = len(X_train)


# Normalization
# -------------
X_train, X_test = proc_normalization(X_train, X_test)    


# Pridict 및 Test 평가
# --------------------
proc_type='T'
test_auc = fit_predict_eval(proc_type, drop_no, model_comparison, X_train, y_train, X_test, y_test)


# 예측 및 테스트 로그 출력
# ----------------------
cur_datetime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
end_time = time.time()
delta_time = end_time - start_time
print(f'[테스트] {cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, [{proc_type}_{drop_no}], AUC: {test_auc:0.6f}, tot_cnt: {tot_cnt:<6}, after_drop_cnt : {after_drop_cnt:<6}, after_smote_cnt: {after_smote_cnt:<6}, X_train:{X_train.shape}, y_train:{y_train.shape}, X_test:{X_test.shape}, y_test:{y_test.shape}')


# print_eval_result(model_comparison)

'''
# Out:
# '\n# 결과 저장소 초기화\n# -----------------\nmodel_comparison = {}  #Dictionary to store the comparison metrics of models\nmodel_eval_comparison = {}                        \ndrop_no = 1\nstart_time = time.time()\n\n\nml_churner_df = test_transform(ml_churner_df)\nafter_drop_cnt = len(ml_churner_df)\n\n# ML 데이터 분리\n# --------------\nX=ml_churner_df.drop([\'is_churned\'],axis=1)\ny=ml_churner_df[\'is_churned\']\n\n\n# 중요 Feature Column 선택\n# -----------------------\n# X_new, selected_columns = select_feature(X, y, \'Xg Boost\')\nX_new, selected_columns = select_feature(X, y, \'ExtraTrees\')\n\n\n# Train and Test 데이터 생성 및 가공\n# ---------------------------------\nX_train, y_train, X_test, y_test = proc_smote(X_new, y)\nX_train_for_normalization = X_train.copy()\nafter_smote_cnt = len(X_train)\n\n\n# Normalization\n# -------------\nX_train, X_test = proc_normalization(X_train, X_test)    \n\n\n# Pridict 및 Test 평가\n# --------------------\nproc_type=\'T\'\ntest_auc = fit_predict_eval(proc_type, drop_no, model_comparison, X_train, y_train, X_test, y_test)\n\n\n# 예측 및 테스트 로그 출력\n# ----------------------\ncur_datetime = datetime.datetime.now().strftime(\'%Y-%m-%d %H:%M:%S\')\nend_time = time.time()\ndelta_time = end_time - start_time\nprint(f\'[테스트] {cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, [{proc_type}_{drop_no}], AUC: {test_auc:0.6f}, tot_cnt: {tot_cnt:<6}, after_drop_cnt : {after_drop_cnt:<6}, after_smote_cnt: {after_smote_cnt:<6}, X_train:{X_train.shape}, y_train:{y_train.shape}, X_test:{X_test.shape}, y_test:{y_test.shape}\')\n\n\n# print_eval_result(model_comparison)\n\n'

# %% [markdown]
# ### 평가 단계 ~ 평가자가 Competition 평가를 위해 사용 하는 단계

# %% [markdown]
# #### 데이터 로딩

# %%
eval_df = pd.read_csv("./data/test_churner.csv") # 평가를 위한 데이터 로드 - 평가데이터 경로를 입력해 주세요!!!
# eval_df = pd.read_csv("./data/test_churner_kaggle_all.csv") # 평가를 위한 데이터 로드 - 평가데이터 경로를 입력해 주세요!!!

fit_df = pd.read_csv("./data/bank_churner.csv") # 학습을 위한 데이터 로드
tot_cnt = len(eval_df)

# %% [markdown]
# #### 평가 및 결과

# %%
from itertools import combinations

model_comparison = {}  #Dictionary to store the comparison metrics of models
model_eval_comparison = {}                        

def drop_null_column(df, drop_list):
    for col_name in drop_list:
        df = df.drop(col_name, axis=1)

    return df

def test_transform_pre(df, drop_column, groupby_column):
    df = df.drop('cstno', axis=1)
    df = drop_null_column(df, drop_column)
   
    if 'imcome_cat' not in drop_column:
        df['imcome_cat']=df['imcome_cat'].replace({'Less than $40K':40000, '$40K - $60K':50000, '$60K - $80K':70000, '$80K - $120K':100000, '$120K +':120000, 'Unknown':63000})

    df = df.groupby(groupby_column).apply(lambda x: x.fillna(x.mean(numeric_only=True)))
    df.dropna(axis=0, inplace=True)
        
   
    # 결측치 처리
    # ----------
    # after_drop_cnt=len(df)
    
    # One-Hot Encoding
    # ----------------
    df = encode_onehot(df)  
   
    return df

        
# -----------
# 예측
# -----------

# 데이터 로드 및 고객번호 삭제
fit_df = pd.read_csv("./data/bank_churner.csv") # 학습을 위한 데이터 로드
eval_df = pd.read_csv("./data/test_churner.csv")
tot_cnt = fit_df.shape
fit_df_org = fit_df.copy()
eval_df_org = eval_df.copy()

fit_df = fit_df.drop('cstno', axis=1)

fit_df_columns = fit_df.columns

best_auc = 0

# Null 처리
result_list = []
drop_target_columns = ['sex','imcome_cat', 'tot_amt_ratio_q4_q1', 'mean_util_pct', 'tot_trans_cnt_for_12m','age','mean_open_to_buy','tot_trans_amt_for_12m']
for j in range(1, len(drop_target_columns)+1):
    for i in combinations(drop_target_columns, j):
        result_list.append(list(i))

# result_list = [['sex'], ['sex', 'age']]

for drop_no, drop_column in enumerate(result_list):
    for group_no, groupby_column in enumerate(fit_df_columns):
        start_time = time.time()
        if groupby_column == 'is_churned' or groupby_column in drop_column:
            continue

        fit_df = fit_df_org
        tot_cnt = fit_df.shape
        eval_df = eval_df_org
        
        # print(f'drop_column: {drop_column}, groupby_column: {groupby_column}')
        
       # -----------------------------------------------------------------------------------    
        # 평가 for Competition
        # -----------------------------------------------------------------------------------

        # 전처리 단계
        # -----------
        fit_df = test_transform_pre(fit_df, drop_column, groupby_column)
        eval_df = test_transform_pre(eval_df, drop_column, groupby_column)
        after_drop_cnt = len(fit_df)
        
        
        # 평가를 위한 데이터 분리
        # ---------------------
        X_train=fit_df.drop(['is_churned'],axis=1)
        y_train=fit_df['is_churned']
        
        X_eval=eval_df.drop(['is_churned'],axis=1)
        y_eval=eval_df['is_churned']


        # 중요 Feature Column 선택
        # -----------------------
        X_new, selected_columns = select_feature(X_train, y_train, 'ExtraTrees')
        X_eval = X_eval[selected_columns]


        # Train and Test 데이터 생성 및 가공
        # ---------------------------------
        X_train, y_train, X_test_temp, y_test_temp = proc_smote(X_new, y_train)
        after_smote_cnt = X_train.shape

        # Evaluation 데이터 생성 및 가공
        # ---------------------------------
        X_train, X_eval = proc_normalization(X_train, X_eval.values)   


        # 최종 평가
        # --------
        proc_type='E'
        # eval_auc = fit_predict(proc_type, drop_no, model_eval_comparison, X_train_for_evaluation, y_train_for_evaluation, X_eval, y_eval)
        eval_auc = fit_predict_eval(proc_type, drop_no, group_no, model_eval_comparison, X_train, y_train, X_eval, y_eval)
        
        if eval_auc > best_auc:
            best_type = f'{proc_type}_{drop_no}_{group_no}'
            best_auc = eval_auc
            


        # 최종 평가 로그 출력
        # ------------------
        cur_datetime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        end_time = time.time()
        delta_time = end_time - start_time
        # print(f'[평  가] {cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, AUC: {test_auc:0.6f}, 처리 건수: {len(eval_df)}, 최종 평가 건수: {len(X_eval)}')
        print(f'[평  가] {cur_datetime}, {str(datetime.timedelta(seconds=delta_time)).split(".")[0]}, [G{proc_type}_{drop_no}_{group_no}], best-type: [{best_type}], Best-AUC: {best_auc:0.6f}, AUC: {eval_auc:0.6f}, tot_cnt: {tot_cnt}, after_drop_cnt: {after_drop_cnt}, after_smote_cnt: {after_smote_cnt}, groupby_column: {groupby_column}, drop_column: {drop_column}')

        # print_eval_result(model_eval_comparison)
# Out:
# [평  가] 2023-09-17 18:11:16, 0:00:05, [GE_0_1], best-type: [E_0_1], Best-AUC: 0.986599, AUC: 0.986599, tot_cnt: (8101, 21), after_drop_cnt: 8096, after_smote_cnt: (10194, 13), groupby_column: age, drop_column: ['sex']
# [평  가] 2023-09-17 18:11:21, 0:00:04, [GE_0_3], best-type: [E_0_3], Best-AUC: 0.988491, AUC: 0.988491, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: dependent_num, drop_column: ['sex']
# [평  가] 2023-09-17 18:11:25, 0:00:04, [GE_0_4], best-type: [E_0_3], Best-AUC: 0.988491, AUC: 0.986986, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: education, drop_column: ['sex']
# [평  가] 2023-09-17 18:11:30, 0:00:05, [GE_0_5], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.991247, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: marital_stat, drop_column: ['sex']
# [평  가] 2023-09-17 18:11:35, 0:00:04, [GE_0_6], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987773, tot_cnt: (8101, 21), after_drop_cnt: 6482, after_smote_cnt: (8122, 13), groupby_column: imcome_cat, drop_column: ['sex']
# [평  가] 2023-09-17 18:11:39, 0:00:04, [GE_0_7], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.990172, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: card_type, drop_column: ['sex']
# [평  가] 2023-09-17 18:11:44, 0:00:04, [GE_0_8], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988434, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: mon_on_book, drop_column: ['sex']
# [평  가] 2023-09-17 18:11:49, 0:00:04, [GE_0_9], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987690, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: tot_product_count, drop_column: ['sex']
# [평  가] 2023-09-17 18:11:54, 0:00:04, [GE_0_10], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988642, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: months_inact_for_12m, drop_column: ['sex']
# [평  가] 2023-09-17 18:11:58, 0:00:04, [GE_0_11], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987665, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: contact_cnt_for_12m, drop_column: ['sex']
# [평  가] 2023-09-17 18:12:28, 0:00:30, [GE_0_12], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981851, tot_cnt: (8101, 21), after_drop_cnt: 3611, after_smote_cnt: (4484, 13), groupby_column: credit_line, drop_column: ['sex']
# [평  가] 2023-09-17 18:12:43, 0:00:14, [GE_0_13], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987012, tot_cnt: (8101, 21), after_drop_cnt: 5475, after_smote_cnt: (6862, 13), groupby_column: tot_revol_balance, drop_column: ['sex']
# [평  가] 2023-09-17 18:13:15, 0:00:32, [GE_0_14], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.979961, tot_cnt: (8101, 21), after_drop_cnt: 3246, after_smote_cnt: (4050, 14), groupby_column: mean_open_to_buy, drop_column: ['sex']
# [평  가] 2023-09-17 18:13:26, 0:00:10, [GE_0_15], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.984094, tot_cnt: (8101, 21), after_drop_cnt: 5327, after_smote_cnt: (6694, 13), groupby_column: tot_amt_ratio_q4_q1, drop_column: ['sex']
# [평  가] 2023-09-17 18:13:50, 0:00:23, [GE_0_16], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981351, tot_cnt: (8101, 21), after_drop_cnt: 3491, after_smote_cnt: (4458, 12), groupby_column: tot_trans_amt_for_12m, drop_column: ['sex']
# [평  가] 2023-09-17 18:13:53, 0:00:03, [GE_0_17], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.984837, tot_cnt: (8101, 21), after_drop_cnt: 4846, after_smote_cnt: (6070, 12), groupby_column: tot_trans_cnt_for_12m, drop_column: ['sex']
# [평  가] 2023-09-17 18:14:03, 0:00:09, [GE_0_18], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983322, tot_cnt: (8101, 21), after_drop_cnt: 6245, after_smote_cnt: (7892, 13), groupby_column: tot_cnt_ratio_q4_q1, drop_column: ['sex']
# [평  가] 2023-09-17 18:14:13, 0:00:09, [GE_0_19], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.984142, tot_cnt: (8101, 21), after_drop_cnt: 5278, after_smote_cnt: (6632, 13), groupby_column: mean_util_pct, drop_column: ['sex']
# [평  가] 2023-09-17 18:14:17, 0:00:04, [GE_1_1], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987629, tot_cnt: (8101, 21), after_drop_cnt: 7288, after_smote_cnt: (9182, 14), groupby_column: age, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:14:22, 0:00:04, [GE_1_2], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987508, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: sex, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:14:26, 0:00:04, [GE_1_3], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988756, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: dependent_num, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:14:30, 0:00:04, [GE_1_4], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988313, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: education, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:14:35, 0:00:04, [GE_1_5], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986576, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: marital_stat, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:14:39, 0:00:04, [GE_1_7], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988524, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: card_type, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:14:43, 0:00:04, [GE_1_8], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.985613, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: mon_on_book, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:14:48, 0:00:04, [GE_1_9], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987546, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: tot_product_count, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:14:52, 0:00:04, [GE_1_10], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988257, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: months_inact_for_12m, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:14:56, 0:00:04, [GE_1_11], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988034, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: contact_cnt_for_12m, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:15:23, 0:00:27, [GE_1_12], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981435, tot_cnt: (8101, 21), after_drop_cnt: 3375, after_smote_cnt: (4202, 14), groupby_column: credit_line, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:15:37, 0:00:13, [GE_1_13], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987120, tot_cnt: (8101, 21), after_drop_cnt: 4986, after_smote_cnt: (6254, 14), groupby_column: tot_revol_balance, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:16:06, 0:00:28, [GE_1_14], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.980330, tot_cnt: (8101, 21), after_drop_cnt: 3095, after_smote_cnt: (3878, 14), groupby_column: mean_open_to_buy, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:16:15, 0:00:09, [GE_1_15], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983918, tot_cnt: (8101, 21), after_drop_cnt: 4799, after_smote_cnt: (6038, 14), groupby_column: tot_amt_ratio_q4_q1, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:16:37, 0:00:21, [GE_1_16], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.984758, tot_cnt: (8101, 21), after_drop_cnt: 3243, after_smote_cnt: (4130, 12), groupby_column: tot_trans_amt_for_12m, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:16:41, 0:00:04, [GE_1_17], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.985116, tot_cnt: (8101, 21), after_drop_cnt: 4360, after_smote_cnt: (5456, 13), groupby_column: tot_trans_cnt_for_12m, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:16:49, 0:00:08, [GE_1_18], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.980962, tot_cnt: (8101, 21), after_drop_cnt: 5618, after_smote_cnt: (7098, 14), groupby_column: tot_cnt_ratio_q4_q1, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:16:58, 0:00:09, [GE_1_19], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986200, tot_cnt: (8101, 21), after_drop_cnt: 4764, after_smote_cnt: (5984, 13), groupby_column: mean_util_pct, drop_column: ['imcome_cat']
# [평  가] 2023-09-17 18:17:03, 0:00:04, [GE_2_1], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981516, tot_cnt: (8101, 21), after_drop_cnt: 7288, after_smote_cnt: (9182, 13), groupby_column: age, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:17:07, 0:00:04, [GE_2_2], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.982002, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: sex, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:17:11, 0:00:04, [GE_2_3], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981662, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: dependent_num, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:17:15, 0:00:04, [GE_2_4], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981507, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: education, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:17:20, 0:00:04, [GE_2_5], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981911, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: marital_stat, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:17:23, 0:00:03, [GE_2_6], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981536, tot_cnt: (8101, 21), after_drop_cnt: 5828, after_smote_cnt: (7312, 13), groupby_column: imcome_cat, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:17:28, 0:00:04, [GE_2_7], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.980784, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: card_type, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:17:32, 0:00:04, [GE_2_8], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.978914, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: mon_on_book, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:17:36, 0:00:04, [GE_2_9], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.982370, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: tot_product_count, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:17:40, 0:00:04, [GE_2_10], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.982175, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: months_inact_for_12m, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:17:45, 0:00:04, [GE_2_11], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.980283, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: contact_cnt_for_12m, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:18:13, 0:00:28, [GE_2_12], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.970843, tot_cnt: (8101, 21), after_drop_cnt: 3543, after_smote_cnt: (4416, 13), groupby_column: credit_line, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:18:27, 0:00:14, [GE_2_13], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.976612, tot_cnt: (8101, 21), after_drop_cnt: 5049, after_smote_cnt: (6344, 14), groupby_column: tot_revol_balance, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:19:00, 0:00:32, [GE_2_14], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.975319, tot_cnt: (8101, 21), after_drop_cnt: 3211, after_smote_cnt: (4028, 13), groupby_column: mean_open_to_buy, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:19:24, 0:00:23, [GE_2_16], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.978210, tot_cnt: (8101, 21), after_drop_cnt: 3375, after_smote_cnt: (4304, 13), groupby_column: tot_trans_amt_for_12m, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:19:28, 0:00:03, [GE_2_17], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981810, tot_cnt: (8101, 21), after_drop_cnt: 4358, after_smote_cnt: (5454, 12), groupby_column: tot_trans_cnt_for_12m, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:19:36, 0:00:08, [GE_2_18], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.973634, tot_cnt: (8101, 21), after_drop_cnt: 5633, after_smote_cnt: (7120, 12), groupby_column: tot_cnt_ratio_q4_q1, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:19:46, 0:00:09, [GE_2_19], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.977632, tot_cnt: (8101, 21), after_drop_cnt: 4795, after_smote_cnt: (6032, 13), groupby_column: mean_util_pct, drop_column: ['tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:19:50, 0:00:04, [GE_3_1], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988196, tot_cnt: (8101, 21), after_drop_cnt: 7288, after_smote_cnt: (9182, 13), groupby_column: age, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:19:55, 0:00:04, [GE_3_2], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987116, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: sex, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:19:59, 0:00:04, [GE_3_3], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988160, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: dependent_num, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:20:03, 0:00:04, [GE_3_4], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988545, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: education, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:20:07, 0:00:04, [GE_3_5], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987768, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: marital_stat, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:20:12, 0:00:04, [GE_3_6], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987802, tot_cnt: (8101, 21), after_drop_cnt: 5828, after_smote_cnt: (7312, 13), groupby_column: imcome_cat, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:20:16, 0:00:04, [GE_3_7], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988016, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: card_type, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:20:21, 0:00:04, [GE_3_8], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986234, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: mon_on_book, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:20:25, 0:00:04, [GE_3_9], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987670, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: tot_product_count, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:20:29, 0:00:04, [GE_3_10], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987827, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: months_inact_for_12m, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:20:33, 0:00:04, [GE_3_11], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987724, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: contact_cnt_for_12m, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:21:03, 0:00:29, [GE_3_12], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983354, tot_cnt: (8101, 21), after_drop_cnt: 3524, after_smote_cnt: (4390, 13), groupby_column: credit_line, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:21:17, 0:00:14, [GE_3_13], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.985480, tot_cnt: (8101, 21), after_drop_cnt: 5059, after_smote_cnt: (6354, 14), groupby_column: tot_revol_balance, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:21:47, 0:00:30, [GE_3_14], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.979169, tot_cnt: (8101, 21), after_drop_cnt: 3252, after_smote_cnt: (4076, 13), groupby_column: mean_open_to_buy, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:21:57, 0:00:10, [GE_3_15], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.984686, tot_cnt: (8101, 21), after_drop_cnt: 4831, after_smote_cnt: (6070, 14), groupby_column: tot_amt_ratio_q4_q1, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:22:21, 0:00:23, [GE_3_16], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983748, tot_cnt: (8101, 21), after_drop_cnt: 3408, after_smote_cnt: (4350, 13), groupby_column: tot_trans_amt_for_12m, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:22:24, 0:00:03, [GE_3_17], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.984646, tot_cnt: (8101, 21), after_drop_cnt: 4359, after_smote_cnt: (5456, 12), groupby_column: tot_trans_cnt_for_12m, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:22:33, 0:00:08, [GE_3_18], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983790, tot_cnt: (8101, 21), after_drop_cnt: 5632, after_smote_cnt: (7118, 12), groupby_column: tot_cnt_ratio_q4_q1, drop_column: ['mean_util_pct']
# [평  가] 2023-09-17 18:22:37, 0:00:04, [GE_4_1], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981160, tot_cnt: (8101, 21), after_drop_cnt: 7291, after_smote_cnt: (9186, 14), groupby_column: age, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:22:42, 0:00:04, [GE_4_2], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.980834, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: sex, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:22:46, 0:00:04, [GE_4_3], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981205, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: dependent_num, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:22:51, 0:00:04, [GE_4_4], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.982649, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: education, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:22:55, 0:00:04, [GE_4_5], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981048, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: marital_stat, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:22:59, 0:00:04, [GE_4_6], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.980309, tot_cnt: (8101, 21), after_drop_cnt: 5828, after_smote_cnt: (7312, 13), groupby_column: imcome_cat, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:23:03, 0:00:04, [GE_4_7], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981187, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: card_type, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:23:08, 0:00:04, [GE_4_8], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.979918, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: mon_on_book, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:23:13, 0:00:05, [GE_4_9], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.980118, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: tot_product_count, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:23:18, 0:00:04, [GE_4_10], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.980449, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: months_inact_for_12m, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:23:22, 0:00:04, [GE_4_11], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.979083, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: contact_cnt_for_12m, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:23:51, 0:00:28, [GE_4_12], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.974191, tot_cnt: (8101, 21), after_drop_cnt: 3749, after_smote_cnt: (4690, 13), groupby_column: credit_line, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:24:05, 0:00:13, [GE_4_13], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.976711, tot_cnt: (8101, 21), after_drop_cnt: 5192, after_smote_cnt: (6526, 14), groupby_column: tot_revol_balance, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:24:36, 0:00:30, [GE_4_14], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.975496, tot_cnt: (8101, 21), after_drop_cnt: 3495, after_smote_cnt: (4400, 13), groupby_column: mean_open_to_buy, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:24:46, 0:00:09, [GE_4_15], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.977736, tot_cnt: (8101, 21), after_drop_cnt: 4853, after_smote_cnt: (6094, 14), groupby_column: tot_amt_ratio_q4_q1, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:25:10, 0:00:23, [GE_4_16], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.974412, tot_cnt: (8101, 21), after_drop_cnt: 3640, after_smote_cnt: (4642, 14), groupby_column: tot_trans_amt_for_12m, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:25:18, 0:00:08, [GE_4_18], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.974353, tot_cnt: (8101, 21), after_drop_cnt: 5656, after_smote_cnt: (7138, 14), groupby_column: tot_cnt_ratio_q4_q1, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:25:28, 0:00:09, [GE_4_19], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.976694, tot_cnt: (8101, 21), after_drop_cnt: 4837, after_smote_cnt: (6084, 14), groupby_column: mean_util_pct, drop_column: ['tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:25:32, 0:00:04, [GE_5_2], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987346, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: sex, drop_column: ['age']
# [평  가] 2023-09-17 18:25:37, 0:00:04, [GE_5_3], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988543, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: dependent_num, drop_column: ['age']
# [평  가] 2023-09-17 18:25:41, 0:00:04, [GE_5_4], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988480, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: education, drop_column: ['age']
# [평  가] 2023-09-17 18:25:45, 0:00:04, [GE_5_5], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987062, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: marital_stat, drop_column: ['age']
# [평  가] 2023-09-17 18:25:49, 0:00:03, [GE_5_6], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986945, tot_cnt: (8101, 21), after_drop_cnt: 5828, after_smote_cnt: (7312, 13), groupby_column: imcome_cat, drop_column: ['age']
# [평  가] 2023-09-17 18:25:53, 0:00:04, [GE_5_7], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988374, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: card_type, drop_column: ['age']
# [평  가] 2023-09-17 18:25:58, 0:00:04, [GE_5_8], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987067, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: mon_on_book, drop_column: ['age']
# [평  가] 2023-09-17 18:26:02, 0:00:04, [GE_5_9], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988102, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: tot_product_count, drop_column: ['age']
# [평  가] 2023-09-17 18:26:06, 0:00:04, [GE_5_10], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988034, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: months_inact_for_12m, drop_column: ['age']
# [평  가] 2023-09-17 18:26:10, 0:00:04, [GE_5_11], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988934, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: contact_cnt_for_12m, drop_column: ['age']
# [평  가] 2023-09-17 18:26:39, 0:00:28, [GE_5_12], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981372, tot_cnt: (8101, 21), after_drop_cnt: 3222, after_smote_cnt: (4000, 13), groupby_column: credit_line, drop_column: ['age']
# [평  가] 2023-09-17 18:26:53, 0:00:14, [GE_5_13], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983556, tot_cnt: (8101, 21), after_drop_cnt: 4931, after_smote_cnt: (6182, 14), groupby_column: tot_revol_balance, drop_column: ['age']
# [평  가] 2023-09-17 18:27:24, 0:00:30, [GE_5_14], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.979391, tot_cnt: (8101, 21), after_drop_cnt: 2919, after_smote_cnt: (3650, 13), groupby_column: mean_open_to_buy, drop_column: ['age']
# [평  가] 2023-09-17 18:27:34, 0:00:09, [GE_5_15], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983106, tot_cnt: (8101, 21), after_drop_cnt: 4786, after_smote_cnt: (6018, 14), groupby_column: tot_amt_ratio_q4_q1, drop_column: ['age']
# [평  가] 2023-09-17 18:27:57, 0:00:23, [GE_5_16], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981160, tot_cnt: (8101, 21), after_drop_cnt: 3112, after_smote_cnt: (3968, 13), groupby_column: tot_trans_amt_for_12m, drop_column: ['age']
# [평  가] 2023-09-17 18:28:01, 0:00:03, [GE_5_17], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986965, tot_cnt: (8101, 21), after_drop_cnt: 4358, after_smote_cnt: (5454, 12), groupby_column: tot_trans_cnt_for_12m, drop_column: ['age']
# [평  가] 2023-09-17 18:28:10, 0:00:08, [GE_5_18], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.984835, tot_cnt: (8101, 21), after_drop_cnt: 5610, after_smote_cnt: (7088, 13), groupby_column: tot_cnt_ratio_q4_q1, drop_column: ['age']
# [평  가] 2023-09-17 18:28:19, 0:00:09, [GE_5_19], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.985449, tot_cnt: (8101, 21), after_drop_cnt: 4750, after_smote_cnt: (5966, 13), groupby_column: mean_util_pct, drop_column: ['age']
# [평  가] 2023-09-17 18:28:24, 0:00:04, [GE_6_1], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988770, tot_cnt: (8101, 21), after_drop_cnt: 7288, after_smote_cnt: (9182, 13), groupby_column: age, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:28:28, 0:00:04, [GE_6_2], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986698, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: sex, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:28:32, 0:00:04, [GE_6_3], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.989107, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: dependent_num, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:28:36, 0:00:04, [GE_6_4], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988498, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: education, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:28:40, 0:00:04, [GE_6_5], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987568, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: marital_stat, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:28:44, 0:00:03, [GE_6_6], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987105, tot_cnt: (8101, 21), after_drop_cnt: 5828, after_smote_cnt: (7312, 13), groupby_column: imcome_cat, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:28:49, 0:00:04, [GE_6_7], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987778, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: card_type, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:28:53, 0:00:04, [GE_6_8], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986306, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: mon_on_book, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:28:57, 0:00:04, [GE_6_9], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987057, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: tot_product_count, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:29:01, 0:00:04, [GE_6_10], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988432, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: months_inact_for_12m, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:29:06, 0:00:04, [GE_6_11], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988106, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 13), groupby_column: contact_cnt_for_12m, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:29:34, 0:00:28, [GE_6_12], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.982253, tot_cnt: (8101, 21), after_drop_cnt: 3222, after_smote_cnt: (4000, 13), groupby_column: credit_line, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:29:48, 0:00:13, [GE_6_13], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.984045, tot_cnt: (8101, 21), after_drop_cnt: 4931, after_smote_cnt: (6182, 14), groupby_column: tot_revol_balance, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:29:58, 0:00:10, [GE_6_15], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.982087, tot_cnt: (8101, 21), after_drop_cnt: 4786, after_smote_cnt: (6018, 14), groupby_column: tot_amt_ratio_q4_q1, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:30:22, 0:00:23, [GE_6_16], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.977303, tot_cnt: (8101, 21), after_drop_cnt: 3112, after_smote_cnt: (3968, 13), groupby_column: tot_trans_amt_for_12m, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:30:25, 0:00:03, [GE_6_17], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986371, tot_cnt: (8101, 21), after_drop_cnt: 4358, after_smote_cnt: (5454, 12), groupby_column: tot_trans_cnt_for_12m, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:30:34, 0:00:08, [GE_6_18], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983480, tot_cnt: (8101, 21), after_drop_cnt: 5610, after_smote_cnt: (7088, 12), groupby_column: tot_cnt_ratio_q4_q1, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:30:43, 0:00:09, [GE_6_19], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986175, tot_cnt: (8101, 21), after_drop_cnt: 4750, after_smote_cnt: (5966, 13), groupby_column: mean_util_pct, drop_column: ['mean_open_to_buy']
# [평  가] 2023-09-17 18:30:48, 0:00:04, [GE_7_1], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.963621, tot_cnt: (8101, 21), after_drop_cnt: 7288, after_smote_cnt: (9182, 14), groupby_column: age, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:30:52, 0:00:04, [GE_7_2], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.958070, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: sex, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:30:57, 0:00:04, [GE_7_3], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.959940, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: dependent_num, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:31:01, 0:00:04, [GE_7_4], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.959546, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: education, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:31:05, 0:00:04, [GE_7_5], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.959485, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: marital_stat, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:31:09, 0:00:03, [GE_7_6], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.954519, tot_cnt: (8101, 21), after_drop_cnt: 5828, after_smote_cnt: (7312, 13), groupby_column: imcome_cat, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:31:14, 0:00:04, [GE_7_7], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.959363, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: card_type, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:31:18, 0:00:04, [GE_7_8], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.956143, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: mon_on_book, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:31:23, 0:00:04, [GE_7_9], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.959786, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: tot_product_count, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:31:27, 0:00:04, [GE_7_10], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.959294, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: months_inact_for_12m, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:31:31, 0:00:04, [GE_7_11], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.957075, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 14), groupby_column: contact_cnt_for_12m, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:32:01, 0:00:29, [GE_7_12], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.944276, tot_cnt: (8101, 21), after_drop_cnt: 3403, after_smote_cnt: (4214, 13), groupby_column: credit_line, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:32:15, 0:00:14, [GE_7_13], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.958254, tot_cnt: (8101, 21), after_drop_cnt: 4989, after_smote_cnt: (6262, 14), groupby_column: tot_revol_balance, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:32:45, 0:00:30, [GE_7_14], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.942422, tot_cnt: (8101, 21), after_drop_cnt: 3090, after_smote_cnt: (3858, 14), groupby_column: mean_open_to_buy, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:32:55, 0:00:10, [GE_7_15], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.951916, tot_cnt: (8101, 21), after_drop_cnt: 4801, after_smote_cnt: (6034, 14), groupby_column: tot_amt_ratio_q4_q1, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:33:00, 0:00:04, [GE_7_17], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.960173, tot_cnt: (8101, 21), after_drop_cnt: 4358, after_smote_cnt: (5454, 14), groupby_column: tot_trans_cnt_for_12m, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:33:09, 0:00:08, [GE_7_18], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.951810, tot_cnt: (8101, 21), after_drop_cnt: 5631, after_smote_cnt: (7114, 14), groupby_column: tot_cnt_ratio_q4_q1, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:33:18, 0:00:09, [GE_7_19], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.952777, tot_cnt: (8101, 21), after_drop_cnt: 4764, after_smote_cnt: (5986, 14), groupby_column: mean_util_pct, drop_column: ['tot_trans_amt_for_12m']
# [평  가] 2023-09-17 18:33:23, 0:00:04, [GE_8_1], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986599, tot_cnt: (8101, 21), after_drop_cnt: 8096, after_smote_cnt: (10194, 13), groupby_column: age, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:33:27, 0:00:04, [GE_8_3], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988491, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: dependent_num, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:33:32, 0:00:04, [GE_8_4], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986689, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 14), groupby_column: education, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:33:36, 0:00:04, [GE_8_5], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.991247, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: marital_stat, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:33:41, 0:00:04, [GE_8_7], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.990172, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: card_type, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:33:45, 0:00:04, [GE_8_8], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988434, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: mon_on_book, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:33:50, 0:00:04, [GE_8_9], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987690, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: tot_product_count, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:33:54, 0:00:04, [GE_8_10], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988920, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 14), groupby_column: months_inact_for_12m, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:33:59, 0:00:04, [GE_8_11], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987665, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: contact_cnt_for_12m, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:34:26, 0:00:26, [GE_8_12], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.982967, tot_cnt: (8101, 21), after_drop_cnt: 3782, after_smote_cnt: (4708, 14), groupby_column: credit_line, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:34:39, 0:00:13, [GE_8_13], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986587, tot_cnt: (8101, 21), after_drop_cnt: 5541, after_smote_cnt: (6946, 13), groupby_column: tot_revol_balance, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:35:07, 0:00:28, [GE_8_14], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983090, tot_cnt: (8101, 21), after_drop_cnt: 3442, after_smote_cnt: (4308, 14), groupby_column: mean_open_to_buy, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:35:17, 0:00:09, [GE_8_15], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983626, tot_cnt: (8101, 21), after_drop_cnt: 5341, after_smote_cnt: (6712, 14), groupby_column: tot_amt_ratio_q4_q1, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:35:39, 0:00:21, [GE_8_16], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.984044, tot_cnt: (8101, 21), after_drop_cnt: 3636, after_smote_cnt: (4636, 13), groupby_column: tot_trans_amt_for_12m, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:35:43, 0:00:03, [GE_8_17], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.985732, tot_cnt: (8101, 21), after_drop_cnt: 4848, after_smote_cnt: (6072, 12), groupby_column: tot_trans_cnt_for_12m, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:35:51, 0:00:08, [GE_8_18], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.982469, tot_cnt: (8101, 21), after_drop_cnt: 6256, after_smote_cnt: (7904, 13), groupby_column: tot_cnt_ratio_q4_q1, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:36:00, 0:00:09, [GE_8_19], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.985442, tot_cnt: (8101, 21), after_drop_cnt: 5294, after_smote_cnt: (6654, 13), groupby_column: mean_util_pct, drop_column: ['sex', 'imcome_cat']
# [평  가] 2023-09-17 18:36:05, 0:00:04, [GE_9_1], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.979612, tot_cnt: (8101, 21), after_drop_cnt: 8096, after_smote_cnt: (10194, 14), groupby_column: age, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:36:09, 0:00:04, [GE_9_3], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983684, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), groupby_column: dependent_num, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:36:14, 0:00:04, [GE_9_4], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.979684, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: education, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:36:18, 0:00:04, [GE_9_5], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.984292, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 14), groupby_column: marital_stat, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:36:22, 0:00:03, [GE_9_6], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981597, tot_cnt: (8101, 21), after_drop_cnt: 6482, after_smote_cnt: (8122, 12), groupby_column: imcome_cat, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:36:26, 0:00:04, [GE_9_7], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983667, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 14), groupby_column: card_type, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:36:31, 0:00:04, [GE_9_8], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981338, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 14), groupby_column: mon_on_book, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:36:36, 0:00:04, [GE_9_9], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.980786, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: tot_product_count, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:36:40, 0:00:04, [GE_9_10], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983108, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: months_inact_for_12m, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:36:44, 0:00:04, [GE_9_11], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981156, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), groupby_column: contact_cnt_for_12m, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:37:13, 0:00:28, [GE_9_12], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.970427, tot_cnt: (8101, 21), after_drop_cnt: 3963, after_smote_cnt: (4940, 13), groupby_column: credit_line, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:37:27, 0:00:13, [GE_9_13], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.975875, tot_cnt: (8101, 21), after_drop_cnt: 5607, after_smote_cnt: (7042, 14), groupby_column: tot_revol_balance, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:37:58, 0:00:30, [GE_9_14], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.973163, tot_cnt: (8101, 21), after_drop_cnt: 3580, after_smote_cnt: (4486, 13), groupby_column: mean_open_to_buy, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:38:21, 0:00:23, [GE_9_16], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.976918, tot_cnt: (8101, 21), after_drop_cnt: 3782, after_smote_cnt: (4828, 12), groupby_column: tot_trans_amt_for_12m, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:38:25, 0:00:03, [GE_9_17], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.979164, tot_cnt: (8101, 21), after_drop_cnt: 4846, after_smote_cnt: (6070, 12), groupby_column: tot_trans_cnt_for_12m, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:38:33, 0:00:08, [GE_9_18], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.979241, tot_cnt: (8101, 21), after_drop_cnt: 6269, after_smote_cnt: (7924, 12), groupby_column: tot_cnt_ratio_q4_q1, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:38:43, 0:00:09, [GE_9_19], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.977254, tot_cnt: (8101, 21), after_drop_cnt: 5328, after_smote_cnt: (6704, 14), groupby_column: mean_util_pct, drop_column: ['sex', 'tot_amt_ratio_q4_q1']
# [평  가] 2023-09-17 18:38:48, 0:00:04, [GE_10_1], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987390, tot_cnt: (8101, 21), after_drop_cnt: 8096, after_smote_cnt: (10194, 13), groupby_column: age, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:38:52, 0:00:04, [GE_10_3], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988462, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), groupby_column: dependent_num, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:38:56, 0:00:04, [GE_10_4], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.985636, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: education, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:39:01, 0:00:04, [GE_10_5], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.989983, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: marital_stat, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:39:05, 0:00:03, [GE_10_6], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988210, tot_cnt: (8101, 21), after_drop_cnt: 6482, after_smote_cnt: (8122, 12), groupby_column: imcome_cat, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:39:09, 0:00:04, [GE_10_7], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.990068, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 13), groupby_column: card_type, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:39:14, 0:00:04, [GE_10_8], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987915, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), groupby_column: mon_on_book, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:39:18, 0:00:04, [GE_10_9], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988851, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), groupby_column: tot_product_count, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:39:22, 0:00:04, [GE_10_10], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987858, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), groupby_column: months_inact_for_12m, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:39:26, 0:00:04, [GE_10_11], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986918, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 12), groupby_column: contact_cnt_for_12m, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:39:55, 0:00:28, [GE_10_12], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.982701, tot_cnt: (8101, 21), after_drop_cnt: 3960, after_smote_cnt: (4928, 13), groupby_column: credit_line, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:40:09, 0:00:14, [GE_10_13], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986682, tot_cnt: (8101, 21), after_drop_cnt: 5624, after_smote_cnt: (7060, 13), groupby_column: tot_revol_balance, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:40:40, 0:00:30, [GE_10_14], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981552, tot_cnt: (8101, 21), after_drop_cnt: 3624, after_smote_cnt: (4528, 13), groupby_column: mean_open_to_buy, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:40:50, 0:00:10, [GE_10_15], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983505, tot_cnt: (8101, 21), after_drop_cnt: 5377, after_smote_cnt: (6748, 14), groupby_column: tot_amt_ratio_q4_q1, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:41:13, 0:00:22, [GE_10_16], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983811, tot_cnt: (8101, 21), after_drop_cnt: 3817, after_smote_cnt: (4870, 12), groupby_column: tot_trans_amt_for_12m, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:41:17, 0:00:03, [GE_10_17], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.983693, tot_cnt: (8101, 21), after_drop_cnt: 4847, after_smote_cnt: (6072, 11), groupby_column: tot_trans_cnt_for_12m, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:41:25, 0:00:08, [GE_10_18], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.984582, tot_cnt: (8101, 21), after_drop_cnt: 6272, after_smote_cnt: (7928, 12), groupby_column: tot_cnt_ratio_q4_q1, drop_column: ['sex', 'mean_util_pct']
# [평  가] 2023-09-17 18:41:30, 0:00:04, [GE_11_1], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.979770, tot_cnt: (8101, 21), after_drop_cnt: 8099, after_smote_cnt: (10198, 14), groupby_column: age, drop_column: ['sex', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:41:35, 0:00:04, [GE_11_3], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.982242, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 14), groupby_column: dependent_num, drop_column: ['sex', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:41:39, 0:00:04, [GE_11_4], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.980688, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 14), groupby_column: education, drop_column: ['sex', 'tot_trans_cnt_for_12m']
# [평  가] 2023-09-17 18:41:44, 0:00:04, [GE_11_5], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.981767, tot_cnt: (8101, 21), after_drop_cnt: 8101, after_smote_cnt: (10200, 14), groupby_column: marital_stat, drop_column: ['sex', 'tot_trans_cnt_for_12m']
# ...
# [평  가] 2023-09-17 21:35:54, 0:00:25, [GE_83_12], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.975301, tot_cnt: (8101, 21), after_drop_cnt: 4183, after_smote_cnt: (5236, 12), groupby_column: credit_line, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:36:06, 0:00:12, [GE_83_13], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.977004, tot_cnt: (8101, 21), after_drop_cnt: 5341, after_smote_cnt: (6724, 12), groupby_column: tot_revol_balance, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:36:15, 0:00:09, [GE_83_15], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.974988, tot_cnt: (8101, 21), after_drop_cnt: 4913, after_smote_cnt: (6166, 12), groupby_column: tot_amt_ratio_q4_q1, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:36:36, 0:00:20, [GE_83_16], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.974745, tot_cnt: (8101, 21), after_drop_cnt: 4041, after_smote_cnt: (5134, 12), groupby_column: tot_trans_amt_for_12m, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:36:44, 0:00:07, [GE_83_18], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.977062, tot_cnt: (8101, 21), after_drop_cnt: 5683, after_smote_cnt: (7172, 12), groupby_column: tot_cnt_ratio_q4_q1, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:36:48, 0:00:04, [GE_84_1], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.914807, tot_cnt: (8101, 21), after_drop_cnt: 7291, after_smote_cnt: (9186, 12), groupby_column: age, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:36:52, 0:00:03, [GE_84_2], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.910809, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: sex, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:36:56, 0:00:04, [GE_84_3], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.913385, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: dependent_num, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:37:00, 0:00:04, [GE_84_4], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.919022, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: education, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:37:05, 0:00:04, [GE_84_5], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.912944, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: marital_stat, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:37:08, 0:00:03, [GE_84_6], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.905566, tot_cnt: (8101, 21), after_drop_cnt: 5828, after_smote_cnt: (7312, 12), groupby_column: imcome_cat, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:37:12, 0:00:04, [GE_84_7], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.911149, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: card_type, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:37:16, 0:00:04, [GE_84_8], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.914528, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: mon_on_book, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:37:20, 0:00:04, [GE_84_9], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.913236, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: tot_product_count, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:37:25, 0:00:04, [GE_84_10], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.912397, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: months_inact_for_12m, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:37:29, 0:00:04, [GE_84_11], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.908349, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: contact_cnt_for_12m, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:37:54, 0:00:25, [GE_84_12], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.903248, tot_cnt: (8101, 21), after_drop_cnt: 4553, after_smote_cnt: (5692, 12), groupby_column: credit_line, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:38:07, 0:00:12, [GE_84_13], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.904833, tot_cnt: (8101, 21), after_drop_cnt: 5446, after_smote_cnt: (6858, 12), groupby_column: tot_revol_balance, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:38:34, 0:00:27, [GE_84_14], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.898438, tot_cnt: (8101, 21), after_drop_cnt: 4372, after_smote_cnt: (5488, 12), groupby_column: mean_open_to_buy, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:38:43, 0:00:09, [GE_84_15], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.903471, tot_cnt: (8101, 21), after_drop_cnt: 4948, after_smote_cnt: (6208, 12), groupby_column: tot_amt_ratio_q4_q1, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:38:51, 0:00:07, [GE_84_18], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.907819, tot_cnt: (8101, 21), after_drop_cnt: 5710, after_smote_cnt: (7204, 12), groupby_column: tot_cnt_ratio_q4_q1, drop_column: ['mean_util_pct', 'tot_trans_cnt_for_12m', 'tot_trans_amt_for_12m']
# [평  가] 2023-09-17 21:38:55, 0:00:03, [GE_85_2], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986794, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: sex, drop_column: ['mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:38:59, 0:00:03, [GE_85_3], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988871, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: dependent_num, drop_column: ['mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:39:03, 0:00:03, [GE_85_4], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.989319, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: education, drop_column: ['mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:39:07, 0:00:03, [GE_85_5], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987584, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: marital_stat, drop_column: ['mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:39:10, 0:00:03, [GE_85_6], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.987112, tot_cnt: (8101, 21), after_drop_cnt: 5828, after_smote_cnt: (7312, 11), groupby_column: imcome_cat, drop_column: ['mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:39:14, 0:00:03, [GE_85_7], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988020, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: card_type, drop_column: ['mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:39:18, 0:00:04, [GE_85_8], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.986949, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: mon_on_book, drop_column: ['mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:39:22, 0:00:03, [GE_85_9], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988664, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: tot_product_count, drop_column: ['mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:39:27, 0:00:04, [GE_85_10], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.989062, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: months_inact_for_12m, drop_column: ['mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:39:32, 0:00:05, [GE_85_11], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.988093, tot_cnt: (8101, 21), after_drop_cnt: 7293, after_smote_cnt: (9188, 12), groupby_column: contact_cnt_for_12m, drop_column: ['mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:40:01, 0:00:28, [GE_85_12], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.984101, tot_cnt: (8101, 21), after_drop_cnt: 3524, after_smote_cnt: (4390, 11), groupby_column: credit_line, drop_column: ['mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:40:14, 0:00:13, [GE_85_13], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.985764, tot_cnt: (8101, 21), after_drop_cnt: 5059, after_smote_cnt: (6354, 12), groupby_column: tot_revol_balance, drop_column: ['mean_util_pct', 'age', 'mean_open_to_buy']
# [평  가] 2023-09-17 21:40:24, 0:00:09, [GE_85_15], best-type: [E_0_5], Best-AUC: 0.991247, AUC: 0.985393, tot_cnt: (8101, 21), after_drop_cnt: 4831, after_smote_cnt: (6070, 12), groupby_column: tot_amt_ratio_q4_q1, drop_column: ['mean_util_pct', 'age', 'mean_open_to_buy']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 78
#      68  eval_df = eval_df_org
#      70  # print(f'drop_column: {drop_column}, groupby_column: {groupby_column}')
#      71
#      72 # -----------------------------------------------------------------------------------
#    (...)
#      76  # 전처리 단계
#      77  # -----------
# ---> 78  fit_df = test_transform(fit_df, drop_column, groupby_column)
#      79  eval_df = test_transform(eval_df, drop_column, groupby_column)
#      80  after_drop_cnt = len(fit_df)
#
# Cell In[57], line 19, in test_transform(df, drop_column, groupby_column)
#      16 if 'imcome_cat' not in drop_column:
#      17     df['imcome_cat']=df['imcome_cat'].replace({'Less than $40K':40000, '$40K - $60K':50000, '$60K - $80K':70000, '$80K - $120K':100000, '$120K +':120000, 'Unknown':63000})
# ---> 19 df = df.groupby(groupby_column).apply(lambda x: x.fillna(x.mean(numeric_only=True)))
#      20 df.dropna(axis=0, inplace=True)
#      23 # 결측치 처리
#      24 # ----------
#      25 # after_drop_cnt=len(df)
#      26
#      27 # One-Hot Encoding
#      28 # ----------------
#
# File c:\Users\USER\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1353, in GroupBy.apply(self, func, *args, **kwargs)
#    1351 with option_context("mode.chained_assignment", None):
#    1352     try:
# -> 1353         result = self._python_apply_general(f, self._selected_obj)
#    1354     except TypeError:
#    1355         # gh-20949
#    1356         # try again, with .apply acting as a filtering
#    (...)
#    1360         # fails on *some* columns, e.g. a numeric operation
#    1361         # on a string grouper column
#    1363         return self._python_apply_general(f, self._obj_with_exclusions)
#
# File c:\Users\USER\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1402, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1367 @final
#    1368 def _python_apply_general(
#    1369     self,
#    (...)
#    1374     is_agg: bool = False,
#    1375 ) -> NDFrameT:
#    1376     """
#    1377     Apply function f in python space
#    1378
#    (...)
#    1400         data after applying f
#    1401     """
# -> 1402     values, mutated = self.grouper.apply(f, data, self.axis)
#    1403     if not_indexed_same is None:
#    1404         not_indexed_same = mutated
#
# File c:\Users\USER\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:767, in BaseGrouper.apply(self, f, data, axis)
#     765 # group might be modified
#     766 group_axes = group.axes
# --> 767 res = f(group)
#     768 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     769     mutated = True
#
# Cell In[57], line 19, in test_transform.<locals>.<lambda>(x)
#      16 if 'imcome_cat' not in drop_column:
#      17     df['imcome_cat']=df['imcome_cat'].replace({'Less than $40K':40000, '$40K - $60K':50000, '$60K - $80K':70000, '$80K - $120K':100000, '$120K +':120000, 'Unknown':63000})
# ---> 19 df = df.groupby(groupby_column).apply(lambda x: x.fillna(x.mean(numeric_only=True)))
#      20 df.dropna(axis=0, inplace=True)
#      23 # 결측치 처리
#      24 # ----------
#      25 # after_drop_cnt=len(df)
#      26
#      27 # One-Hot Encoding
#      28 # ----------------
#
# File c:\Users\USER\anaconda3\lib\site-packages\pandas\core\generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\USER\anaconda3\lib\site-packages\pandas\core\generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File c:\Users\USER\anaconda3\lib\site-packages\pandas\core\generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File c:\Users\USER\anaconda3\lib\site-packages\pandas\core\frame.py:10496, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10494 df = self
#   10495 if numeric_only:
# > 10496     df = _get_data()
#   10497 if axis is None:
#   10498     return func(df.values)
#
# File c:\Users\USER\anaconda3\lib\site-packages\pandas\core\frame.py:10486, in DataFrame._reduce.<locals>._get_data()
#   10484 def _get_data() -> DataFrame:
#   10485     if filter_type is None:
# > 10486         data = self._get_numeric_data()
#   10487     else:
#   10488         # GH#25101, GH#24434
#   10489         assert filter_type == "bool"
#
# File c:\Users\USER\anaconda3\lib\site-packages\pandas\core\generic.py:6112, in NDFrame._get_numeric_data(self)
#    6110 @final
#    6111 def _get_numeric_data(self: NDFrameT) -> NDFrameT:
# -> 6112     return self._constructor(self._mgr.get_numeric_data()).__finalize__(self)
#
# File c:\Users\USER\anaconda3\lib\site-packages\pandas\core\internals\managers.py:580, in BaseBlockManager.get_numeric_data(self, copy)
#     578         return self.copy(deep=True)
#     579     return self
# --> 580 return self._combine(numeric_blocks, copy)
#
# File c:\Users\USER\anaconda3\lib\site-packages\pandas\core\internals\managers.py:597, in BaseBlockManager._combine(self, blocks, copy, index)
#     594     return self.make_empty()
#     596 # FIXME: optimization potential
# --> 597 indexer = np.sort(np.concatenate([b.mgr_locs.as_array for b in blocks]))
#     598 inv_indexer = lib.get_reverse_indexer(indexer, self.shape[0])
#     600 new_blocks: list[Block] = []
#
# File <__array_function__ internals>:200, in sort(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:1030, in sort(a, axis, kind, order)
#    1028 else:
#    1029     a = asanyarray(a).copy(order="K")
# -> 1030 a.sort(axis=axis, kind=kind, order=order)
#    1031 return a
#
# KeyboardInterrupt:

# %%
print_eval_result(model_eval_comparison)
# Out:
# <style type="text/css">
# #T_fa977_row0_col0, #T_fa977_row0_col1, #T_fa977_row0_col3, #T_fa977_row5_col4, #T_fa977_row7_col2 {
#   background-color: yellow;
#   color: black;
# }
# #T_fa977_row0_col2, #T_fa977_row0_col4, #T_fa977_row1_col0, #T_fa977_row1_col1, #T_fa977_row1_col2, #T_fa977_row1_col3, #T_fa977_row1_col4, #T_fa977_row2_col0, #T_fa977_row2_col1, #T_fa977_row2_col2, #T_fa977_row2_col3, #T_fa977_row2_col4, #T_fa977_row3_col0, #T_fa977_row3_col1, #T_fa977_row3_col2, #T_fa977_row3_col3, #T_fa977_row3_col4, #T_fa977_row4_col0, #T_fa977_row4_col1, #T_fa977_row4_col2, #T_fa977_row4_col3, #T_fa977_row4_col4, #T_fa977_row5_col0, #T_fa977_row5_col1, #T_fa977_row5_col2, #T_fa977_row5_col3, #T_fa977_row6_col0, #T_fa977_row6_col1, #T_fa977_row6_col2, #T_fa977_row6_col3, #T_fa977_row6_col4, #T_fa977_row7_col0, #T_fa977_row7_col1, #T_fa977_row7_col3, #T_fa977_row7_col4, #T_fa977_row8_col0, #T_fa977_row8_col1, #T_fa977_row8_col2, #T_fa977_row8_col3, #T_fa977_row8_col4, #T_fa977_row9_col0, #T_fa977_row9_col1, #T_fa977_row9_col2, #T_fa977_row9_col3, #T_fa977_row9_col4 {
#   color: black;
# }
# #T_fa977_row0_col6, #T_fa977_row6_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_fa977">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa977_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_fa977_level0_col1" class="col_heading level0 col1" >Accuracy-No</th>
#       <th id="T_fa977_level0_col2" class="col_heading level0 col2" >Accuracy-Yes</th>
#       <th id="T_fa977_level0_col3" class="col_heading level0 col3" >F1-Score</th>
#       <th id="T_fa977_level0_col4" class="col_heading level0 col4" >CV AUC</th>
#       <th id="T_fa977_level0_col5" class="col_heading level0 col5" >CV std</th>
#       <th id="T_fa977_level0_col6" class="col_heading level0 col6" >AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa977_level0_row0" class="row_heading level0 row0" >LightGBM_E_1_16</th>
#       <td id="T_fa977_row0_col0" class="data row0 col0" >95.11%</td>
#       <td id="T_fa977_row0_col1" class="data row0 col1" >97.23%</td>
#       <td id="T_fa977_row0_col2" class="data row0 col2" >84.10%</td>
#       <td id="T_fa977_row0_col3" class="data row0 col3" >95.10%</td>
#       <td id="T_fa977_row0_col4" class="data row0 col4" >99.72%</td>
#       <td id="T_fa977_row0_col5" class="data row0 col5" >0.002504</td>
#       <td id="T_fa977_row0_col6" class="data row0 col6" >0.980661</td>
#     </tr>
#     <tr>
#       <th id="T_fa977_level0_row1" class="row_heading level0 row1" >LightGBM_E_0_13</th>
#       <td id="T_fa977_row1_col0" class="data row1 col0" >94.47%</td>
#       <td id="T_fa977_row1_col1" class="data row1 col1" >96.41%</td>
#       <td id="T_fa977_row1_col2" class="data row1 col2" >84.40%</td>
#       <td id="T_fa977_row1_col3" class="data row1 col3" >94.51%</td>
#       <td id="T_fa977_row1_col4" class="data row1 col4" >99.59%</td>
#       <td id="T_fa977_row1_col5" class="data row1 col5" >0.003808</td>
#       <td id="T_fa977_row1_col6" class="data row1 col6" >0.980458</td>
#     </tr>
#     <tr>
#       <th id="T_fa977_level0_row2" class="row_heading level0 row2" >LightGBM_E_1_13</th>
#       <td id="T_fa977_row2_col0" class="data row2 col0" >94.52%</td>
#       <td id="T_fa977_row2_col1" class="data row2 col1" >96.41%</td>
#       <td id="T_fa977_row2_col2" class="data row2 col2" >84.71%</td>
#       <td id="T_fa977_row2_col3" class="data row2 col3" >94.56%</td>
#       <td id="T_fa977_row2_col4" class="data row2 col4" >99.51%</td>
#       <td id="T_fa977_row2_col5" class="data row2 col5" >0.006373</td>
#       <td id="T_fa977_row2_col6" class="data row2 col6" >0.979445</td>
#     </tr>
#     <tr>
#       <th id="T_fa977_level0_row3" class="row_heading level0 row3" >LightGBM_E_1_10</th>
#       <td id="T_fa977_row3_col0" class="data row3 col0" >95.01%</td>
#       <td id="T_fa977_row3_col1" class="data row3 col1" >97.12%</td>
#       <td id="T_fa977_row3_col2" class="data row3 col2" >84.10%</td>
#       <td id="T_fa977_row3_col3" class="data row3 col3" >95.01%</td>
#       <td id="T_fa977_row3_col4" class="data row3 col4" >99.58%</td>
#       <td id="T_fa977_row3_col5" class="data row3 col5" >0.004501</td>
#       <td id="T_fa977_row3_col6" class="data row3 col6" >0.979178</td>
#     </tr>
#     <tr>
#       <th id="T_fa977_level0_row4" class="row_heading level0 row4" >LightGBM_E_0_10</th>
#       <td id="T_fa977_row4_col0" class="data row4 col0" >95.06%</td>
#       <td id="T_fa977_row4_col1" class="data row4 col1" >97.06%</td>
#       <td id="T_fa977_row4_col2" class="data row4 col2" >84.71%</td>
#       <td id="T_fa977_row4_col3" class="data row4 col3" >95.06%</td>
#       <td id="T_fa977_row4_col4" class="data row4 col4" >99.61%</td>
#       <td id="T_fa977_row4_col5" class="data row4 col5" >0.004498</td>
#       <td id="T_fa977_row4_col6" class="data row4 col6" >0.978894</td>
#     </tr>
#     <tr>
#       <th id="T_fa977_level0_row5" class="row_heading level0 row5" >LightGBM_E_0_16</th>
#       <td id="T_fa977_row5_col0" class="data row5 col0" >94.62%</td>
#       <td id="T_fa977_row5_col1" class="data row5 col1" >97.12%</td>
#       <td id="T_fa977_row5_col2" class="data row5 col2" >81.65%</td>
#       <td id="T_fa977_row5_col3" class="data row5 col3" >94.58%</td>
#       <td id="T_fa977_row5_col4" class="data row5 col4" >99.79%</td>
#       <td id="T_fa977_row5_col5" class="data row5 col5" >0.002707</td>
#       <td id="T_fa977_row5_col6" class="data row5 col6" >0.978795</td>
#     </tr>
#     <tr>
#       <th id="T_fa977_level0_row6" class="row_heading level0 row6" >LightGBM_E_1_7</th>
#       <td id="T_fa977_row6_col0" class="data row6 col0" >94.47%</td>
#       <td id="T_fa977_row6_col1" class="data row6 col1" >96.76%</td>
#       <td id="T_fa977_row6_col2" class="data row6 col2" >82.57%</td>
#       <td id="T_fa977_row6_col3" class="data row6 col3" >94.47%</td>
#       <td id="T_fa977_row6_col4" class="data row6 col4" >99.44%</td>
#       <td id="T_fa977_row6_col5" class="data row6 col5" >0.008166</td>
#       <td id="T_fa977_row6_col6" class="data row6 col6" >0.978662</td>
#     </tr>
#     <tr>
#       <th id="T_fa977_level0_row7" class="row_heading level0 row7" >LightGBM_E_1_17</th>
#       <td id="T_fa977_row7_col0" class="data row7 col0" >93.98%</td>
#       <td id="T_fa977_row7_col1" class="data row7 col1" >95.59%</td>
#       <td id="T_fa977_row7_col2" class="data row7 col2" >85.63%</td>
#       <td id="T_fa977_row7_col3" class="data row7 col3" >94.08%</td>
#       <td id="T_fa977_row7_col4" class="data row7 col4" >99.66%</td>
#       <td id="T_fa977_row7_col5" class="data row7 col5" >0.003987</td>
#       <td id="T_fa977_row7_col6" class="data row7 col6" >0.978514</td>
#     </tr>
#     <tr>
#       <th id="T_fa977_level0_row8" class="row_heading level0 row8" >LightGBM_E_1_5</th>
#       <td id="T_fa977_row8_col0" class="data row8 col0" >94.42%</td>
#       <td id="T_fa977_row8_col1" class="data row8 col1" >96.47%</td>
#       <td id="T_fa977_row8_col2" class="data row8 col2" >83.79%</td>
#       <td id="T_fa977_row8_col3" class="data row8 col3" >94.45%</td>
#       <td id="T_fa977_row8_col4" class="data row8 col4" >99.56%</td>
#       <td id="T_fa977_row8_col5" class="data row8 col5" >0.003547</td>
#       <td id="T_fa977_row8_col6" class="data row8 col6" >0.978111</td>
#     </tr>
#     <tr>
#       <th id="T_fa977_level0_row9" class="row_heading level0 row9" >LightGBM_E_1_9</th>
#       <td id="T_fa977_row9_col0" class="data row9 col0" >94.67%</td>
#       <td id="T_fa977_row9_col1" class="data row9 col1" >96.53%</td>
#       <td id="T_fa977_row9_col2" class="data row9 col2" >85.02%</td>
#       <td id="T_fa977_row9_col3" class="data row9 col3" >94.70%</td>
#       <td id="T_fa977_row9_col4" class="data row9 col4" >99.66%</td>
#       <td id="T_fa977_row9_col5" class="data row9 col5" >0.003657</td>
#       <td id="T_fa977_row9_col6" class="data row9 col6" >0.977936</td>
#     </tr>
#   </tbody>
# </table>
