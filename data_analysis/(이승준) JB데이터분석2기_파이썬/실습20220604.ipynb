# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt       # 그래프를 세부적으로 그리기 위한 옵션 설정
import matplotlib as mpl              # 한글폰트, 글씨체, 음수기호 등 전체적인 옵션 조정

import missingno as msno
# %matplotlib inline      
# NoteBook 내에 그래프 그리기
# %matplotlib tk 는 별도의 창에 그래프를 그리고 직접 그래프의 속성을 변경할 수 있음

# 실수형 포맷
pd.options.display.float_format = '{:0,.5f}'.format 
np.random.seed(12345)

mpl.rc('font', family='NanumGothic')  # 한글 폰트 설정
                                        # 윈도우 폰트 위치 - C:\Windows\Fonts
mpl.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(16, 8))              # 그래프 사이즈 설정
plt.rc('figure', figsize=(16, 8))

# %%
class display(object):
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)
    
    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

# %%
def f():
    print("간단한 함수 호출")
    
f()
# Out:
# 간단한 함수 호출

# %%
def my_func(s):
    text = "전달된 값은 '{}'이고, 길이는 {}입니다.".format(s, len(s))
    return text

my_func("인생은 나그네길")
# Out:
# "전달된 값은 '인생은 나그네길'이고, 길이는 8입니다."

# %%
def my_sum(a, b):
    s = a + b  
    return s  
s = my_sum(10, 20)
print(s)
# Out:
# 30

# %%
def get_sign(x):
    if x > 0:
        return "양수"
    elif x < 0:  
        return "음수"
    else:
        return "영"

for x in [-1, 0, 1]:
    print(get_sign(x))
# Out:
# 음수
# 영
# 양수

# %%
def stat_func(a, b):
    total = a + b
    avg = total / 2
    return total, avg 

stat_func(10, 20)
# Out:
# (30, 15.0)

# %%
s, a = stat_func(10, 20)
print(s)
print(a)
# Out:
# 30
# 15.0

# %%
def f(x, y, z=0):
    print(x, y, z)

f(10, 20, z=50)
# Out:
# 10 20 50

# %%
f(10, 20)
# Out:
# 10 20 0

# %%
lst= [3,4,2,5 ]
sorted(lst)
# Out:
# [2, 3, 4, 5]

# %%
sorted(lst, reverse=True)
# Out:
# [5, 4, 3, 2]

# %%
import math
r=3
area = math.pi * math.pow(r,2)
area
# Out:
# 28.274333882308138

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %%
help(math.pow)
# Out:
# Help on built-in function pow in module math:
#
# pow(x, y, /)
#     Return x**y (x to the power of y).

# %%
import pandas
len(dir(pandas))
# Out:
# 142

# %%
import sys
sys.version
# Out:
# '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]'

# %%
s = 'D-A-D is a Danish rock band. It was originally named "Disneyland After Dark", but changed their name to avoid a lawsuit from The Walt Disney Company'
len(s.split())
# Out:
# 26

# %%
text = '''
(서울=연합뉴스) 문다영 기자 = 한국형 발사체(KSLV-Ⅱ) 누리호 발사일인 15일이 열흘 남짓 앞으로 다가왔다.

4일 과학기술정보통신부(과기정통부)와 한국항공우주연구원(항우연)에 따르면 누리호는 예정된 일정에 따라 전남 고흥군 나로우주센터 발사체 종합조립동에서 순조롭게 조립되고 있다.

점검을 마친 성능검증위성이 누리호 3단에 탑재됐으며, 오는 12일께는 3단과 1·2단의 결합이 이뤄질 것으로 예상된다.

나로우주센터에서 조립을 마친 누리호가 어떻게 발사대로 옮겨져 우주 공간까지 날아가는지, 누리호의 발사 당일 전후 일정을 정리해봤다.

전날 발사대로 이동해 기립…15일 오후 발사 예정
항우연에 따르면 누리호는 발사 전날(14일) 조립동에서 무인특수이동차량(트랜스포터)에 실려 제2발사대로 이동한다.

발사패드까지 수평으로 눕혀서 이동한 누리호는 이렉터(erector)를 이용해 발사패드에 고정돼, 수직으로 기립한다.

제2발사대는 현대중공업이 총괄해 순수 국내 기술로 구축했다. 제1발사대인 나로호 발사대와 달리 지상에 높이 45ｍ의 엄빌리칼(umbilical) 타워를 설치해 발사체에 추진제와 가스류 등 연료를 공급한다.

하늘을 향해 꼿꼿이 선 누리호에 페어링 공조 엄빌리칼, 전기 공급 엄빌리칼 등을 연결하고 연료나 산화제 충전 과정에서 막히거나 새는 곳은 없는지 기밀시험을 한다.

발사 당일인 15일에는 연료와 전기 계통을 중심으로 모든 부분을 종합적으로 점검한다.

발사 4시간 전부터는 연료와 산화제 주입을 위한 절차를 시작하며, 충전을 마치면 기립 장치를 제거한다.

발사 예정 시간까지 모든 기기가 정상상태를 유지하고 주변 환경이 이상이 없다면 10분 전부터는 발사자동운용(PLO) 프로그램을 가동한다.

PLO 프로그램을 통해 자동으로 준비 작업이 이뤄지며, 1단 엔진 추력이 300t에 도달하면 지상고정장치(VHD) 해제 명령이 내려진다.

이때 누리호는 나로우주센터(동경 127.53도, 북위 34.43도)에서 이륙한다. 정확한 발사 시각은 당일에 결정되지만, 지난 1차 발사 때와 비슷하게 오후 3시∼7시에 이뤄질 예정이다.

발사 14분 57초만에 목표 궤도 올라…42분 23초 뒤 첫 위성 신호 수신
누리호는 이륙 이후 2분 7초(127초) 이후 고도 59㎞에서 1단이 분리된다. 3분 53초(233초) 후에는 공기 마찰이 거의 없는 고도 191㎞에서 페어링(위성 등 발사체 탑재물을 보호하는 역할을 하는 덮개)이 분리된다.

발사 후 4분 34초(274초)가 지나면 고도 258㎞에서 2단이 분리되고 3단 엔진이 가동된다.

1단과 페어링, 2단이 분리된 뒤 낙하하는 곳은 각각 발사장에서 약 413㎞, 1천514㎞, 2천800㎞ 떨어진 해상일 것으로 예상된다.

발사 후 14분 57초(897초)에 초속 7.5㎞의 궤도속도에 이르고 고도 700㎞에 오르면 약 180㎏의 성능검증위성이 분리된다.

발사 후 16분 7초(967초)에는 같은 고도인 700㎞에서 1.3t 위성모사체를 분리한다. 위성모사체는 누리호의 사업 목표인 '1.5t 위성 탑재'를 달성하기 위해 실린다.

성능검증위성과 위성모사체가 제대로 분리돼 목표 궤도에 올라가 있는지를 확인하는 데는 데이터 분석이 필요하며, 약 30분 뒤에 성공 여부를 확실히 확인할 수 있다.

누리호의 추적을 위해 나로우주센터와 제주도에서 추적 레이더와 텔레메트리 안테나를 운용한다. 3단 엔진 종료와 위성 분리 등 후반부 비행에 관한 데이터는 서태평양에 있는 팔라우 추적소를 통해 받는다.

성능검증위성의 첫 교신은 발사 후 42분 23초에 남극 세종기지에서 이뤄질 예정이다. 발사 1시간 40분 6초가 지나면 대전 항우연 지상국에서 다시 한번 교신을 시도한다.

발사 약 4시간 뒤에는 세종기지에서 비콘 신호를 확인해 성능검증 위성의 자세가 안정화됐는지를 확인한다.

발사 다음 날부터는 대전 지상국에서 지속해서 교신하며 위성의 상태를 더욱 자세하게 파악할 수 있을 것으로 보인다.
'''

# %%
word_list = text.split()

# %%
word_list[:10]
# Out:
# ['(서울=연합뉴스)',
#  '문다영',
#  '기자',
#  '=',
#  '한국형',
#  '발사체(KSLV-Ⅱ)',
#  '누리호',
#  '발사일인',
#  '15일이',
#  '열흘']

# %%
len(word_list)
# Out:
# 415

# %%
from collections import Counter

cntr = Counter(word_list)
print(cntr.most_common(10))
# Out:
# [('발사', 16), ('누리호는', 5), ('고도', 4), ('후', 4), ('약', 4), ('이뤄질', 3), ('것으로', 3), ('누리호의', 3), ('등', 3), ('위성', 3)]

# %%
from datetime import datetime, timedelta

dt = datetime(1972,10,7)
dt
cur_date = datetime.now()

# %%
cur_date
# Out:
# datetime.datetime(2022, 6, 4, 11, 17, 4, 666983)

# %%
my_dt = cur_date - dt

# %%
my_dt.days
# Out:
# 18137

# %%
now = datetime.today()
now
# Out:
# datetime.datetime(2022, 6, 4, 11, 19, 27, 555230)

# %%
datetime.today()
# Out:
# datetime.datetime(2022, 6, 4, 11, 20, 27, 216088)

# %%
now = datetime.today() + timedelta(hours=9)
now
# Out:
# datetime.datetime(2022, 6, 4, 20, 23, 10, 101228)

# %%
d = datetime(1972,10,7)

# %%
print(f"나의 생일은 {d}. 요일은 {'월화수목금토일'[d.weekday()]}요일 입니다.")
# Out:
# 나의 생일은 1972-10-07 00:00:00. 요일은 토요일 입니다.

# %%
import keyword
print(len(keyword.kwlist))
print(keyword.kwlist)
# Out:
# 35
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
data = {
'A' : [10, 20, 30],
'B' : [40, 50, 60],
'C' : [70, 80, 90],
}
data
# Out:
# {'A': [10, 20, 30], 'B': [40, 50, 60], 'C': [70, 80, 90]}

# %%
import pandas as pd

df = pd.DataFrame(data, index=[1,2,3])
df
# Out:
#     A   B   C
# 1  10  40  70
# 2  20  50  80
# 3  30  60  90

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index
# Out:
# Int64Index([1, 2, 3], dtype='int64')

# %%
df.values
# Out:
# array([[10, 40, 70],
#        [20, 50, 80],
#        [30, 60, 90]], dtype=int64)

# %%
df.A
# Out:
# 1    10
# 2    20
# 3    30
# Name: A, dtype: int64

# %%
df.C
# Out:
# 1    70
# 2    80
# 3    90
# Name: C, dtype: int64

# %%
df.B
# Out:
# 1    40
# 2    50
# 3    60
# Name: B, dtype: int64

# %%
df[['A','B']]
# Out:
#     A   B
# 1  10  40
# 2  20  50
# 3  30  60

# %%
df.B
# Out:
# 1    40
# 2    50
# 3    60
# Name: B, dtype: int64

# %%
df.B.values
# Out:
# array([40, 50, 60], dtype=int64)

# %%
df.B
# Out:
# 1    40
# 2    50
# 3    60
# Name: B, dtype: int64

# %%
df.B.values
# Out:
# array([40, 50, 60], dtype=int64)

# %%
df
# Out:
#     A   B   C
# 1  10  40  70
# 2  20  50  80
# 3  30  60  90

# %%
df[1:2]
# Out:
#     A   B   C
# 2  20  50  80

# %%
df.iloc[1]
# Out:
# A    20
# B    50
# C    80
# Name: 2, dtype: int64

# %%
df.iloc['A']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-3cf21a555a1f> in <module>
# ----> 1 df.iloc['A']
#
# c:\Users\User\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# c:\Users\User\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1496             key = item_from_zerodim(key)
#    1497             if not is_integer(key):
# -> 1498                 raise TypeError("Cannot index by location index with a non-integer key")
#    1499
#    1500             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
df.iloc[1,1]
# Out:
# 50

# %%
df['텔레콤_합계'] = 0

# %%
df
# Out:
#     A   B   C  텔레콤_합계
# 1  10  40  70       0
# 2  20  50  80       0
# 3  30  60  90       0

# %%
df['텔레콤_합계'] = 1+1

# %%
df
# Out:
#     A   B   C  텔레콤_합계
# 1  10  40  70       2
# 2  20  50  80       2
# 3  30  60  90       2

# %%
df = df/100

# %%
df
# Out:
#      A    B    C  텔레콤_합계
# 1  0.1  0.4  0.7    0.02
# 2  0.2  0.5  0.8    0.02
# 3  0.3  0.6  0.9    0.02

# %%
df = df*100

# %%
df
# Out:
#       A     B     C  텔레콤_합계
# 1  10.0  40.0  70.0     2.0
# 2  20.0  50.0  80.0     2.0
# 3  30.0  60.0  90.0     2.0

# %%
df.dtypes
# Out:
# A         float64
# B         float64
# C         float64
# 텔레콤_합계    float64
# dtype: object

# %%
df = df.astype(int)

# %%
df
# Out:
#     A   B   C  텔레콤_합계
# 1  10  40  70       2
# 2  20  50  80       2
# 3  30  60  90       2

# %%
values = {
'삼성전자': [17213058, 15767139, 14289812, 4972074, 23522875, 25040023],
'LG전자': [17695770, 18344561, 14807176, 11391979, 4874541, 17347968],
'현대자동차': [ 7691742, 9932071, 12660962, 9596229, 4993788, 6374132],
'SK텔레콤' : [5811352, 5760428, 6626276, 5834792, 2757485, 3168658],
'KT': [4966225, 2329041, 8914585, 3650543, 5236393, 6835417],
}

dates = pd.to_datetime(['2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03'])

df = pd.DataFrame(values, index=dates)
df
# Out:
#                 삼성전자      LG전자     현대자동차    SK텔레콤       KT
# 2019-10-01  17213058  17695770   7691742  5811352  4966225
# 2019-11-01  15767139  18344561   9932071  5760428  2329041
# 2019-12-01  14289812  14807176  12660962  6626276  8914585
# 2020-01-01   4972074  11391979   9596229  5834792  3650543
# 2020-02-01  23522875   4874541   4993788  2757485  5236393
# 2020-03-01  25040023  17347968   6374132  3168658  6835417

# %%
df.index
# Out:
# DatetimeIndex(['2019-10-01', '2019-11-01', '2019-12-01', '2020-01-01',
#                '2020-02-01', '2020-03-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
df.삼성전자<150
# Out:
# 2019-10-01    False
# 2019-11-01    False
# 2019-12-01    False
# 2020-01-01    False
# 2020-02-01    False
# 2020-03-01    False
# Name: 삼성전자, dtype: bool

# %%
df1 = df/100000
df1
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417

# %%
df1.삼성전자<150
# Out:
# 2019-10-01    False
# 2019-11-01    False
# 2019-12-01     True
# 2020-01-01     True
# 2020-02-01    False
# 2020-03-01    False
# Name: 삼성전자, dtype: bool

# %%
df1[df1.삼성전자<150]
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543

# %%
df1[df1.삼성전자 > df1.삼성전자.mean()]
# Out:
#                  삼성전자       LG전자     현대자동차     SK텔레콤        KT
# 2019-10-01  172.13058  176.95770  76.91742  58.11352  49.66225
# 2020-02-01  235.22875   48.74541  49.93788  27.57485  52.36393
# 2020-03-01  250.40023  173.47968  63.74132  31.68658  68.35417

# %%
df.삼성전자 > 150
# Out:
# 2019-10-01    True
# 2019-11-01    True
# 2019-12-01    True
# 2020-01-01    True
# 2020-02-01    True
# 2020-03-01    True
# Name: 삼성전자, dtype: bool

# %%
df1[(df1.삼성전자 > 150) & (df1.삼성전자 < 200)]
# Out:
#                  삼성전자       LG전자     현대자동차     SK텔레콤        KT
# 2019-10-01  172.13058  176.95770  76.91742  58.11352  49.66225
# 2019-11-01  157.67139  183.44561  99.32071  57.60428  23.29041

# %%
df1.query('150 < 삼성전자<200')
# Out:
#                  삼성전자       LG전자     현대자동차     SK텔레콤        KT
# 2019-10-01  172.13058  176.95770  76.91742  58.11352  49.66225
# 2019-11-01  157.67139  183.44561  99.32071  57.60428  23.29041

# %%
df1.sort_index()
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417

# %%
df1.sort_index(ascending=False)
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225

# %%
df1.sort_values(by="삼성전자", ascending=False)
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543

# %%
df1[['삼성전자', 'LG전자']].plot()
# Out:
# <AxesSubplot:>

# %%
# %matplotlib inline

# %%
df1.plot(figsize=(10,6), title='광고비(월별)')
# Out:
# <AxesSubplot:title={'center':'광고비(월별)'}>

# %%
import pandas as pd

s = pd.Series([7,0,-3,8,1])
s
# Out:
# 0    7
# 1    0
# 2   -3
# 3    8
# 4    1
# dtype: int64

# %%
data = [7,0,-3,8,1]
inx = ['A','B','C','D','E']

s = pd.Series(data, index=inx)
s
# Out:
# A    7
# B    0
# C   -3
# D    8
# E    1
# dtype: int64

# %%
s[0] # 7
# Out:
# 7

# %%
s['A'] # 7
# Out:
# 7

# %%
import pandas as pd

data = {
    'A':[10,20,30],
    'B':[40,50,60],
    'C':[70,80,90]
}
df = pd.DataFrame(data, index=[1,2,3])
df
# Out:
#     A   B   C
# 1  10  40  70
# 2  20  50  80
# 3  30  60  90

# %%
values = [[10,20,30], [40,50,60], [70,80,90]]
index=[1,2,3]
columns=['A','B','C']

df = pd.DataFrame(values, index=index, columns=columns)
df
# Out:
#     A   B   C
# 1  10  20  30
# 2  40  50  60
# 3  70  80  90

# %%
df.head(2)
# Out:
#     A   B   C
# 1  10  20  30
# 2  40  50  60

# %%
df.tail(2)
# Out:
#     A   B   C
# 2  40  50  60
# 3  70  80  90

# %%
df[df.A >= 50]
# Out:
#     A   B   C
# 3  70  80  90

# %%
df
# Out:
#     A   B   C
# 1  10  20  30
# 2  40  50  60
# 3  70  80  90

# %%
df.iloc[1:3]
# Out:
#     A   B   C
# 2  40  50  60
# 3  70  80  90

# %%
df.iloc[:,[1, 0]]
# Out:
#     B   A
# 1  20  10
# 2  50  40
# 3  80  70

# %%
df.loc[:,'A':'B']
# Out:
#     A   B
# 1  10  20
# 2  40  50
# 3  70  80

# %%
df.loc[df['B']>40, ['B','A']]
# Out:
#     B   A
# 2  50  40
# 3  80  70

# %%
df.loc[df['B']>40, ['A','B']]
# Out:
#     A   B
# 2  40  50
# 3  70  80

# %%
df.loc[:, ['A','B']]
# Out:
#     A   B
# 1  10  20
# 2  40  50
# 3  70  80

# %%
df.iloc[:,0:2]
# Out:
#     A   B
# 1  10  20
# 2  40  50
# 3  70  80

# %%
df.iloc[1:2, :]
# Out:
#     A   B   C
# 2  40  50  60

# %%
df[['A','B']]
# Out:
#     A   B
# 1  10  20
# 2  40  50
# 3  70  80

# %%
pd.to_datetime('2022-5-1')
# Out:
# Timestamp('2022-05-01 00:00:00')

# %%
pd.to_datetime(['2022-5-01','1 May 2002', '20020101'])
# Out:
# DatetimeIndex(['2022-05-01', '2002-05-01', '2002-01-01'], dtype='datetime64[ns]', freq=None)

# %%
df1
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417

# %%
df1.to_excel('기업별광고비.xlsx')

# %%
 # !dir
# Out:
#  C ����̺��� �������� �̸��� �����ϴ�.
#  ���� �Ϸ� ��ȣ: 34CA-6DBE
#
#  c:\Users\User\Quick_Ref\data_analysis\JB�����ͺм�2��_���̽�_�̽��� ���͸�
#
# 2022-06-04  ���� 02:37    <DIR>          .
# 2022-06-04  ���� 02:37    <DIR>          ..
# 2022-05-28  ���� 03:34           305,602 Colab �ǽ� 01.ipynb
# 2022-06-04  ���� 02:37             5,868 �����������.xlsx
# 2022-06-04  ���� 02:03            53,510 �ǽ�20220604.ipynb
#                3�� ����             364,980 ����Ʈ
#                2�� ���͸�   8,614,563,840 ����Ʈ ����

# %%
df = pd.read_excel('기업별광고비.xlsx', index_col=0)

# %%
df
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6 entries, 2019-10-01 to 2020-03-01
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   삼성전자    6 non-null      float64
#  1   LG전자    6 non-null      float64
#  2   현대자동차   6 non-null      float64
#  3   SK텔레콤   6 non-null      float64
#  4   KT      6 non-null      float64
# dtypes: float64(5)
# memory usage: 288.0 bytes

# %%
df
# Out:
#   Unnamed: 0       삼성전자       LG전자      현대자동차     SK텔레콤        KT
# 0 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225
# 1 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041
# 2 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585
# 3 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543
# 4 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393
# 5 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417

# %%
df1
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417

# %%
df.loc[:,['SK텔레콤','KT']]
# Out:
#                SK텔레콤        KT
# 2019-10-01  58.11352  49.66225
# 2019-11-01  57.60428  23.29041
# 2019-12-01  66.26276  89.14585
# 2020-01-01  58.34792  36.50543
# 2020-02-01  27.57485  52.36393
# 2020-03-01  31.68658  68.35417

# %%
df['텔레콤_합계'] = 0

# %%
df['텔레콤_합계'] = df['SK텔레콤'] + df['KT']
df
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT     텔레콤_합계
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225  107.77577
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041   80.89469
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585  155.40861
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543   94.85335
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393   79.93878
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417  100.04075

# %%
df['전자합계'] = df['삼성전자'] + df['LG전자']
df
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT     텔레콤_합계  \
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225  107.77577
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041   80.89469
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585  155.40861
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543   94.85335
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393   79.93878
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417  100.04075
#
#                  전자합계
# 2019-10-01  349.08828
# 2019-11-01  341.11700
# 2019-12-01  290.96988
# 2020-01-01  163.64053
# 2020-02-01  283.97416
# 2020-03-01  423.87991

# %%
df.drop('텔레콤_합계', axis=1)
# Out:
#                  삼성전자       LG전자      현대자동차     SK텔레콤        KT       전자합계
# 2019-10-01  172.13058  176.95770   76.91742  58.11352  49.66225  349.08828
# 2019-11-01  157.67139  183.44561   99.32071  57.60428  23.29041  341.11700
# 2019-12-01  142.89812  148.07176  126.60962  66.26276  89.14585  290.96988
# 2020-01-01   49.72074  113.91979   95.96229  58.34792  36.50543  163.64053
# 2020-02-01  235.22875   48.74541   49.93788  27.57485  52.36393  283.97416
# 2020-03-01  250.40023  173.47968   63.74132  31.68658  68.35417  423.87991

# %%
df.query('삼성전자>삼성전자.mean()')
# Out:
#                  삼성전자       LG전자     현대자동차     SK텔레콤        KT     텔레콤_합계  \
# 2019-10-01  172.13058  176.95770  76.91742  58.11352  49.66225  107.77577
# 2020-02-01  235.22875   48.74541  49.93788  27.57485  52.36393   79.93878
# 2020-03-01  250.40023  173.47968  63.74132  31.68658  68.35417  100.04075
#
#                  전자합계
# 2019-10-01  349.08828
# 2020-02-01  283.97416
# 2020-03-01  423.87991

# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("https://finance.naver.com/sise/")
soup = BeautifulSoup(r.text)
tag = soup.find(id="KOSPI_now")
kospi = float(tag.text.replace(",",""))
kospi
# Out:
# 2670.65

# %%
import requests
from bs4 import BeautifulSoup

def finance_index(id_str):
    r = requests.get("https://finance.naver.com/sise/")
    soup = BeautifulSoup(r.text)
    tag = soup.find(id=id_str)
    return float(tag.text.replace(",",""))

print(finance_index('KOSPI_now'))
print(finance_index('KOSDAQ_now'))
print(finance_index('KPI200_now'))
# Out:
# 2670.65
# 891.51
# 352.01

# %%
import pandas as pd
from datetime import datetime

datetime.now().strftime('%Y%m%d')

df_list = pd.read_html("https://finance.naver.com/marketindex/", encoding='euc-kr')
df = df_list[0]
df
df.loc[[1]]
df.to_excel(f"국내시장금리_{datetime.now().strftime('%Y%m%d')}.xlsx")

# %%
# Out:
#             구분    금리   등락율
# 0    CD금리(91일)  1.96  0.00
# 1         콜 금리  1.70  0.16
# 2     국고채 (3년)  3.12  0.00
# 3     회사채 (3년)  3.89  0.00
# 4     COFIX 잔액  1.58  0.08
# 5  COFIX 신규취급액  1.84  0.12

# %%
df_list[1]
# Out:
#        구분      금리   등락율
# 0  달러 인덱스  102.16  0.33

# %%
df_list[2]
# Out:
# Empty DataFrame
# Columns: [업체명, 거래량, 전일비]
# Index: []

# %%
from datetime import datetime

dt = datetime.now()
dt.strftime('%Y%m%d')
# Out:
# '20220604'

# %%
import pandas as pd
from datetime import datetime

datetime.now().strftime('%Y%m%d')

for num in range(1,10):
    df_list = pd.read_html(f"https://finance.naver.com/sise/sise_market_sum.naver?&page={num}", encoding='euc-kr')
    df = df_list[0]
    df
    df.loc[[1]]
    df.to_excel(f"국내시장금리_{datetime.now().strftime('%Y%m%d')}.xlsx")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
import numpy as np 
df_list = pd.read_html(f"https://finance.naver.com/sise/sise_market_sum.naver?&page=1", encoding='euc-kr')
df = df_list[1]

df.N == np.nan
# df[df["N"] ==np.nan]
# .dropna(axis=0)
# df
# df.loc[[1]]
# df.to_excel(f"국내시장금리_{datetime.now().strftime('%Y%m%d')}.xlsx")
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 76    False
# 77    False
# 78    False
# 79    False
# 80    False
# Name: N, Length: 81, dtype: bool

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://kosis.kr/visual/nsportalStats/index.do?menuId=all&&mb=N"
r = requests.get(url)
soup = BeautifulSoup(r.text)
# Out:
# <title>KOSIS 100대 지표</title>

# %%
soup.title
# Out:
# <title>KOSIS 100대 지표</title>

# %%
soup.title.text
# Out:
# 'KOSIS 100대 지표'

# %%
# find(), find_all()
tag = soup.find("title")
tag.text
# Out:
# 'KOSIS 100대 지표'

# %%
right_list = soup.find_all("span", {"class":"textRight"})

# %%
len(right_list)
# Out:
# 100

# %%
right_list[0]
# Out:
# <span class="textRight">
#
# 						  51,628,117
#
# 					  </span>

# %%
right_list[0].text
# Out:
# '\r\n\t\t\t\t\t\t  \r\n\t\t\t\t\t\t  51,628,117\r\n\t\t\t\t\t\t  \r\n\t\t\t\t\t  '

# %%
right_list[0].text.strip()
# Out:
# '51,628,117'

# %%
right_list[0].text.strip().replace(",","")
# Out:
# '51628117'

# %%
float(right_list[0].text.strip().replace(",",""))
# Out:
# 51628117.0

# %%
left_list = soup.find_all("span", {"class":"textLeft"})
left_list[0]
# Out:
# <span class="textLeft">
# <img alt="주기" class="Y" src="#" style="padding-bottom:6px;padding-top:0px;text-align:justify;"/>
# <a href="/visual/nsportalStats/detail.do;jsessionid=zh17Xx87sgEKm7wHbTcAJHNu7xuF8RYIbWvIINqCL7YI3FPH7c0ogtHYiUxEaW84.STAT_SIGA1_servlet_engine4?menuId=10&amp;NUM=1001&amp;cntUpdate=Y" style="padding-bottom:6px;padding-top:0px;position:absolute;" title="추계인구('22)">
# 					  	추계인구('22)
#
# 					  </a>
# </span>

# %%
left_list[0].text.strip()
# Out:
# "추계인구('22)"

# %%
# 정리
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://kosis.kr/visual/nsportalStats/index.do?menuId=all&&mb=N"
r = requests.get(url)
soup = BeautifulSoup(r.text)

left_list = soup.find_all("span", {"class":"textLeft"})
names = [tag.text.strip() for tag in left_list]

right_list = soup.find_all("span", {"class":"textRight"})
values = [float(tag.text.strip().replace(",","")) for tag in right_list]

df = pd.DataFrame({'항목':names, '값':values})
df.to_excel("100대통계지표.xlsx")

# %%
df.loc[98, '값']
# Out:
# 701.37

# %%
df.loc[[98]], df.iloc[[98]]
# Out:
# (               항목       값
#  98  온실가스총배출량('19)  701.37,
#                 항목       값
#  98  온실가스총배출량('19)  701.37)

# %%
stock_list = [
 ["삼성전자", "005930"],
 ["SK하이닉스", "000660"],
 ["삼성전자우", "005935"],
 ["삼성바이오로직스", "207940"],
 ["NAVER", "035420"],
 ["셀트리온", "068270"],
 ["LG화학", "051910"],
 ["LG생활건강", "051900"],
 ["JB금융지주", "175330"]
]

# %%
import requests

def stock_factor(code):
    url = f'https://finance.naver.com/item/main.nhn?code={code}'
    r = requests.get(url)
    soup = BeautifulSoup(r.text)
    per = float(soup.find(id='_per').text.replace(',',''))
    eps = float(soup.find(id='_per').text.replace(',',''))
    
    return per, eps


row_list = []
for name, code in stock_list:
    per, eps = stock_factor(code)
    row_list.append([name, code, per,eps])

df = pd.DataFrame(row_list, columns=['종목명','코드','PER','EPS'])
df
# Out:
#         종목명      코드     PER     EPS
# 0      삼성전자  005930   10.01   10.01
# 1    SK하이닉스  000660    7.11    7.11
# 2     삼성전자우  005935    9.18    9.18
# 3  삼성바이오로직스  207940  113.24  113.24
# 4     NAVER  035420   32.83   32.83
# 5      셀트리온  068270   44.87   44.87
# 6      LG화학  051910   14.96   14.96
# 7    LG생활건강  051900   17.03   17.03
# 8    JB금융지주  175330    3.09    3.09

# %%
   
    
    
for stock in stock_list:
    url=f"https://finance.naver.com/item/main.nhn?code={stock[1]}"
    r = requests.get(url)
    soup = BeautifulSoup(r.text)
    
    per = float(soup.find(id='_per').text.replace(',',''))
    eps = float(soup.find(id='_eps').text.replace(',',''))
    
    print(f'{stock[0]} {stock[1]} {per} {eps}')
    
    
    # per = soup.find("em", {"id:_per"})
    # eps = soup.find("em", {"id:_eps"})
    # print(per)
    
    #print(f"{stock[0]} {per.text} {eps.text}")
# Out:
# 삼성전자 005930 10.01 6372.0
# SK하이닉스 000660 7.11 14548.0
# 삼성전자우 005935 9.18 6372.0
# 삼성바이오로직스 207940 113.24 7162.0
# NAVER 035420 32.83 8225.0
# 셀트리온 068270 44.87 3555.0
# LG화학 051910 14.96 38978.0
# LG생활건강 051900 17.03 39459.0
# JB금융지주 175330 3.09 2747.0

# %%
tag = sou#p.find("em", {"id":"_per"})
tag.text
# Out:
# '10.01'

# %%
import requests

def stock_factor(code):
    url = f'https://finance.naver.com/item/main.nhn?code={code}'
    r = requests.get(url)
    soup = BeautifulSoup(r.text)
    per = float(soup.find(id='_per').text.replace(',',''))
    eps = float(soup.find(id='_per').text.replace(',',''))
    
    return per, eps
    

stock_factor('005930')
# Out:
# (10.01, 10.01)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url='http://ecos.bok.or.kr/api/KeyStatisticList/AYLTA7EZ4TA23QVXUEM4/json/kr/1/100'
r = requests.get(url)
j = r.json()

df = pd.json_normalize(j['KeyStatisticList']['row'])
df


#j['KeyStatisticList']['row']
# soup = BeautifulSoup(r.text)
# soup
# Out:
#    CLASS_NAME     KEYSTAT_NAME  DATA_VALUE     CYCLE   UNIT_NAME
# 0        시장금리        한국은행 기준금리        1.75  20220608          %
# 1        시장금리         콜금리(익일물)       1.793  20220609          %
# 2        시장금리     KORIBOR(3개월)        1.96  20220610          %
# 3        시장금리       CD수익률(91일)        1.96  20220610          %
# 4        시장금리    통안증권수익률(364일)       2.329  20220610          %
# ..        ...              ...         ...       ...         ...
# 95     부동산 가격         주택매매가격지수  104.829612    202204  2021.6=100
# 96     부동산 가격         주택전세가격지수  103.236549    202204  2021.6=100
# 97     부동산 가격      지가변동률(전기대비)       0.318    202204          %
# 98        원자재  국제유가(Dubai, 현물)       117.1    202205         달러
# 99        원자재                금     1837.36    202205         달러
#
# [100 rows x 5 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# %matplotlib inline

url='http://ecos.bok.or.kr/api/StatisticSearch/AYLTA7EZ4TA23QVXUEM4/json/kr/1/100/901Y009/M/201501/300001/0'
r = requests.get(url)
j = r.json()

df = pd.json_normalize(j['StatisticSearch']['row'])
cpi = df[['TIME', 'DATA_VALUE']].copy()
cpi
cpi['TIME'] = pd.to_datetime(cpi['TIME'], format='%Y%m')
cpi['DATA_VALUE'] = pd.to_numeric(cpi['DATA_VALUE'])
cpi = cpi.set_index('TIME')
cpi.plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='TIME'>

# %%
value = {"A":[1,2,3,4],
        "B":[2,3,4,5]}
df = pd.DataFrame(value)
df
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4
# 3  4  5

# %%
df.sum()
# Out:
# A    10
# B    14
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# 0    3
# 1    5
# 2    7
# 3    9
# dtype: int64

# %%
df.sum().sum()
# Out:
# 24

# %%
df.sum()['A']
# Out:
# 10

# %%
import pandas as pd

data = [
  [  10,   20, None, 100], 
  [  20,   20, None, 200], 
  [None, None, None, None],
  [None, None, None, 400],
]

# %%
data
# Out:
# [[10, 20, None, 100],
#  [20, 20, None, 200],
#  [None, None, None, None],
#  [None, None, None, 400]]

# %%
df = pd.DataFrame(data, columns=list('ABCD'))
df
# Out:
#       A     B     C      D
# 0  10.0  20.0  None  100.0
# 1  20.0  20.0  None  200.0
# 2   NaN   NaN  None    NaN
# 3   NaN   NaN  None  400.0

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
df.dropna(how='all')
# Out:
#       A     B     C      D
# 0  10.0  20.0  None  100.0
# 1  20.0  20.0  None  200.0
# 3   NaN   NaN  None  400.0

# %%
df.dropna(how='all', axis=1)
# Out:
#       A     B      D
# 0  10.0  20.0  100.0
# 1  20.0  20.0  200.0
# 2   NaN   NaN    NaN
# 3   NaN   NaN  400.0

# %%
df
# Out:
#          A        B     C         D
# 0 10.00000 20.00000  None 100.00000
# 1 20.00000 20.00000  None 200.00000
# 2      NaN      NaN  None       NaN
# 3      NaN      NaN  None 400.00000

# %%
df.mean()
# Out:
# A    15.00000
# B    20.00000
# C         NaN
# D   233.33333
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 0    43.33333
# 1    80.00000
# 2         NaN
# 3   400.00000
# dtype: float64

# %%
df.fillna(df.mean())
# Out:
#          A        B   C         D
# 0 10.00000 20.00000 NaN 100.00000
# 1 20.00000 20.00000 NaN 200.00000
# 2 15.00000 20.00000 NaN 233.33333
# 3 15.00000 20.00000 NaN 400.00000

# %%
df
# Out:
#          A        B     C         D
# 0 10.00000 20.00000  None 100.00000
# 1 20.00000 20.00000  None 200.00000
# 2      NaN      NaN  None       NaN
# 3      NaN      NaN  None 400.00000

# %%
df.fillna(value=0)
# Out:
#          A        B  C         D
# 0 10.00000 20.00000  0 100.00000
# 1 20.00000 20.00000  0 200.00000
# 2  0.00000  0.00000  0   0.00000
# 3  0.00000  0.00000  0 400.00000

# %%
data = [
  [  10,   20, None, 100], 
  [  20,   20,   80, 200], 
  [  30,   40, None, 300],
  [None, None,  400, 400],
]

df = pd.DataFrame(data, columns=list('ABCD'))
df
# Out:
#          A        B         C    D
# 0 10.00000 20.00000       NaN  100
# 1 20.00000 20.00000  80.00000  200
# 2 30.00000 40.00000       NaN  300
# 3      NaN      NaN 400.00000  400

# %%
df.fillna(0)
# Out:
#          A        B         C    D
# 0 10.00000 20.00000   0.00000  100
# 1 20.00000 20.00000  80.00000  200
# 2 30.00000 40.00000   0.00000  300
# 3  0.00000  0.00000 400.00000  400

# %%
df.fillna(-1)
# Out:
#          A        B         C    D
# 0 10.00000 20.00000  -1.00000  100
# 1 20.00000 20.00000  80.00000  200
# 2 30.00000 40.00000  -1.00000  300
# 3 -1.00000 -1.00000 400.00000  400

# %%
df.fillna(df.mean())
# Out:
#          A        B         C    D
# 0 10.00000 20.00000 240.00000  100
# 1 20.00000 20.00000  80.00000  200
# 2 30.00000 40.00000 240.00000  300
# 3 20.00000 26.66667 400.00000  400

# %%
df_01 = pd.DataFrame([[11, 12, 13], [14, 15, 16]], columns=list('ABC'))
df_01
# Out:
#     A   B   C
# 0  11  12  13
# 1  14  15  16

# %%
df_02 = pd.DataFrame([[21, 22, 23], [24, 25, 26]], columns=list('ABC'))
df_02
# Out:
#     A   B   C
# 0  21  22  23
# 1  24  25  26

# %%
pd.concat([df_01, df_02])
# Out:
#     A   B   C
# 0  11  12  13
# 1  14  15  16
# 0  21  22  23
# 1  24  25  26

# %%
df_01 = pd.DataFrame([[11, 12], [14, 15]], columns=list('AB'))
df_01
# Out:
#     A   B
# 0  11  12
# 1  14  15

# %%
df_02 = pd.DataFrame([[21, 22], [24, 25]], columns=list('CD'))
df_02
# Out:
#     C   D
# 0  21  22
# 1  24  25

# %%
pd.concat([df_01, df_02])
# Out:
#          A        B        C        D
# 0 11.00000 12.00000      NaN      NaN
# 1 14.00000 15.00000      NaN      NaN
# 0      NaN      NaN 21.00000 22.00000
# 1      NaN      NaN 24.00000 25.00000

# %%
pd.concat([df_01, df_02], axis=1)
# Out:
#     A   B   C   D
# 0  11  12  21  22
# 1  14  15  24  25

# %%
관심종목 = [
  ['005930', '삼성전자'],
  ['017670', 'SK텔레콤'],
  ['105560', 'KB금융'],
]

배당 = [
  ['005930', '삼성전자', 21000.0, 1.05],
  ['000660', 'SK하이닉스', 500.0, 1.02],
  ['005380', '현대차', 4000.0, 2.74],
  ['105560', 'KB금융', 980.0, 2.0],
  ['015760', '한국전력', 3100.0, 7.45],
]

df1 = pd.DataFrame(관심종목, columns=['종목코드', '종목명'])
df2 = pd.DataFrame(배당, columns=['종목코드', '종목명', '주당배당금', '배당수익률'])

# %%
df1
# Out:
#      종목코드    종목명
# 0  005930   삼성전자
# 1  017670  SK텔레콤
# 2  105560   KB금융

# %%
df2
# Out:
#      종목코드     종목명        주당배당금   배당수익률
# 0  005930    삼성전자 21,000.00000 1.05000
# 1  000660  SK하이닉스    500.00000 1.02000
# 2  005380     현대차  4,000.00000 2.74000
# 3  105560    KB금융    980.00000 2.00000
# 4  015760    한국전력  3,100.00000 7.45000

# %%
pd.merge(df1, df2)
# Out:
#      종목코드   종목명        주당배당금   배당수익률
# 0  005930  삼성전자 21,000.00000 1.05000
# 1  105560  KB금융    980.00000 2.00000

# %%
pd.merge(df1, df2, how='left')
# Out:
#      종목코드    종목명        주당배당금   배당수익률
# 0  005930   삼성전자 21,000.00000 1.05000
# 1  017670  SK텔레콤          NaN     NaN
# 2  105560   KB금융    980.00000 2.00000

# %%
pd.merge(df1, df2, how='outer')
# Out:
#      종목코드     종목명        주당배당금   배당수익률
# 0  005930    삼성전자 21,000.00000 1.05000
# 1  017670   SK텔레콤          NaN     NaN
# 2  105560    KB금융    980.00000 2.00000
# 3  000660  SK하이닉스    500.00000 1.02000
# 4  005380     현대차  4,000.00000 2.74000
# 5  015760    한국전력  3,100.00000 7.45000

# %%
관심종목 = [
  ['005930', '삼성전자'],
  ['017670', 'SK텔레콤'],
  ['105560', 'KB금융'],
]

배당 = [
  ['005930', '삼성전자', 21000.0, 1.05],
  ['000660', 'SK하이닉스', 500.0, 1.02],
  ['005380', '현대차', 4000.0, 2.74],
  ['105560', 'KB금융', 980.0, 2.0],
  ['015760', '한국전력', 3100.0, 7.45],
]

df1 = pd.DataFrame(관심종목, columns=['종목코드', '종목명'])
df2 = pd.DataFrame(배당, columns=['종목코드', '종목명', '주당배당금', '배당수익률'])

# %%
df1 = df1.set_index('종목코드')
df1
# Out:
#           종목명
# 종목코드
# 005930   삼성전자
# 017670  SK텔레콤
# 105560   KB금융

# %%
df2 = df2.set_index('종목코드')
df2
# Out:
#            종목명        주당배당금   배당수익률
# 종목코드
# 005930    삼성전자 21,000.00000 1.05000
# 000660  SK하이닉스    500.00000 1.02000
# 005380     현대차  4,000.00000 2.74000
# 105560    KB금융    980.00000 2.00000
# 015760    한국전력  3,100.00000 7.45000

# %%
df1[['주당배당금', '배당수익률']] = df2[['주당배당금', '배당수익률']]
df1
# Out:
#           종목명        주당배당금   배당수익률
# 종목코드
# 005930   삼성전자 21,000.00000 1.05000
# 017670  SK텔레콤          NaN     NaN
# 105560   KB금융    980.00000 2.00000

# %%
import pandas as pd

data = [
  ['2013-01', 'KT', 60.30],
  ['2013-02', 'KT', 69.60],
  ['2013-03', 'KT', 64.38],
  ['2013-01', 'SKT', 52.77],
  ['2013-02', 'SKT', 95.23],
  ['2013-03', 'SKT', 84.20],
]

df = pd.DataFrame(data, columns=['month', 'corp', 'ad_exp'])
df
# Out:
#      month corp   ad_exp
# 0  2013-01   KT 60.30000
# 1  2013-02   KT 69.60000
# 2  2013-03   KT 64.38000
# 3  2013-01  SKT 52.77000
# 4  2013-02  SKT 95.23000
# 5  2013-03  SKT 84.20000

# %%
df.pivot( index='month', columns='corp', values='ad_exp' )
# Out:
# corp          KT      SKT
# month
# 2013-01 60.30000 52.77000
# 2013-02 69.60000 95.23000
# 2013-03 64.38000 84.20000

# %%
import pandas as pd

data = [
  ['1', 'A', 10],
  ['1', 'A', 20],
  ['2', 'A', 30],
  ['2', 'B', 40],
]

df = pd.DataFrame(data, columns=['ix', 'col', 'val'])
df
# Out:
#   ix col  val
# 0  1   A   10
# 1  1   A   20
# 2  2   A   30
# 3  2   B   40

# %%
df.pivot_table(index='ix', columns='col', values='val', aggfunc='sum')
# Out:
# col        A        B
# ix
# 1   30.00000      NaN
# 2   30.00000 40.00000

# %%
import pandas as pd

data = [
  ['2013-01', 'KT', 50.30],
  ['2013-01', 'KT', 10.09],
  ['2013-02', 'KT', 69.60],
  ['2013-03', 'KT', 64.38],
  ['2013-01', 'SKT', 52.77],
  ['2013-02', 'SKT', 95.23],
  ['2013-03', 'SKT', 84.20],
]

df = pd.DataFrame(data, columns=['month', 'corp', 'ad_exp'])
df
# Out:
#      month corp   ad_exp
# 0  2013-01   KT 50.30000
# 1  2013-01   KT 10.09000
# 2  2013-02   KT 69.60000
# 3  2013-03   KT 64.38000
# 4  2013-01  SKT 52.77000
# 5  2013-02  SKT 95.23000
# 6  2013-03  SKT 84.20000

# %%
df.pivot_table( index='month', columns='corp', values='ad_exp' )
# Out:
# corp          KT      SKT
# month
# 2013-01 30.19500 52.77000
# 2013-02 69.60000 95.23000
# 2013-03 64.38000 84.20000

# %%
df.pivot_table( index='month', columns='corp', values='ad_exp', aggfunc='sum')
# Out:
# corp          KT      SKT
# month
# 2013-01 60.39000 52.77000
# 2013-02 69.60000 95.23000
# 2013-03 64.38000 84.20000

# %%
df.pivot_table( index='month', columns='corp', values='ad_exp', aggfunc='sum', margins=True)
# Out:
# corp           KT       SKT       All
# month
# 2013-01  60.39000  52.77000 113.16000
# 2013-02  69.60000  95.23000 164.83000
# 2013-03  64.38000  84.20000 148.58000
# All     194.37000 232.20000 426.57000

# %%
import pandas as pd
# 리스트로 부터 생성하기

values = [
  ['2019-10', 17213058, 17695770, 7691742, 5811352, 4966225],
  ['2019-11', 15767139, 18344561, 9932071, 5760428, 2329041],
  ['2019-12', 14289812, 14807176, 12660962, 6626276, 8914585],
  ['2020-01', 4972074, 11391979, 9596229, 5834792, 3650543],
  ['2020-02', 23522875, 4874541, 4993788, 2757485, 5236393],
  ['2020-03', 25040023, 17347968, 6374132, 3168658, 6835417],
]

cols = ['날짜', '삼성전자', 'LG전자', '현대자동차', 'SK텔레콤', 'KT']
df = pd.DataFrame(values, columns=cols)
df['날짜'] = pd.to_datetime(df['날짜'])
df = df.set_index('날짜')
df
# Out:
#                 삼성전자      LG전자     현대자동차    SK텔레콤       KT
# 날짜
# 2019-10-01  17213058  17695770   7691742  5811352  4966225
# 2019-11-01  15767139  18344561   9932071  5760428  2329041
# 2019-12-01  14289812  14807176  12660962  6626276  8914585
# 2020-01-01   4972074  11391979   9596229  5834792  3650543
# 2020-02-01  23522875   4874541   4993788  2757485  5236393
# 2020-03-01  25040023  17347968   6374132  3168658  6835417

# %%
# 특정 컬럼만 지정해서 그리기
df[['삼성전자', 'LG전자']].plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:xlabel='날짜'>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:ylabel='날짜'>

# %%
import seaborn as sns
df = sns.load_dataset("mpg")
df
# Out:
#          mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.00000          8     307.00000   130.00000    3504      12.00000
# 1   15.00000          8     350.00000   165.00000    3693      11.50000
# 2   18.00000          8     318.00000   150.00000    3436      11.00000
# 3   16.00000          8     304.00000   150.00000    3433      12.00000
# 4   17.00000          8     302.00000   140.00000    3449      10.50000
# ..       ...        ...           ...         ...     ...           ...
# 393 27.00000          4     140.00000    86.00000    2790      15.60000
# 394 44.00000          4      97.00000    52.00000    2130      24.60000
# 395 32.00000          4     135.00000    84.00000    2295      11.60000
# 396 28.00000          4     120.00000    79.00000    2625      18.60000
# 397 31.00000          4     119.00000    82.00000    2720      19.40000
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.sort_values('mpg', ascending=False)
# Out:
#          mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322 46.60000          4      86.00000    65.00000    2110      17.90000
# 329 44.60000          4      91.00000    67.00000    1850      13.80000
# 325 44.30000          4      90.00000    48.00000    2085      21.70000
# 394 44.00000          4      97.00000    52.00000    2130      24.60000
# 326 43.40000          4      90.00000    48.00000    2335      23.70000
# ..       ...        ...           ...         ...     ...           ...
# 103 11.00000          8     400.00000   150.00000    4997      14.00000
# 67  11.00000          8     429.00000   208.00000    4633      11.00000
# 25  10.00000          8     360.00000   215.00000    4615      14.00000
# 26  10.00000          8     307.00000   200.00000    4376      15.00000
# 28   9.00000          8     304.00000   193.00000    4732      18.50000
#
#      model_year  origin                  name
# 322          80   japan             mazda glc
# ...

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0       5.10000      3.50000       1.40000      0.20000  setosa
# 1       4.90000      3.00000       1.40000      0.20000  setosa
# 2       4.70000      3.20000       1.30000      0.20000  setosa
# 3       4.60000      3.10000       1.50000      0.20000  setosa
# 4       5.00000      3.60000       1.40000      0.20000  setosa

# %%
df.filter(regex='^sepal')
# Out:
#      sepal_length  sepal_width
# 0         5.10000      3.50000
# 1         4.90000      3.00000
# 2         4.70000      3.20000
# 3         4.60000      3.10000
# 4         5.00000      3.60000
# ..            ...          ...
# 145       6.70000      3.00000
# 146       6.30000      2.50000
# 147       6.50000      3.00000
# 148       6.20000      3.40000
# 149       5.90000      3.00000
#
# [150 rows x 2 columns]

# %%
df.filter(regex='length$')
# Out:
#      sepal_length  petal_length
# 0         5.10000       1.40000
# 1         4.90000       1.40000
# 2         4.70000       1.30000
# 3         4.60000       1.50000
# 4         5.00000       1.40000
# ..            ...           ...
# 145       6.70000       5.20000
# 146       6.30000       5.00000
# 147       6.50000       5.20000
# 148       6.20000       5.40000
# 149       5.90000       5.10000
#
# [150 rows x 2 columns]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0         5.10000      3.50000       1.40000      0.20000     setosa
# 1         4.90000      3.00000       1.40000      0.20000     setosa
# 2         4.70000      3.20000       1.30000      0.20000     setosa
# 3         4.60000      3.10000       1.50000      0.20000     setosa
# 4         5.00000      3.60000       1.40000      0.20000     setosa
# ..            ...          ...           ...          ...        ...
# 145       6.70000      3.00000       5.20000      2.30000  virginica
# 146       6.30000      2.50000       5.00000      1.90000  virginica
# 147       6.50000      3.00000       5.20000      2.00000  virginica
# 148       6.20000      3.40000       5.40000      2.30000  virginica
# 149       5.90000      3.00000       5.10000      1.80000  virginica
#
# [150 rows x 5 columns]

# %%
df['species'].value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: species, dtype: int64

# %%
df['species'].nunique()
# Out:
# 3

# %%
len(df)
# Out:
# 150

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     150.00000    150.00000     150.00000    150.00000
# mean        5.84333      3.05733       3.75800      1.19933
# std         0.82807      0.43587       1.76530      0.76224
# min         4.30000      2.00000       1.00000      0.10000
# 25%         5.10000      2.80000       1.60000      0.30000
# 50%         5.80000      3.00000       4.35000      1.30000
# 75%         6.40000      3.30000       5.10000      1.80000
# max         7.90000      4.40000       6.90000      2.50000

# %%
df.describe(include='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width    species
# count      150.00000    150.00000     150.00000    150.00000        150
# unique           NaN          NaN           NaN          NaN          3
# top              NaN          NaN           NaN          NaN  virginica
# freq             NaN          NaN           NaN          NaN         50
# mean         5.84333      3.05733       3.75800      1.19933        NaN
# std          0.82807      0.43587       1.76530      0.76224        NaN
# min          4.30000      2.00000       1.00000      0.10000        NaN
# 25%          5.10000      2.80000       1.60000      0.30000        NaN
# 50%          5.80000      3.00000       4.35000      1.30000        NaN
# 75%          6.40000      3.30000       5.10000      1.80000        NaN
# max          7.90000      4.40000       6.90000      2.50000        NaN

# %%
df = sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0         5.10000      3.50000       1.40000      0.20000     setosa
# 1         4.90000      3.00000       1.40000      0.20000     setosa
# 2         4.70000      3.20000       1.30000      0.20000     setosa
# 3         4.60000      3.10000       1.50000      0.20000     setosa
# 4         5.00000      3.60000       1.40000      0.20000     setosa
# ..            ...          ...           ...          ...        ...
# 145       6.70000      3.00000       5.20000      2.30000  virginica
# 146       6.30000      2.50000       5.00000      1.90000  virginica
# 147       6.50000      3.00000       5.20000      2.00000  virginica
# 148       6.20000      3.40000       5.40000      2.30000  virginica
# 149       5.90000      3.00000       5.10000      1.80000  virginica
#
# [150 rows x 5 columns]

# %%
# 새로운 열 추가
df['all_length'] = df.sepal_length + df.petal_length
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0         5.10000      3.50000       1.40000      0.20000     setosa
# 1         4.90000      3.00000       1.40000      0.20000     setosa
# 2         4.70000      3.20000       1.30000      0.20000     setosa
# 3         4.60000      3.10000       1.50000      0.20000     setosa
# 4         5.00000      3.60000       1.40000      0.20000     setosa
# ..            ...          ...           ...          ...        ...
# 145       6.70000      3.00000       5.20000      2.30000  virginica
# 146       6.30000      2.50000       5.00000      1.90000  virginica
# 147       6.50000      3.00000       5.20000      2.00000  virginica
# 148       6.20000      3.40000       5.40000      2.30000  virginica
# 149       5.90000      3.00000       5.10000      1.80000  virginica
#
#      all_length
# 0       6.50000
# 1       6.30000
# 2       6.00000
# 3       6.10000
# 4       6.40000
# ..          ...
# ...

# %%
# 여러 열 추가: assign
df = df.assign(sepal2=lambda df: df.sepal_length*df.sepal_width,
               petal2=lambda df: df.petal_length*df.petal_width)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0         5.10000      3.50000       1.40000      0.20000     setosa
# 1         4.90000      3.00000       1.40000      0.20000     setosa
# 2         4.70000      3.20000       1.30000      0.20000     setosa
# 3         4.60000      3.10000       1.50000      0.20000     setosa
# 4         5.00000      3.60000       1.40000      0.20000     setosa
# ..            ...          ...           ...          ...        ...
# 145       6.70000      3.00000       5.20000      2.30000  virginica
# 146       6.30000      2.50000       5.00000      1.90000  virginica
# 147       6.50000      3.00000       5.20000      2.00000  virginica
# 148       6.20000      3.40000       5.40000      2.30000  virginica
# 149       5.90000      3.00000       5.10000      1.80000  virginica
#
#      all_length   sepal2   petal2
# 0       6.50000 17.85000  0.28000
# 1       6.30000 14.70000  0.28000
# ...

# %%
pd.qcut(df.sepal2, 2, labels=False)
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 145    1
# 146    0
# 147    1
# 148    1
# 149    1
# Name: sepal2, Length: 150, dtype: int64

# %%
adf = pd.DataFrame({"x1": ["A", "B", "C"], "x2": [1, 2, 3]})
bdf = pd.DataFrame({"x1": ["A", "B", "D"], "x3": ["T", "F", "T"]})

# %%
adf
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3

# %%
df = sns.load_dataset("diamonds")
df.head()
# Out:
#     carat      cut color clarity    depth    table  price       x       y  \
# 0 0.23000    Ideal     E     SI2 61.50000 55.00000    326 3.95000 3.98000
# 1 0.21000  Premium     E     SI1 59.80000 61.00000    326 3.89000 3.84000
# 2 0.23000     Good     E     VS1 56.90000 65.00000    327 4.05000 4.07000
# 3 0.29000  Premium     I     VS2 62.40000 58.00000    334 4.20000 4.23000
# 4 0.31000     Good     J     SI2 63.30000 58.00000    335 4.34000 4.35000
#
#         z
# 0 2.43000
# 1 2.31000
# 2 2.31000
# 3 2.63000
# 4 2.75000

# %%
len(df)
# Out:
# 53940

# %%
df.groupby(by="cut").size()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# dtype: int64

# %%
df.groupby(by="cut").size() / len(df)
# Out:
# cut
# Ideal       0.39954
# Premium     0.25567
# Very Good   0.22399
# Good        0.09095
# Fair        0.02985
# dtype: float64

# %%
df.groupby(by="cut").mean()
# Out:
#             carat    depth    table       price       x       y       z
# cut
# Ideal     0.70284 61.70940 55.95167 3,457.54197 5.50745 5.52008 3.40145
# Premium   0.89195 61.26467 58.74610 4,584.25770 5.97389 5.94488 3.64712
# Very Good 0.80638 61.81828 57.95615 3,981.75989 5.74070 5.77003 3.55980
# Good      0.84918 62.36588 58.69464 3,928.86445 5.83879 5.85074 3.63951
# Fair      1.04614 64.04168 59.05379 4,358.75776 6.24689 6.18265 3.98277

# %%
np.random.seed(9)

df = pd.DataFrame(np.random.randint(-50, 50, 240),
                  index=pd.date_range('2022-01-01', periods=240),
                  columns=['Price'])

df = df.cumsum()
df
# Out:
#             Price
# 2022-01-01     42
# 2022-01-02     46
# 2022-01-03     52
# 2022-01-04     24
# 2022-01-05     39
# ...           ...
# 2022-08-24    287
# 2022-08-25    253
# 2022-08-26    251
# 2022-08-27    242
# 2022-08-28    212
#
# [240 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['Price'].rolling(window=5).mean()
# Out:
# 2022-01-01         NaN
# 2022-01-02         NaN
# 2022-01-03         NaN
# 2022-01-04         NaN
# 2022-01-05    40.60000
#                 ...
# 2022-08-24   289.00000
# 2022-08-25   281.00000
# 2022-08-26   266.80000
# 2022-08-27   259.40000
# 2022-08-28   249.00000
# Freq: D, Name: Price, Length: 240, dtype: float64

# %%
df['Price'].rolling(window=5).mean().plot()
# Out:
# <AxesSubplot:>

# %%
df['MA10'] = df['Price'].rolling(window=10).mean()
df['MA20'] = df['Price'].rolling(window=20).mean()

df.plot(grid=True)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#             Price      MA10      MA20
# 2022-01-01     42       NaN       NaN
# 2022-01-02     46       NaN       NaN
# 2022-01-03     52       NaN       NaN
# 2022-01-04     24       NaN       NaN
# 2022-01-05     39       NaN       NaN
# ...           ...       ...       ...
# 2022-08-24    287 318.90000 365.65000
# 2022-08-25    253 308.50000 358.25000
# 2022-08-26    251 297.90000 351.25000
# 2022-08-27    242 285.50000 343.85000
# 2022-08-28    212 272.80000 334.25000
#
# [240 rows x 3 columns]

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0         5.10000      3.50000       1.40000      0.20000     setosa
# 1         4.90000      3.00000       1.40000      0.20000     setosa
# 2         4.70000      3.20000       1.30000      0.20000     setosa
# 3         4.60000      3.10000       1.50000      0.20000     setosa
# 4         5.00000      3.60000       1.40000      0.20000     setosa
# ..            ...          ...           ...          ...        ...
# 145       6.70000      3.00000       5.20000      2.30000  virginica
# 146       6.30000      2.50000       5.00000      1.90000  virginica
# 147       6.50000      3.00000       5.20000      2.00000  virginica
# 148       6.20000      3.40000       5.40000      2.30000  virginica
# 149       5.90000      3.00000       5.10000      1.80000  virginica
#
# [150 rows x 5 columns]

# %%
df.plot.hist(alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist(alpha=0.5, bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['species'].astype('category')
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: category
# Categories (3, object): ['setosa', 'versicolor', 'virginica']

# %%
df['species'].astype('category').cat.codes
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Length: 150, dtype: int8

# %%
df['species_cat'] = df['species'].astype('category').cat.codes
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0         5.10000      3.50000       1.40000      0.20000     setosa
# 1         4.90000      3.00000       1.40000      0.20000     setosa
# 2         4.70000      3.20000       1.30000      0.20000     setosa
# 3         4.60000      3.10000       1.50000      0.20000     setosa
# 4         5.00000      3.60000       1.40000      0.20000     setosa
# ..            ...          ...           ...          ...        ...
# 145       6.70000      3.00000       5.20000      2.30000  virginica
# 146       6.30000      2.50000       5.00000      1.90000  virginica
# 147       6.50000      3.00000       5.20000      2.00000  virginica
# 148       6.20000      3.40000       5.40000      2.30000  virginica
# 149       5.90000      3.00000       5.10000      1.80000  virginica
#
#      species_cat
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# ...

# %%
df.plot.scatter(x='petal_length', y='petal_width', c='species_cat', colormap='plasma', )
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
from pandas.plotting import scatter_matrix

axes = scatter_matrix(df, alpha=0.5, figsize=(8, 8), diagonal='kde')

# %%
import pandas as pd

df = pd.read_csv("https://bit.ly/3GNOsZi")
df
# Out:
#                    religion   <$10k   $10-20k  $20-30k  $30-40k   $40-50k  \
# 0                  Agnostic      27        34       60       81        76
# 1                   Atheist      12        27       37       52        35
# 2                  Buddhist      27        21       30       34        33
# 3                  Catholic     418       617      732      670       638
# 4         Dont know/refused      15        14       15       11        10
# 5         Evangelical Prot      575       869     1064      982       881
# 6                    Hindu        1         9        7        9        11
# 7  Historically Black Prot      228       244      236      238       197
# 8         Jehovahs Witness       20        27       24       24        21
# 9                   Jewish       19        19       25       25        30
#
#    $50-75k
# 0      137
# 1       70
# 2       58
# 3     1116
# 4       35
# 5     1486
# 6       34
# 7      223
# 8       30
# 9       95

# %%
formatted_df = pd.melt(df,["religion"], var_name="income", value_name="freq")
formatted_df = formatted_df.sort_values(by=['religion'])
formatted_df.head(10)
# Out:
#     religion    income  freq
# 0   Agnostic     <$10k    27
# 30  Agnostic   $30-40k    81
# 40  Agnostic   $40-50k    76
# 50  Agnostic   $50-75k   137
# 10  Agnostic   $10-20k    34
# 20  Agnostic   $20-30k    60
# 41   Atheist   $40-50k    35
# 21   Atheist   $20-30k    37
# 11   Atheist   $10-20k    27
# 31   Atheist   $30-40k    52
