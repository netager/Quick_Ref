# %% [markdown]
# # 10. DataFrame 활용

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# 한글 설정
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
#matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac

# 글자 크기
matplotlib.rcParams['font.size'] = 15 # 글자 크기

# 한글 폰트 사용시 마이너스 글자가 깨지는 현상 해결
matplotlib.rcParams['axes.unicode_minus'] = False

# 그래프 크기
plt.figure(figsize=(10, 5))

# %matplotlib inline

# %%
df = pd.read_excel('../Pandas/score.xlsx', index_col='지원번호')
df.reset_index(inplace=True)
df

# %%
plt.plot(df['지원번호'], df['키'])

# %%
plt.plot(df['지원번호'], df['영어'], color='r')
plt.plot(df['지원번호'], df['수학'], color='g')
plt.grid(axis='y', color='purple', alpha=0.4, linestyle='--', linewidth=1)
